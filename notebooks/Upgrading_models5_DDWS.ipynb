# %% [markdown]
# ## BC_ResNet

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats
import librosa
import librosa.display
import math
import sys
#sys.path.insert(0,'/home/ikwak2/hmd/notebooks')
#sys.path.insert(0,'/home/ikwak2/hmd/iy_classifier')
sys.path.insert(0,'utils')
from helper_code import *
from get_feature import *
from models import *
from Generator0 import *

# %%
root_dir = 'physionet.org/files/circor-heart-sound/1.0.3'
training_data_file = root_dir + '/' + 'training_data.csv'
training_data_dir = root_dir + '/' + 'training_data'
model_dir = root_dir + '/' + 'model'

# %%
import tensorflow as tf

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
print(gpu_info)
# Out:
# Tue Jul 12 11:25:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:05.0 Off |                  Off |
# | N/A   37C    P0    39W / 300W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:00:06.0 Off |                  Off |
# | N/A   41C    P0    46W / 300W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
    except RuntimeError as e:
        print(e)

# %%
data_folder =  'physionet.org/files/circor-heart-sound/1.0.3/training_data'
train_folder =  '/home/ubuntu/data/hmd/murmur/train'
test_folder = '/home/ubuntu/data/hmd/murmur/test'

# %%
model_folder = 'ddws1'

# %% [markdown]
# ## Modeling

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint

# %%
def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start
    elif e > end:
        return lr_end

    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))

    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

# %% [markdown]
# ### get feature 함수확장: 음성피쳐 옵션들과, 추가 음성들 고려한 피쳐추출

# %%
patient_files_trn = find_patient_files(train_folder)
patient_files_test = find_patient_files(test_folder)

# %%
params_feature = {'samp_sec': 20,
                  #### melspec, stft 피쳐 옵션들  
                  'pre_emphasis': 0,
                  'hop_length': 256,
                  'win_length':512,
                  'n_mels': 100,
                  #### cqt 피쳐 옵션들  
                  'filter_scale': 1,
                  'n_bins': 80,
                  'fmin': 10
}

# %%
features_trn, mm_lbs_trn, out_lbs_trn, mel_input_shape, cqt_input_shape, stft_input_shape = get_features_3lb_all(train_folder, patient_files_trn, **params_feature)
features_test, mm_lbs_test, out_lbs_test, _, _, _ = get_features_3lb_all(test_folder, patient_files_test, **params_feature)
# Out:
# melspec:  100 313
# cqt:  80 157
# stft:  257 313
# utils/get_feature.py:599: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   features[k1] = np.array(features[k1])
# melspec:  100 313
# cqt:  80 157
# stft:  257 313

# %% [markdown]
# ### DDWS

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, maximum, DepthwiseConv2D, AveragePooling2D, UpSampling2D
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, SpatialDropout2D
from tensorflow.keras.layers import Convolution2D, GlobalAveragePooling2D, MaxPool2D, ZeroPadding2D
from tensorflow.keras.layers import add,concatenate
from tensorflow.keras.activations import relu, softmax, swish

def SubSpectralNorm(S, A = True, eps=1e-5):
    # S : number of sub-bands
    # A : 'Sub' Transform type if True, 
    #     'All' Transform type if False.          <- cannot be implemented yet.
    # Can be applied only for image inputs.
    
    
    def f(x):
        if S == 1:
            y = BatchNormalization()(x)
            
        else:
            F = x.shape[1]             # number of frequencies of the input.
            if F % S == 0:
                Q = F // S             # length of each sub-band.
                subs = []
                for i in range(S):     
                    subs.append(x[:, i*Q:(i+1)*Q, :,:])
                    
                for i in range(S):
                    subs[i] = BatchNormalization()(subs[i])
                    
            else:
                Q = F // S
                subs = []
                for i in range(S-1):
                    subs.append(x[:,i*Q:(i+1)*Q,:,:])
                    
                subs.append(x[:,(S-1)*Q:,:,:])      # the shape of x and y must be the same.
                
                for i in range(S):
                    subs[i] = BatchNormalization()(subs[i])
                    
            
            y = tf.concat(subs, axis=1)
            
        return y
    
    return f


def TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1),
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.3):
    
    def f(x):
        if out_channels:
            y = Conv2D(filters=out_channels, kernel_size=(1,1), strides=strides,
                       activation=None, kernel_initializer='he_uniform')(x)
            y = BatchNormalization()(y)
            y = relu(y)
            
            z = DepthwiseConv2D(kernel_size=freq_kernel_size, strides=(1,1), padding='same',
                                activation=None, kernel_initializer='he_uniform')(y)
            z = SubSpectralNorm(S=2)(z)
            
        else :
            z = DepthwiseConv2D(kernel_size=freq_kernel_size, strides=(1,1), padding='same',
                                activation=None, kernel_initializer='he_uniform')(x)
            z = SubSpectralNorm(S=2)(z)
            
        z = relu(z)
        z = DepthwiseConv2D(kernel_size=temporal_kernel_size, strides=(1,1), padding='same',
                                activation=None, kernel_initializer='he_uniform')(z)
        z = SubSpectralNorm(S=2)(z)
            #        y = relu(y)
        z = swish(z)
            
        if out_channels:
            z = Conv2D(filters=y.shape[3], kernel_size=(1,1), strides=(1,1),
                    activation='relu', kernel_initializer='he_uniform')(z)
        else :
            z = Conv2D(filters=x.shape[3], kernel_size=(1,1), strides=(1,1),
                       activation='relu', kernel_initializer='he_uniform')(z)
                
        z = SpatialDropout2D(dropout_rate)(z)
        ############################
            
        if out_channels:
            return add([y, z])
        else:
            return add([x, z])
            
    return f


    
def BC_ResMax(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
              freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1):

    def f(x):
        if out_channels:
            y = Conv2D(filters=out_channels, kernel_size=(1,1), strides=strides, 
                       activation=None, kernel_initializer='he_uniform')(x)
            y = BatchNormalization()(y)
            y = relu(y)
            
            y = DepthwiseConv2D(kernel_size=freq_kernel_size, strides=(1,1), padding='same',
                                 activation=None, kernel_initializer='he_uniform')(y)
#            y2 = DepthwiseConv2D(kernel_size=freq_kernel_size, strides=(1,1), padding='same',
#                                 activation=None, kernel_initializer='he_uniform')(y)
#            y = tf.keras.layers.maximum([y1, y2])

        else :
            y = DepthwiseConv2D(kernel_size=freq_kernel_size, strides=(1,1), padding='same',
                                 activation=None, kernel_initializer='he_uniform')(x)
#            y2 = DepthwiseConv2D(kernel_size=freq_kernel_size, strides=(1,1), padding='same',
#                                 activation=None, kernel_initializer='he_uniform')(x)
#            y = tf.keras.layers.maximum([y1, y2])
            
        y = SubSpectralNorm(S=2)(y)                   # Should be changed to SSN
        y = relu(y)
        ############################
        
        z = AveragePooling2D(pool_size=(y.shape[1],1))(y)
        
        ########### f1 #############
        z = DepthwiseConv2D(kernel_size=temporal_kernel_size, strides=(1,1), dilation_rate=dilation_rate,
                            padding='same', activation=None, kernel_initializer='he_uniform')(z)
        z = BatchNormalization()(z)
        z = swish(z)

        z = Conv2D(filters=y.shape[3], kernel_size=(1,1), strides=(1,1),
                   activation='relu', kernel_initializer='he_uniform')(z)
        z = SpatialDropout2D(dropout_rate)(z)                  
        ############################
        
        
        ########### BC #############
        z = UpSampling2D(size=(y.shape[1],1), interpolation='nearest')(z)
        ############################
        
        if out_channels:
            return add([y, z])
        else: 
            return add([x, y, z])
        
    return f

def ResMax(n_output, k, l, upscale=False):
    def f(x):
        conv1_1 = Conv2D(filters = n_output, kernel_size =k, strides=(1, 1), padding='same', activation=None)(x)
        conv1_2 = Conv2D(filters = n_output, kernel_size =k, strides=(1, 1), padding='same', activation=None)(x)
        h = maximum([conv1_1, conv1_2])
        if l :
            conv1_1 = Conv2D(filters = n_output, kernel_size =k, strides=(1, 1), padding='same', activation=None)(h)
            conv1_2 = Conv2D(filters = n_output, kernel_size =k, strides=(1, 1), padding='same', activation=None)(h)
            h = maximum([conv1_1, conv1_2])
        if upscale:
            f = Conv2D(kernel_size=1, filters=n_output, strides=1, padding='same')(x)
        else:
            f = x
        return add([f, h])
    return f




def get_DDWS_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, use_stft = True):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    mel1 = keras.Input(shape=(mel_input_shape), name = 'mel')
    cqt1 = keras.Input(shape=(cqt_input_shape), name = 'cqt')
    stft1 = keras.Input(shape=(stft_input_shape), name = 'stft')
        
        
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)

    ## mel embedding
    x1 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(mel1)
    x2 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(mel1)
    x = maximum([x1, x2])
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 24, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 32, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 48, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)
    mel2 = GlobalAveragePooling2D()(x)
    
    ## cqt embedding
    x1 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(cqt1)
    x2 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(cqt1)
    x = maximum([x1, x2])
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 24, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 32, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 48, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)
    mel2 = GlobalAveragePooling2D()(x)
    cqt2 = GlobalAveragePooling2D()(x)

    ## stft embedding
    x1 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(stft1)
    x2 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(stft1)
    x = maximum([x1, x2])
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 24, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 32, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 48, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)
    stft2 = GlobalAveragePooling2D()(x)
    
#    concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg])
#    d1 = layers.Dense(2, activation = 'relu')(concat1)
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2
#    concat2 = layers.Dense(10, activation = 'relu')(concat2)
    res1 = layers.Dense(3, activation = "softmax")(concat2)
    res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,mel1,cqt1,stft1] , outputs = res1 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)

def get_DDWS_2(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, use_stft = True):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    mel1 = keras.Input(shape=(mel_input_shape), name = 'mel')
    cqt1 = keras.Input(shape=(cqt_input_shape), name = 'cqt')
    stft1 = keras.Input(shape=(stft_input_shape), name = 'stft')
        
        
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)

    ## mel embedding
    x1 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(mel1)
    x2 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(mel1)
    x = maximum([x1, x2])
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 32, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

#    x = TF_ResMax_seq(out_channels = 48, strides=(1,1), dilation_rate=(1,1), 
#                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
#    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
#                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
#    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

#    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
#                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
#    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
#                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
#    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)
    mel2 = GlobalAveragePooling2D()(x)
    
    ## cqt embedding
    x1 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(cqt1)
    x2 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(cqt1)
    x = maximum([x1, x2])
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 24, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 32, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 48, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)
    mel2 = GlobalAveragePooling2D()(x)
    cqt2 = GlobalAveragePooling2D()(x)

    ## stft embedding
    x1 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(stft1)
    x2 = Conv2D(filters = 16, kernel_size = (3,3), activation = None)(stft1)
    x = maximum([x1, x2])
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 24, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 32, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 48, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)

    x = TF_ResMax_seq(out_channels = 64, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = TF_ResMax_seq(out_channels = False, strides=(1,1), dilation_rate=(1,1), 
                  freq_kernel_size=(3,1), temporal_kernel_size=(1,3), dropout_rate=0.1)(x)
    x = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x)
    stft2 = GlobalAveragePooling2D()(x)
    
#    concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg])
#    d1 = layers.Dense(2, activation = 'relu')(concat1)
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2
#    concat2 = layers.Dense(10, activation = 'relu')(concat2)
    res1 = layers.Dense(3, activation = "softmax")(concat2)
    res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,mel1,cqt1,stft1] , outputs = res2 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)

# %%
#model1 = get_toy5_1(mel_input_shape, cqt_input_shape, stft_input_shape)
#model2 = get_toy5_2(mel_input_shape, cqt_input_shape, stft_input_shape)

# %%
model1 = get_DDWS_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = False, use_stft = False)
model2 = get_DDWS_2(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = False, use_stft = False)

# %%
model1.summary()
# Out:
# Model: "model_384"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cqt (InputLayer)                [(None, 80, 157, 1)] 0
# __________________________________________________________________________________________________
# conv2d_17295 (Conv2D)           (None, 78, 155, 16)  160         cqt[0][0]
# __________________________________________________________________________________________________
# conv2d_17296 (Conv2D)           (None, 78, 155, 16)  160         cqt[0][0]
# __________________________________________________________________________________________________
# maximum_1153 (Maximum)          (None, 78, 155, 16)  0           conv2d_17295[0][0]
#                                                                  conv2d_17296[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6918 (MaxPooling2 (None, 39, 78, 16)   0           maximum_1153[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20754 (Depthwi (None, 39, 78, 16)   64          max_pooling2d_6918[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41508  (None, 19, 78, 16)   0           depthwise_conv2d_20754[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41509  (None, 20, 78, 16)   0           depthwise_conv2d_20754[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46120 (Batc (None, 19, 78, 16)   64          tf.__operators__.getitem_41508[0]
# __________________________________________________________________________________________________
# batch_normalization_46121 (Batc (None, 20, 78, 16)   64          tf.__operators__.getitem_41509[0]
# __________________________________________________________________________________________________
# tf.concat_20754 (TFOpLambda)    (None, 39, 78, 16)   0           batch_normalization_46120[0][0]
#                                                                  batch_normalization_46121[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14989 (TFOpLambda)   (None, 39, 78, 16)   0           tf.concat_20754[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20755 (Depthwi (None, 39, 78, 16)   64          tf.nn.relu_14989[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41510  (None, 19, 78, 16)   0           depthwise_conv2d_20755[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41511  (None, 20, 78, 16)   0           depthwise_conv2d_20755[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46122 (Batc (None, 19, 78, 16)   64          tf.__operators__.getitem_41510[0]
# __________________________________________________________________________________________________
# batch_normalization_46123 (Batc (None, 20, 78, 16)   64          tf.__operators__.getitem_41511[0]
# __________________________________________________________________________________________________
# tf.concat_20755 (TFOpLambda)    (None, 39, 78, 16)   0           batch_normalization_46122[0][0]
#                                                                  batch_normalization_46123[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10377 (TFOpLambda)   (None, 39, 78, 16)   0           tf.concat_20755[0][0]
# __________________________________________________________________________________________________
# conv2d_17297 (Conv2D)           (None, 39, 78, 16)   272         tf.nn.silu_10377[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10377 (Spatia (None, 39, 78, 16)   0           conv2d_17297[0][0]
# __________________________________________________________________________________________________
# add_10377 (Add)                 (None, 39, 78, 16)   0           max_pooling2d_6918[0][0]
#                                                                  spatial_dropout2d_10377[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6919 (MaxPooling2 (None, 20, 39, 16)   0           add_10377[0][0]
# __________________________________________________________________________________________________
# conv2d_17298 (Conv2D)           (None, 20, 39, 24)   408         max_pooling2d_6919[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46124 (Batc (None, 20, 39, 24)   96          conv2d_17298[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14990 (TFOpLambda)   (None, 20, 39, 24)   0           batch_normalization_46124[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20756 (Depthwi (None, 20, 39, 24)   96          tf.nn.relu_14990[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41512  (None, 10, 39, 24)   0           depthwise_conv2d_20756[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41513  (None, 10, 39, 24)   0           depthwise_conv2d_20756[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46125 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41512[0]
# __________________________________________________________________________________________________
# batch_normalization_46126 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41513[0]
# __________________________________________________________________________________________________
# tf.concat_20756 (TFOpLambda)    (None, 20, 39, 24)   0           batch_normalization_46125[0][0]
#                                                                  batch_normalization_46126[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14991 (TFOpLambda)   (None, 20, 39, 24)   0           tf.concat_20756[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20757 (Depthwi (None, 20, 39, 24)   96          tf.nn.relu_14991[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41514  (None, 10, 39, 24)   0           depthwise_conv2d_20757[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41515  (None, 10, 39, 24)   0           depthwise_conv2d_20757[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46127 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41514[0]
# __________________________________________________________________________________________________
# batch_normalization_46128 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41515[0]
# __________________________________________________________________________________________________
# tf.concat_20757 (TFOpLambda)    (None, 20, 39, 24)   0           batch_normalization_46127[0][0]
#                                                                  batch_normalization_46128[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10378 (TFOpLambda)   (None, 20, 39, 24)   0           tf.concat_20757[0][0]
# __________________________________________________________________________________________________
# conv2d_17299 (Conv2D)           (None, 20, 39, 24)   600         tf.nn.silu_10378[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10378 (Spatia (None, 20, 39, 24)   0           conv2d_17299[0][0]
# __________________________________________________________________________________________________
# add_10378 (Add)                 (None, 20, 39, 24)   0           tf.nn.relu_14990[0][0]
#                                                                  spatial_dropout2d_10378[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20758 (Depthwi (None, 20, 39, 24)   96          add_10378[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41516  (None, 10, 39, 24)   0           depthwise_conv2d_20758[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41517  (None, 10, 39, 24)   0           depthwise_conv2d_20758[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46129 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41516[0]
# __________________________________________________________________________________________________
# batch_normalization_46130 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41517[0]
# __________________________________________________________________________________________________
# tf.concat_20758 (TFOpLambda)    (None, 20, 39, 24)   0           batch_normalization_46129[0][0]
#                                                                  batch_normalization_46130[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14992 (TFOpLambda)   (None, 20, 39, 24)   0           tf.concat_20758[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20759 (Depthwi (None, 20, 39, 24)   96          tf.nn.relu_14992[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41518  (None, 10, 39, 24)   0           depthwise_conv2d_20759[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41519  (None, 10, 39, 24)   0           depthwise_conv2d_20759[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46131 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41518[0]
# __________________________________________________________________________________________________
# batch_normalization_46132 (Batc (None, 10, 39, 24)   96          tf.__operators__.getitem_41519[0]
# __________________________________________________________________________________________________
# tf.concat_20759 (TFOpLambda)    (None, 20, 39, 24)   0           batch_normalization_46131[0][0]
#                                                                  batch_normalization_46132[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10379 (TFOpLambda)   (None, 20, 39, 24)   0           tf.concat_20759[0][0]
# __________________________________________________________________________________________________
# conv2d_17300 (Conv2D)           (None, 20, 39, 24)   600         tf.nn.silu_10379[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10379 (Spatia (None, 20, 39, 24)   0           conv2d_17300[0][0]
# __________________________________________________________________________________________________
# add_10379 (Add)                 (None, 20, 39, 24)   0           add_10378[0][0]
#                                                                  spatial_dropout2d_10379[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6920 (MaxPooling2 (None, 10, 20, 24)   0           add_10379[0][0]
# __________________________________________________________________________________________________
# conv2d_17301 (Conv2D)           (None, 10, 20, 32)   800         max_pooling2d_6920[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46133 (Batc (None, 10, 20, 32)   128         conv2d_17301[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14993 (TFOpLambda)   (None, 10, 20, 32)   0           batch_normalization_46133[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20760 (Depthwi (None, 10, 20, 32)   128         tf.nn.relu_14993[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41520  (None, 5, 20, 32)    0           depthwise_conv2d_20760[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41521  (None, 5, 20, 32)    0           depthwise_conv2d_20760[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46134 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41520[0]
# __________________________________________________________________________________________________
# batch_normalization_46135 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41521[0]
# __________________________________________________________________________________________________
# tf.concat_20760 (TFOpLambda)    (None, 10, 20, 32)   0           batch_normalization_46134[0][0]
#                                                                  batch_normalization_46135[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14994 (TFOpLambda)   (None, 10, 20, 32)   0           tf.concat_20760[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20761 (Depthwi (None, 10, 20, 32)   128         tf.nn.relu_14994[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41522  (None, 5, 20, 32)    0           depthwise_conv2d_20761[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41523  (None, 5, 20, 32)    0           depthwise_conv2d_20761[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46136 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41522[0]
# __________________________________________________________________________________________________
# batch_normalization_46137 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41523[0]
# __________________________________________________________________________________________________
# tf.concat_20761 (TFOpLambda)    (None, 10, 20, 32)   0           batch_normalization_46136[0][0]
#                                                                  batch_normalization_46137[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10380 (TFOpLambda)   (None, 10, 20, 32)   0           tf.concat_20761[0][0]
# __________________________________________________________________________________________________
# conv2d_17302 (Conv2D)           (None, 10, 20, 32)   1056        tf.nn.silu_10380[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10380 (Spatia (None, 10, 20, 32)   0           conv2d_17302[0][0]
# __________________________________________________________________________________________________
# add_10380 (Add)                 (None, 10, 20, 32)   0           tf.nn.relu_14993[0][0]
#                                                                  spatial_dropout2d_10380[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20762 (Depthwi (None, 10, 20, 32)   128         add_10380[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41524  (None, 5, 20, 32)    0           depthwise_conv2d_20762[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41525  (None, 5, 20, 32)    0           depthwise_conv2d_20762[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46138 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41524[0]
# __________________________________________________________________________________________________
# batch_normalization_46139 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41525[0]
# __________________________________________________________________________________________________
# tf.concat_20762 (TFOpLambda)    (None, 10, 20, 32)   0           batch_normalization_46138[0][0]
#                                                                  batch_normalization_46139[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14995 (TFOpLambda)   (None, 10, 20, 32)   0           tf.concat_20762[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20763 (Depthwi (None, 10, 20, 32)   128         tf.nn.relu_14995[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41526  (None, 5, 20, 32)    0           depthwise_conv2d_20763[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41527  (None, 5, 20, 32)    0           depthwise_conv2d_20763[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46140 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41526[0]
# __________________________________________________________________________________________________
# batch_normalization_46141 (Batc (None, 5, 20, 32)    128         tf.__operators__.getitem_41527[0]
# __________________________________________________________________________________________________
# tf.concat_20763 (TFOpLambda)    (None, 10, 20, 32)   0           batch_normalization_46140[0][0]
#                                                                  batch_normalization_46141[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10381 (TFOpLambda)   (None, 10, 20, 32)   0           tf.concat_20763[0][0]
# __________________________________________________________________________________________________
# conv2d_17303 (Conv2D)           (None, 10, 20, 32)   1056        tf.nn.silu_10381[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10381 (Spatia (None, 10, 20, 32)   0           conv2d_17303[0][0]
# __________________________________________________________________________________________________
# add_10381 (Add)                 (None, 10, 20, 32)   0           add_10380[0][0]
#                                                                  spatial_dropout2d_10381[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6921 (MaxPooling2 (None, 5, 10, 32)    0           add_10381[0][0]
# __________________________________________________________________________________________________
# conv2d_17304 (Conv2D)           (None, 5, 10, 48)    1584        max_pooling2d_6921[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46142 (Batc (None, 5, 10, 48)    192         conv2d_17304[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14996 (TFOpLambda)   (None, 5, 10, 48)    0           batch_normalization_46142[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20764 (Depthwi (None, 5, 10, 48)    192         tf.nn.relu_14996[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41528  (None, 2, 10, 48)    0           depthwise_conv2d_20764[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41529  (None, 3, 10, 48)    0           depthwise_conv2d_20764[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46143 (Batc (None, 2, 10, 48)    192         tf.__operators__.getitem_41528[0]
# __________________________________________________________________________________________________
# batch_normalization_46144 (Batc (None, 3, 10, 48)    192         tf.__operators__.getitem_41529[0]
# __________________________________________________________________________________________________
# tf.concat_20764 (TFOpLambda)    (None, 5, 10, 48)    0           batch_normalization_46143[0][0]
#                                                                  batch_normalization_46144[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14997 (TFOpLambda)   (None, 5, 10, 48)    0           tf.concat_20764[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20765 (Depthwi (None, 5, 10, 48)    192         tf.nn.relu_14997[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41530  (None, 2, 10, 48)    0           depthwise_conv2d_20765[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41531  (None, 3, 10, 48)    0           depthwise_conv2d_20765[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46145 (Batc (None, 2, 10, 48)    192         tf.__operators__.getitem_41530[0]
# __________________________________________________________________________________________________
# batch_normalization_46146 (Batc (None, 3, 10, 48)    192         tf.__operators__.getitem_41531[0]
# __________________________________________________________________________________________________
# tf.concat_20765 (TFOpLambda)    (None, 5, 10, 48)    0           batch_normalization_46145[0][0]
#                                                                  batch_normalization_46146[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10382 (TFOpLambda)   (None, 5, 10, 48)    0           tf.concat_20765[0][0]
# __________________________________________________________________________________________________
# conv2d_17305 (Conv2D)           (None, 5, 10, 48)    2352        tf.nn.silu_10382[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10382 (Spatia (None, 5, 10, 48)    0           conv2d_17305[0][0]
# __________________________________________________________________________________________________
# add_10382 (Add)                 (None, 5, 10, 48)    0           tf.nn.relu_14996[0][0]
#                                                                  spatial_dropout2d_10382[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20766 (Depthwi (None, 5, 10, 48)    192         add_10382[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41532  (None, 2, 10, 48)    0           depthwise_conv2d_20766[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41533  (None, 3, 10, 48)    0           depthwise_conv2d_20766[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46147 (Batc (None, 2, 10, 48)    192         tf.__operators__.getitem_41532[0]
# __________________________________________________________________________________________________
# batch_normalization_46148 (Batc (None, 3, 10, 48)    192         tf.__operators__.getitem_41533[0]
# __________________________________________________________________________________________________
# tf.concat_20766 (TFOpLambda)    (None, 5, 10, 48)    0           batch_normalization_46147[0][0]
#                                                                  batch_normalization_46148[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14998 (TFOpLambda)   (None, 5, 10, 48)    0           tf.concat_20766[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20767 (Depthwi (None, 5, 10, 48)    192         tf.nn.relu_14998[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41534  (None, 2, 10, 48)    0           depthwise_conv2d_20767[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41535  (None, 3, 10, 48)    0           depthwise_conv2d_20767[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46149 (Batc (None, 2, 10, 48)    192         tf.__operators__.getitem_41534[0]
# __________________________________________________________________________________________________
# batch_normalization_46150 (Batc (None, 3, 10, 48)    192         tf.__operators__.getitem_41535[0]
# __________________________________________________________________________________________________
# tf.concat_20767 (TFOpLambda)    (None, 5, 10, 48)    0           batch_normalization_46149[0][0]
#                                                                  batch_normalization_46150[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10383 (TFOpLambda)   (None, 5, 10, 48)    0           tf.concat_20767[0][0]
# __________________________________________________________________________________________________
# conv2d_17306 (Conv2D)           (None, 5, 10, 48)    2352        tf.nn.silu_10383[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10383 (Spatia (None, 5, 10, 48)    0           conv2d_17306[0][0]
# __________________________________________________________________________________________________
# add_10383 (Add)                 (None, 5, 10, 48)    0           add_10382[0][0]
#                                                                  spatial_dropout2d_10383[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6922 (MaxPooling2 (None, 3, 5, 48)     0           add_10383[0][0]
# __________________________________________________________________________________________________
# conv2d_17307 (Conv2D)           (None, 3, 5, 64)     3136        max_pooling2d_6922[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46151 (Batc (None, 3, 5, 64)     256         conv2d_17307[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_14999 (TFOpLambda)   (None, 3, 5, 64)     0           batch_normalization_46151[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20768 (Depthwi (None, 3, 5, 64)     256         tf.nn.relu_14999[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41536  (None, 1, 5, 64)     0           depthwise_conv2d_20768[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41537  (None, 2, 5, 64)     0           depthwise_conv2d_20768[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46152 (Batc (None, 1, 5, 64)     256         tf.__operators__.getitem_41536[0]
# __________________________________________________________________________________________________
# batch_normalization_46153 (Batc (None, 2, 5, 64)     256         tf.__operators__.getitem_41537[0]
# __________________________________________________________________________________________________
# tf.concat_20768 (TFOpLambda)    (None, 3, 5, 64)     0           batch_normalization_46152[0][0]
#                                                                  batch_normalization_46153[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_15000 (TFOpLambda)   (None, 3, 5, 64)     0           tf.concat_20768[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20769 (Depthwi (None, 3, 5, 64)     256         tf.nn.relu_15000[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41538  (None, 1, 5, 64)     0           depthwise_conv2d_20769[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41539  (None, 2, 5, 64)     0           depthwise_conv2d_20769[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46154 (Batc (None, 1, 5, 64)     256         tf.__operators__.getitem_41538[0]
# __________________________________________________________________________________________________
# batch_normalization_46155 (Batc (None, 2, 5, 64)     256         tf.__operators__.getitem_41539[0]
# __________________________________________________________________________________________________
# tf.concat_20769 (TFOpLambda)    (None, 3, 5, 64)     0           batch_normalization_46154[0][0]
#                                                                  batch_normalization_46155[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10384 (TFOpLambda)   (None, 3, 5, 64)     0           tf.concat_20769[0][0]
# __________________________________________________________________________________________________
# conv2d_17308 (Conv2D)           (None, 3, 5, 64)     4160        tf.nn.silu_10384[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10384 (Spatia (None, 3, 5, 64)     0           conv2d_17308[0][0]
# __________________________________________________________________________________________________
# add_10384 (Add)                 (None, 3, 5, 64)     0           tf.nn.relu_14999[0][0]
#                                                                  spatial_dropout2d_10384[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20770 (Depthwi (None, 3, 5, 64)     256         add_10384[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41540  (None, 1, 5, 64)     0           depthwise_conv2d_20770[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41541  (None, 2, 5, 64)     0           depthwise_conv2d_20770[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46156 (Batc (None, 1, 5, 64)     256         tf.__operators__.getitem_41540[0]
# __________________________________________________________________________________________________
# batch_normalization_46157 (Batc (None, 2, 5, 64)     256         tf.__operators__.getitem_41541[0]
# __________________________________________________________________________________________________
# tf.concat_20770 (TFOpLambda)    (None, 3, 5, 64)     0           batch_normalization_46156[0][0]
#                                                                  batch_normalization_46157[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_15001 (TFOpLambda)   (None, 3, 5, 64)     0           tf.concat_20770[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20771 (Depthwi (None, 3, 5, 64)     256         tf.nn.relu_15001[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41542  (None, 1, 5, 64)     0           depthwise_conv2d_20771[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_41543  (None, 2, 5, 64)     0           depthwise_conv2d_20771[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46158 (Batc (None, 1, 5, 64)     256         tf.__operators__.getitem_41542[0]
# __________________________________________________________________________________________________
# batch_normalization_46159 (Batc (None, 2, 5, 64)     256         tf.__operators__.getitem_41543[0]
# __________________________________________________________________________________________________
# tf.concat_20771 (TFOpLambda)    (None, 3, 5, 64)     0           batch_normalization_46158[0][0]
#                                                                  batch_normalization_46159[0][0]
# __________________________________________________________________________________________________
# tf.nn.silu_10385 (TFOpLambda)   (None, 3, 5, 64)     0           tf.concat_20771[0][0]
# __________________________________________________________________________________________________
# conv2d_17309 (Conv2D)           (None, 3, 5, 64)     4160        tf.nn.silu_10385[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10385 (Spatia (None, 3, 5, 64)     0           conv2d_17309[0][0]
# __________________________________________________________________________________________________
# add_10385 (Add)                 (None, 3, 5, 64)     0           add_10384[0][0]
#                                                                  spatial_dropout2d_10385[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6923 (MaxPooling2 (None, 2, 3, 64)     0           add_10385[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1537 ( (None, 64)           0           max_pooling2d_6923[0][0]
# __________________________________________________________________________________________________
# age_cat (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# sex_cat (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# height_weight (InputLayer)      [(None, 2)]          0
# __________________________________________________________________________________________________
# is_preg (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# loc (InputLayer)                [(None, 5)]          0
# __________________________________________________________________________________________________
# mel (InputLayer)                [(None, 100, 313, 1) 0
# __________________________________________________________________________________________________
# stft (InputLayer)               [(None, 257, 313, 1) 0
# __________________________________________________________________________________________________
# dense_2308 (Dense)              (None, 3)            195         global_average_pooling2d_1537[0][
# ==================================================================================================
# Total params: 32,171
# Trainable params: 29,019
# Non-trainable params: 3,152
# __________________________________________________________________________________________________

# %%
n_epoch = 100
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
batch_size = 64
params = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': True,
          'beta_param': 0.7,
          'mixup': True,
#          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
#          'highpass': [.5, [78,79,80,81,82,83,84,85]]
          'ranfilter2' : [3, [18,19,20,21,22,23]]
#           'dropblock' : [30, 100]
          #'device' : device
}

params_no_shuffle = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': False,
          'beta_param': 0.7,
          'mixup': False
          #'device': device
}

TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
           features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                        mm_lbs_trn,  ## our Y
                        **params)()

#ValDGen_1 = Generator0([features_test[0]['age'],features_test[0]['sex'], features_test[0]['hw'], features_test[0]['preg'], features_test[0]['loc'], 
#           features_test[0]['mel1'],features_test[0]['cqt1'],features_test[0]['stft1']], 
#                        mm_lbs_test,  ## our Y
#                        **params_no_shuffle)()

    
model1.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                              features_test['preg'], features_test['loc'], features_test['mel1'], 
                              features_test['cqt1'], features_test['stft1']], 
                             mm_lbs_test), 
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(mm_lbs_trn)/64),
                             epochs = n_epoch)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 13s 197ms/step - loss: 0.7163 - accuracy: 0.7592 - auc: 0.8355 - val_loss: 0.6463 - val_accuracy: 0.7448 - val_auc: 0.8205
# Epoch 2/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.6047 - accuracy: 0.7644 - auc: 0.8652 - val_loss: 0.7297 - val_accuracy: 0.7448 - val_auc: 0.8661
# Epoch 3/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.6113 - accuracy: 0.7576 - auc: 0.8639 - val_loss: 0.7050 - val_accuracy: 0.7448 - val_auc: 0.8387
# Epoch 4/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.6133 - accuracy: 0.7565 - auc: 0.8574 - val_loss: 0.7012 - val_accuracy: 0.7448 - val_auc: 0.8316
# Epoch 5/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5880 - accuracy: 0.7777 - auc: 0.8639 - val_loss: 0.6801 - val_accuracy: 0.7448 - val_auc: 0.8157
# Epoch 6/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.6218 - accuracy: 0.7460 - auc: 0.8665 - val_loss: 0.6971 - val_accuracy: 0.7448 - val_auc: 0.8258
# Epoch 7/100
# 40/40 [==============================] - 6s 151ms/step - loss: 0.5948 - accuracy: 0.7715 - auc: 0.8651 - val_loss: 0.7066 - val_accuracy: 0.7448 - val_auc: 0.8538
# Epoch 8/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6158 - accuracy: 0.7496 - auc: 0.8631 - val_loss: 0.6880 - val_accuracy: 0.7448 - val_auc: 0.8498
# Epoch 9/100
# 40/40 [==============================] - 6s 153ms/step - loss: 0.6060 - accuracy: 0.7505 - auc: 0.8643 - val_loss: 0.6760 - val_accuracy: 0.7448 - val_auc: 0.8575
# Epoch 10/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5928 - accuracy: 0.7663 - auc: 0.8692 - val_loss: 0.6773 - val_accuracy: 0.7448 - val_auc: 0.8588
# Epoch 11/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5890 - accuracy: 0.7796 - auc: 0.8670 - val_loss: 0.6676 - val_accuracy: 0.7464 - val_auc: 0.8663
# Epoch 12/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5870 - accuracy: 0.7723 - auc: 0.8636 - val_loss: 0.6800 - val_accuracy: 0.7544 - val_auc: 0.8729
# Epoch 13/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5917 - accuracy: 0.7658 - auc: 0.8603 - val_loss: 0.6684 - val_accuracy: 0.7686 - val_auc: 0.8726
# Epoch 14/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5847 - accuracy: 0.7698 - auc: 0.8741 - val_loss: 0.6198 - val_accuracy: 0.7512 - val_auc: 0.8755
# Epoch 15/100
# 40/40 [==============================] - 6s 153ms/step - loss: 0.5943 - accuracy: 0.7655 - auc: 0.8710 - val_loss: 0.6689 - val_accuracy: 0.7179 - val_auc: 0.8586
# Epoch 16/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5849 - accuracy: 0.7687 - auc: 0.8743 - val_loss: 0.5978 - val_accuracy: 0.7496 - val_auc: 0.8748
# Epoch 17/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5809 - accuracy: 0.7706 - auc: 0.8693 - val_loss: 0.5888 - val_accuracy: 0.7575 - val_auc: 0.8769
# Epoch 18/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5785 - accuracy: 0.7707 - auc: 0.8676 - val_loss: 0.5831 - val_accuracy: 0.7575 - val_auc: 0.8816
# Epoch 19/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5863 - accuracy: 0.7654 - auc: 0.8740 - val_loss: 0.5911 - val_accuracy: 0.7591 - val_auc: 0.8771
# Epoch 20/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5902 - accuracy: 0.7619 - auc: 0.8753 - val_loss: 0.5672 - val_accuracy: 0.7464 - val_auc: 0.8771
# Epoch 21/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5865 - accuracy: 0.7617 - auc: 0.8762 - val_loss: 0.5685 - val_accuracy: 0.7496 - val_auc: 0.8790
# Epoch 22/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5918 - accuracy: 0.7569 - auc: 0.8728 - val_loss: 0.5702 - val_accuracy: 0.7464 - val_auc: 0.8802
# Epoch 23/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5776 - accuracy: 0.7614 - auc: 0.8754 - val_loss: 0.5713 - val_accuracy: 0.7448 - val_auc: 0.8792
# Epoch 24/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5855 - accuracy: 0.7596 - auc: 0.8767 - val_loss: 0.5736 - val_accuracy: 0.7448 - val_auc: 0.8768
# Epoch 25/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5857 - accuracy: 0.7596 - auc: 0.8683 - val_loss: 0.5719 - val_accuracy: 0.7591 - val_auc: 0.8809
# Epoch 26/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5821 - accuracy: 0.7577 - auc: 0.8764 - val_loss: 0.5742 - val_accuracy: 0.7765 - val_auc: 0.8871
# Epoch 27/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5870 - accuracy: 0.7656 - auc: 0.8737 - val_loss: 0.5703 - val_accuracy: 0.7559 - val_auc: 0.8827
# Epoch 28/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5505 - accuracy: 0.7866 - auc: 0.8764 - val_loss: 0.5792 - val_accuracy: 0.7528 - val_auc: 0.8753
# Epoch 29/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5703 - accuracy: 0.7745 - auc: 0.8736 - val_loss: 0.6034 - val_accuracy: 0.7512 - val_auc: 0.8735
# Epoch 30/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5741 - accuracy: 0.7706 - auc: 0.8702 - val_loss: 0.5704 - val_accuracy: 0.7575 - val_auc: 0.8767
# Epoch 31/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5845 - accuracy: 0.7642 - auc: 0.8745 - val_loss: 0.5565 - val_accuracy: 0.7892 - val_auc: 0.8809
# Epoch 32/100
# 40/40 [==============================] - 6s 151ms/step - loss: 0.5744 - accuracy: 0.7725 - auc: 0.8757 - val_loss: 0.5610 - val_accuracy: 0.7607 - val_auc: 0.8808
# Epoch 33/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5616 - accuracy: 0.7757 - auc: 0.8769 - val_loss: 0.5603 - val_accuracy: 0.7734 - val_auc: 0.8786
# Epoch 34/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5651 - accuracy: 0.7809 - auc: 0.8776 - val_loss: 0.5602 - val_accuracy: 0.7639 - val_auc: 0.8732
# Epoch 35/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5750 - accuracy: 0.7680 - auc: 0.8729 - val_loss: 0.5527 - val_accuracy: 0.7734 - val_auc: 0.8789
# Epoch 36/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5793 - accuracy: 0.7670 - auc: 0.8738 - val_loss: 0.5648 - val_accuracy: 0.7718 - val_auc: 0.8759
# Epoch 37/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5774 - accuracy: 0.7734 - auc: 0.8717 - val_loss: 0.5617 - val_accuracy: 0.7797 - val_auc: 0.8789
# Epoch 38/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.5658 - accuracy: 0.7714 - auc: 0.8752 - val_loss: 0.5598 - val_accuracy: 0.7655 - val_auc: 0.8796
# Epoch 39/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5837 - accuracy: 0.7569 - auc: 0.8730 - val_loss: 0.5525 - val_accuracy: 0.7813 - val_auc: 0.8837
# Epoch 40/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5816 - accuracy: 0.7727 - auc: 0.8768 - val_loss: 0.5926 - val_accuracy: 0.7718 - val_auc: 0.8839
# Epoch 41/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5743 - accuracy: 0.7677 - auc: 0.8749 - val_loss: 0.5630 - val_accuracy: 0.7702 - val_auc: 0.8837
# Epoch 42/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5761 - accuracy: 0.7776 - auc: 0.8763 - val_loss: 0.5485 - val_accuracy: 0.7750 - val_auc: 0.8822
# Epoch 43/100
# 40/40 [==============================] - 6s 151ms/step - loss: 0.5904 - accuracy: 0.7506 - auc: 0.8652 - val_loss: 0.5562 - val_accuracy: 0.7607 - val_auc: 0.8780
# Epoch 44/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5735 - accuracy: 0.7653 - auc: 0.8751 - val_loss: 0.5567 - val_accuracy: 0.7829 - val_auc: 0.8821
# Epoch 45/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5995 - accuracy: 0.7385 - auc: 0.8726 - val_loss: 0.5619 - val_accuracy: 0.7813 - val_auc: 0.8819
# Epoch 46/100
# 40/40 [==============================] - 6s 152ms/step - loss: 0.5682 - accuracy: 0.7809 - auc: 0.8794 - val_loss: 0.5612 - val_accuracy: 0.7845 - val_auc: 0.8835
# Epoch 47/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5844 - accuracy: 0.7560 - auc: 0.8771 - val_loss: 0.5744 - val_accuracy: 0.7861 - val_auc: 0.8838
# Epoch 48/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5804 - accuracy: 0.7533 - auc: 0.8753 - val_loss: 0.5670 - val_accuracy: 0.7845 - val_auc: 0.8837
# Epoch 49/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5804 - accuracy: 0.7648 - auc: 0.8774 - val_loss: 0.5504 - val_accuracy: 0.7829 - val_auc: 0.8859
# Epoch 50/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5759 - accuracy: 0.7670 - auc: 0.8690 - val_loss: 0.5806 - val_accuracy: 0.7623 - val_auc: 0.8788
# Epoch 51/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5742 - accuracy: 0.7738 - auc: 0.8807 - val_loss: 0.5595 - val_accuracy: 0.7924 - val_auc: 0.8884
# Epoch 52/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5734 - accuracy: 0.7614 - auc: 0.8807 - val_loss: 0.5728 - val_accuracy: 0.7924 - val_auc: 0.8877
# Epoch 53/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5645 - accuracy: 0.7736 - auc: 0.8817 - val_loss: 0.5549 - val_accuracy: 0.8003 - val_auc: 0.8887
# Epoch 54/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5754 - accuracy: 0.7678 - auc: 0.8687 - val_loss: 0.5446 - val_accuracy: 0.8003 - val_auc: 0.8871
# Epoch 55/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5693 - accuracy: 0.7708 - auc: 0.8779 - val_loss: 0.5344 - val_accuracy: 0.8035 - val_auc: 0.8889
# Epoch 56/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5698 - accuracy: 0.7746 - auc: 0.8806 - val_loss: 0.5407 - val_accuracy: 0.7956 - val_auc: 0.8848
# Epoch 57/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5786 - accuracy: 0.7609 - auc: 0.8754 - val_loss: 0.5428 - val_accuracy: 0.7971 - val_auc: 0.8838
# Epoch 58/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5841 - accuracy: 0.7599 - auc: 0.8720 - val_loss: 0.5431 - val_accuracy: 0.7971 - val_auc: 0.8856
# Epoch 59/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5680 - accuracy: 0.7760 - auc: 0.8776 - val_loss: 0.5506 - val_accuracy: 0.8019 - val_auc: 0.8864
# Epoch 60/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5777 - accuracy: 0.7560 - auc: 0.8798 - val_loss: 0.5543 - val_accuracy: 0.8051 - val_auc: 0.8861
# Epoch 61/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5605 - accuracy: 0.7877 - auc: 0.8842 - val_loss: 0.5401 - val_accuracy: 0.8003 - val_auc: 0.8861
# Epoch 62/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5931 - accuracy: 0.7502 - auc: 0.8727 - val_loss: 0.5385 - val_accuracy: 0.7956 - val_auc: 0.8882
# Epoch 63/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5623 - accuracy: 0.7774 - auc: 0.8801 - val_loss: 0.5368 - val_accuracy: 0.7908 - val_auc: 0.8854
# Epoch 64/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5764 - accuracy: 0.7662 - auc: 0.8774 - val_loss: 0.5378 - val_accuracy: 0.7971 - val_auc: 0.8858
# Epoch 65/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5655 - accuracy: 0.7752 - auc: 0.8795 - val_loss: 0.5380 - val_accuracy: 0.8035 - val_auc: 0.8851
# Epoch 66/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5552 - accuracy: 0.7856 - auc: 0.8765 - val_loss: 0.5436 - val_accuracy: 0.8035 - val_auc: 0.8841
# Epoch 67/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5760 - accuracy: 0.7648 - auc: 0.8761 - val_loss: 0.5416 - val_accuracy: 0.8051 - val_auc: 0.8855
# Epoch 68/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5643 - accuracy: 0.7745 - auc: 0.8733 - val_loss: 0.5389 - val_accuracy: 0.8035 - val_auc: 0.8872
# Epoch 69/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5726 - accuracy: 0.7565 - auc: 0.8801 - val_loss: 0.5389 - val_accuracy: 0.8019 - val_auc: 0.8872
# Epoch 70/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5720 - accuracy: 0.7728 - auc: 0.8823 - val_loss: 0.5346 - val_accuracy: 0.8019 - val_auc: 0.8877
# Epoch 71/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5738 - accuracy: 0.7599 - auc: 0.8764 - val_loss: 0.5364 - val_accuracy: 0.8035 - val_auc: 0.8868
# Epoch 72/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5627 - accuracy: 0.7733 - auc: 0.8783 - val_loss: 0.5361 - val_accuracy: 0.7956 - val_auc: 0.8851
# Epoch 73/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5660 - accuracy: 0.7685 - auc: 0.8806 - val_loss: 0.5378 - val_accuracy: 0.7924 - val_auc: 0.8863
# Epoch 74/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5663 - accuracy: 0.7692 - auc: 0.8890 - val_loss: 0.5374 - val_accuracy: 0.7924 - val_auc: 0.8843
# Epoch 75/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5615 - accuracy: 0.7779 - auc: 0.8818 - val_loss: 0.5378 - val_accuracy: 0.7971 - val_auc: 0.8845
# Epoch 76/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5674 - accuracy: 0.7698 - auc: 0.8784 - val_loss: 0.5371 - val_accuracy: 0.7987 - val_auc: 0.8849
# Epoch 77/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5707 - accuracy: 0.7656 - auc: 0.8804 - val_loss: 0.5375 - val_accuracy: 0.8003 - val_auc: 0.8851
# Epoch 78/100
# 40/40 [==============================] - 6s 152ms/step - loss: 0.5755 - accuracy: 0.7580 - auc: 0.8778 - val_loss: 0.5370 - val_accuracy: 0.8019 - val_auc: 0.8863
# Epoch 79/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5747 - accuracy: 0.7598 - auc: 0.8771 - val_loss: 0.5372 - val_accuracy: 0.8035 - val_auc: 0.8861
# Epoch 80/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5642 - accuracy: 0.7795 - auc: 0.8811 - val_loss: 0.5366 - val_accuracy: 0.8019 - val_auc: 0.8852
# Epoch 81/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5738 - accuracy: 0.7789 - auc: 0.8689 - val_loss: 0.5369 - val_accuracy: 0.7971 - val_auc: 0.8850
# Epoch 82/100
# 40/40 [==============================] - 6s 151ms/step - loss: 0.5929 - accuracy: 0.7424 - auc: 0.8728 - val_loss: 0.5375 - val_accuracy: 0.7956 - val_auc: 0.8849
# Epoch 83/100
# 40/40 [==============================] - 6s 153ms/step - loss: 0.5816 - accuracy: 0.7678 - auc: 0.8757 - val_loss: 0.5381 - val_accuracy: 0.7940 - val_auc: 0.8846
# Epoch 84/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5697 - accuracy: 0.7710 - auc: 0.8799 - val_loss: 0.5378 - val_accuracy: 0.7940 - val_auc: 0.8838
# Epoch 85/100
# 40/40 [==============================] - 7s 165ms/step - loss: 0.5894 - accuracy: 0.7572 - auc: 0.8748 - val_loss: 0.5379 - val_accuracy: 0.7971 - val_auc: 0.8842
# Epoch 86/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5633 - accuracy: 0.7757 - auc: 0.8848 - val_loss: 0.5386 - val_accuracy: 0.7987 - val_auc: 0.8848
# Epoch 87/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5696 - accuracy: 0.7705 - auc: 0.8810 - val_loss: 0.5388 - val_accuracy: 0.7987 - val_auc: 0.8848
# Epoch 88/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5677 - accuracy: 0.7723 - auc: 0.8809 - val_loss: 0.5389 - val_accuracy: 0.7971 - val_auc: 0.8851
# Epoch 89/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5710 - accuracy: 0.7616 - auc: 0.8754 - val_loss: 0.5381 - val_accuracy: 0.7971 - val_auc: 0.8854
# Epoch 90/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5759 - accuracy: 0.7708 - auc: 0.8834 - val_loss: 0.5391 - val_accuracy: 0.7971 - val_auc: 0.8852
# Epoch 91/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5939 - accuracy: 0.7431 - auc: 0.8751 - val_loss: 0.5391 - val_accuracy: 0.7971 - val_auc: 0.8849
# Epoch 92/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5718 - accuracy: 0.7647 - auc: 0.8835 - val_loss: 0.5392 - val_accuracy: 0.7971 - val_auc: 0.8845
# Epoch 93/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5731 - accuracy: 0.7729 - auc: 0.8750 - val_loss: 0.5390 - val_accuracy: 0.7971 - val_auc: 0.8844
# Epoch 94/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5857 - accuracy: 0.7532 - auc: 0.8791 - val_loss: 0.5383 - val_accuracy: 0.7956 - val_auc: 0.8852
# Epoch 95/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.5581 - accuracy: 0.7667 - auc: 0.8825 - val_loss: 0.5376 - val_accuracy: 0.7987 - val_auc: 0.8853
# Epoch 96/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5703 - accuracy: 0.7623 - auc: 0.8824 - val_loss: 0.5377 - val_accuracy: 0.7987 - val_auc: 0.8855
# Epoch 97/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5893 - accuracy: 0.7579 - auc: 0.8813 - val_loss: 0.5372 - val_accuracy: 0.7971 - val_auc: 0.8867
# Epoch 98/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5899 - accuracy: 0.7539 - auc: 0.8770 - val_loss: 0.5374 - val_accuracy: 0.7987 - val_auc: 0.8867
# Epoch 99/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.5667 - accuracy: 0.7705 - auc: 0.8792 - val_loss: 0.5380 - val_accuracy: 0.7987 - val_auc: 0.8866
# Epoch 100/100
# 40/40 [==============================] - 6s 149ms/step - loss: 0.5792 - accuracy: 0.7562 - auc: 0.8741 - val_loss: 0.5383 - val_accuracy: 0.7987 - val_auc: 0.8872

# %% [markdown]
# 트레이닝 accuracy 와 auc 가 validation accuracy, auc 와 거의 유사함

# %%
n_epoch = 100
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
batch_size = 64
params = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': True,
          'beta_param': 0.7,
          'mixup': True,
#          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
          'highpass': [.5, [78,79,80,81,82,83,84,85]],
          'ranfilter2' : [3, [18,19,20,21,22,23]]
#           'dropblock' : [30, 100]
          #'device' : device
}

params_no_shuffle = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': False,
          'beta_param': 0.7,
          'mixup': False
          #'device': device
}

TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
           features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                        out_lbs_trn,  ## our Y
                        **params)()

#ValDGen_1 = Generator0([features_test[0]['age'],features_test[0]['sex'], features_test[0]['hw'], features_test[0]['preg'], features_test[0]['loc'], 
#           features_test[0]['mel1'],features_test[0]['cqt1'],features_test[0]['stft1']], 
#                        features_test[2],  ## our Y
#                        **params_no_shuffle)()

    
model2.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                              features_test['preg'], features_test['loc'], features_test['mel1'], 
                              features_test['cqt1'], features_test['stft1']], 
                             out_lbs_test), 
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(out_lbs_trn)/64),
                             epochs = n_epoch)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 16s 274ms/step - loss: 0.8414 - accuracy: 0.4985 - auc: 0.4948 - val_loss: 0.8687 - val_accuracy: 0.5008 - val_auc: 0.4129
# Epoch 2/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.7458 - accuracy: 0.5083 - auc: 0.5044 - val_loss: 0.6909 - val_accuracy: 0.5293 - val_auc: 0.5479
# Epoch 3/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.7489 - accuracy: 0.4721 - auc: 0.4861 - val_loss: 0.7319 - val_accuracy: 0.4992 - val_auc: 0.5665
# Epoch 4/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.7182 - accuracy: 0.5093 - auc: 0.5419 - val_loss: 0.7464 - val_accuracy: 0.4992 - val_auc: 0.4850
# Epoch 5/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.7269 - accuracy: 0.5227 - auc: 0.5064 - val_loss: 0.7990 - val_accuracy: 0.4992 - val_auc: 0.4370
# Epoch 6/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.7298 - accuracy: 0.5089 - auc: 0.4982 - val_loss: 0.7864 - val_accuracy: 0.4992 - val_auc: 0.4425
# Epoch 7/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.7195 - accuracy: 0.5145 - auc: 0.5138 - val_loss: 0.7176 - val_accuracy: 0.4992 - val_auc: 0.4888
# Epoch 8/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.7147 - accuracy: 0.5031 - auc: 0.5164 - val_loss: 0.7000 - val_accuracy: 0.4992 - val_auc: 0.5250
# Epoch 9/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.7079 - accuracy: 0.5230 - auc: 0.5409 - val_loss: 0.6924 - val_accuracy: 0.4992 - val_auc: 0.5356
# Epoch 10/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.7241 - accuracy: 0.4908 - auc: 0.5094 - val_loss: 0.6863 - val_accuracy: 0.5119 - val_auc: 0.5423
# Epoch 11/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.7142 - accuracy: 0.5159 - auc: 0.5282 - val_loss: 0.6791 - val_accuracy: 0.5563 - val_auc: 0.6022
# Epoch 12/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.7085 - accuracy: 0.5455 - auc: 0.5383 - val_loss: 0.6699 - val_accuracy: 0.6022 - val_auc: 0.6484
# Epoch 13/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.7094 - accuracy: 0.5147 - auc: 0.5132 - val_loss: 0.6700 - val_accuracy: 0.6165 - val_auc: 0.6490
# Epoch 14/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.7202 - accuracy: 0.4894 - auc: 0.4974 - val_loss: 0.6709 - val_accuracy: 0.5943 - val_auc: 0.6441
# Epoch 15/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.7055 - accuracy: 0.5144 - auc: 0.5188 - val_loss: 0.6724 - val_accuracy: 0.5658 - val_auc: 0.6111
# Epoch 16/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.7037 - accuracy: 0.5185 - auc: 0.5274 - val_loss: 0.6998 - val_accuracy: 0.5071 - val_auc: 0.5627
# Epoch 17/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6987 - accuracy: 0.5257 - auc: 0.5368 - val_loss: 0.6698 - val_accuracy: 0.5594 - val_auc: 0.6216
# Epoch 18/100
# 40/40 [==============================] - 6s 153ms/step - loss: 0.6966 - accuracy: 0.5345 - auc: 0.5591 - val_loss: 0.6747 - val_accuracy: 0.5895 - val_auc: 0.6156
# Epoch 19/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.7073 - accuracy: 0.4980 - auc: 0.5240 - val_loss: 0.6832 - val_accuracy: 0.5246 - val_auc: 0.5724
# Epoch 20/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.7074 - accuracy: 0.5107 - auc: 0.5234 - val_loss: 0.6817 - val_accuracy: 0.5388 - val_auc: 0.5742
# Epoch 21/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.7088 - accuracy: 0.4925 - auc: 0.4954 - val_loss: 0.6753 - val_accuracy: 0.6117 - val_auc: 0.6405
# Epoch 22/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.7046 - accuracy: 0.5002 - auc: 0.5286 - val_loss: 0.6801 - val_accuracy: 0.5468 - val_auc: 0.5874
# Epoch 23/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.7019 - accuracy: 0.4934 - auc: 0.5273 - val_loss: 0.6777 - val_accuracy: 0.5895 - val_auc: 0.6151
# Epoch 24/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6979 - accuracy: 0.5193 - auc: 0.5301 - val_loss: 0.6692 - val_accuracy: 0.5927 - val_auc: 0.6489
# Epoch 25/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.7016 - accuracy: 0.5129 - auc: 0.5206 - val_loss: 0.6739 - val_accuracy: 0.5927 - val_auc: 0.6274
# Epoch 26/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6966 - accuracy: 0.5370 - auc: 0.5405 - val_loss: 0.6705 - val_accuracy: 0.5705 - val_auc: 0.6167
# Epoch 27/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.7107 - accuracy: 0.4872 - auc: 0.5073 - val_loss: 0.6684 - val_accuracy: 0.6149 - val_auc: 0.6608
# Epoch 28/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6996 - accuracy: 0.5102 - auc: 0.5383 - val_loss: 0.6771 - val_accuracy: 0.5753 - val_auc: 0.6073
# Epoch 29/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.7020 - accuracy: 0.5178 - auc: 0.5121 - val_loss: 0.6798 - val_accuracy: 0.5404 - val_auc: 0.5734
# Epoch 30/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6974 - accuracy: 0.5394 - auc: 0.5449 - val_loss: 0.6702 - val_accuracy: 0.6260 - val_auc: 0.6534
# Epoch 31/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.7023 - accuracy: 0.4953 - auc: 0.5220 - val_loss: 0.6659 - val_accuracy: 0.6276 - val_auc: 0.6717
# Epoch 32/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.6941 - accuracy: 0.5227 - auc: 0.5495 - val_loss: 0.6662 - val_accuracy: 0.6212 - val_auc: 0.6706
# Epoch 33/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6969 - accuracy: 0.5242 - auc: 0.5382 - val_loss: 0.6572 - val_accuracy: 0.6371 - val_auc: 0.6995
# Epoch 34/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6939 - accuracy: 0.5312 - auc: 0.5567 - val_loss: 0.6639 - val_accuracy: 0.5832 - val_auc: 0.6426
# Epoch 35/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6943 - accuracy: 0.5228 - auc: 0.5523 - val_loss: 0.6626 - val_accuracy: 0.6149 - val_auc: 0.6768
# Epoch 36/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6957 - accuracy: 0.5123 - auc: 0.5497 - val_loss: 0.6687 - val_accuracy: 0.5990 - val_auc: 0.6437
# Epoch 37/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.6942 - accuracy: 0.5245 - auc: 0.5504 - val_loss: 0.6569 - val_accuracy: 0.6276 - val_auc: 0.6841
# Epoch 38/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6968 - accuracy: 0.5181 - auc: 0.5416 - val_loss: 0.6662 - val_accuracy: 0.6181 - val_auc: 0.6532
# Epoch 39/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.6972 - accuracy: 0.5203 - auc: 0.5569 - val_loss: 0.6596 - val_accuracy: 0.6070 - val_auc: 0.6681
# Epoch 40/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6920 - accuracy: 0.5421 - auc: 0.5746 - val_loss: 0.6537 - val_accuracy: 0.6070 - val_auc: 0.6686
# Epoch 41/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.6988 - accuracy: 0.5176 - auc: 0.5440 - val_loss: 0.6528 - val_accuracy: 0.6244 - val_auc: 0.6707
# Epoch 42/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6947 - accuracy: 0.5213 - auc: 0.5489 - val_loss: 0.6626 - val_accuracy: 0.5705 - val_auc: 0.6238
# Epoch 43/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6896 - accuracy: 0.5445 - auc: 0.5612 - val_loss: 0.6625 - val_accuracy: 0.5610 - val_auc: 0.6284
# Epoch 44/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6938 - accuracy: 0.5292 - auc: 0.5475 - val_loss: 0.6694 - val_accuracy: 0.5468 - val_auc: 0.6140
# Epoch 45/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6922 - accuracy: 0.5534 - auc: 0.5554 - val_loss: 0.6568 - val_accuracy: 0.6006 - val_auc: 0.6678
# Epoch 46/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.6900 - accuracy: 0.5260 - auc: 0.5539 - val_loss: 0.6506 - val_accuracy: 0.6498 - val_auc: 0.7033
# Epoch 47/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.6890 - accuracy: 0.5509 - auc: 0.5674 - val_loss: 0.6468 - val_accuracy: 0.6513 - val_auc: 0.7061
# Epoch 48/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6870 - accuracy: 0.5443 - auc: 0.5880 - val_loss: 0.6424 - val_accuracy: 0.6783 - val_auc: 0.7195
# Epoch 49/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6891 - accuracy: 0.5305 - auc: 0.5797 - val_loss: 0.6486 - val_accuracy: 0.6593 - val_auc: 0.7025
# Epoch 50/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6889 - accuracy: 0.5494 - auc: 0.5730 - val_loss: 0.6504 - val_accuracy: 0.6466 - val_auc: 0.6983
# Epoch 51/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6926 - accuracy: 0.5262 - auc: 0.5661 - val_loss: 0.6493 - val_accuracy: 0.6466 - val_auc: 0.6988
# Epoch 52/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.6940 - accuracy: 0.5359 - auc: 0.5598 - val_loss: 0.6477 - val_accuracy: 0.6561 - val_auc: 0.7079
# Epoch 53/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6871 - accuracy: 0.5521 - auc: 0.5771 - val_loss: 0.6458 - val_accuracy: 0.6672 - val_auc: 0.7146
# Epoch 54/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6929 - accuracy: 0.5430 - auc: 0.5539 - val_loss: 0.6477 - val_accuracy: 0.6513 - val_auc: 0.7048
# Epoch 55/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6856 - accuracy: 0.5470 - auc: 0.5891 - val_loss: 0.6487 - val_accuracy: 0.6529 - val_auc: 0.7099
# Epoch 56/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6931 - accuracy: 0.5349 - auc: 0.5494 - val_loss: 0.6503 - val_accuracy: 0.6403 - val_auc: 0.6989
# Epoch 57/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6914 - accuracy: 0.5361 - auc: 0.5520 - val_loss: 0.6553 - val_accuracy: 0.6212 - val_auc: 0.6816
# Epoch 58/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.6912 - accuracy: 0.5293 - auc: 0.5419 - val_loss: 0.6520 - val_accuracy: 0.6450 - val_auc: 0.7001
# Epoch 59/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6933 - accuracy: 0.5221 - auc: 0.5434 - val_loss: 0.6467 - val_accuracy: 0.6593 - val_auc: 0.7152
# Epoch 60/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6919 - accuracy: 0.5227 - auc: 0.5506 - val_loss: 0.6465 - val_accuracy: 0.6513 - val_auc: 0.7163
# Epoch 61/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6953 - accuracy: 0.5315 - auc: 0.5505 - val_loss: 0.6504 - val_accuracy: 0.6529 - val_auc: 0.7033
# Epoch 62/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6866 - accuracy: 0.5634 - auc: 0.5897 - val_loss: 0.6492 - val_accuracy: 0.6561 - val_auc: 0.7105
# Epoch 63/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6895 - accuracy: 0.5483 - auc: 0.5834 - val_loss: 0.6488 - val_accuracy: 0.6561 - val_auc: 0.7150
# Epoch 64/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6907 - accuracy: 0.5385 - auc: 0.5770 - val_loss: 0.6475 - val_accuracy: 0.6672 - val_auc: 0.7248
# Epoch 65/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6917 - accuracy: 0.5212 - auc: 0.5694 - val_loss: 0.6510 - val_accuracy: 0.6466 - val_auc: 0.7129
# Epoch 66/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.6905 - accuracy: 0.5417 - auc: 0.5673 - val_loss: 0.6514 - val_accuracy: 0.6593 - val_auc: 0.7150
# Epoch 67/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6898 - accuracy: 0.5416 - auc: 0.5633 - val_loss: 0.6527 - val_accuracy: 0.6545 - val_auc: 0.7096
# Epoch 68/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.6832 - accuracy: 0.5691 - auc: 0.5914 - val_loss: 0.6502 - val_accuracy: 0.6609 - val_auc: 0.7161
# Epoch 69/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.6910 - accuracy: 0.5380 - auc: 0.5500 - val_loss: 0.6500 - val_accuracy: 0.6561 - val_auc: 0.7176
# Epoch 70/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6938 - accuracy: 0.5241 - auc: 0.5566 - val_loss: 0.6508 - val_accuracy: 0.6482 - val_auc: 0.7094
# Epoch 71/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6915 - accuracy: 0.5223 - auc: 0.5610 - val_loss: 0.6522 - val_accuracy: 0.6260 - val_auc: 0.7023
# Epoch 72/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6895 - accuracy: 0.5486 - auc: 0.5690 - val_loss: 0.6517 - val_accuracy: 0.6529 - val_auc: 0.7101
# Epoch 73/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6936 - accuracy: 0.5314 - auc: 0.5445 - val_loss: 0.6497 - val_accuracy: 0.6640 - val_auc: 0.7189
# Epoch 74/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6923 - accuracy: 0.5207 - auc: 0.5719 - val_loss: 0.6500 - val_accuracy: 0.6561 - val_auc: 0.7127
# Epoch 75/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6930 - accuracy: 0.5220 - auc: 0.5560 - val_loss: 0.6499 - val_accuracy: 0.6577 - val_auc: 0.7137
# Epoch 76/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6886 - accuracy: 0.5345 - auc: 0.5710 - val_loss: 0.6496 - val_accuracy: 0.6672 - val_auc: 0.7149
# Epoch 77/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.6888 - accuracy: 0.5456 - auc: 0.5806 - val_loss: 0.6498 - val_accuracy: 0.6577 - val_auc: 0.7137
# Epoch 78/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6910 - accuracy: 0.5266 - auc: 0.5478 - val_loss: 0.6502 - val_accuracy: 0.6561 - val_auc: 0.7111
# Epoch 79/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6936 - accuracy: 0.5339 - auc: 0.5491 - val_loss: 0.6502 - val_accuracy: 0.6577 - val_auc: 0.7109
# Epoch 80/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6855 - accuracy: 0.5506 - auc: 0.5966 - val_loss: 0.6500 - val_accuracy: 0.6529 - val_auc: 0.7106
# Epoch 81/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6862 - accuracy: 0.5563 - auc: 0.5829 - val_loss: 0.6490 - val_accuracy: 0.6609 - val_auc: 0.7126
# Epoch 82/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6902 - accuracy: 0.5349 - auc: 0.5620 - val_loss: 0.6494 - val_accuracy: 0.6498 - val_auc: 0.7096
# Epoch 83/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6877 - accuracy: 0.5472 - auc: 0.5778 - val_loss: 0.6490 - val_accuracy: 0.6561 - val_auc: 0.7135
# Epoch 84/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6917 - accuracy: 0.5281 - auc: 0.5584 - val_loss: 0.6493 - val_accuracy: 0.6466 - val_auc: 0.7108
# Epoch 85/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6918 - accuracy: 0.5320 - auc: 0.5619 - val_loss: 0.6492 - val_accuracy: 0.6545 - val_auc: 0.7133
# Epoch 86/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6919 - accuracy: 0.5363 - auc: 0.5714 - val_loss: 0.6492 - val_accuracy: 0.6593 - val_auc: 0.7131
# Epoch 87/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6870 - accuracy: 0.5410 - auc: 0.5937 - val_loss: 0.6486 - val_accuracy: 0.6624 - val_auc: 0.7156
# Epoch 88/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.6898 - accuracy: 0.5497 - auc: 0.5848 - val_loss: 0.6486 - val_accuracy: 0.6751 - val_auc: 0.7143
# Epoch 89/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6873 - accuracy: 0.5485 - auc: 0.5766 - val_loss: 0.6490 - val_accuracy: 0.6561 - val_auc: 0.7131
# Epoch 90/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6878 - accuracy: 0.5347 - auc: 0.5649 - val_loss: 0.6490 - val_accuracy: 0.6529 - val_auc: 0.7139
# Epoch 91/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6904 - accuracy: 0.5237 - auc: 0.5602 - val_loss: 0.6489 - val_accuracy: 0.6561 - val_auc: 0.7146
# Epoch 92/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6960 - accuracy: 0.5334 - auc: 0.5471 - val_loss: 0.6496 - val_accuracy: 0.6482 - val_auc: 0.7120
# Epoch 93/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6913 - accuracy: 0.5375 - auc: 0.5697 - val_loss: 0.6499 - val_accuracy: 0.6513 - val_auc: 0.7110
# Epoch 94/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.6906 - accuracy: 0.5321 - auc: 0.5667 - val_loss: 0.6504 - val_accuracy: 0.6498 - val_auc: 0.7084
# Epoch 95/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.6904 - accuracy: 0.5401 - auc: 0.5752 - val_loss: 0.6493 - val_accuracy: 0.6513 - val_auc: 0.7122
# Epoch 96/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6852 - accuracy: 0.5606 - auc: 0.5674 - val_loss: 0.6500 - val_accuracy: 0.6450 - val_auc: 0.7099
# Epoch 97/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.6904 - accuracy: 0.5247 - auc: 0.5647 - val_loss: 0.6500 - val_accuracy: 0.6498 - val_auc: 0.7105
# Epoch 98/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6918 - accuracy: 0.5405 - auc: 0.5607 - val_loss: 0.6498 - val_accuracy: 0.6450 - val_auc: 0.7103
# Epoch 99/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6880 - accuracy: 0.5611 - auc: 0.5722 - val_loss: 0.6493 - val_accuracy: 0.6498 - val_auc: 0.7126
# Epoch 100/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6942 - accuracy: 0.5220 - auc: 0.5681 - val_loss: 0.6497 - val_accuracy: 0.6513 - val_auc: 0.7112

# %% [markdown]
# ### 팀코드 수정해야 할 함수들..

# %%
params_feature
# Out:
# {'samp_sec': 20,
#  'pre_emphasis': 0,
#  'hop_length': 256,
#  'win_length': 512,
#  'n_mels': 100,
#  'filter_scale': 1,
#  'n_bins': 80,
#  'fmin': 10,
#  'mel_shape': (100, 313, 1),
#  'cqt_shape': (80, 157, 1),
#  'stft_shape': (257, 313, 1),
#  'model1': 'ddws1',
#  'model2': 'ddws2',
#  'model_fnm1': 'ddws1/ddws1_model1.hdf5',
#  'model_fnm2': 'ddws1/ddws2_model2.hdf5'}

# %%
params_feature['mel_shape'] = mel_input_shape
params_feature['cqt_shape'] = cqt_input_shape
params_feature['stft_shape'] = stft_input_shape

# %%
import pickle as pk
def save_challenge_model(model_folder, model1, model2, m_name1, m_name2, param_feature) :
    os.makedirs(model_folder, exist_ok=True)
    info_fnm = os.path.join(model_folder, 'desc.pk')
    filename1 = os.path.join(model_folder, m_name1 + '_model1.hdf5')
    filename2 = os.path.join(model_folder, m_name2 + '_model2.hdf5')
    model1.save(filename1)
    model2.save(filename2)
    param_feature['model1'] = m_name1
    param_feature['model2'] = m_name2
    param_feature['model_fnm1'] = filename1
    param_feature['model_fnm2'] = filename2

    with open(info_fnm, 'wb') as f:
        pk.dump(param_feature, f, pk.HIGHEST_PROTOCOL)
    return 1

# %%
model_folder
# Out:
# 'ddws1'

# %%
save_challenge_model(model_folder, model1, model2, m_name1 = 'ddws1', m_name2 = 'ddws2', param_feature = params_feature)
# Out:
# 1

# %%
def load_challenge_model(model_folder, verbose):
    info_fnm = os.path.join(model_folder, 'desc.pk')
    with open(info_fnm, 'rb') as f:
        info_m = pk.load(f)
#    if info_m['model'] == 'toy' :
#        model = get_toy(info_m['mel_shape'])
#    filename = os.path.join(model_folder, info_m['model'] + '_model.hdf5')
#    model.load_weights(filename)
    return info_m

# %%
params_feature
# Out:
# {'samp_sec': 20,
#  'pre_emphasis': 0,
#  'hop_length': 256,
#  'win_length': 512,
#  'n_mels': 100,
#  'filter_scale': 1,
#  'n_bins': 80,
#  'fmin': 10,
#  'mel_shape': (100, 313, 1),
#  'cqt_shape': (80, 157, 1),
#  'stft_shape': (257, 313, 1),
#  'model1': 'ddws1',
#  'model2': 'ddws2',
#  'model_fnm1': 'ddws1/ddws1_model1.hdf5',
#  'model_fnm2': 'ddws1/ddws2_model2.hdf5'}

# %%
def run_challenge_model(model, data, recordings, verbose):
    
    murmur_classes = ['Present', 'Unknown', 'Absent']
    outcome_classes = ['Abnormal', 'Normal']
    
    if model['model1'] == 'toy1' :
        model1 = get_toy5_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'] )
    if model['model2'] == 'toy2' :
        model2 = get_toy5_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'])
    if model['model1'] == 'lcnn1' :
        model1 = get_LCNN_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model2'] == 'lcnn2' :
        model2 = get_LCNN_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model1'] == 'resmax1' :
        model1 = get_ResMax_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model2'] == 'resmax2' :
        model2 = get_ResMax_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model1'] == 'ddws1' :
        model1 = get_DDWS_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model2'] == 'ddws2' :
        model2 = get_DDWS_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model1'] == 'bcresmax1' :
        model1 = get_BCResMax_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model2'] == 'bcresmax2' :
        model2 = get_BCResMax_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    model1.load_weights(model['model_fnm1'])
    model2.load_weights(model['model_fnm2'])
    
#    classes = model['classes']
    # Load features.
    features = get_feature_one(data, verbose = 0)

    samp_sec = model['samp_sec'] 
    pre_emphasis = model['pre_emphasis']
    hop_length = model['hop_length']
    win_length = model['win_length']
    n_mels = model['n_mels']
    filter_scale = model['filter_scale']
    n_bins = model['n_bins']
    fmin = model['fmin']
    
    features['mel1'] = []
    for i in range(len(recordings)) :
        mel1 = feature_extract_melspec(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                           win_length = win_length, n_mels = n_mels)[0]
        features['mel1'].append(mel1)
    M, N = features['mel1'][0].shape
    for i in range(len(features['mel1'])) :
        features['mel1'][i] = features['mel1'][i].reshape(M,N,1)   
    features['mel1'] = np.array(features['mel1'])

    features['cqt1'] = []
    for i in range(len(recordings)) :
        mel1 = feature_extract_cqt(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale, 
                                        n_bins = n_bins, fmin = fmin)[0]
        features['cqt1'].append(mel1)
    M, N = features['cqt1'][0].shape
    for i in range(len(features['cqt1'])) :
        features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)   
    features['cqt1'] = np.array(features['cqt1'])

    features['stft1'] = []
    for i in range(len(recordings)) :
        mel1 = feature_extract_stft(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                       win_length = win_length)[0]
        features['stft1'].append(mel1)
    M, N = features['stft1'][0].shape
    for i in range(len(features['stft1'])) :
        features['stft1'][i] = features['stft1'][i].reshape(M,N,1)           
    features['stft1'] = np.array(features['stft1'])

    #    print(features)
    # Impute missing data.
    res1 = model1.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], features['mel1'], features['cqt1'], features['stft1']])
    res2 = model2.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], features['mel1'], features['cqt1'], features['stft1']])

    # Get classifier probabilities.
    idx1 = res1.argmax(axis=0)[0]
    murmur_probabilities = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
    outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기
#    idx = np.argmax(prob1)

    ## 이부분도 생각 필요.. rule 을 cost를 maximize 하는 기준으로 threshold 탐색 필요할지도..
    # Choose label with highest probability.
    murmur_labels = np.zeros(len(murmur_classes), dtype=np.int_)
    idx = np.argmax(murmur_probabilities)
    murmur_labels[idx] = 1
    outcome_labels = np.zeros(len(outcome_classes), dtype=np.int_)
    idx = np.argmax(outcome_probabilities)
    outcome_labels[idx] = 1
    
    # Concatenate classes, labels, and probabilities.
    classes = murmur_classes + outcome_classes
    labels = np.concatenate((murmur_labels, outcome_labels))
    probabilities = np.concatenate((murmur_probabilities, outcome_probabilities))
    
    return classes, labels, probabilities

# %% [markdown]
# ### 대회 평가용 run_model 함수 (수정 불필요)

# %%
# Run model.
def run_model(model_folder, data_folder, output_folder, allow_failures, verbose):
    # Load models.
    if verbose >= 1:
        print('Loading Challenge model...')

    model = load_challenge_model(model_folder, verbose) ### Teams: Implement this function!!!

    # Find the patient data files.
    patient_files = find_patient_files(data_folder)
    num_patient_files = len(patient_files)

    if num_patient_files==0:
        raise Exception('No data was provided.')

    # Create a folder for the Challenge outputs if it does not already exist.
    os.makedirs(output_folder, exist_ok=True)

    # Run the team's model on the Challenge data.
    if verbose >= 1:
        print('Running model on Challenge data...')

    # Iterate over the patient files.
    for i in range(num_patient_files):
        if verbose >= 2:
            print('    {}/{}...'.format(i+1, num_patient_files))

        patient_data = load_patient_data(patient_files[i])
        recordings = load_recordings(data_folder, patient_data)

        # Allow or disallow the model to fail on parts of the data; helpful for debugging.
        try:
            classes, labels, probabilities = run_challenge_model(model, patient_data, recordings, verbose) ### Teams: Implement this function!!!
        except:
            if allow_failures:
                if verbose >= 2:
                    print('... failed.')
                classes, labels, probabilities = list(), list(), list()
            else:
                raise

        # Save Challenge outputs.
        head, tail = os.path.split(patient_files[i])
        root, extension = os.path.splitext(tail)
        output_file = os.path.join(output_folder, root + '.csv')
        patient_id = get_patient_id(patient_data)
        save_challenge_outputs(output_file, patient_id, classes, labels, probabilities)

    if verbose >= 1:
        print('Done.')

# %%
## 우리 모형 저장된 폴더이름
model_folder
# Out:
# 'ddws1'

# %%
## 테스트 데이터 폴더
test_folder
# Out:
# '/home/ubuntu/data/hmd/murmur/test'

# %%
## 테스트 데이터에 모형 돌려서 스코어 저장할 폴더
output_folder = '/home/ubuntu/hmd/notebooks/out_ddws1'

# %%
run_model(model_folder, test_folder, output_folder, allow_failures = True, verbose = 1)
# Out:
# Loading Challenge model...
# Running model on Challenge data...
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0830a4dc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f083c523ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f085d6ed200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f10b4074c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08e4aa83b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0824857dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fbec3830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fbcc49e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08242b5560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0824089950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0854bb4050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f085c200b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0827f03290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fb361a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08000a5290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0800328c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f96f2200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f94c4f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0824786200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f9a613b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0831a4d440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0827f037a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0800715a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08005aec20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08251a45f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fbcc4170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f8c858c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fb284560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0839bdc0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fb40ecb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f083934f9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08261d2cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f9acaa70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f9db0dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08e4df5170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08302057a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f3c01440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f8103830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08304d0170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa083ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f083c8838c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0831ba4950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08e49fc4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa367f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f98a5d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f9ca2f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f3c27ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f8c33cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa10cf80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fbe97050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f96e33b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa201b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f085c2a13b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fb489ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f9ef7ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f9f6e680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa542cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fb3e9710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa73f9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07fa91b0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0826040cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0825d46200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0826173d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08318a2d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d2a33290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07db8183b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07eb605050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d34bca70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d2d965f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d3ea6200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d80a5a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d8635290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07e29f6440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07da62aa70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d16c6200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d108a320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d0546200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f828df80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f8628710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d2d10200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07d151d290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07dbf00cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07dbc273b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07f8786560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f07dacbed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Done.

# %%
# !cat /home/ubuntu/hmd/notebooks/out_ddws1/49628.csv
# Out:
# #49628
# Present,Unknown,Absent,Abnormal,Normal
# 0,0,1,0,1
# 0.16892476,0.010964039,0.8201113,0.4091206,0.59087944

# %%
from evaluate_model import *

# %%
murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)
classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
    + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string

if len(sys.argv) == 3:
    print(output_string)
elif len(sys.argv) == 4:
    with open(sys.argv[3], 'w') as f:
        f.write(output_string)
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000

# %% [markdown]
# ### Threshold 변경해가며 결과 탐색

# %%
label_folder = test_folder
murmur_classes = ['Present', 'Unknown', 'Absent']
outcome_classes = ['Abnormal', 'Normal']

# Load and parse label and model output files.
label_files, output_files = find_challenge_files(label_folder, output_folder)
murmur_labels = load_murmurs(label_files, murmur_classes)
murmur_binary_outputs, murmur_scalar_outputs = load_classifier_outputs(output_files, murmur_classes)
outcome_labels = load_outcomes(label_files, outcome_classes)
outcome_binary_outputs, outcome_scalar_outputs = load_classifier_outputs(output_files, outcome_classes)


print(np.mean(murmur_scalar_outputs[:,0]))
print(np.mean(murmur_scalar_outputs[:,2]))
print(np.mean(outcome_scalar_outputs[:,0]))
print(np.mean(outcome_scalar_outputs[:,1]))
# Out:
# 0.1643587870680628
# 0.8252893641361255
# 0.4018099971727749
# 0.5981900063350785

# %%
## threshold 바꿔가면서 결과 출력

for th1 in [0.01, 0.05, 0.1, 0.15,0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8] :
    murmur_binary_outputs[:,0] = murmur_scalar_outputs[:,0] > th1
    murmur_binary_outputs[:,2] = murmur_scalar_outputs[:,2] > 1 - th1
    outcome_binary_outputs[:,0] = outcome_scalar_outputs[:,0] > th1
    outcome_binary_outputs[:,1] = outcome_scalar_outputs[:,1] > 1 - th1
    # For each patient, set the 'Present' or 'Abnormal' class to positive if no class is positive or if multiple classes are positive.
    murmur_labels = enforce_positives(murmur_labels, murmur_classes, 'Present')
    murmur_binary_outputs = enforce_positives(murmur_binary_outputs, murmur_classes, 'Present')
    outcome_labels = enforce_positives(outcome_labels, outcome_classes, 'Abnormal')
    outcome_binary_outputs = enforce_positives(outcome_binary_outputs, outcome_classes, 'Abnormal')
    # Evaluate the murmur model by comparing the labels and model outputs.
    murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes = compute_auc(murmur_labels, murmur_scalar_outputs)
    murmur_f_measure, murmur_f_measure_classes = compute_f_measure(murmur_labels, murmur_binary_outputs)
    murmur_accuracy, murmur_accuracy_classes = compute_accuracy(murmur_labels, murmur_binary_outputs)
    murmur_weighted_accuracy = compute_weighted_accuracy(murmur_labels, murmur_binary_outputs, murmur_classes) # This is the murmur scoring metric.
    murmur_cost = compute_cost(outcome_labels, murmur_binary_outputs, outcome_classes, murmur_classes) # Use *outcomes* to score *murmurs* for the Challenge cost metric, but this is not the actual murmur scoring metric.
    murmur_scores = (murmur_classes, murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes, \
                 murmur_f_measure, murmur_f_measure_classes, murmur_accuracy, murmur_accuracy_classes, murmur_weighted_accuracy, murmur_cost)

    # Evaluate the outcome model by comparing the labels and model outputs.
    outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes = compute_auc(outcome_labels, outcome_scalar_outputs)
    outcome_f_measure, outcome_f_measure_classes = compute_f_measure(outcome_labels, outcome_binary_outputs)
    outcome_accuracy, outcome_accuracy_classes = compute_accuracy(outcome_labels, outcome_binary_outputs)
    outcome_weighted_accuracy = compute_weighted_accuracy(outcome_labels, outcome_binary_outputs, outcome_classes)
    outcome_cost = compute_cost(outcome_labels, outcome_binary_outputs, outcome_classes, outcome_classes) # This is the clinical outcomes scoring metric.
    outcome_scores = (outcome_classes, outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes, \
                  outcome_f_measure, outcome_f_measure_classes, outcome_accuracy, outcome_accuracy_classes, outcome_weighted_accuracy, outcome_cost)



    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
    murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
    outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
                + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
    print("threshold: ", th1)
    print(output_string)
    print("-------------")
# Out:
# threshold:  0.01
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.111,0.199,0.512,15140.890
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.332,0.000,0.000
# Accuracy,1.000,0.000,0.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.05
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.111,0.199,0.512,15140.890
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.332,0.000,0.000
# Accuracy,1.000,0.000,0.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.1
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.111,0.199,0.512,15140.890
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.332,0.000,0.000
# Accuracy,1.000,0.000,0.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.15
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.111,0.199,0.512,15140.890
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.332,0.000,0.000
# Accuracy,1.000,0.000,0.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.2
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.25
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.3
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.35
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.4
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.484,0.508,0.640,13408.704
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.595,0.373
# Accuracy,0.704,0.301
#
# -------------
# threshold:  0.45
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.5
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.55
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.6
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.65
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.7
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.75
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
# threshold:  0.8
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.628,0.390,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.553,0.569,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.634,0.674,0.577
# AUPRC,0.299,0.135,0.736
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.553,0.553
# AUPRC,0.619,0.518
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
