# %% [markdown]
# ## LSTM_fix

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats
import librosa
import librosa.display
import math
import sys
#sys.path.insert(0,'/home/ikwak2/hmd/notebooks')
#sys.path.insert(0,'/home/ikwak2/hmd/iy_classifier')
sys.path.insert(0,'utils')
from helper_code import *
from get_feature import *
from models import *
from Generator0 import *
import tensorflow as tf
import datetime
from evaluate_model import *

# %%
root_dir = 'physionet.org/files/circor-heart-sound/1.0.3'
training_data_file = root_dir + '/' + 'training_data.csv'
training_data_dir = root_dir + '/' + 'training_data'
model_dir = root_dir + '/' + 'model'

# %%
import tensorflow as tf

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
print(gpu_info)
# Out:
# Fri Aug  5 11:29:16 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:05.0 Off |                  Off |
# | N/A   52C    P0   144W / 300W |  31097MiB / 32510MiB |     77%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:00:06.0 Off |                  Off |
# | N/A   33C    P0    37W / 300W |      2MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     16044      C   ...sorflow2.4_p37/bin/python    31095MiB |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[1], 'GPU')
    except RuntimeError as e:
        print(e)

# %%
data_folder =  'physionet.org/files/circor-heart-sound/1.0.3/training_data'
train_folder =  '/home/ubuntu/data/hmd/murmur/train'
test_folder = '/home/ubuntu/data/hmd/murmur/test'

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint

def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start
    elif e > end:
        return lr_end

    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))

    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

# %%
# Run model.
def run_model(model_folder, data_folder, output_folder, allow_failures, verbose):
    # Load models.
    if verbose >= 1:
        print('Loading Challenge model...')

    model = load_challenge_model(model_folder, verbose) ### Teams: Implement this function!!!

    # Find the patient data files.
    patient_files = find_patient_files(data_folder)
    num_patient_files = len(patient_files)

    if num_patient_files==0:
        raise Exception('No data was provided.')

    # Create a folder for the Challenge outputs if it does not already exist.
    os.makedirs(output_folder, exist_ok=True)

    # Run the team's model on the Challenge data.
    if verbose >= 1:
        print('Running model on Challenge data...')

#    @tf.function
    # Iterate over the patient files.
    for i in range(num_patient_files):
        if verbose >= 2:
            print('    {}/{}...'.format(i+1, num_patient_files))

        patient_data = load_patient_data(patient_files[i])
        recordings = load_recordings(data_folder, patient_data)

        # Allow or disallow the model to fail on parts of the data; helpful for debugging.
        try:
            classes, labels, probabilities = run_challenge_model(model, patient_data, recordings, verbose) ### Teams: Implement this function!!!
        except:
            if allow_failures:
                if verbose >= 2:
                    print('... failed.')
                classes, labels, probabilities = list(), list(), list()
            else:
                raise

        # Save Challenge outputs.
        head, tail = os.path.split(patient_files[i])
        root, extension = os.path.splitext(tail)
        output_file = os.path.join(output_folder, root + '.csv')
        patient_id = get_patient_id(patient_data)
        save_challenge_outputs(output_file, patient_id, classes, labels, probabilities)

    if verbose >= 1:
        print('Done.')

# %%
import pickle as pk
def save_challenge_model(model_folder, model1, model2, m_name1, m_name2, param_feature) :
    os.makedirs(model_folder, exist_ok=True)
    info_fnm = os.path.join(model_folder, 'desc.pk')
    filename1 = os.path.join(model_folder, m_name1 + '_model1.hdf5')
    filename2 = os.path.join(model_folder, m_name2 + '_model2.hdf5')
    model1.save(filename1)
    model2.save(filename2)
    param_feature['model1'] = m_name1
    param_feature['model2'] = m_name2
    param_feature['model_fnm1'] = filename1
    param_feature['model_fnm2'] = filename2
    with open(info_fnm, 'wb') as f:
        pk.dump(param_feature, f, pk.HIGHEST_PROTOCOL)
    return 1

def load_challenge_model(model_folder, verbose):
    info_fnm = os.path.join(model_folder, 'desc.pk')
    with open(info_fnm, 'rb') as f:
        info_m = pk.load(f)
#    if info_m['model'] == 'toy' :
#        model = get_toy(info_m['mel_shape'])
#    filename = os.path.join(model_folder, info_m['model'] + '_model.hdf5')
#    model.load_weights(filename)
    return info_m

# %%
def run_challenge_model(model, data, recordings, verbose):
    
    murmur_classes = ['Present', 'Unknown', 'Absent']
    outcome_classes = ['Abnormal', 'Normal']
    
    if model['model1'] == 'toy1' :
        model1 = get_toy5_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'] )
    if model['model2'] == 'toy2' :
        model2 = get_toy5_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'])
    if model['model1'] == 'lcnn1' :
        model1 = get_LCNN_o_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'lcnn2' :
        model2 = get_LCNN_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'])
    if model['model1'] == 'resmax1' :
        model1 = get_ResMax_o_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'resmax2' :
        model2 = get_ResMax_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'])
    if model['model1'] == 'lcnn1_dr' :
        model1 = get_LCNN_o_1_dr(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'], dp = model['dp'], fc = model['fc'], ext = model['ext'])
    if model['model2'] == 'lcnn2_dr' :
        model2 = get_LCNN_2_dr(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], 
                               use_cqt = model['use_cqt'], use_stft = model['use_stft'], dp = model['dp'], fc = model['fc'], ext = model['ext'])
    model1.load_weights(model['model_fnm1'])
    model2.load_weights(model['model_fnm2'])
    
#    classes = model['classes']
    # Load features.
    features = get_feature_one(data, verbose = 0)

    samp_sec = model['samp_sec'] 
    pre_emphasis = model['pre_emphasis']
    hop_length = model['hop_length']
    win_length = model['win_length']
    n_mels = model['n_mels']
    filter_scale = model['filter_scale']
    n_bins = model['n_bins']
    fmin = model['fmin']
    use_mel = model['use_mel']
    use_cqt = model['use_cqt']
    use_stft = model['use_stft']
#    use_raw = model['use_raw']
    trim = model['trim']
    
    features['mel1'] = []
    for i in range(len(recordings)) :
        if use_mel :
            mel1 = feature_extract_melspec(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                           win_length = win_length, n_mels = n_mels, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1) )
        features['mel1'].append(mel1)
    M, N = features['mel1'][0].shape

    if use_mel :
        for i in range(len(features['mel1'])) :
            features['mel1'][i] = features['mel1'][i].reshape(M,N,1)
    features['mel1'] = np.array(features['mel1'])

    features['cqt1'] = []
    for i in range(len(recordings)) :
        if use_cqt :
            mel1 = feature_extract_cqt(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale, 
                                        n_bins = n_bins, fmin = fmin, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1))
        features['cqt1'].append(mel1)
    M, N = features['cqt1'][0].shape
    if use_cqt :
        for i in range(len(features['cqt1'])) :
            features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)   
    features['cqt1'] = np.array(features['cqt1'])

    features['stft1'] = []
    for i in range(len(recordings)) :
        if use_stft :
            mel1 = feature_extract_stft(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                        win_length = win_length, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1) )
        features['stft1'].append(mel1)
    M, N = features['stft1'][0].shape
    if use_stft :
        for i in range(len(features['stft1'])) :
            features['stft1'][i] = features['stft1'][i].reshape(M,N,1)           
    features['stft1'] = np.array(features['stft1'])

    #    print(features)
    # Impute missing data.
    res1 = model1.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], features['mel1'], features['cqt1'], features['stft1']])
    res2 = model2.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], features['mel1'], features['cqt1'], features['stft1']])

    # Get classifier probabilities.
    if model['ord1'] :
        idx1 = res1.argmax(axis=0)[0]
        murmur_p = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
        murmur_probabilities = np.zeros((3,))
        murmur_probabilities[0] = murmur_p[0]
        murmur_probabilities[1] = 0
        murmur_probabilities[2] = murmur_p[1]
        outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기
    else :
        if model['mm_mean'] :
            murmur_probabilities = res1.mean(axis = 0)
        else :
            idx1 = res1.argmax(axis=0)[0]
            murmur_probabilities = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
        outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기

    # Get classifier probabilities.
#    idx1 = res1.argmax(axis=0)[0]
#    murmur_probabilities = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
#    outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기
#    idx = np.argmax(prob1)

    ## 이부분도 생각 필요.. rule 을 cost를 maximize 하는 기준으로 threshold 탐색 필요할지도..
    # Choose label with highest probability.
    murmur_labels = np.zeros(len(murmur_classes), dtype=np.int_)
#    idx = np.argmax(murmur_probabilities)
    if murmur_probabilities[0] > 0.482 :
        idx = 0
    else :
        idx = 2
    murmur_labels[idx] = 1

    outcome_labels = np.zeros(len(outcome_classes), dtype=np.int_)
    if outcome_probabilities[0] > 0.607 :
        idx = 0
    else :
        idx = 1    
        # idx = np.argmax(outcome_probabilities)
    outcome_labels[idx] = 1
    
    # Concatenate classes, labels, and probabilities.
    classes = murmur_classes + outcome_classes
    labels = np.concatenate((murmur_labels, outcome_labels))
    probabilities = np.concatenate((murmur_probabilities, outcome_probabilities))
    
    return classes, labels, probabilities

# %%
patient_files_trn = find_patient_files(train_folder)
patient_files_test = find_patient_files(test_folder)

# %%
model_folder = 'lcnn_dr_11'
output_folder = '/home/ubuntu/hmd/notebooks/tmp/out_lcnn_dr_11'

winlen = 512
hoplen = 256
#    winlen = int(winlen)
#    hoplen = int(hoplen)
nmel = 120 #np.random.choice([100, 120, 140])
nsec = 20 #np.random.choice([10, 20, 30, 40, 50])
#    nmel = int(nmel)

trim = 0 #np.random.choice([0,2000, 4000])
use_cqt = False #np.random.choice([True,False])
use_stft = False#np.random.choice([True, False])

params_feature = {'samp_sec': nsec,
              #### melspec, stft 피쳐 옵션들  
              'pre_emphasis': 0,
              'hop_length': hoplen,
              'win_length':winlen,
              'n_mels': nmel,
              #### cqt 피쳐 옵션들  
              'filter_scale': 1,
              'n_bins': 80,
                  'fmin': 10,
                ### 사용할 피쳐 지정
                  'trim' : trim, # 앞뒤 얼마나 자를지? 4000 이면 1초
                  'use_mel' : True,
                  'use_cqt' : use_cqt,
                  'use_stft' : use_stft
}
mm_weight = 3 #np.random.choice([2,3,4,5])
oo_weight = 3 #np.random.choice([2,3,4,5,6])
ord1 = True #np.random.choice([True,False])
mm_mean = False #np.random.choice([True,False])
dp = 0 #np.random.choice([0, .1, .2, .3])
fc = False #np.random.choice([True,False])
ext = False
chaug = 10 #np.random.choice([0, 10])
mixup = True #np.random.choice([True,False])
cout = .8 #np.random.choice([0, 0.8])
wunknown = 1 #np.random.choice([1, 0.7, .5, .2])
n1 = 0 #np.random.choice([0,2])
if n1 == 0 :
    ranfil = False
else :
    ranfil = [n1, [18,19,20,21,22,23]]

# %%
use_mel = params_feature['use_mel']
#    use_cqt = params_feature['use_cqt']
#    use_stft = params_feature['use_stft']


if ord1 :
    features_trn, mm_lbs_trn, out_lbs_trn, mel_input_shape, cqt_input_shape, stft_input_shape = get_features_3lb_all_ord(train_folder, patient_files_trn, **params_feature)
    features_test, mm_lbs_test, out_lbs_test, _, _, _ = get_features_3lb_all_ord(test_folder, patient_files_test, **params_feature)
else :
    features_trn, mm_lbs_trn, out_lbs_trn, mel_input_shape, cqt_input_shape, stft_input_shape = get_features_3lb_all(train_folder, patient_files_trn, **params_feature)
    features_test, mm_lbs_test, out_lbs_test, _, _, _ = get_features_3lb_all(test_folder, patient_files_test, **params_feature)

params_feature['ord1'] = ord1
params_feature['mm_mean'] = mm_mean
params_feature['dp'] = dp
params_feature['fc'] = fc
params_feature['ext'] = ext
params_feature['oo_weight'] = oo_weight
params_feature['mm_weight'] = mm_weight
params_feature['chaug'] = chaug
params_feature['cout'] = cout
params_feature['wunknown'] = wunknown
params_feature['mixup'] = mixup
params_feature['n1'] = n1

print(params_feature)
# Out:
# melspec:  120 313
# melspec:  120 313
# {'samp_sec': 20, 'pre_emphasis': 0, 'hop_length': 256, 'win_length': 512, 'n_mels': 120, 'filter_scale': 1, 'n_bins': 80, 'fmin': 10, 'trim': 0, 'use_mel': True, 'use_cqt': False, 'use_stft': False, 'ord1': True, 'mm_mean': False, 'dp': 0, 'fc': False, 'ext': False, 'oo_weight': 3, 'mm_weight': 3, 'chaug': 10, 'cout': 0.8, 'wunknown': 1, 'mixup': True, 'n1': 0}

# %%
model1 = get_LCNN_o_1_dr(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = use_mel, use_cqt = use_cqt, use_stft = use_stft, ord1 = ord1, dp = dp, fc = fc, ext = ext)
model2 = get_LCNN_2_dr(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = use_mel, use_cqt = use_cqt, use_stft = use_stft, dp = dp, fc = fc, ext = ext)

n_epoch = 100
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
batch_size = 64

if mixup :
    beta_param = .7
else :
    beta_param = 0

params = {'batch_size': batch_size,
          #          'input_shape': (100, 313, 1),
          'shuffle': True,
          'chaug': chaug,
          'beta_param': beta_param,
          'cout': cout
#              'mixup': mixup,
          #          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
          #          'highpass': [.5, [78,79,80,81,82,83,84,85]]
#              'ranfilter2' : [3, [18,19,20,21,22,23]]
          #           'dropblock' : [30, 100]
          #'device' : device
}

if mixup :
    params['mixup'] = mixup
    params['ranfilter2'] = ranfil
else :
    params['cutout'] = cout

params_no_shuffle = {'batch_size': batch_size,
                     #          'input_shape': (100, 313, 1),
                     'shuffle': False,
                     'beta_param': 0.7,
                     'mixup': False
                     #'device': device
}

if ord1 :
    class_weight = {0: mm_weight, 1: 1.}
else :
    class_weight = {0: mm_weight, 1: wunknown, 2:1.}

if mixup :
    TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
                          features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                         mm_lbs_trn,  ## our Y
                             **params)()
    model1.fit(TrainDGen_1,
               validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                                   features_test['preg'], features_test['loc'], features_test['mel1'], 
                                   features_test['cqt1'], features_test['stft1']], 
                                  mm_lbs_test), 
               callbacks=[lr],
               steps_per_epoch=np.ceil(len(mm_lbs_trn)/64),
               class_weight=class_weight, 
               epochs = n_epoch)

else :
    TrainGen = DataGenerator([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
                      features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                     mm_lbs_trn,  ## our Y
                     **params)
    model1.fit(TrainGen,
               validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                                   features_test['preg'], features_test['loc'], features_test['mel1'], 
                                   features_test['cqt1'], features_test['stft1']], 
                                  mm_lbs_test), 
               callbacks=[lr],
               #        steps_per_epoch=np.ceil(len(mm_lbs_trn)/64),
               class_weight=class_weight, 
               epochs = n_epoch)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 13s 96ms/step - loss: 1.0043 - accuracy: 0.7309 - auc: 0.7988 - val_loss: 4.5131 - val_accuracy: 0.2108 - val_auc: 0.2115
# Epoch 2/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8897 - accuracy: 0.8001 - auc: 0.8607 - val_loss: 2.1322 - val_accuracy: 0.2155 - val_auc: 0.1731
# Epoch 3/100
# 40/40 [==============================] - 3s 67ms/step - loss: 0.8946 - accuracy: 0.7907 - auc: 0.8559 - val_loss: 2.4003 - val_accuracy: 0.2124 - val_auc: 0.1838
# Epoch 4/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8831 - accuracy: 0.7932 - auc: 0.8464 - val_loss: 0.7905 - val_accuracy: 0.3106 - val_auc: 0.3380
# Epoch 5/100
# 40/40 [==============================] - 3s 66ms/step - loss: 0.9084 - accuracy: 0.7658 - auc: 0.8606 - val_loss: 0.5883 - val_accuracy: 0.6910 - val_auc: 0.7671
# Epoch 6/100
# 40/40 [==============================] - 3s 66ms/step - loss: 0.8280 - accuracy: 0.8090 - auc: 0.8745 - val_loss: 0.5446 - val_accuracy: 0.8336 - val_auc: 0.9046
# Epoch 7/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.8710 - accuracy: 0.7946 - auc: 0.8642 - val_loss: 0.4079 - val_accuracy: 0.8288 - val_auc: 0.9039
# Epoch 8/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8140 - accuracy: 0.8070 - auc: 0.8666 - val_loss: 0.4336 - val_accuracy: 0.8811 - val_auc: 0.9093
# Epoch 9/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.7834 - accuracy: 0.8269 - auc: 0.8751 - val_loss: 0.3999 - val_accuracy: 0.8494 - val_auc: 0.9052
# Epoch 10/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8161 - accuracy: 0.8175 - auc: 0.8713 - val_loss: 0.5095 - val_accuracy: 0.8479 - val_auc: 0.9206
# Epoch 11/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.8236 - accuracy: 0.8179 - auc: 0.8788 - val_loss: 0.5201 - val_accuracy: 0.8558 - val_auc: 0.9053
# Epoch 12/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.8469 - accuracy: 0.8165 - auc: 0.8805 - val_loss: 0.5750 - val_accuracy: 0.7876 - val_auc: 0.8812
# Epoch 13/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.8303 - accuracy: 0.8062 - auc: 0.8797 - val_loss: 0.9509 - val_accuracy: 0.8051 - val_auc: 0.8557
# Epoch 14/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8187 - accuracy: 0.8231 - auc: 0.8838 - val_loss: 0.4621 - val_accuracy: 0.8605 - val_auc: 0.8850
# Epoch 15/100
# 40/40 [==============================] - 3s 66ms/step - loss: 0.8019 - accuracy: 0.8057 - auc: 0.8706 - val_loss: 0.4505 - val_accuracy: 0.8653 - val_auc: 0.9227
# Epoch 16/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8319 - accuracy: 0.7996 - auc: 0.8713 - val_loss: 0.4469 - val_accuracy: 0.8700 - val_auc: 0.9104
# Epoch 17/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7695 - accuracy: 0.8353 - auc: 0.8941 - val_loss: 0.3588 - val_accuracy: 0.8700 - val_auc: 0.9355
# Epoch 18/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8256 - accuracy: 0.8027 - auc: 0.8834 - val_loss: 0.5274 - val_accuracy: 0.8288 - val_auc: 0.9041
# Epoch 19/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.8209 - accuracy: 0.8071 - auc: 0.8816 - val_loss: 0.4188 - val_accuracy: 0.8938 - val_auc: 0.9326
# Epoch 20/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8021 - accuracy: 0.8196 - auc: 0.8697 - val_loss: 0.4106 - val_accuracy: 0.8906 - val_auc: 0.9153
# Epoch 21/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7829 - accuracy: 0.8292 - auc: 0.8839 - val_loss: 0.6378 - val_accuracy: 0.6355 - val_auc: 0.6944
# Epoch 22/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.8023 - accuracy: 0.8193 - auc: 0.8874 - val_loss: 0.4320 - val_accuracy: 0.8764 - val_auc: 0.9439
# Epoch 23/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7817 - accuracy: 0.8261 - auc: 0.8876 - val_loss: 0.4562 - val_accuracy: 0.8637 - val_auc: 0.9355
# Epoch 24/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.8018 - accuracy: 0.8184 - auc: 0.8889 - val_loss: 0.3828 - val_accuracy: 0.8716 - val_auc: 0.9190
# Epoch 25/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7857 - accuracy: 0.8243 - auc: 0.8925 - val_loss: 0.6477 - val_accuracy: 0.5990 - val_auc: 0.6495
# Epoch 26/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8068 - accuracy: 0.8177 - auc: 0.8823 - val_loss: 0.5917 - val_accuracy: 0.8067 - val_auc: 0.9024
# Epoch 27/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.8054 - accuracy: 0.8270 - auc: 0.8882 - val_loss: 0.4683 - val_accuracy: 0.8637 - val_auc: 0.9382
# Epoch 28/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7861 - accuracy: 0.8241 - auc: 0.8998 - val_loss: 0.6785 - val_accuracy: 0.4976 - val_auc: 0.5539
# Epoch 29/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7835 - accuracy: 0.8053 - auc: 0.8671 - val_loss: 0.5921 - val_accuracy: 0.7385 - val_auc: 0.8232
# Epoch 30/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.7920 - accuracy: 0.8386 - auc: 0.8890 - val_loss: 0.4885 - val_accuracy: 0.8082 - val_auc: 0.9042
# Epoch 31/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8209 - accuracy: 0.8078 - auc: 0.8690 - val_loss: 0.3614 - val_accuracy: 0.8875 - val_auc: 0.9322
# Epoch 32/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7813 - accuracy: 0.8209 - auc: 0.8851 - val_loss: 0.4508 - val_accuracy: 0.8368 - val_auc: 0.9120
# Epoch 33/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7954 - accuracy: 0.8124 - auc: 0.8764 - val_loss: 0.4389 - val_accuracy: 0.8320 - val_auc: 0.9147
# Epoch 34/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8680 - accuracy: 0.7886 - auc: 0.8633 - val_loss: 0.5132 - val_accuracy: 0.8605 - val_auc: 0.9162
# Epoch 35/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7707 - accuracy: 0.8263 - auc: 0.8936 - val_loss: 0.3903 - val_accuracy: 0.8970 - val_auc: 0.9399
# Epoch 36/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.8053 - accuracy: 0.8129 - auc: 0.8843 - val_loss: 0.5074 - val_accuracy: 0.8542 - val_auc: 0.9223
# Epoch 37/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7368 - accuracy: 0.8419 - auc: 0.9025 - val_loss: 0.3829 - val_accuracy: 0.8906 - val_auc: 0.9326
# Epoch 38/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7792 - accuracy: 0.8343 - auc: 0.8903 - val_loss: 0.3970 - val_accuracy: 0.8954 - val_auc: 0.9179
# Epoch 39/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7880 - accuracy: 0.8247 - auc: 0.8929 - val_loss: 0.4767 - val_accuracy: 0.8700 - val_auc: 0.9110
# Epoch 40/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.8166 - accuracy: 0.8110 - auc: 0.8891 - val_loss: 0.3610 - val_accuracy: 0.8954 - val_auc: 0.9456
# Epoch 41/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7764 - accuracy: 0.8251 - auc: 0.8939 - val_loss: 0.7490 - val_accuracy: 0.4263 - val_auc: 0.4748
# Epoch 42/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7905 - accuracy: 0.8315 - auc: 0.8939 - val_loss: 0.4597 - val_accuracy: 0.8574 - val_auc: 0.9394
# Epoch 43/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7838 - accuracy: 0.8150 - auc: 0.8845 - val_loss: 0.3625 - val_accuracy: 0.8748 - val_auc: 0.9212
# Epoch 44/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7427 - accuracy: 0.8354 - auc: 0.8973 - val_loss: 0.4011 - val_accuracy: 0.8336 - val_auc: 0.9250
# Epoch 45/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7937 - accuracy: 0.8120 - auc: 0.8950 - val_loss: 0.3480 - val_accuracy: 0.8922 - val_auc: 0.9410
# Epoch 46/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7518 - accuracy: 0.8254 - auc: 0.9116 - val_loss: 0.4946 - val_accuracy: 0.8257 - val_auc: 0.9013
# Epoch 47/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.7383 - accuracy: 0.8272 - auc: 0.9004 - val_loss: 0.3733 - val_accuracy: 0.8906 - val_auc: 0.9523
# Epoch 48/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7864 - accuracy: 0.8203 - auc: 0.8871 - val_loss: 0.4867 - val_accuracy: 0.8019 - val_auc: 0.8925
# Epoch 49/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7834 - accuracy: 0.8088 - auc: 0.8950 - val_loss: 0.3364 - val_accuracy: 0.8891 - val_auc: 0.9362
# Epoch 50/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7707 - accuracy: 0.8232 - auc: 0.8945 - val_loss: 0.3519 - val_accuracy: 0.8938 - val_auc: 0.9441
# Epoch 51/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.8279 - accuracy: 0.8037 - auc: 0.8868 - val_loss: 0.5826 - val_accuracy: 0.7163 - val_auc: 0.7994
# Epoch 52/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.7790 - accuracy: 0.8201 - auc: 0.8905 - val_loss: 0.3581 - val_accuracy: 0.9033 - val_auc: 0.9452
# Epoch 53/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7922 - accuracy: 0.8233 - auc: 0.9079 - val_loss: 0.3487 - val_accuracy: 0.9017 - val_auc: 0.9471
# Epoch 54/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7749 - accuracy: 0.8214 - auc: 0.8945 - val_loss: 0.4904 - val_accuracy: 0.8399 - val_auc: 0.9047
# Epoch 55/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7705 - accuracy: 0.8373 - auc: 0.8993 - val_loss: 0.3611 - val_accuracy: 0.9017 - val_auc: 0.9493
# Epoch 56/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.7874 - accuracy: 0.8180 - auc: 0.8947 - val_loss: 0.3873 - val_accuracy: 0.8875 - val_auc: 0.9485
# Epoch 57/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7948 - accuracy: 0.8112 - auc: 0.8786 - val_loss: 0.4279 - val_accuracy: 0.8906 - val_auc: 0.9470
# Epoch 58/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8002 - accuracy: 0.8146 - auc: 0.8979 - val_loss: 0.4156 - val_accuracy: 0.9002 - val_auc: 0.9451
# Epoch 59/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7625 - accuracy: 0.8360 - auc: 0.8958 - val_loss: 0.4554 - val_accuracy: 0.8082 - val_auc: 0.9150
# Epoch 60/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7718 - accuracy: 0.8357 - auc: 0.9059 - val_loss: 0.3772 - val_accuracy: 0.8384 - val_auc: 0.9276
# Epoch 61/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7568 - accuracy: 0.8415 - auc: 0.9008 - val_loss: 0.3845 - val_accuracy: 0.9128 - val_auc: 0.9513
# Epoch 62/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7570 - accuracy: 0.8271 - auc: 0.8964 - val_loss: 0.4186 - val_accuracy: 0.8685 - val_auc: 0.9342
# Epoch 63/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7812 - accuracy: 0.8216 - auc: 0.8967 - val_loss: 0.3303 - val_accuracy: 0.9049 - val_auc: 0.9365
# Epoch 64/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.7546 - accuracy: 0.8331 - auc: 0.9132 - val_loss: 0.4375 - val_accuracy: 0.8922 - val_auc: 0.9390
# Epoch 65/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7816 - accuracy: 0.8296 - auc: 0.8992 - val_loss: 0.3922 - val_accuracy: 0.9017 - val_auc: 0.9495
# Epoch 66/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7613 - accuracy: 0.8315 - auc: 0.8933 - val_loss: 0.3600 - val_accuracy: 0.9081 - val_auc: 0.9536
# Epoch 67/100
# 40/40 [==============================] - 2s 61ms/step - loss: 0.7667 - accuracy: 0.8282 - auc: 0.9032 - val_loss: 0.3359 - val_accuracy: 0.9049 - val_auc: 0.9458
# Epoch 68/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7574 - accuracy: 0.8253 - auc: 0.8966 - val_loss: 0.3636 - val_accuracy: 0.9065 - val_auc: 0.9481
# Epoch 69/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.7925 - accuracy: 0.8191 - auc: 0.8966 - val_loss: 0.3488 - val_accuracy: 0.9065 - val_auc: 0.9449
# Epoch 70/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7489 - accuracy: 0.8456 - auc: 0.9105 - val_loss: 0.3476 - val_accuracy: 0.9097 - val_auc: 0.9481
# Epoch 71/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8020 - accuracy: 0.8170 - auc: 0.8893 - val_loss: 0.3695 - val_accuracy: 0.9097 - val_auc: 0.9487
# Epoch 72/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7842 - accuracy: 0.8295 - auc: 0.8997 - val_loss: 0.3798 - val_accuracy: 0.9097 - val_auc: 0.9500
# Epoch 73/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7922 - accuracy: 0.8169 - auc: 0.9021 - val_loss: 0.3764 - val_accuracy: 0.9081 - val_auc: 0.9495
# Epoch 74/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7888 - accuracy: 0.8223 - auc: 0.9020 - val_loss: 0.3804 - val_accuracy: 0.8986 - val_auc: 0.9472
# Epoch 75/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7419 - accuracy: 0.8343 - auc: 0.9079 - val_loss: 0.3618 - val_accuracy: 0.9065 - val_auc: 0.9483
# Epoch 76/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7371 - accuracy: 0.8386 - auc: 0.9001 - val_loss: 0.3883 - val_accuracy: 0.8970 - val_auc: 0.9459
# Epoch 77/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7234 - accuracy: 0.8243 - auc: 0.9117 - val_loss: 0.3365 - val_accuracy: 0.9017 - val_auc: 0.9483
# Epoch 78/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7645 - accuracy: 0.8247 - auc: 0.9034 - val_loss: 0.3916 - val_accuracy: 0.8875 - val_auc: 0.9447
# Epoch 79/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7401 - accuracy: 0.8266 - auc: 0.9084 - val_loss: 0.3723 - val_accuracy: 0.9049 - val_auc: 0.9491
# Epoch 80/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7531 - accuracy: 0.8217 - auc: 0.9050 - val_loss: 0.3884 - val_accuracy: 0.8986 - val_auc: 0.9457
# Epoch 81/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7626 - accuracy: 0.8159 - auc: 0.9113 - val_loss: 0.3970 - val_accuracy: 0.8906 - val_auc: 0.9440
# Epoch 82/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.7775 - accuracy: 0.8278 - auc: 0.9057 - val_loss: 0.3954 - val_accuracy: 0.8922 - val_auc: 0.9439
# Epoch 83/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7777 - accuracy: 0.8320 - auc: 0.9056 - val_loss: 0.3880 - val_accuracy: 0.8938 - val_auc: 0.9461
# Epoch 84/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7756 - accuracy: 0.8207 - auc: 0.9021 - val_loss: 0.3803 - val_accuracy: 0.9033 - val_auc: 0.9468
# Epoch 85/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.8183 - accuracy: 0.8199 - auc: 0.9038 - val_loss: 0.3723 - val_accuracy: 0.9002 - val_auc: 0.9480
# Epoch 86/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7514 - accuracy: 0.8275 - auc: 0.8998 - val_loss: 0.3665 - val_accuracy: 0.9017 - val_auc: 0.9499
# Epoch 87/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7415 - accuracy: 0.8419 - auc: 0.9111 - val_loss: 0.3723 - val_accuracy: 0.9049 - val_auc: 0.9491
# Epoch 88/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7684 - accuracy: 0.8185 - auc: 0.9008 - val_loss: 0.3822 - val_accuracy: 0.8986 - val_auc: 0.9466
# Epoch 89/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7733 - accuracy: 0.8299 - auc: 0.9019 - val_loss: 0.3846 - val_accuracy: 0.9002 - val_auc: 0.9464
# Epoch 90/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7898 - accuracy: 0.8243 - auc: 0.8964 - val_loss: 0.3852 - val_accuracy: 0.9049 - val_auc: 0.9476
# Epoch 91/100
# 40/40 [==============================] - 3s 65ms/step - loss: 0.7762 - accuracy: 0.8327 - auc: 0.8990 - val_loss: 0.3901 - val_accuracy: 0.9002 - val_auc: 0.9457
# Epoch 92/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7489 - accuracy: 0.8312 - auc: 0.9062 - val_loss: 0.3860 - val_accuracy: 0.9002 - val_auc: 0.9467
# Epoch 93/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7599 - accuracy: 0.8259 - auc: 0.8995 - val_loss: 0.3897 - val_accuracy: 0.9017 - val_auc: 0.9460
# Epoch 94/100
# 40/40 [==============================] - 2s 62ms/step - loss: 0.7665 - accuracy: 0.8384 - auc: 0.8983 - val_loss: 0.3725 - val_accuracy: 0.9081 - val_auc: 0.9491
# Epoch 95/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7728 - accuracy: 0.8169 - auc: 0.9060 - val_loss: 0.3690 - val_accuracy: 0.9033 - val_auc: 0.9488
# Epoch 96/100
# 40/40 [==============================] - 2s 63ms/step - loss: 0.7410 - accuracy: 0.8265 - auc: 0.9079 - val_loss: 0.3737 - val_accuracy: 0.9049 - val_auc: 0.9480
# Epoch 97/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7480 - accuracy: 0.8137 - auc: 0.9035 - val_loss: 0.3830 - val_accuracy: 0.9033 - val_auc: 0.9468
# Epoch 98/100
# 40/40 [==============================] - 3s 64ms/step - loss: 0.7610 - accuracy: 0.8175 - auc: 0.9040 - val_loss: 0.3819 - val_accuracy: 0.9017 - val_auc: 0.9459
# Epoch 99/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7683 - accuracy: 0.8261 - auc: 0.9071 - val_loss: 0.3812 - val_accuracy: 0.8986 - val_auc: 0.9460
# Epoch 100/100
# 40/40 [==============================] - 3s 63ms/step - loss: 0.7157 - accuracy: 0.8407 - auc: 0.9013 - val_loss: 0.3752 - val_accuracy: 0.9017 - val_auc: 0.9471

# %%
n_epoch = 100
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
batch_size = 64
params = {'batch_size': batch_size,
          #          'input_shape': (100, 313, 1),
          'shuffle': True,
          'chaug': 0,
          'beta_param': beta_param,
          'cout': cout,
#              'mixup': True,
          #          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
#            'highpass': [.5, [78,79,80,81,82,83,84,85]],
#              'ranfilter2' : [3, [18,19,20,21,22,23]]
        #           'dropblock' : [30, 100]
          #'device' : device
}



if mixup :
    params['mixup'] = mixup
    params['ranfilter2'] = ranfil
else :
    params['cutout'] = cout


params_no_shuffle = {'batch_size': batch_size,
                     #          'input_shape': (100, 313, 1),
                     'shuffle': False,
                     'beta_param': 0.7,
                     'mixup': False
                     #'device': device
}

class_weight = {0: oo_weight, 1: 1.}

if mixup :
    TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
                          features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                         out_lbs_trn,  ## our Y
                         **params)()

    model2.fit(TrainDGen_1,
               validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                                   features_test['preg'], features_test['loc'], features_test['mel1'], 
                                   features_test['cqt1'], features_test['stft1']], 
                                  out_lbs_test), 
               callbacks=[lr],
               steps_per_epoch=np.ceil(len(out_lbs_trn)/64),
               class_weight=class_weight, 
               epochs = n_epoch)
else :
    TrainGen = DataGenerator([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
                      features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                     out_lbs_trn,  ## our Y
                     **params)
    model2.fit(TrainGen,
               validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                                   features_test['preg'], features_test['loc'], features_test['mel1'], 
                                   features_test['cqt1'], features_test['stft1']], 
                                  out_lbs_test), 
               callbacks=[lr],
               class_weight=class_weight, 
               epochs = n_epoch)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 4s 77ms/step - loss: 1.6541 - accuracy: 0.4945 - auc: 0.4996 - val_loss: 10.9620 - val_accuracy: 0.5008 - val_auc: 0.5008
# Epoch 2/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2180 - accuracy: 0.4672 - auc: 0.4940 - val_loss: 0.7141 - val_accuracy: 0.6339 - val_auc: 0.6671
# Epoch 3/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2270 - accuracy: 0.4925 - auc: 0.5162 - val_loss: 0.9140 - val_accuracy: 0.5658 - val_auc: 0.6102
# Epoch 4/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.2247 - accuracy: 0.4861 - auc: 0.5178 - val_loss: 0.6965 - val_accuracy: 0.6022 - val_auc: 0.6304
# Epoch 5/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2131 - accuracy: 0.4735 - auc: 0.5100 - val_loss: 0.6775 - val_accuracy: 0.5420 - val_auc: 0.6110
# Epoch 6/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2149 - accuracy: 0.4798 - auc: 0.5219 - val_loss: 0.7312 - val_accuracy: 0.5341 - val_auc: 0.5933
# Epoch 7/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2108 - accuracy: 0.4715 - auc: 0.5117 - val_loss: 0.7174 - val_accuracy: 0.5024 - val_auc: 0.5948
# Epoch 8/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2204 - accuracy: 0.4827 - auc: 0.5126 - val_loss: 0.7188 - val_accuracy: 0.4992 - val_auc: 0.6071
# Epoch 9/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.2363 - accuracy: 0.5032 - auc: 0.5330 - val_loss: 0.6668 - val_accuracy: 0.5721 - val_auc: 0.6191
# Epoch 10/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2150 - accuracy: 0.4583 - auc: 0.5123 - val_loss: 0.7124 - val_accuracy: 0.4770 - val_auc: 0.5077
# Epoch 11/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2017 - accuracy: 0.4781 - auc: 0.5238 - val_loss: 0.6589 - val_accuracy: 0.5689 - val_auc: 0.6319
# Epoch 12/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2101 - accuracy: 0.4688 - auc: 0.5287 - val_loss: 0.7690 - val_accuracy: 0.4992 - val_auc: 0.5784
# Epoch 13/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2209 - accuracy: 0.4844 - auc: 0.5352 - val_loss: 0.7350 - val_accuracy: 0.4976 - val_auc: 0.6075
# Epoch 14/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2246 - accuracy: 0.4914 - auc: 0.5097 - val_loss: 0.7372 - val_accuracy: 0.4992 - val_auc: 0.5998
# Epoch 15/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1944 - accuracy: 0.4705 - auc: 0.5355 - val_loss: 0.8251 - val_accuracy: 0.4929 - val_auc: 0.5180
# Epoch 16/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2093 - accuracy: 0.4977 - auc: 0.5557 - val_loss: 0.7112 - val_accuracy: 0.5198 - val_auc: 0.5791
# Epoch 17/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2062 - accuracy: 0.4808 - auc: 0.5285 - val_loss: 0.9083 - val_accuracy: 0.4992 - val_auc: 0.5738
# Epoch 18/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2119 - accuracy: 0.5040 - auc: 0.5568 - val_loss: 0.7163 - val_accuracy: 0.5499 - val_auc: 0.6115
# Epoch 19/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2196 - accuracy: 0.4811 - auc: 0.5122 - val_loss: 0.7098 - val_accuracy: 0.5024 - val_auc: 0.5848
# Epoch 20/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2100 - accuracy: 0.4809 - auc: 0.5379 - val_loss: 0.6861 - val_accuracy: 0.5087 - val_auc: 0.5781
# Epoch 21/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2184 - accuracy: 0.4625 - auc: 0.5347 - val_loss: 0.6808 - val_accuracy: 0.5214 - val_auc: 0.6054
# Epoch 22/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2244 - accuracy: 0.4776 - auc: 0.5340 - val_loss: 0.6349 - val_accuracy: 0.6292 - val_auc: 0.6850
# Epoch 23/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.1996 - accuracy: 0.4994 - auc: 0.5572 - val_loss: 0.7155 - val_accuracy: 0.4992 - val_auc: 0.5990
# Epoch 24/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2246 - accuracy: 0.4861 - auc: 0.5303 - val_loss: 0.7002 - val_accuracy: 0.5246 - val_auc: 0.5836
# Epoch 25/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2149 - accuracy: 0.4891 - auc: 0.5321 - val_loss: 0.7375 - val_accuracy: 0.5024 - val_auc: 0.6059
# Epoch 26/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.2150 - accuracy: 0.4751 - auc: 0.5275 - val_loss: 0.7356 - val_accuracy: 0.4992 - val_auc: 0.6106
# Epoch 27/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1911 - accuracy: 0.4729 - auc: 0.5501 - val_loss: 0.7358 - val_accuracy: 0.4976 - val_auc: 0.5923
# Epoch 28/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2305 - accuracy: 0.5136 - auc: 0.5523 - val_loss: 0.7203 - val_accuracy: 0.5119 - val_auc: 0.5928
# Epoch 29/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.1976 - accuracy: 0.4841 - auc: 0.5533 - val_loss: 0.7117 - val_accuracy: 0.5008 - val_auc: 0.6031
# Epoch 30/100
# 40/40 [==============================] - 2s 61ms/step - loss: 1.1908 - accuracy: 0.4911 - auc: 0.5571 - val_loss: 0.6539 - val_accuracy: 0.6307 - val_auc: 0.6563
# Epoch 31/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.2124 - accuracy: 0.4788 - auc: 0.5317 - val_loss: 0.7001 - val_accuracy: 0.5008 - val_auc: 0.5484
# Epoch 32/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1830 - accuracy: 0.4909 - auc: 0.5580 - val_loss: 0.6695 - val_accuracy: 0.5468 - val_auc: 0.5951
# Epoch 33/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2287 - accuracy: 0.4941 - auc: 0.5360 - val_loss: 0.7905 - val_accuracy: 0.4992 - val_auc: 0.5734
# Epoch 34/100
# 40/40 [==============================] - 2s 61ms/step - loss: 1.2178 - accuracy: 0.5037 - auc: 0.5589 - val_loss: 0.7102 - val_accuracy: 0.5277 - val_auc: 0.5646
# Epoch 35/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2201 - accuracy: 0.4665 - auc: 0.5090 - val_loss: 0.6956 - val_accuracy: 0.5246 - val_auc: 0.5827
# Epoch 36/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2023 - accuracy: 0.5009 - auc: 0.5674 - val_loss: 0.6891 - val_accuracy: 0.4992 - val_auc: 0.6009
# Epoch 37/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2000 - accuracy: 0.4930 - auc: 0.5546 - val_loss: 0.7288 - val_accuracy: 0.4992 - val_auc: 0.6010
# Epoch 38/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2050 - accuracy: 0.4787 - auc: 0.5426 - val_loss: 0.7846 - val_accuracy: 0.4976 - val_auc: 0.5913
# Epoch 39/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1975 - accuracy: 0.4945 - auc: 0.5457 - val_loss: 0.6251 - val_accuracy: 0.6165 - val_auc: 0.6885
# Epoch 40/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1807 - accuracy: 0.4817 - auc: 0.5655 - val_loss: 0.7442 - val_accuracy: 0.4992 - val_auc: 0.5841
# Epoch 41/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.2030 - accuracy: 0.4907 - auc: 0.5497 - val_loss: 0.6373 - val_accuracy: 0.6403 - val_auc: 0.6863
# Epoch 42/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1834 - accuracy: 0.4767 - auc: 0.5519 - val_loss: 0.7523 - val_accuracy: 0.5008 - val_auc: 0.5933
# Epoch 43/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1929 - accuracy: 0.4810 - auc: 0.5439 - val_loss: 0.6635 - val_accuracy: 0.5357 - val_auc: 0.6013
# Epoch 44/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2212 - accuracy: 0.4910 - auc: 0.5399 - val_loss: 0.6487 - val_accuracy: 0.5753 - val_auc: 0.6393
# Epoch 45/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2109 - accuracy: 0.4919 - auc: 0.5445 - val_loss: 0.8569 - val_accuracy: 0.4992 - val_auc: 0.5997
# Epoch 46/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1957 - accuracy: 0.4880 - auc: 0.5662 - val_loss: 0.9101 - val_accuracy: 0.4992 - val_auc: 0.5208
# Epoch 47/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1753 - accuracy: 0.4933 - auc: 0.5686 - val_loss: 0.6362 - val_accuracy: 0.6244 - val_auc: 0.6811
# Epoch 48/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1942 - accuracy: 0.4692 - auc: 0.5435 - val_loss: 0.6368 - val_accuracy: 0.6244 - val_auc: 0.6805
# Epoch 49/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2062 - accuracy: 0.4958 - auc: 0.5417 - val_loss: 0.7655 - val_accuracy: 0.4992 - val_auc: 0.5901
# Epoch 50/100
# 40/40 [==============================] - 3s 65ms/step - loss: 1.1755 - accuracy: 0.5083 - auc: 0.5712 - val_loss: 0.6631 - val_accuracy: 0.5658 - val_auc: 0.6255
# Epoch 51/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1843 - accuracy: 0.5033 - auc: 0.5746 - val_loss: 0.6492 - val_accuracy: 0.6181 - val_auc: 0.6711
# Epoch 52/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1700 - accuracy: 0.4793 - auc: 0.5653 - val_loss: 0.7387 - val_accuracy: 0.5008 - val_auc: 0.5591
# Epoch 53/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.2004 - accuracy: 0.4772 - auc: 0.5529 - val_loss: 1.0047 - val_accuracy: 0.4992 - val_auc: 0.5854
# Epoch 54/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1936 - accuracy: 0.4830 - auc: 0.5544 - val_loss: 0.6666 - val_accuracy: 0.5578 - val_auc: 0.6077
# Epoch 55/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1911 - accuracy: 0.5136 - auc: 0.5735 - val_loss: 1.0160 - val_accuracy: 0.4992 - val_auc: 0.5234
# Epoch 56/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1919 - accuracy: 0.4940 - auc: 0.5686 - val_loss: 0.6925 - val_accuracy: 0.5103 - val_auc: 0.5913
# Epoch 57/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1855 - accuracy: 0.5193 - auc: 0.5896 - val_loss: 0.6335 - val_accuracy: 0.6181 - val_auc: 0.6771
# Epoch 58/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1895 - accuracy: 0.4935 - auc: 0.5625 - val_loss: 0.6815 - val_accuracy: 0.5230 - val_auc: 0.6062
# Epoch 59/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1920 - accuracy: 0.5128 - auc: 0.5773 - val_loss: 0.7311 - val_accuracy: 0.4976 - val_auc: 0.5941
# Epoch 60/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1901 - accuracy: 0.5079 - auc: 0.5788 - val_loss: 0.7108 - val_accuracy: 0.5040 - val_auc: 0.5912
# Epoch 61/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1788 - accuracy: 0.4936 - auc: 0.5702 - val_loss: 0.6888 - val_accuracy: 0.5087 - val_auc: 0.5977
# Epoch 62/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1838 - accuracy: 0.5034 - auc: 0.5712 - val_loss: 0.6340 - val_accuracy: 0.5848 - val_auc: 0.6607
# Epoch 63/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.1549 - accuracy: 0.5161 - auc: 0.6084 - val_loss: 0.6667 - val_accuracy: 0.5436 - val_auc: 0.6164
# Epoch 64/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1720 - accuracy: 0.5019 - auc: 0.5716 - val_loss: 0.6268 - val_accuracy: 0.6181 - val_auc: 0.6874
# Epoch 65/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1674 - accuracy: 0.5222 - auc: 0.5917 - val_loss: 0.6753 - val_accuracy: 0.5341 - val_auc: 0.6171
# Epoch 66/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1599 - accuracy: 0.5064 - auc: 0.5828 - val_loss: 0.7427 - val_accuracy: 0.5040 - val_auc: 0.5821
# Epoch 67/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1597 - accuracy: 0.5179 - auc: 0.5972 - val_loss: 0.7420 - val_accuracy: 0.5071 - val_auc: 0.6009
# Epoch 68/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1711 - accuracy: 0.5248 - auc: 0.5869 - val_loss: 0.6783 - val_accuracy: 0.5372 - val_auc: 0.6111
# Epoch 69/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1700 - accuracy: 0.4820 - auc: 0.5815 - val_loss: 0.6617 - val_accuracy: 0.5563 - val_auc: 0.6145
# Epoch 70/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1871 - accuracy: 0.5267 - auc: 0.5978 - val_loss: 0.6925 - val_accuracy: 0.5246 - val_auc: 0.5965
# Epoch 71/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.1770 - accuracy: 0.5113 - auc: 0.5824 - val_loss: 0.6922 - val_accuracy: 0.5166 - val_auc: 0.6016
# Epoch 72/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1533 - accuracy: 0.5031 - auc: 0.5906 - val_loss: 0.7940 - val_accuracy: 0.4992 - val_auc: 0.5706
# Epoch 73/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1783 - accuracy: 0.5241 - auc: 0.5921 - val_loss: 0.7145 - val_accuracy: 0.5119 - val_auc: 0.5899
# Epoch 74/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1615 - accuracy: 0.5038 - auc: 0.5756 - val_loss: 0.6962 - val_accuracy: 0.5214 - val_auc: 0.6062
# Epoch 75/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1781 - accuracy: 0.5070 - auc: 0.5919 - val_loss: 0.7189 - val_accuracy: 0.5230 - val_auc: 0.5951
# Epoch 76/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1837 - accuracy: 0.5422 - auc: 0.6001 - val_loss: 1.0213 - val_accuracy: 0.5008 - val_auc: 0.5285
# Epoch 77/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1964 - accuracy: 0.5059 - auc: 0.5777 - val_loss: 0.7464 - val_accuracy: 0.4992 - val_auc: 0.5843
# Epoch 78/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1560 - accuracy: 0.5212 - auc: 0.5839 - val_loss: 0.6757 - val_accuracy: 0.5499 - val_auc: 0.6163
# Epoch 79/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1491 - accuracy: 0.5025 - auc: 0.5937 - val_loss: 0.7132 - val_accuracy: 0.5230 - val_auc: 0.5964
# Epoch 80/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1432 - accuracy: 0.5172 - auc: 0.5906 - val_loss: 0.6913 - val_accuracy: 0.5325 - val_auc: 0.6059
# Epoch 81/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1907 - accuracy: 0.5122 - auc: 0.5796 - val_loss: 0.6997 - val_accuracy: 0.5246 - val_auc: 0.6004
# Epoch 82/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.1540 - accuracy: 0.5115 - auc: 0.5874 - val_loss: 0.6877 - val_accuracy: 0.5325 - val_auc: 0.6009
# Epoch 83/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.2018 - accuracy: 0.5342 - auc: 0.5878 - val_loss: 0.6593 - val_accuracy: 0.5674 - val_auc: 0.6284
# Epoch 84/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1722 - accuracy: 0.5129 - auc: 0.5951 - val_loss: 0.6852 - val_accuracy: 0.5341 - val_auc: 0.6035
# Epoch 85/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1722 - accuracy: 0.5406 - auc: 0.6044 - val_loss: 0.6892 - val_accuracy: 0.5357 - val_auc: 0.6050
# Epoch 86/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1437 - accuracy: 0.5076 - auc: 0.6016 - val_loss: 0.7106 - val_accuracy: 0.5151 - val_auc: 0.5921
# Epoch 87/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1630 - accuracy: 0.5078 - auc: 0.5937 - val_loss: 0.6859 - val_accuracy: 0.5309 - val_auc: 0.5992
# Epoch 88/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1931 - accuracy: 0.5165 - auc: 0.5885 - val_loss: 0.6812 - val_accuracy: 0.5277 - val_auc: 0.6037
# Epoch 89/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1811 - accuracy: 0.5038 - auc: 0.5774 - val_loss: 0.7120 - val_accuracy: 0.5182 - val_auc: 0.5926
# Epoch 90/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1768 - accuracy: 0.5020 - auc: 0.5809 - val_loss: 0.7099 - val_accuracy: 0.5151 - val_auc: 0.5935
# Epoch 91/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1739 - accuracy: 0.5065 - auc: 0.5710 - val_loss: 0.7156 - val_accuracy: 0.5103 - val_auc: 0.5905
# Epoch 92/100
# 40/40 [==============================] - 2s 63ms/step - loss: 1.1633 - accuracy: 0.5055 - auc: 0.6003 - val_loss: 0.7105 - val_accuracy: 0.5119 - val_auc: 0.5897
# Epoch 93/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1528 - accuracy: 0.4898 - auc: 0.5811 - val_loss: 0.7186 - val_accuracy: 0.5119 - val_auc: 0.5865
# Epoch 94/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1894 - accuracy: 0.5134 - auc: 0.5716 - val_loss: 0.6828 - val_accuracy: 0.5246 - val_auc: 0.6013
# Epoch 95/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1716 - accuracy: 0.5263 - auc: 0.6043 - val_loss: 0.7000 - val_accuracy: 0.5103 - val_auc: 0.5959
# Epoch 96/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1552 - accuracy: 0.5064 - auc: 0.6041 - val_loss: 0.7176 - val_accuracy: 0.5087 - val_auc: 0.5908
# Epoch 97/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1555 - accuracy: 0.5183 - auc: 0.6056 - val_loss: 0.6973 - val_accuracy: 0.5103 - val_auc: 0.5995
# Epoch 98/100
# 40/40 [==============================] - 3s 64ms/step - loss: 1.1320 - accuracy: 0.5023 - auc: 0.6078 - val_loss: 0.7186 - val_accuracy: 0.5087 - val_auc: 0.5917
# Epoch 99/100
# 40/40 [==============================] - 2s 62ms/step - loss: 1.1650 - accuracy: 0.5026 - auc: 0.5807 - val_loss: 0.7260 - val_accuracy: 0.5071 - val_auc: 0.5912
# Epoch 100/100
# 40/40 [==============================] - 3s 63ms/step - loss: 1.1714 - accuracy: 0.5163 - auc: 0.5868 - val_loss: 0.7233 - val_accuracy: 0.5071 - val_auc: 0.5925

# %%
params_feature['mel_shape'] = mel_input_shape
params_feature['cqt_shape'] = cqt_input_shape
params_feature['stft_shape'] = stft_input_shape

params_feature['use_mel'] = use_mel
params_feature['use_cqt'] = use_cqt
params_feature['use_stft'] = use_stft

save_challenge_model(model_folder, model1, model2, m_name1 = 'lcnn1_dr', m_name2 = 'lcnn2_dr', param_feature = params_feature)

run_model(model_folder, test_folder, output_folder, allow_failures = True, verbose = 1)

murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)
classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
','.join(classes),
','.join('{:.3f}'.format(x) for x in auroc_classes),
','.join('{:.3f}'.format(x) for x in auprc_classes),
','.join('{:.3f}'.format(x) for x in f_measure_classes),
','.join('{:.3f}'.format(x) for x in accuracy_classes))

params_feature['mm_weighted_accuracy'] = weighted_accuracy

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
','.join(classes),
','.join('{:.3f}'.format(x) for x in auroc_classes),
','.join('{:.3f}'.format(x) for x in auprc_classes),
','.join('{:.3f}'.format(x) for x in f_measure_classes),
','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
+ '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
# Out:
# Loading Challenge model...
# Running model on Challenge data...
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c60694440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb47ab8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d48199440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68421c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb410fb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6045c3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d407d7e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c681373b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68259e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c602489e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68318830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6078d8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c605018c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6061fc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d407d7b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6045c320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d482a18c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d482a1830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6061f680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6078d830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c60248680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb4651ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6846d7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb44a1c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c682a5830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c682a5560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8db9692b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d48199170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68137320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6846d8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6858da70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c606949e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8ce4582dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d407d79e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c607a8560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d407d7680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb45a58c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c603f5560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb43477a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8ce45b1ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c682a54d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c682a58c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d480c80e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d4015e8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d4015e5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6858d8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb45a5d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb45a5290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68567dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d480c80e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6045c200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb448eb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb46983b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68137f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c60496dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c60496440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6858dc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb45a5b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c60248a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb43bec20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb452b3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6040df80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d591abd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb448ef80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb4790830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d51e533b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb43479e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb4793050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb437ddd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb47479e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb4793ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c680f7a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c6858d290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb4790f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c606ce290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb4103b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb42bd560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8d54621320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8ce4049d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8c68137680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb47470e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb40ca680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb43475f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb437d050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8cb437d950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Done.

# %%
print(output_string)
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.767,0.619,0.544,0.817,0.798,17571.442
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.713,0.709,0.514,0.581,0.815,11846.100
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.958,0.500,0.842
# AUPRC,0.886,0.073,0.897
# F-measure,0.753,0.000,0.880
# Accuracy,0.921,0.000,0.871
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.713,0.713
# AUPRC,0.751,0.667
# F-measure,0.695,0.333
# Accuracy,0.929,0.215
