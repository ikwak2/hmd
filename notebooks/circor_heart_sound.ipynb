# %% [markdown]
# <a href="https://colab.research.google.com/github/ikwak2/hmd/blob/main/notebooks/circor_heart_sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The dataset: https://physionet.org/content/circor-heart-sound/1.0.1/

# %%
# !wget -r -N -c -np https://physionet.org/files/circor-heart-sound/1.0.1/
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 159916 (156K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85270_TV.wav’
#
# physionet.org/files 100%[===================>] 156.17K  --.-KB/s    in 0.008s
#
# 2022-02-23 23:12:31 (20.0 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85270_TV.wav’ saved [159916/159916]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85276.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 570 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276.txt’
#
# physionet.org/files 100%[===================>]     570  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (89.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276.txt’ saved [570/570]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (8.78 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1193 (1.2K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.tsv’
#
# physionet.org/files 100%[===================>]   1.17K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (202 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.tsv’ saved [1193/1193]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 166316 (162K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.wav’
#
# physionet.org/files 100%[===================>] 162.42K  --.-KB/s    in 0.007s
#
# 2022-02-23 23:12:31 (23.1 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85276_MV.wav’ saved [166316/166316]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 682 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277.txt’
#
# physionet.org/files 100%[===================>]     682  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (109 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277.txt’ saved [682/682]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (9.39 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.hea’ saved [59/59]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1171 (1.1K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.tsv’
#
# physionet.org/files 100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (169 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.tsv’ saved [1171/1171]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 160812 (157K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.wav’
#
# physionet.org/files 100%[===================>] 157.04K  --.-KB/s    in 0.004s
#
# 2022-02-23 23:12:31 (37.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_AV.wav’ saved [160812/160812]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (10.2 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2847 (2.8K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.tsv’
#
# physionet.org/files 100%[===================>]   2.78K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:31 (459 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.tsv’ saved [2847/2847]
#
# --2022-02-23 23:12:31--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158380 (155K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.wav’
#
# physionet.org/files 100%[===================>] 154.67K  --.-KB/s    in 0.007s
#
# 2022-02-23 23:12:32 (22.9 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_MV.wav’ saved [158380/158380]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (8.40 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.hea’ saved [59/59]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1983 (1.9K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.tsv’
#
# physionet.org/files 100%[===================>]   1.94K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (318 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.tsv’ saved [1983/1983]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 168492 (165K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.wav’
#
# physionet.org/files 100%[===================>] 164.54K  --.-KB/s    in 0.004s
#
# 2022-02-23 23:12:32 (39.6 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_PV.wav’ saved [168492/168492]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (10.1 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.hea’ saved [59/59]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2525 (2.5K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.tsv’
#
# physionet.org/files 100%[===================>]   2.47K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (364 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.tsv’ saved [2525/2525]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 159916 (156K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.wav’
#
# physionet.org/files 100%[===================>] 156.17K  --.-KB/s    in 0.005s
#
# 2022-02-23 23:12:32 (27.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85277_TV.wav’ saved [159916/159916]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 682 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278.txt’
#
# physionet.org/files 100%[===================>]     682  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (140 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278.txt’ saved [682/682]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (9.44 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.hea’ saved [59/59]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 767 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.tsv’
#
# physionet.org/files 100%[===================>]     767  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (111 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.tsv’ saved [767/767]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 103212 (101K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.wav’
#
# physionet.org/files 100%[===================>] 100.79K  --.-KB/s    in 0.003s
#
# 2022-02-23 23:12:32 (37.2 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_AV.wav’ saved [103212/103212]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.hea’
#
# physionet.org/files 100%[===================>]      60  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (10.6 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.hea’ saved [60/60]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1778 (1.7K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.tsv’
#
# physionet.org/files 100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (283 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.tsv’ saved [1778/1778]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 202284 (198K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.wav’
#
# physionet.org/files 100%[===================>] 197.54K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:12:32 (6.69 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_MV.wav’ saved [202284/202284]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (10.0 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.hea’ saved [59/59]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1775 (1.7K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.tsv’
#
# physionet.org/files 100%[===================>]   1.73K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (265 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.tsv’ saved [1775/1775]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 116780 (114K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.wav’
#
# physionet.org/files 100%[===================>] 114.04K  --.-KB/s    in 0.004s
#
# 2022-02-23 23:12:32 (29.6 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_PV.wav’ saved [116780/116780]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (11.1 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.hea’ saved [59/59]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 879 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.tsv’
#
# physionet.org/files 100%[===================>]     879  --.-KB/s    in 0s
#
# 2022-02-23 23:12:32 (133 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.tsv’ saved [879/879]
#
# --2022-02-23 23:12:32--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143148 (140K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.wav’
#
# physionet.org/files 100%[===================>] 139.79K  --.-KB/s    in 0.007s
#
# 2022-02-23 23:12:33 (18.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85278_TV.wav’ saved [143148/143148]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 681 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279.txt’
#
# physionet.org/files 100%[===================>]     681  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (118 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279.txt’ saved [681/681]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (9.60 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.hea’ saved [59/59]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1269 (1.2K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.tsv’
#
# physionet.org/files 100%[===================>]   1.24K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (198 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.tsv’ saved [1269/1269]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 179628 (175K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.wav’
#
# physionet.org/files 100%[===================>] 175.42K  --.-KB/s    in 0.007s
#
# 2022-02-23 23:12:33 (23.4 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_AV.wav’ saved [179628/179628]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (7.66 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2658 (2.6K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.tsv’
#
# physionet.org/files 100%[===================>]   2.60K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (464 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.tsv’ saved [2658/2658]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 195884 (191K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.wav’
#
# physionet.org/files 100%[===================>] 191.29K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:12:33 (6.22 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_MV.wav’ saved [195884/195884]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (7.48 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.hea’ saved [59/59]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1421 (1.4K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.tsv’
#
# physionet.org/files 100%[===================>]   1.39K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (135 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.tsv’ saved [1421/1421]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 159660 (156K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.wav’
#
# physionet.org/files 100%[===================>] 155.92K  --.-KB/s    in 0.006s
#
# 2022-02-23 23:12:33 (24.2 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_PV.wav’ saved [159660/159660]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.hea’
#
# physionet.org/files 100%[===================>]      60  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (17.3 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.hea’ saved [60/60]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1947 (1.9K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.tsv’
#
# physionet.org/files 100%[===================>]   1.90K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (542 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.tsv’ saved [1947/1947]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 251180 (245K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.wav’
#
# physionet.org/files 100%[===================>] 245.29K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:12:33 (7.17 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85279_TV.wav’ saved [251180/251180]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 681 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282.txt’
#
# physionet.org/files 100%[===================>]     681  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (193 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282.txt’ saved [681/681]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (16.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.hea’ saved [59/59]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1016 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.tsv’
#
# physionet.org/files 100%[===================>]    1016  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (238 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.tsv’ saved [1016/1016]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 77228 (75K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.wav’
#
# physionet.org/files 100%[===================>]  75.42K  --.-KB/s    in 0.003s
#
# 2022-02-23 23:12:33 (28.6 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_AV.wav’ saved [77228/77228]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:33 (19.1 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:33--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2893 (2.8K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.tsv’
#
# physionet.org/files 100%[===================>]   2.83K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (432 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.tsv’ saved [2893/2893]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 175148 (171K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.wav’
#
# physionet.org/files 100%[===================>] 171.04K  --.-KB/s    in 0.01s
#
# 2022-02-23 23:12:34 (15.3 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_MV.wav’ saved [175148/175148]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (8.81 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.hea’ saved [59/59]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 819 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.tsv’
#
# physionet.org/files 100%[===================>]     819  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (129 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.tsv’ saved [819/819]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 108460 (106K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.wav’
#
# physionet.org/files 100%[===================>] 105.92K  --.-KB/s    in 0.005s
#
# 2022-02-23 23:12:34 (21.3 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_PV.wav’ saved [108460/108460]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (9.37 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.hea’ saved [59/59]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2288 (2.2K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.tsv’
#
# physionet.org/files 100%[===================>]   2.23K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (333 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.tsv’ saved [2288/2288]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 135724 (133K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.wav’
#
# physionet.org/files 100%[===================>] 132.54K  --.-KB/s    in 0.005s
#
# 2022-02-23 23:12:34 (24.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85282_TV.wav’ saved [135724/135724]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 681 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285.txt’
#
# physionet.org/files 100%[===================>]     681  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (102 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285.txt’ saved [681/681]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (10.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.hea’ saved [59/59]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 561 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.tsv’
#
# physionet.org/files 100%[===================>]     561  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (96.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.tsv’ saved [561/561]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 171692 (168K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.wav’
#
# physionet.org/files 100%[===================>] 167.67K  --.-KB/s    in 0.005s
#
# 2022-02-23 23:12:34 (34.3 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_AV.wav’ saved [171692/171692]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (19.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.tsv
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1761 (1.7K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.tsv’
#
# physionet.org/files 100%[===================>]   1.72K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:34 (295 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.tsv’ saved [1761/1761]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169516 (166K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.wav’
#
# physionet.org/files 100%[===================>] 165.54K  --.-KB/s    in 0.07s
#
# 2022-02-23 23:12:34 (2.38 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_MV.wav’ saved [169516/169516]
#
# --2022-02-23 23:12:34--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (10.4 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.hea’ saved [59/59]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1489 (1.5K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.tsv’
#
# physionet.org/files 100%[===================>]   1.45K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (210 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.tsv’ saved [1489/1489]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 164012 (160K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.wav’
#
# physionet.org/files 100%[===================>] 160.17K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:12:35 (5.34 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_PV.wav’ saved [164012/164012]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.hea’
#
# physionet.org/files 100%[===================>]      60  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (12.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.hea’ saved [60/60]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2728 (2.7K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.tsv’
#
# physionet.org/files 100%[===================>]   2.66K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (711 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.tsv’ saved [2728/2728]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 248364 (243K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.wav’
#
# physionet.org/files 100%[===================>] 242.54K  --.-KB/s    in 0.04s
#
# 2022-02-23 23:12:35 (5.96 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85285_TV.wav’ saved [248364/248364]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 682 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286.txt’
#
# physionet.org/files 100%[===================>]     682  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (205 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286.txt’ saved [682/682]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (18.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.hea’ saved [59/59]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2788 (2.7K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.tsv’
#
# physionet.org/files 100%[===================>]   2.72K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (720 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.tsv’ saved [2788/2788]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 161324 (158K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.wav’
#
# physionet.org/files 100%[===================>] 157.54K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:12:35 (5.43 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_AV.wav’ saved [161324/161324]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (18.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2309 (2.3K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.tsv’
#
# physionet.org/files 100%[===================>]   2.25K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (384 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.tsv’ saved [2309/2309]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 159276 (156K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.wav’
#
# physionet.org/files 100%[===================>] 155.54K  --.-KB/s    in 0.04s
#
# 2022-02-23 23:12:35 (4.08 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_MV.wav’ saved [159276/159276]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (16.5 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.hea’ saved [59/59]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2510 (2.5K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.tsv’
#
# physionet.org/files 100%[===================>]   2.45K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:35 (622 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.tsv’ saved [2510/2510]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181292 (177K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.wav’
#
# physionet.org/files 100%[===================>] 177.04K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:12:35 (5.74 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_PV.wav’ saved [181292/181292]
#
# --2022-02-23 23:12:35--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (18.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.hea’ saved [59/59]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2289 (2.2K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.tsv’
#
# physionet.org/files 100%[===================>]   2.24K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (349 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.tsv’ saved [2289/2289]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 128044 (125K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.wav’
#
# physionet.org/files 100%[===================>] 125.04K  --.-KB/s    in 0.005s
#
# 2022-02-23 23:12:36 (26.2 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85286_TV.wav’ saved [128044/128044]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 640 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287.txt’
#
# physionet.org/files 100%[===================>]     640  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (108 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287.txt’ saved [640/640]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (9.68 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.hea’ saved [59/59]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2051 (2.0K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.tsv’
#
# physionet.org/files 100%[===================>]   2.00K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (365 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.tsv’ saved [2051/2051]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 160428 (157K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.wav’
#
# physionet.org/files 100%[===================>] 156.67K  --.-KB/s    in 0.006s
#
# 2022-02-23 23:12:36 (27.4 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_MV.wav’ saved [160428/160428]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 60 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.hea’
#
# physionet.org/files 100%[===================>]      60  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (11.6 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.hea’ saved [60/60]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2349 (2.3K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.tsv’
#
# physionet.org/files 100%[===================>]   2.29K  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (370 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.tsv’ saved [2349/2349]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 221612 (216K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.wav’
#
# physionet.org/files 100%[===================>] 216.42K  --.-KB/s    in 0.04s
#
# 2022-02-23 23:12:36 (4.96 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_PV.wav’ saved [221612/221612]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_TV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:12:36 (10.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_TV.hea’ saved [59/59]
#
# --2022-02-23 23:12:36--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1317 (1.3K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85287_TV.tsv’
#
# physionet.org/files 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# ...
#
# physionet.org/files 100%[===================>]     817  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (136 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_PV.tsv’ saved [817/817]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158892 (155K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_PV.wav’
#
# physionet.org/files 100%[===================>] 155.17K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:01 (5.35 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_PV.wav’ saved [158892/158892]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.hea’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (10.0 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.hea’ saved [59/59]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 677 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.tsv’
#
# physionet.org/files 100%[===================>]     677  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (117 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.tsv’ saved [677/677]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 157228 (154K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.wav’
#
# physionet.org/files 100%[===================>] 153.54K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:01 (5.28 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/85349_TV.wav’ saved [157228/157228]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 697 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979.txt’
#
# physionet.org/files 100%[===================>]     697  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (121 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979.txt’ saved [697/697]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (6.77 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.hea’ saved [57/57]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 616 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.tsv’
#
# physionet.org/files 100%[===================>]     616  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (80.0 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.tsv’ saved [616/616]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 145324 (142K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.wav’
#
# physionet.org/files 100%[===================>] 141.92K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:01 (4.83 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_AV.wav’ saved [145324/145324]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (7.85 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.hea’ saved [57/57]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1777 (1.7K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.tsv’
#
# physionet.org/files 100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (377 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.tsv’ saved [1777/1777]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169260 (165K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.wav’
#
# physionet.org/files 100%[===================>] 165.29K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:01 (5.54 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_MV.wav’ saved [169260/169260]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (8.85 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.hea’ saved [57/57]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1327 (1.3K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.tsv’
#
# physionet.org/files 100%[===================>]   1.30K  --.-KB/s    in 0s
#
# 2022-02-23 23:13:01 (181 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.tsv’ saved [1327/1327]
#
# --2022-02-23 23:13:01--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 162092 (158K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.wav’
#
# physionet.org/files 100%[===================>] 158.29K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:02 (5.34 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_PV.wav’ saved [162092/162092]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (11.8 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.hea’ saved [57/57]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 685 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.tsv’
#
# physionet.org/files 100%[===================>]     685  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (98.1 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.tsv’ saved [685/685]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 183212 (179K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.wav’
#
# physionet.org/files 100%[===================>] 178.92K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:02 (5.90 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9979_TV.wav’ saved [183212/183212]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 669 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983.txt’
#
# physionet.org/files 100%[===================>]     669  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (66.0 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983.txt’ saved [669/669]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (7.17 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.hea’ saved [57/57]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 713 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.tsv’
#
# physionet.org/files 100%[===================>]     713  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (135 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.tsv’ saved [713/713]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 184492 (180K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.wav’
#
# physionet.org/files 100%[===================>] 180.17K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:02 (5.81 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_AV.wav’ saved [184492/184492]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (9.39 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.hea’ saved [57/57]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 813 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.tsv’
#
# physionet.org/files 100%[===================>]     813  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (108 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.tsv’ saved [813/813]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 159660 (156K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.wav’
#
# physionet.org/files 100%[===================>] 155.92K  --.-KB/s    in 0.008s
#
# 2022-02-23 23:13:02 (18.6 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_MV.wav’ saved [159660/159660]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 58 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.hea’
#
# physionet.org/files 100%[===================>]      58  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (2.69 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.hea’ saved [58/58]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 661 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.tsv’
#
# physionet.org/files 100%[===================>]     661  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (16.0 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.tsv’ saved [661/661]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 213292 (208K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.wav’
#
# physionet.org/files 100%[===================>] 208.29K  --.-KB/s    in 0.03s
#
# 2022-02-23 23:13:02 (6.40 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_PV.wav’ saved [213292/213292]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (8.43 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.hea’ saved [57/57]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.tsv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674 [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.tsv’
#
# physionet.org/files 100%[===================>]     674  --.-KB/s    in 0s
#
# 2022-02-23 23:13:02 (109 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.tsv’ saved [674/674]
#
# --2022-02-23 23:13:02--  https://physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.wav
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158380 (155K) [text/plain]
# Saving to: ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.wav’
#
# physionet.org/files 100%[===================>] 154.67K  --.-KB/s    in 0.006s
#
# 2022-02-23 23:13:02 (26.4 MB/s) - ‘physionet.org/files/circor-heart-sound/1.0.1/training_data/9983_TV.wav’ saved [158380/158380]
#
# FINISHED --2022-02-23 23:13:02--
# Total wall clock time: 10m 22s
# Downloaded: 10438 files, 560M in 1m 9s (8.10 MB/s)

# %%
import os
import pandas as pd

# %%
data_dir = '/content/physionet.org/files/circor-heart-sound/1.0.1'
training_data_file = data_dir + '/' + 'training_data.csv'
os.listdir(data_dir)
# Out:
# ['training_data.csv',
#  'LICENSE.txt',
#  'RECORDS',
#  'index.html',
#  'training_data',
#  'SHA256SUMS.txt']

# %%
df = pd.read_csv(training_data_file)
df
# Out:
#      Patient ID    Locations  ... Campaign Additional ID
# 0          2530  AV+PV+TV+MV  ...   CC2015           NaN
# 1          9979  AV+PV+TV+MV  ...   CC2015           NaN
# 2          9983  AV+PV+TV+MV  ...   CC2015           NaN
# 3         13918  AV+PV+TV+MV  ...   CC2015           NaN
# 4         14241  AV+PV+TV+MV  ...   CC2015           NaN
# ..          ...          ...  ...      ...           ...
# 937       85340  AV+PV+TV+MV  ...   CC2015           NaN
# 938       85341  AV+PV+TV+MV  ...   CC2015           NaN
# 939       85343  AV+PV+TV+MV  ...   CC2015           NaN
# 940       85345        AV+PV  ...   CC2015           NaN
# 941       85349     AV+PV+TV  ...   CC2015           NaN
#
# [942 rows x 22 columns]

# %%
df.dtypes
# Out:
# Patient ID                    int64
# Locations                    object
# Age                          object
# Sex                          object
# Height                      float64
# Weight                      float64
# Pregnancy status               bool
# Murmur                       object
# Murmur locations             object
# Most audible location        object
# Systolic murmur timing       object
# Systolic murmur shape        object
# Systolic murmur grading      object
# Systolic murmur pitch        object
# Systolic murmur quality      object
# Diastolic murmur timing      object
# Diastolic murmur shape       object
# Diastolic murmur grading     object
# Diastolic murmur pitch       object
# Diastolic murmur quality     object
# Campaign                     object
# Additional ID               float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Patient ID', 'Locations', 'Age', 'Sex', 'Height', 'Weight',
#        'Pregnancy status', 'Murmur', 'Murmur locations',
#        'Most audible location', 'Systolic murmur timing',
#        'Systolic murmur shape', 'Systolic murmur grading',
#        'Systolic murmur pitch', 'Systolic murmur quality',
#        'Diastolic murmur timing', 'Diastolic murmur shape',
#        'Diastolic murmur grading', 'Diastolic murmur pitch',
#        'Diastolic murmur quality', 'Campaign', 'Additional ID'],
#       dtype='object')

# %%
# summary of NA's in each column
df.isnull().sum()
# Out:
# Patient ID                    0
# Locations                     0
# Age                          74
# Sex                           0
# Height                      116
# Weight                      105
# Pregnancy status              0
# Murmur                        0
# Murmur locations            763
# Most audible location       763
# Systolic murmur timing      764
# Systolic murmur shape       764
# Systolic murmur grading     764
# Systolic murmur pitch       764
# Systolic murmur quality     764
# Diastolic murmur timing     937
# Diastolic murmur shape      937
# Diastolic murmur grading    937
# Diastolic murmur pitch      937
# Diastolic murmur quality    937
# Campaign                      0
# Additional ID               802
# dtype: int64

# %%
df['Murmur'].value_counts().plot.bar()

# %%
df.value_counts(['Murmur', 'Locations'], normalize = True)
# Out:
# Murmur   Locations
# Absent   AV+PV+TV+MV          0.485138
# Present  AV+PV+TV+MV          0.123142
# Absent   AV+MV                0.075372
#          PV+TV+MV             0.054140
#          AV+PV+TV             0.025478
# Unknown  AV+MV                0.024416
# Absent   MV                   0.023355
# Present  AV+MV                0.022293
#          PV+TV+MV             0.014862
# Absent   AV+PV                0.013800
# Unknown  AV+PV+TV+MV          0.013800
# Absent   PV+TV                0.012739
# Present  MV                   0.010616
# Absent   AV+PV+MV             0.008493
#          PV                   0.008493
# Unknown  PV+TV+MV             0.006369
# Absent   AV                   0.006369
# Unknown  MV                   0.005308
# Absent   AV+TV+MV             0.005308
# Unknown  PV                   0.004246
# Present  AV+PV+TV             0.004246
# Unknown  TV                   0.004246
# Present  AV+PV                0.003185
# Absent   PV+MV                0.003185
# Unknown  AV+PV+MV             0.003185
# Absent   AV+PV+TV+MV+MV       0.003185
#          AV+PV+TV+TV+MV       0.003185
# Unknown  AV                   0.003185
#          PV+MV                0.002123
# Present  AV+PV+MV             0.002123
# Unknown  PV+TV                0.002123
# Present  PV+MV                0.002123
# Unknown  AV+PV                0.002123
# Absent   AV+MV+MV             0.001062
#          AV+AV+PV+TV+MV       0.001062
#          AV+AV+PV+TV+MV+MV    0.001062
# Unknown  AV+PV+TV             0.001062
# Absent   AV+AV+MV             0.001062
#          AV+AV+MV+MV          0.001062
#          TV+MV                0.001062
# Present  TV+MV+Phc            0.001062
#          AV+AV+PV+PV+TV+MV    0.001062
# Absent   AV+PV+MV+Phc+Phc     0.001062
# Present  AV+TV+MV             0.001062
#          AV+PV+TV+TV+MV       0.001062
#          AV+PV+TV+MV+Phc      0.001062
#          AV+PV+PV+TV+TV+MV    0.001062
# Absent   AV+AV+AV+MV          0.001062
#          PV+TV+TV             0.001062
# Present  TV+MV                0.001062
# dtype: float64

# %%
df['Age'].value_counts().plot.bar()

# %%
df['Sex'].value_counts().plot.bar()
