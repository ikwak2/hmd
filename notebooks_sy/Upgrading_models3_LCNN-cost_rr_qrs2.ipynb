# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# /tmp/ipykernel_79390/912229180.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## LCNN

# %%
pwd
# Out:
# '/Data2/hmd/hmd_sy/notebooks'

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats
import librosa
import librosa.display
import math
import sys
#sys.path.insert(0,'/home/ikwak2/hmd/notebooks')
#sys.path.insert(0,'/home/ikwak2/hmd/iy_classifier')
sys.path.insert(0,'/Data2/hmd/hmd_sy/evaluation-2022')
sys.path.insert(0,'utils')
from helper_code import *
from get_feature import *
from models import *
from Generator0 import *
import tensorflow as tf
import datetime
from evaluate_model import *
# Out:
# 2022-07-30 03:57:20.673389: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
root_dir = 'physionet.org/files/circor-heart-sound/1.0.3'
training_data_file = root_dir + '/' + 'training_data.csv'
training_data_dir = root_dir + '/' + 'training_data'
model_dir = root_dir + '/' + 'model'

# %%
import tensorflow as tf

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
print(gpu_info)
# Out:
# Sat Jul 30 03:57:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |   4819MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Quadro RTX 8000     On   | 00000000:3D:00.0 Off |                  Off |
# | 33%   27C    P8     6W / 260W |   3310MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Quadro RTX 8000     On   | 00000000:3E:00.0 Off |                  Off |
# | 33%   28C    P8    12W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Quadro RTX 8000     On   | 00000000:40:00.0 Off |                  Off |
# | 33%   27C    P8     7W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Quadro RTX 8000     On   | 00000000:41:00.0 Off |                  Off |
# | 48%   70C    P2   249W / 260W |  48121MiB / 48601MiB |     93%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[3], 'GPU')
    except RuntimeError as e:
        print(e)
# Out:
# 2022-07-30 03:57:33.037462: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-07-30 03:57:33.122827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1a:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 03:57:33.124639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3d:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 03:57:33.126455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:3e:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 03:57:33.128252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:40:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 03:57:33.128994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:41:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 03:57:33.129054: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-07-30 03:57:33.164397: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-07-30 03:57:33.164562: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-07-30 03:57:33.176644: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-07-30 03:57:33.181721: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-07-30 03:57:33.188406: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-07-30 03:57:33.195562: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-07-30 03:57:33.197101: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-07-30 03:57:33.227041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4

# %%
data_folder =  '/Data2/hmd/physionet.org/files/circor-heart-sound/1.0.3/training_data'
train_folder =  '/Data2/hmd/data_split/murmur/train'
test_folder = '/Data2/hmd/data_split/murmur/test'

# %% [markdown]
# ## QRS_Utils

# %%
## detect QRS complex from ECG time series

import numpy as np 
import math
from numpy import genfromtxt
import matplotlib.pyplot as plt

def read_ecg(file_name):
	return genfromtxt(file_name, delimiter=',')

def lgth_transform(ecg, ws):
	lgth=ecg.shape[0]
	sqr_diff=np.zeros(lgth)
	diff=np.zeros(lgth)
	ecg=np.pad(ecg, ws, 'edge')
	for i in range(lgth):
		temp=ecg[i:i+ws+ws+1]
		left=temp[ws]-temp[0]
		right=temp[ws]-temp[-1]
		diff[i]=min(left, right)
		diff[diff<0]=0
	# sqr_diff=np.multiply(diff, diff)
	# diff=ecg[:-1]-ecg[1:]
	# sqr_diff[:-1]=np.multiply(diff, diff)
	# sqr_diff[-1]=sqr_diff[-2]
	return np.multiply(diff, diff)

def integrate(ecg, ws):
	lgth=ecg.shape[0]
	integrate_ecg=np.zeros(lgth)
	ecg=np.pad(ecg, math.ceil(ws/2), mode='symmetric')
	for i in range(lgth):
		integrate_ecg[i]=np.sum(ecg[i:i+ws])/ws
	return integrate_ecg

def find_peak(data, ws):
	lgth=data.shape[0]
	true_peaks=list()
	for i in range(lgth-ws+1):
		temp=data[i:i+ws]
		if np.var(temp)<5:
			continue
		index=int((ws-1)/2)
		peak=True
		for j in range(index):
			if temp[index-j]<=temp[index-j-1] or temp[index+j]<=temp[index+j+1]:
				peak=False
				break

		if peak is True:
			true_peaks.append(int(i+(ws-1)/2))
	return np.asarray(true_peaks)

def find_R_peaks(ecg, peaks, ws):
	num_peak=peaks.shape[0]
	R_peaks=list()
	for index in range(num_peak):
		i=peaks[index]
		if i-2*ws>0 and i<ecg.shape[0]:
			temp_ecg=ecg[i-2*ws:i]
			R_peaks.append(int(np.argmax(temp_ecg)+i-2*ws))
	return np.asarray(R_peaks)

def find_S_point(ecg, R_peaks):
	num_peak=R_peaks.shape[0]
	S_point=list()
	for index in range(num_peak):
		i=R_peaks[index]
		cnt=i
		if cnt+1>=ecg.shape[0]:
			break
		while ecg[cnt]>ecg[cnt+1]:
			cnt+=1
			if cnt>=ecg.shape[0]:
				break
		S_point.append(cnt)
	return np.asarray(S_point)


def find_Q_point(ecg, R_peaks):
	num_peak=R_peaks.shape[0]
	Q_point=list()
	for index in range(num_peak):
		i=R_peaks[index]
		cnt=i
		if cnt-1<0:
			break
		while ecg[cnt]>ecg[cnt-1]:
			cnt-=1
			if cnt<0:
				break
		Q_point.append(cnt)
	return np.asarray(Q_point)

# QRS 계산하는 함수
def EKG_QRS_detect1(ecg, fs, QS, plot=False):
	sig_lgth=ecg.shape[0]
	ecg=ecg-np.mean(ecg)
	ecg_lgth_transform=lgth_transform(ecg, int(fs/222))
	# ecg_lgth_transform=lgth_transform(ecg_lgth_transform, int(fs/40))

	ws=int(fs/89)
	ecg_integrate=integrate(ecg_lgth_transform, ws)/ws
	ws=int(fs/67)
	ecg_integrate=integrate(ecg_integrate, ws)
	ws=int(fs/400)
	ecg_integrate=integrate(ecg_integrate, ws)
	ws=int(fs/800)
	ecg_integrate=integrate(ecg_integrate, ws)

	peaks=find_peak(ecg_integrate, int(fs/111))
	R_peaks=find_R_peaks(ecg, peaks, int(fs/444))
	if QS:
		S_point=find_S_point(ecg, R_peaks)
		Q_point=find_Q_point(ecg, R_peaks)
	else:
		S_point=None
		Q_point=None
	if plot:
		index=np.arange(sig_lgth)/fs
		fig, ax=plt.subplots()
		ax.plot(index, ecg, 'b', label='EKG')
		ax.plot(R_peaks/fs, ecg[R_peaks], 'ro', label='R peaks')
		if QS:
			ax.plot(S_point/fs, ecg[S_point], 'go', label='S')
			ax.plot(Q_point/fs, ecg[Q_point], 'yo', label='Q')
		ax.set_xlim([0, sig_lgth/fs])
		ax.set_xlabel('Time [sec]')
		ax.legend()
		# ax[1].plot(ecg_integrate)
		# ax[1].set_xlim([0, ecg_integrate.shape[0]])
		# ax[2].plot(ecg_lgth_transform)
		# ax[2].set_xlim([0, ecg_lgth_transform.shape[0]])
		plt.figure(figsize=(20,45))
		plt.show()
	return R_peaks, S_point, Q_point

# %% [markdown]
# ## Modeling

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint

# %%
def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start
    elif e > end:
        return lr_end

    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))

    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

# %% [markdown]
# ### get feature 함수확장: 음성피쳐 옵션들과, 추가 음성들 고려한 피쳐추출

# %%
patient_files_trn = find_patient_files(train_folder)
patient_files_test = find_patient_files(test_folder)

# %%
pwd
# Out:
# '/Data2/hmd/hmd_sy/notebooks'

# %%
model_folder = 'lcnn__rr_qrs2'
output_folder = '/Data2/hmd/hmd_sy/notebooks/out_lcnn__rr_qrs2'

# %%
def get_features_3lb_all_ord_rr_qrs(data_folder, patient_files_trn, po = .3,
                          samp_sec=20, pre_emphasis = 0, hop_length=256, win_length = 512, n_mels = 100,
                             filter_scale = 1, n_bins = 80, fmin = 10, trim = 4000,
                             use_mel = True, use_cqt = False, use_stft = False, use_raw = False,
                             use_rr = False, use_qrs=False
                         ) :
    features = dict()
    features['id'] = []
    features['age'] = []
    features['sex'] = []
    features['hw'] = []
    features['preg'] = []
    features['loc'] = []
    features['mel1'] = []
    features['cqt1'] = []
    features['stft1'] = []
    features['raw1'] = []
    features['rr1'] = []
    features['qrs1'] = []
    
    mm_labels = []
    out_labels = []

    age_classes = ['Neonate', 'Infant', 'Child', 'Adolescent', 'Young Adult']
    recording_locations = ['AV', 'MV', 'PV', 'TV', 'PhC']

    num_patient_files = len(patient_files_trn)

    for i in tqdm.tqdm(range(num_patient_files)) :

        # Load the current patient data and recordings.
        current_patient_data = load_patient_data(patient_files_trn[i])
        num_locations = get_num_locations(current_patient_data)
        recording_information = current_patient_data.split('\n')[1:num_locations+1]
        for j in range(num_locations) :
            entries = recording_information[j].split(' ')
            recording_file = entries[2]
            filename = os.path.join(data_folder, recording_file)

            # Extract id
            id1 = recording_file.split('_')[0]
            features['id'].append(id1)

            # Extract melspec
            if use_mel :
                mel1 = feature_extract_melspec(filename, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                               win_length = win_length, n_mels = n_mels, trim = trim)[0]
            else :
                mel1 = np.zeros( (1,1,1) )
            features['mel1'].append(mel1)

            if use_cqt :
                mel2 = feature_extract_cqt(filename, samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale, 
                                           n_bins = n_bins, fmin = fmin, trim = trim)[0]
            else :
                mel2 = np.zeros( (1,1,1) )
            features['cqt1'].append(mel2)

            if use_stft :
                mel3 = feature_extract_stft(filename, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                            win_length = win_length, trim = trim)[0]
            else :
                mel3 = np.zeros( (1,1,1) )
            features['stft1'].append(mel3)

            if use_raw :
                frequency1, recording1 = sp.io.wavfile.read(filename)
            else :
                recording1 = np.zeros((1))
            features['raw1'].append(recording1)
            
            
            if use_rr :
                try:
                    ____, recording1 = sp.io.wavfile.read(filename)
                    ____, info = nk.ecg_process(recording1, sampling_rate=4000)
                    rr = np.mean(np.diff(info['ECG_R_Peaks'])/4000)
                    current_rr = rr
                except:
                    print(filename)
                    current_rr=np.zeros((1))
            else :
                current_rr = np.zeros((1))
            features['rr1'].append(current_rr)        
            
            
            if use_qrs :
                ____, recording1 = sp.io.wavfile.read(filename)
                R_peaks, S_point, Q_point=EKG_QRS_detect1(recording1, 4000, True, False)
                qrs = np.mean(S_point-Q_point)
            else :
                qrs = np.zeros((1))
            features['qrs1'].append(qrs)   
            
            
            # Extract age_group
            age_group = get_age(current_patient_data)
            current_age_group = np.zeros(6, dtype=int)
            if age_group in age_classes:
                j = age_classes.index(age_group)
                current_age_group[j] = 1
            else :
                current_age_group[5] = 1
            features['age'].append(current_age_group)

            # Extract sex
            sex = get_sex(current_patient_data)
            sex_features = np.zeros(2, dtype=int)
            if compare_strings(sex, 'Female'):
                sex_features[0] = 1
            elif compare_strings(sex, 'Male'):
                sex_features[1] = 1
            features['sex'].append(sex_features)

            # Extract height and weight.
            height = get_height(current_patient_data)
            weight = get_weight(current_patient_data)
            ## simple impute
            if math.isnan(height) :
                height = 110.846
            if math.isnan(weight) :
                weight = 23.767
                
            features['hw'].append(np.array([height, weight]))

            # Extract pregnancy
            is_pregnant = get_pregnancy_status(current_patient_data)
            features['preg'].append(is_pregnant)

            # Extract location
            locations = entries[0]
            num_recording_locations = len(recording_locations)
            loc_features = np.zeros(num_recording_locations)
            if locations in recording_locations:
                j = recording_locations.index(locations)
                loc_features[j] = 1
            features['loc'].append(loc_features)

            # Extract labels 
            mm_label = get_murmur(current_patient_data)
            out_label = get_outcome(current_patient_data)
            if mm_label == 'Absent' :
                current_mm_labels = np.array([0, 1])
            elif mm_label == 'Unknown' :
                current_mm_labels = np.array([po, 1-po])
            else :
                mm_loc = get_murmur_loc(current_patient_data)
                if mm_loc == 'nan' :
                    current_mm_labels = np.array([0.9, 0.1])
                else :
                    mm_loc = mm_loc.split('+')
                    if locations in mm_loc :
                        current_mm_labels = np.array([1, 0])
                    else :
                        current_mm_labels = np.array([0.8, 0.2])

            if out_label == 'Normal' :
                current_out_labels = np.array([0, 1])
            else :
                current_out_labels = np.array([1, 0])
#                if mm_label == 'Absent' :
#                    current_out_labels = np.array([0.8, 0.2])
#                elif mm_label == 'unknown' :
#                    current_out_labels = np.array([0.85, 0.15])
#                else :
#                    current_out_labels = np.array([1, 0])
                
            mm_labels.append(current_mm_labels)
            out_labels.append(current_out_labels)

    if use_mel : 
        M, N = features['mel1'][i].shape
        for i in range(len(features['mel1'])) :
            features['mel1'][i] = features['mel1'][i].reshape(M,N,1)
        print("melspec: ", M,N)
    else :
        M, N, _ = features['mel1'][i].shape
    mel_input_shape = (M,N,1)
        
    if use_cqt :
        M, N = features['cqt1'][i].shape
        for i in range(len(features['cqt1'])) :
            features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)
        print("cqt: ", M,N)
    else :
        M, N, _ = features['cqt1'][i].shape
    cqt_input_shape = (M,N,1)

    
    if use_stft :
        M, N = features['stft1'][i].shape
        for i in range(len(features['stft1'])) :
            features['stft1'][i] = features['stft1'][i].reshape(M,N,1)
        print("stft: ", M,N)
    else :
        M, N, _ = features['stft1'][i].shape
    stft_input_shape = (M,N,1)
        
    for k1 in features.keys() :
        features[k1] = np.array(features[k1])
    
    mm_labels = np.array(mm_labels)
    out_labels = np.array(out_labels)
    return features, mm_labels, out_labels, mel_input_shape, cqt_input_shape, stft_input_shape

# %%
trim = 0
use_mel = True
use_cqt = True #np.random.choice([True,False])
use_stft = True #np.random.choice([True,False])
use_rr = True
use_qrs = True

params_feature = {'samp_sec': 20,
                  #### melspec, stft 피쳐 옵션들
                  'pre_emphasis': 0,
                  'hop_length': 128,
                  'win_length':256,
                  'n_mels': 100,
                  #### cqt 피쳐 옵션들
                  'filter_scale': 1,
                  'n_bins': 80,
                  'fmin': 10,
                  ### 사용할 피쳐 지정
                      'trim' : trim, # 앞뒤 얼마나 자를지? 4000 이면 1초
                      'use_mel' : use_mel,
                      'use_cqt' : use_cqt,
                      'use_stft' : use_stft,
                      'use_rr': use_rr,
                      'use_qrs': use_qrs
    }

# %%
features_trn, mm_lbs_trn, out_lbs_trn, mel_input_shape, cqt_input_shape, stft_input_shape = get_features_3lb_all_ord_rr_qrs(train_folder, patient_files_trn, **params_feature)
features_test, mm_lbs_test, out_lbs_test, _, _, _ = get_features_3lb_all_ord_rr_qrs(test_folder, patient_files_test, **params_feature)
# Out:
#   0%|▏                                        | 3/751 [01:34<6:39:34, 32.05s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   1%|▍                                        | 7/751 [03:45<7:01:11, 33.97s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   2%|▋                                       | 12/751 [05:35<4:58:48, 24.26s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   4%|█▍                                      | 27/751 [12:16<7:04:50, 35.21s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   5%|██▏                                     | 40/751 [22:04<9:19:57, 47.25s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   5%|██▏                                    | 41/751 [23:09<10:20:48, 52.46s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   6%|██▏                                     | 42/751 [23:42<9:11:17, 46.65s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   6%|██▍                                    | 48/751 [28:47<10:53:44, 55.80s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   7%|██▉                                     | 56/751 [36:13<9:00:25, 46.66s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   8%|███▎                                    | 63/751 [41:19<8:06:54, 42.46s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   9%|███▌                                    | 66/751 [43:50<9:07:04, 47.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   9%|███▍                                   | 67/751 [44:54<10:01:10, 52.73s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   9%|███▌                                    | 68/751 [45:19<8:28:09, 44.64s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  11%|████▌                                   | 85/751 [53:36<4:10:53, 22.60s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  12%|████▋                                   | 87/751 [54:35<4:43:48, 25.65s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  12%|████▋                                   | 89/751 [56:38<7:56:50, 43.22s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  12%|████▊                                   | 90/751 [57:38<8:48:50, 48.00s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  13%|████▉                                 | 98/751 [1:01:51<6:18:27, 34.77s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  14%|█████                                | 104/751 [1:05:42<6:23:56, 35.60s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▎                               | 109/751 [1:08:45<7:29:26, 42.00s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▌                               | 114/751 [1:12:33<7:57:55, 45.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▋                               | 115/751 [1:13:02<7:08:02, 40.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▋                               | 116/751 [1:13:56<7:49:11, 44.33s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  16%|█████▊                               | 117/751 [1:14:41<7:49:28, 44.43s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  17%|██████▍                              | 131/751 [1:24:10<7:37:17, 44.25s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  18%|██████▌                              | 134/751 [1:27:04<9:26:48, 55.12s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  19%|██████▉                              | 140/751 [1:30:31<6:00:34, 35.41s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  20%|███████▎                             | 148/751 [1:34:45<5:04:44, 30.32s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  20%|███████▍                             | 152/751 [1:36:33<4:32:24, 27.29s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  21%|███████▌                             | 154/751 [1:37:40<5:13:07, 31.47s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  21%|███████▋                             | 155/751 [1:38:30<6:08:07, 37.06s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  22%|████████▏                            | 166/751 [1:43:40<4:24:57, 27.18s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  22%|████████▏                            | 167/751 [1:44:33<5:40:16, 34.96s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  23%|████████▍                            | 171/751 [1:46:59<5:32:29, 34.40s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  24%|████████▊                            | 179/751 [1:52:52<6:47:21, 42.73s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  24%|████████▉                            | 181/751 [1:54:00<5:45:44, 36.39s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  24%|█████████                            | 183/751 [1:55:38<6:40:04, 42.26s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  25%|█████████▏                           | 186/751 [1:57:03<5:19:56, 33.98s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  25%|█████████▍                           | 191/751 [2:00:40<6:09:05, 39.55s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▍                           | 192/751 [2:01:05<5:28:23, 35.25s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▌                           | 193/751 [2:01:51<5:58:25, 38.54s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▌                           | 194/751 [2:02:44<6:38:25, 42.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▋                           | 197/751 [2:04:58<6:31:05, 42.36s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  27%|█████████▊                           | 200/751 [2:07:11<6:37:56, 43.33s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  27%|██████████                           | 203/751 [2:08:44<5:12:17, 34.19s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  28%|██████████▍                          | 211/751 [2:13:58<4:57:41, 33.08s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  28%|██████████▍                          | 213/751 [2:15:29<5:56:42, 39.78s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  28%|██████████▌                          | 214/751 [2:16:23<6:33:07, 43.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  29%|██████████▊                          | 219/751 [2:20:12<7:28:26, 50.58s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|███████████                          | 225/751 [2:24:51<6:44:40, 46.16s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|███████████▏                         | 227/751 [2:26:18<6:16:58, 43.17s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|███████████▏                         | 228/751 [2:26:54<5:59:04, 41.19s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  31%|███████████▍                         | 232/751 [2:29:58<6:30:33, 45.15s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  31%|███████████▍                         | 233/751 [2:30:56<7:02:11, 48.90s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  31%|███████████▋                         | 236/751 [2:33:28<7:07:44, 49.83s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  32%|███████████▊                         | 241/751 [2:38:02<7:32:26, 53.23s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  33%|████████████                         | 245/751 [2:40:22<5:05:40, 36.25s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  34%|████████████▍                        | 253/751 [2:45:36<5:46:09, 41.70s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  34%|████████████▌                        | 256/751 [2:47:54<6:19:47, 46.04s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  35%|████████████▊                        | 260/751 [2:50:25<5:51:47, 42.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  35%|████████████▉                        | 263/751 [2:52:16<5:03:24, 37.31s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  35%|█████████████                        | 264/751 [2:53:10<5:44:01, 42.39s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  36%|█████████████▍                       | 273/751 [3:00:11<6:20:57, 47.82s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  36%|█████████████▍                       | 274/751 [3:01:05<6:34:34, 49.63s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  37%|█████████████▌                       | 276/751 [3:02:59<7:02:59, 53.43s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  37%|█████████████▋                       | 279/751 [3:05:02<6:09:15, 46.94s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  38%|█████████████▉                       | 283/751 [3:08:05<5:58:41, 45.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  38%|██████████████                       | 286/751 [3:10:34<5:55:40, 45.89s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  39%|██████████████▌                      | 296/751 [3:17:16<4:54:18, 38.81s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|██████████████▊                      | 300/751 [3:20:17<5:18:58, 42.44s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|██████████████▊                      | 301/751 [3:21:08<5:38:41, 45.16s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|██████████████▉                      | 304/751 [3:23:38<6:02:58, 48.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  41%|███████████████                      | 306/751 [3:25:19<6:08:18, 49.66s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  41%|███████████████▏                     | 307/751 [3:26:10<6:09:30, 49.93s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▍                     | 313/751 [3:30:11<5:14:55, 43.14s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▌                     | 315/751 [3:31:25<5:07:08, 42.27s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▌                     | 317/751 [3:32:30<4:16:50, 35.51s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▋                     | 318/751 [3:33:24<4:55:55, 41.01s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  43%|███████████████▊                     | 320/751 [3:34:42<4:38:35, 38.78s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  43%|████████████████                     | 326/751 [3:39:12<5:43:03, 48.43s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  44%|████████████████▎                    | 331/751 [3:43:28<6:02:29, 51.79s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  44%|████████████████▎                    | 332/751 [3:44:17<5:55:46, 50.95s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  44%|████████████████▍                    | 333/751 [3:45:22<6:24:36, 55.21s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|████████████████▋                    | 338/751 [3:49:09<5:03:29, 44.09s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|████████████████▊                    | 340/751 [3:50:06<4:08:01, 36.21s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|████████████████▉                    | 345/751 [3:52:10<2:41:06, 23.81s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|█████████████████                    | 346/751 [3:52:27<2:27:58, 21.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|█████████████████▏                   | 348/751 [3:53:32<3:03:38, 27.34s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|█████████████████▏                   | 349/751 [3:53:44<2:33:16, 22.88s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  47%|█████████████████▏                   | 350/751 [3:54:02<2:23:46, 21.51s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  47%|█████████████████▍                   | 353/751 [3:55:22<2:37:04, 23.68s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|█████████████████▋                   | 358/751 [3:56:36<1:53:27, 17.32s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|█████████████████▊                   | 361/751 [3:57:22<1:45:16, 16.20s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|█████████████████▉                   | 364/751 [3:58:30<2:01:06, 18.78s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|█████████████████▉                   | 365/751 [3:58:41<1:45:42, 16.43s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|██████████████████                   | 367/751 [3:59:20<1:53:33, 17.74s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|██████████████████▏                  | 368/751 [3:59:37<1:53:02, 17.71s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▍                  | 374/751 [4:01:31<2:12:20, 21.06s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▌                  | 377/751 [4:02:40<2:22:48, 22.91s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▌                  | 378/751 [4:03:11<2:36:18, 25.14s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▋                  | 379/751 [4:03:41<2:44:40, 26.56s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  51%|██████████████████▋                  | 380/751 [4:03:57<2:24:31, 23.37s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  51%|██████████████████▊                  | 383/751 [4:04:47<2:07:02, 20.71s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  52%|███████████████████                  | 387/751 [4:06:44<2:58:02, 29.35s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  52%|███████████████████▏                 | 390/751 [4:07:54<2:20:16, 23.31s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  53%|███████████████████▍                 | 395/751 [4:10:02<2:32:25, 25.69s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  53%|███████████████████▌                 | 397/751 [4:10:55<2:34:42, 26.22s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  53%|███████████████████▋                 | 400/751 [4:12:19<2:44:18, 28.09s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|████████████▏                           | 58/191 [32:46<1:14:44, 33.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  32%|████████████▊                           | 61/191 [34:22<1:08:10, 31.47s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  32%|████████████▉                           | 62/191 [35:33<1:33:06, 43.30s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  34%|█████████████▌                          | 65/191 [37:12<1:08:47, 32.76s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  37%|██████████████▊                         | 71/191 [44:40<2:38:07, 79.06s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  38%|███████████████▎                        | 73/191 [46:04<1:58:39, 60.33s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|███████████████▉                        | 76/191 [48:26<1:39:09, 51.74s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|████████████████▏                       | 77/191 [49:17<1:38:16, 51.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|██████████████████▉                       | 86/191 [52:46<35:20, 20.20s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|████████████████████▏                     | 92/191 [55:11<39:02, 23.66s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|████████████████████▍                     | 93/191 [55:42<42:34, 26.07s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|████████████████████▉                     | 95/191 [56:38<44:58, 28.11s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  54%|█████████████████████                  | 103/191 [1:00:00<43:44, 29.83s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  54%|█████████████████████▏                 | 104/191 [1:00:13<35:57, 24.80s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  56%|█████████████████████▊                 | 107/191 [1:01:41<37:40, 26.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  63%|████████████████████████▌              | 120/191 [1:06:04<30:09, 25.49s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  63%|████████████████████████▋              | 121/191 [1:06:26<28:48, 24.69s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  64%|████████████████████████▉              | 122/191 [1:06:39<24:15, 21.10s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  65%|█████████████████████████▎             | 124/191 [1:07:19<23:26, 20.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  66%|█████████████████████████▉             | 127/191 [1:08:25<21:13, 19.89s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  68%|██████████████████████████▎            | 129/191 [1:09:29<26:31, 25.66s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  73%|████████████████████████████▍          | 139/191 [1:13:23<20:15, 23.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  75%|█████████████████████████████▍         | 144/191 [1:15:44<23:06, 29.51s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  77%|██████████████████████████████▏        | 148/191 [1:17:30<18:40, 26.05s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  79%|██████████████████████████████▊        | 151/191 [1:18:48<17:50, 26.77s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  84%|████████████████████████████████▋      | 160/191 [1:22:17<13:09, 25.48s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  87%|█████████████████████████████████▉     | 166/191 [1:24:54<09:54, 23.78s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  91%|███████████████████████████████████▌   | 174/191 [1:27:44<06:16, 22.15s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  93%|████████████████████████████████████▏  | 177/191 [1:28:57<05:43, 24.56s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  95%|████████████████████████████████████▉  | 181/191 [1:30:27<03:42, 22.27s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  96%|█████████████████████████████████████▎ | 183/191 [1:31:29<03:40, 27.56s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  97%|█████████████████████████████████████▉ | 186/191 [1:32:37<01:59, 23.96s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  98%|██████████████████████████████████████▏| 187/191 [1:33:14<01:51, 27.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  99%|██████████████████████████████████████▌| 189/191 [1:34:03<00:54, 27.11s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|███████████████████████████████████████| 191/191 [1:34:40<00:00, 29.74s/it]
# melspec:  100 626
# cqt:  80 157
# stft:  129 626

# %%
with open('features_trn_rr_qrs2.pkl','wb') as f:
    pickle.dump(features_trn,f)
    
with open('mm_lbs_trn_rr_qrs2.pkl','wb') as f:
    pickle.dump(mm_lbs_trn,f)
    
with open('out_lbs_trn_rr_qrs2.pkl','wb') as f:
    pickle.dump(out_lbs_trn,f)
    
with open('mel_input_shape_rr_qrs2.pkl','wb') as f:
    pickle.dump(mel_input_shape,f)

with open('cqt_input_shape_rr_qrs2.pkl','wb') as f:
    pickle.dump(cqt_input_shape,f)
    
with open('stft_input_shape_rr_qrs2.pkl','wb') as f:
    pickle.dump(stft_input_shape,f)
    
with open('features_test_rr_qrs2.pkl','wb') as f:
    pickle.dump(features_test,f)
    
with open('mm_lbs_test_rr_qrs2.pkl','wb') as f:
    pickle.dump(mm_lbs_test,f)

with open('out_lbs_test_rr_qrs2.pkl','wb') as f:
    pickle.dump(out_lbs_test,f)

# %%
import pickle
with open('/Data2/hmd/hmd_sy/notebooks/features_trn_rr_qrs2.pkl','rb') as f:
    features_trn = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/mm_lbs_trn_rr_qrs2.pkl','rb') as f:
    mm_lbs_trn = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/out_lbs_trn_rr_qrs2.pkl','rb') as f:
    out_lbs_trn = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/mel_input_shape_rr_qrs2.pkl','rb') as f:
    mel_input_shape = pickle.load(f)

with open('/Data2/hmd/hmd_sy/notebooks/cqt_input_shape_rr_qrs2.pkl','rb') as f:
    cqt_input_shape = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/stft_input_shape_rr_qrs2.pkl','rb') as f:
    stft_input_shape = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/features_test_rr_qrs2.pkl','rb') as f:
    features_test = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/mm_lbs_test_rr_qrs2.pkl','rb') as f:
    mm_lbs_test = pickle.load(f)

with open('/Data2/hmd/hmd_sy/notebooks/out_lbs_test_rr_qrs2.pkl','rb') as f:
    out_lbs_test = pickle.load(f)

# %% [markdown]
# ### model

# %%
def get_LCNN_o_5_dr_qrs2(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, 
                        use_stft = True, ord1 = True, dp = .5, fc = False, ext = False):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    rr = keras.Input(shape=(1,), name = 'rr')
    qrs = keras.Input(shape=(1,), name = 'qrs') 
    mel1 = keras.Input(shape=mel_input_shape, name = 'mel')
    cqt1 = keras.Input(shape=cqt_input_shape, name = 'cqt')
    stft1 = keras.Input(shape=stft_input_shape, name = 'stft')
    
    
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)
    
    ## rr interval embedding
    
    rr1 = layers.Dense(20, activation = "relu")(rr)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)

    ## qrs interval embedding    
    qrs1 = layers.Dense(20, activation = "relu")(qrs)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)

    ## mel embedding
    if use_mel :
        
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)

        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        mel2 = layers.GlobalAveragePooling2D()(max28)
        mel2 = Dropout(dp)(mel2)

    if use_cqt :
        
        ## cqt embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm27)
        cqt2 = layers.GlobalAveragePooling2D()(max28)
        if dp :
            cqt2 = Dropout(dp)(cqt2)
            
    if use_stft :
        ## stft embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)
        
        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)
        
        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])
        
        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])
        
        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        stft2 = layers.GlobalAveragePooling2D()(max28)
        stft2 = Dropout(dp)(stft2)
    
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2

    if ext :
        concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg,rr1,qrs1])
        d1 = layers.Dense(5, activation = 'relu')(concat1)
        concat2 = layers.Concatenate()([concat2, d1]) # rr1,qrs1 따로 concat
        
    if fc :
        concat2 = layers.Dense(10, activation = "relu")(concat2)
        concat2 = Dropout(dp)(concat2)
        
    if ord1 :
        res1 = layers.Dense(2, activation = "softmax")(concat2)
    else :
        res1 = layers.Dense(3, activation = "softmax")(concat2)

        
#     res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,rr,qrs, mel1,cqt1, stft1] , outputs = res1 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)




def get_LCNN_o_5_dr_qrs2_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, 
                        use_stft = True, ord1 = True, dp = .5, fc = False, ext = False):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    rr = keras.Input(shape=(1,), name = 'rr')
    qrs = keras.Input(shape=(1,), name = 'qrs') 
    mel1 = keras.Input(shape=mel_input_shape, name = 'mel')
    cqt1 = keras.Input(shape=cqt_input_shape, name = 'cqt')
    stft1 = keras.Input(shape=stft_input_shape, name = 'stft')
    
    
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)
    
    ## rr interval embedding
    
    rr1 = layers.Dense(20, activation = "relu")(rr)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)

    ## qrs interval embedding    
    qrs1 = layers.Dense(20, activation = "relu")(qrs)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)

    ## mel embedding
    if use_mel :
        
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)

        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        mel2 = layers.GlobalAveragePooling2D()(max28)
        mel2 = Dropout(dp)(mel2)

    if use_cqt :
        
        ## cqt embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm27)
        cqt2 = layers.GlobalAveragePooling2D()(max28)
        if dp :
            cqt2 = Dropout(dp)(cqt2)
            
    if use_stft :
        ## stft embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)
        
        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)
        
        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])
        
        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])
        
        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        stft2 = layers.GlobalAveragePooling2D()(max28)
        stft2 = Dropout(dp)(stft2)
    
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2

    if ext :
        concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg,rr1,qrs1])
        d1 = layers.Dense(5, activation = 'relu')(concat1)
        concat2 = layers.Concatenate()([concat2, d1]) # rr1,qrs1 따로 concat
        
    if fc :
        concat2 = layers.Dense(10, activation = "relu")(concat2)
        concat2 = Dropout(dp)(concat2)
        
    if ord1 :
        res2 = layers.Dense(2, activation = "softmax")(concat2)
    else :
        res2 = layers.Dense(3, activation = "softmax")(concat2)

        
#     res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,rr,qrs, mel1,cqt1, stft1] , outputs = res2 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)

# %%
use_mel = True
use_cqt = True
use_stft = True

model1 = get_LCNN_o_5_dr_qrs2(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = use_mel, use_cqt = use_cqt, use_stft = use_stft)
model2 = get_LCNN_o_5_dr_qrs2_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = use_mel, use_cqt = use_cqt, use_stft = use_stft)
# Out:
# 2022-07-30 15:12:08.904481: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-30 15:12:08.919712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:40:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 15:12:08.928954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 3
# 2022-07-30 15:12:08.930153: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-07-30 15:12:10.427486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-07-30 15:12:10.427572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      3
# 2022-07-30 15:12:10.427588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   N
# 2022-07-30 15:12:10.437689: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 47232 MB memory) -> physical GPU (device: 3, name: Quadro RTX 8000, pci bus id: 0000:40:00.0, compute capability: 7.5)

# %%
params_feature['ord1'] = True 
params_feature['mm_mean'] = False
params_feature['trim'] = False

# %%
    n_epoch = 100
    lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
    batch_size = 64
    params = {'batch_size': batch_size,
              #          'input_shape': (100, 313, 1),
              'shuffle': True,
              'beta_param': 0.7,
              'mixup': True,
              #          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
              #          'highpass': [.5, [78,79,80,81,82,83,84,85]]
              'ranfilter2' : [3, [18,19,20,21,22,23]]
              #           'dropblock' : [30, 100]
              #'device' : device
    }

    params_no_shuffle = {'batch_size': batch_size,
                         #          'input_shape': (100, 313, 1),
                         'shuffle': False,
                         'beta_param': 0.7,
                         'mixup': False
                         #'device': device
    }

    TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'],
                              features_trn['rr1'],features_trn['qrs1'],
                              features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']],
                             mm_lbs_trn,  ## our Y
                             **params)()

    class_weight = {0: 3, 1: 1.}

    model1.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'],
                              features_test['preg'], features_test['loc'], 
                              features_test['rr1'], features_test['qrs1'],
                              features_test['mel1'],
                              features_test['cqt1'], features_test['stft1']],
                             mm_lbs_test),
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(mm_lbs_trn)/64),
                           class_weight=class_weight,
                             epochs = n_epoch)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 2022-07-30 15:12:14.917540: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-07-30 15:12:14.936900: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2100000000 Hz
# 2022-07-30 15:12:18.341945: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-07-30 15:12:19.797515: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8100
# 2022-07-30 15:12:22.317486: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-07-30 15:12:23.722433: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 40/40 [==============================] - 27s 368ms/step - loss: 1.1420 - accuracy: 0.6457 - auc: 0.6993 - val_loss: 0.8266 - val_accuracy: 0.7892 - val_auc: 0.8451
# Epoch 2/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.9654 - accuracy: 0.6926 - auc: 0.7767 - val_loss: 0.6973 - val_accuracy: 0.5198 - val_auc: 0.5334
# Epoch 3/100
# 40/40 [==============================] - 12s 311ms/step - loss: 0.8732 - accuracy: 0.7637 - auc: 0.8237 - val_loss: 0.5452 - val_accuracy: 0.7512 - val_auc: 0.8265
# Epoch 4/100
# 40/40 [==============================] - 12s 310ms/step - loss: 0.8560 - accuracy: 0.7840 - auc: 0.8388 - val_loss: 0.5730 - val_accuracy: 0.7528 - val_auc: 0.8219
# Epoch 5/100
# 40/40 [==============================] - 12s 313ms/step - loss: 0.8291 - accuracy: 0.8180 - auc: 0.8481 - val_loss: 0.5753 - val_accuracy: 0.7179 - val_auc: 0.8081
# Epoch 6/100
# 40/40 [==============================] - 12s 311ms/step - loss: 0.7891 - accuracy: 0.8219 - auc: 0.8665 - val_loss: 0.6093 - val_accuracy: 0.6466 - val_auc: 0.7420
# Epoch 7/100
# 40/40 [==============================] - 13s 315ms/step - loss: 0.7818 - accuracy: 0.8387 - auc: 0.8553 - val_loss: 0.6464 - val_accuracy: 0.6086 - val_auc: 0.6630
# Epoch 8/100
# 40/40 [==============================] - 13s 315ms/step - loss: 0.7649 - accuracy: 0.8375 - auc: 0.8565 - val_loss: 0.9536 - val_accuracy: 0.4865 - val_auc: 0.5123
# Epoch 9/100
# 40/40 [==============================] - 12s 312ms/step - loss: 0.7303 - accuracy: 0.8566 - auc: 0.8665 - val_loss: 1.0168 - val_accuracy: 0.4517 - val_auc: 0.4865
# Epoch 10/100
# 40/40 [==============================] - 13s 313ms/step - loss: 0.7321 - accuracy: 0.8570 - auc: 0.8745 - val_loss: 0.6381 - val_accuracy: 0.8209 - val_auc: 0.8884
# Epoch 11/100
# 40/40 [==============================] - 12s 312ms/step - loss: 0.7064 - accuracy: 0.8668 - auc: 0.8734 - val_loss: 0.5906 - val_accuracy: 0.8273 - val_auc: 0.8949
# Epoch 12/100
# 40/40 [==============================] - 12s 305ms/step - loss: 0.6998 - accuracy: 0.8590 - auc: 0.8685 - val_loss: 0.3317 - val_accuracy: 0.8811 - val_auc: 0.9427
# Epoch 13/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6811 - accuracy: 0.8887 - auc: 0.8764 - val_loss: 0.4620 - val_accuracy: 0.8669 - val_auc: 0.9232
# Epoch 14/100
# 40/40 [==============================] - 12s 305ms/step - loss: 0.6760 - accuracy: 0.8738 - auc: 0.8808 - val_loss: 0.3605 - val_accuracy: 0.8764 - val_auc: 0.9337
# Epoch 15/100
# 40/40 [==============================] - 12s 312ms/step - loss: 0.6744 - accuracy: 0.8801 - auc: 0.8730 - val_loss: 0.3683 - val_accuracy: 0.8891 - val_auc: 0.9381
# Epoch 16/100
# 40/40 [==============================] - 12s 312ms/step - loss: 0.6702 - accuracy: 0.8816 - auc: 0.8841 - val_loss: 0.3319 - val_accuracy: 0.8748 - val_auc: 0.9394
# Epoch 17/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.6634 - accuracy: 0.8922 - auc: 0.8835 - val_loss: 0.2974 - val_accuracy: 0.9033 - val_auc: 0.9501
# Epoch 18/100
# 40/40 [==============================] - 12s 305ms/step - loss: 0.6470 - accuracy: 0.8938 - auc: 0.8859 - val_loss: 0.3346 - val_accuracy: 0.8669 - val_auc: 0.9346
# Epoch 19/100
# 40/40 [==============================] - 13s 315ms/step - loss: 0.6455 - accuracy: 0.8891 - auc: 0.8788 - val_loss: 0.3115 - val_accuracy: 0.8843 - val_auc: 0.9503
# Epoch 20/100
# 40/40 [==============================] - 12s 310ms/step - loss: 0.6236 - accuracy: 0.8941 - auc: 0.8927 - val_loss: 0.3187 - val_accuracy: 0.8986 - val_auc: 0.9425
# Epoch 21/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.6587 - accuracy: 0.8867 - auc: 0.8882 - val_loss: 0.3650 - val_accuracy: 0.8605 - val_auc: 0.9326
# Epoch 22/100
# 40/40 [==============================] - 12s 309ms/step - loss: 0.6482 - accuracy: 0.8789 - auc: 0.8916 - val_loss: 0.3395 - val_accuracy: 0.8542 - val_auc: 0.9296
# Epoch 23/100
# 40/40 [==============================] - 13s 317ms/step - loss: 0.6346 - accuracy: 0.8867 - auc: 0.8905 - val_loss: 0.3028 - val_accuracy: 0.8875 - val_auc: 0.9473
# Epoch 24/100
# 40/40 [==============================] - 13s 318ms/step - loss: 0.6581 - accuracy: 0.8793 - auc: 0.8801 - val_loss: 0.2943 - val_accuracy: 0.8859 - val_auc: 0.9497
# Epoch 25/100
# 40/40 [==============================] - 12s 309ms/step - loss: 0.6464 - accuracy: 0.8855 - auc: 0.8765 - val_loss: 0.5666 - val_accuracy: 0.6830 - val_auc: 0.7716
# Epoch 26/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.6084 - accuracy: 0.8980 - auc: 0.8898 - val_loss: 0.3073 - val_accuracy: 0.8764 - val_auc: 0.9445
# Epoch 27/100
# 40/40 [==============================] - 12s 311ms/step - loss: 0.6289 - accuracy: 0.8902 - auc: 0.8939 - val_loss: 0.2989 - val_accuracy: 0.9065 - val_auc: 0.9456
# Epoch 28/100
# 40/40 [==============================] - 12s 310ms/step - loss: 0.6030 - accuracy: 0.8973 - auc: 0.8815 - val_loss: 0.3472 - val_accuracy: 0.8764 - val_auc: 0.9396
# Epoch 29/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.6188 - accuracy: 0.8930 - auc: 0.8869 - val_loss: 0.3372 - val_accuracy: 0.8796 - val_auc: 0.9394
# Epoch 30/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.6273 - accuracy: 0.9059 - auc: 0.8835 - val_loss: 0.4389 - val_accuracy: 0.7876 - val_auc: 0.8736
# Epoch 31/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.6052 - accuracy: 0.8969 - auc: 0.8931 - val_loss: 0.3502 - val_accuracy: 0.8510 - val_auc: 0.9240
# Epoch 32/100
# 40/40 [==============================] - 12s 304ms/step - loss: 0.6136 - accuracy: 0.8883 - auc: 0.8892 - val_loss: 0.7693 - val_accuracy: 0.5705 - val_auc: 0.6243
# Epoch 33/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.5820 - accuracy: 0.9027 - auc: 0.8932 - val_loss: 0.3134 - val_accuracy: 0.9002 - val_auc: 0.9486
# Epoch 34/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6034 - accuracy: 0.9020 - auc: 0.8891 - val_loss: 0.2950 - val_accuracy: 0.8938 - val_auc: 0.9489
# Epoch 35/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5899 - accuracy: 0.9035 - auc: 0.8935 - val_loss: 0.3185 - val_accuracy: 0.8843 - val_auc: 0.9471
# Epoch 36/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.6001 - accuracy: 0.9004 - auc: 0.8769 - val_loss: 0.3405 - val_accuracy: 0.8843 - val_auc: 0.9379
# Epoch 37/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.6118 - accuracy: 0.9000 - auc: 0.8956 - val_loss: 0.4840 - val_accuracy: 0.7670 - val_auc: 0.8544
# Epoch 38/100
# 40/40 [==============================] - 12s 309ms/step - loss: 0.6124 - accuracy: 0.8902 - auc: 0.8928 - val_loss: 0.6054 - val_accuracy: 0.8669 - val_auc: 0.9162
# Epoch 39/100
# 40/40 [==============================] - 12s 304ms/step - loss: 0.6048 - accuracy: 0.9039 - auc: 0.8907 - val_loss: 0.4784 - val_accuracy: 0.8336 - val_auc: 0.9134
# Epoch 40/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.5921 - accuracy: 0.8938 - auc: 0.8913 - val_loss: 0.2978 - val_accuracy: 0.9097 - val_auc: 0.9489
# Epoch 41/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.5858 - accuracy: 0.9043 - auc: 0.8839 - val_loss: 0.3324 - val_accuracy: 0.8970 - val_auc: 0.9445
# Epoch 42/100
# 40/40 [==============================] - 12s 310ms/step - loss: 0.5792 - accuracy: 0.9133 - auc: 0.8932 - val_loss: 0.2807 - val_accuracy: 0.9081 - val_auc: 0.9560
# Epoch 43/100
# 40/40 [==============================] - 12s 305ms/step - loss: 0.5817 - accuracy: 0.9047 - auc: 0.8894 - val_loss: 0.2965 - val_accuracy: 0.9049 - val_auc: 0.9510
# Epoch 44/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.5929 - accuracy: 0.9113 - auc: 0.8976 - val_loss: 0.3387 - val_accuracy: 0.8605 - val_auc: 0.9313
# Epoch 45/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5505 - accuracy: 0.9238 - auc: 0.9017 - val_loss: 0.3844 - val_accuracy: 0.8764 - val_auc: 0.9349
# Epoch 46/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5510 - accuracy: 0.9129 - auc: 0.8928 - val_loss: 0.3065 - val_accuracy: 0.9002 - val_auc: 0.9431
# Epoch 47/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.5655 - accuracy: 0.9109 - auc: 0.8922 - val_loss: 0.3051 - val_accuracy: 0.8748 - val_auc: 0.9486
# Epoch 48/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.5540 - accuracy: 0.9094 - auc: 0.9047 - val_loss: 0.2971 - val_accuracy: 0.9065 - val_auc: 0.9476
# Epoch 49/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.5444 - accuracy: 0.9234 - auc: 0.9027 - val_loss: 0.3549 - val_accuracy: 0.8574 - val_auc: 0.9287
# Epoch 50/100
# 40/40 [==============================] - 12s 304ms/step - loss: 0.5433 - accuracy: 0.9207 - auc: 0.9024 - val_loss: 0.4148 - val_accuracy: 0.8051 - val_auc: 0.8922
# Epoch 51/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.5468 - accuracy: 0.9141 - auc: 0.8976 - val_loss: 0.2933 - val_accuracy: 0.8938 - val_auc: 0.9491
# Epoch 52/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5392 - accuracy: 0.9211 - auc: 0.9053 - val_loss: 0.2884 - val_accuracy: 0.9002 - val_auc: 0.9508
# Epoch 53/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5253 - accuracy: 0.9215 - auc: 0.8997 - val_loss: 0.6730 - val_accuracy: 0.8193 - val_auc: 0.9146
# Epoch 54/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5141 - accuracy: 0.9344 - auc: 0.9027 - val_loss: 0.3581 - val_accuracy: 0.8431 - val_auc: 0.9281
# Epoch 55/100
# 40/40 [==============================] - 12s 305ms/step - loss: 0.5417 - accuracy: 0.9297 - auc: 0.8976 - val_loss: 0.3453 - val_accuracy: 0.9002 - val_auc: 0.9383
# Epoch 56/100
# 40/40 [==============================] - 12s 304ms/step - loss: 0.5199 - accuracy: 0.9301 - auc: 0.9051 - val_loss: 0.4473 - val_accuracy: 0.8796 - val_auc: 0.9355
# Epoch 57/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.5203 - accuracy: 0.9395 - auc: 0.8995 - val_loss: 0.2970 - val_accuracy: 0.9049 - val_auc: 0.9473
# Epoch 58/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.5255 - accuracy: 0.9273 - auc: 0.9048 - val_loss: 0.2930 - val_accuracy: 0.9033 - val_auc: 0.9514
# Epoch 59/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.5221 - accuracy: 0.9328 - auc: 0.9038 - val_loss: 0.2986 - val_accuracy: 0.8938 - val_auc: 0.9525
# Epoch 60/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5078 - accuracy: 0.9383 - auc: 0.9027 - val_loss: 0.4349 - val_accuracy: 0.8780 - val_auc: 0.9326
# Epoch 61/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4982 - accuracy: 0.9387 - auc: 0.9048 - val_loss: 0.3222 - val_accuracy: 0.8875 - val_auc: 0.9483
# Epoch 62/100
# 40/40 [==============================] - 12s 301ms/step - loss: 0.5006 - accuracy: 0.9363 - auc: 0.9081 - val_loss: 0.3431 - val_accuracy: 0.9002 - val_auc: 0.9469
# Epoch 63/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.5020 - accuracy: 0.9344 - auc: 0.9072 - val_loss: 0.2900 - val_accuracy: 0.8986 - val_auc: 0.9499
# Epoch 64/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.4829 - accuracy: 0.9367 - auc: 0.9096 - val_loss: 0.3292 - val_accuracy: 0.9049 - val_auc: 0.9442
# Epoch 65/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.4903 - accuracy: 0.9363 - auc: 0.9124 - val_loss: 0.2980 - val_accuracy: 0.8891 - val_auc: 0.9478
# Epoch 66/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.4945 - accuracy: 0.9391 - auc: 0.9051 - val_loss: 0.3163 - val_accuracy: 0.8954 - val_auc: 0.9495
# Epoch 67/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.4968 - accuracy: 0.9449 - auc: 0.9121 - val_loss: 0.3419 - val_accuracy: 0.8954 - val_auc: 0.9493
# Epoch 68/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.5032 - accuracy: 0.9445 - auc: 0.9113 - val_loss: 0.3070 - val_accuracy: 0.8780 - val_auc: 0.9457
# Epoch 69/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4821 - accuracy: 0.9465 - auc: 0.9062 - val_loss: 0.3922 - val_accuracy: 0.8954 - val_auc: 0.9413
# Epoch 70/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4888 - accuracy: 0.9406 - auc: 0.9122 - val_loss: 0.2996 - val_accuracy: 0.9049 - val_auc: 0.9486
# Epoch 71/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4662 - accuracy: 0.9461 - auc: 0.9116 - val_loss: 0.3345 - val_accuracy: 0.9049 - val_auc: 0.9463
# Epoch 72/100
# 40/40 [==============================] - 12s 301ms/step - loss: 0.4919 - accuracy: 0.9469 - auc: 0.9137 - val_loss: 0.3297 - val_accuracy: 0.9017 - val_auc: 0.9453
# Epoch 73/100
# 40/40 [==============================] - 12s 301ms/step - loss: 0.4749 - accuracy: 0.9484 - auc: 0.9107 - val_loss: 0.3178 - val_accuracy: 0.8970 - val_auc: 0.9471
# Epoch 74/100
# 40/40 [==============================] - 12s 304ms/step - loss: 0.4756 - accuracy: 0.9480 - auc: 0.9101 - val_loss: 0.4031 - val_accuracy: 0.8906 - val_auc: 0.9370
# Epoch 75/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.4708 - accuracy: 0.9496 - auc: 0.9045 - val_loss: 0.3217 - val_accuracy: 0.9002 - val_auc: 0.9474
# Epoch 76/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.4790 - accuracy: 0.9457 - auc: 0.9077 - val_loss: 0.3410 - val_accuracy: 0.8986 - val_auc: 0.9457
# Epoch 77/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4903 - accuracy: 0.9477 - auc: 0.9104 - val_loss: 0.3411 - val_accuracy: 0.8986 - val_auc: 0.9467
# Epoch 78/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4718 - accuracy: 0.9465 - auc: 0.9062 - val_loss: 0.3343 - val_accuracy: 0.8938 - val_auc: 0.9472
# Epoch 79/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4804 - accuracy: 0.9438 - auc: 0.9096 - val_loss: 0.3198 - val_accuracy: 0.8986 - val_auc: 0.9471
# Epoch 80/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4732 - accuracy: 0.9488 - auc: 0.9117 - val_loss: 0.3134 - val_accuracy: 0.8986 - val_auc: 0.9476
# Epoch 81/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4936 - accuracy: 0.9391 - auc: 0.9082 - val_loss: 0.3531 - val_accuracy: 0.9002 - val_auc: 0.9447
# Epoch 82/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.4618 - accuracy: 0.9473 - auc: 0.9035 - val_loss: 0.3172 - val_accuracy: 0.9033 - val_auc: 0.9465
# Epoch 83/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.4805 - accuracy: 0.9473 - auc: 0.9103 - val_loss: 0.3149 - val_accuracy: 0.8986 - val_auc: 0.9472
# Epoch 84/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4617 - accuracy: 0.9504 - auc: 0.9106 - val_loss: 0.3307 - val_accuracy: 0.8986 - val_auc: 0.9454
# Epoch 85/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.4681 - accuracy: 0.9500 - auc: 0.9040 - val_loss: 0.3352 - val_accuracy: 0.8986 - val_auc: 0.9447
# Epoch 86/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.4837 - accuracy: 0.9434 - auc: 0.9101 - val_loss: 0.3232 - val_accuracy: 0.9002 - val_auc: 0.9463
# Epoch 87/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.4532 - accuracy: 0.9551 - auc: 0.9050 - val_loss: 0.3169 - val_accuracy: 0.8970 - val_auc: 0.9463
# Epoch 88/100
# 40/40 [==============================] - 12s 301ms/step - loss: 0.4827 - accuracy: 0.9469 - auc: 0.9106 - val_loss: 0.3345 - val_accuracy: 0.8970 - val_auc: 0.9464
# Epoch 89/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.4735 - accuracy: 0.9457 - auc: 0.9139 - val_loss: 0.3366 - val_accuracy: 0.8970 - val_auc: 0.9463
# Epoch 90/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4719 - accuracy: 0.9469 - auc: 0.9193 - val_loss: 0.3287 - val_accuracy: 0.9002 - val_auc: 0.9468
# Epoch 91/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4617 - accuracy: 0.9492 - auc: 0.9066 - val_loss: 0.3214 - val_accuracy: 0.9002 - val_auc: 0.9471
# Epoch 92/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4807 - accuracy: 0.9570 - auc: 0.9096 - val_loss: 0.3371 - val_accuracy: 0.8954 - val_auc: 0.9451
# Epoch 93/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4736 - accuracy: 0.9414 - auc: 0.9128 - val_loss: 0.3354 - val_accuracy: 0.8954 - val_auc: 0.9455
# Epoch 94/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4634 - accuracy: 0.9438 - auc: 0.9144 - val_loss: 0.3318 - val_accuracy: 0.8986 - val_auc: 0.9459
# Epoch 95/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.4764 - accuracy: 0.9473 - auc: 0.9113 - val_loss: 0.3278 - val_accuracy: 0.9002 - val_auc: 0.9475
# Epoch 96/100
# 40/40 [==============================] - 12s 303ms/step - loss: 0.4702 - accuracy: 0.9539 - auc: 0.9101 - val_loss: 0.3263 - val_accuracy: 0.8986 - val_auc: 0.9462
# Epoch 97/100
# 40/40 [==============================] - 12s 305ms/step - loss: 0.4663 - accuracy: 0.9504 - auc: 0.9119 - val_loss: 0.3230 - val_accuracy: 0.9049 - val_auc: 0.9469
# Epoch 98/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.4625 - accuracy: 0.9477 - auc: 0.9124 - val_loss: 0.3170 - val_accuracy: 0.8986 - val_auc: 0.9472
# Epoch 99/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.4854 - accuracy: 0.9492 - auc: 0.9086 - val_loss: 0.3256 - val_accuracy: 0.9002 - val_auc: 0.9474
# Epoch 100/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.4943 - accuracy: 0.9500 - auc: 0.9080 - val_loss: 0.3205 - val_accuracy: 0.9017 - val_auc: 0.9473

# %%
    n_epoch = 100
    lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
    batch_size = 64
    params = {'batch_size': batch_size,
              #          'input_shape': (100, 313, 1),
              'shuffle': True,
              'beta_param': 0.7,
              'mixup': True,
              #          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
            'highpass': [.5, [78,79,80,81,82,83,84,85]],
              'ranfilter2' : [3, [18,19,20,21,22,23]]
            #           'dropblock' : [30, 100]
              #'device' : device
    }
    params_no_shuffle = {'batch_size': batch_size,
                         #          'input_shape': (100, 313, 1),
                         'shuffle': False,
                         'beta_param': 0.7,
                         'mixup': False
                         #'device': device
    }

    TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'],
                              features_trn['rr1'],features_trn['qrs1'],
                              features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']],
                             out_lbs_trn,  ## our Y
                             **params)()

    class_weight = {0: 3, 1: 1.}

    model2.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'],
                              features_test['preg'], features_test['loc'], 
                              features_test['rr1'], features_test['qrs1'],
                              features_test['mel1'],
                              features_test['cqt1'], features_test['stft1']],
                             out_lbs_test),
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(out_lbs_trn)/64),
                             epochs = n_epoch)


    params_feature['mel_shape'] = mel_input_shape
    params_feature['cqt_shape'] = cqt_input_shape
    params_feature['stft_shape'] = stft_input_shape

    params_feature['use_mel'] = use_mel
    params_feature['use_cqt'] = use_cqt
    params_feature['use_stft'] = use_stft
# Out:
# Epoch 1/100
# 40/40 [==============================] - 17s 327ms/step - loss: 0.9835 - accuracy: 0.5211 - auc: 0.5239 - val_loss: 11.0773 - val_accuracy: 0.5008 - val_auc: 0.5008
# Epoch 2/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.7711 - accuracy: 0.5160 - auc: 0.5263 - val_loss: 6.6856 - val_accuracy: 0.5008 - val_auc: 0.5040
# Epoch 3/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.7346 - accuracy: 0.5227 - auc: 0.5377 - val_loss: 1.4915 - val_accuracy: 0.5087 - val_auc: 0.5943
# Epoch 4/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.7142 - accuracy: 0.5371 - auc: 0.5386 - val_loss: 1.3328 - val_accuracy: 0.5230 - val_auc: 0.5995
# Epoch 5/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6929 - accuracy: 0.5617 - auc: 0.5922 - val_loss: 1.0991 - val_accuracy: 0.5230 - val_auc: 0.5967
# Epoch 6/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6934 - accuracy: 0.5449 - auc: 0.5645 - val_loss: 0.7127 - val_accuracy: 0.6260 - val_auc: 0.6730
# Epoch 7/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6823 - accuracy: 0.5801 - auc: 0.5998 - val_loss: 0.7430 - val_accuracy: 0.5610 - val_auc: 0.6328
# Epoch 8/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6846 - accuracy: 0.5742 - auc: 0.5885 - val_loss: 0.6310 - val_accuracy: 0.6672 - val_auc: 0.6990
# Epoch 9/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6778 - accuracy: 0.5730 - auc: 0.6018 - val_loss: 0.6401 - val_accuracy: 0.6086 - val_auc: 0.6600
# Epoch 10/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6785 - accuracy: 0.5816 - auc: 0.5955 - val_loss: 0.6924 - val_accuracy: 0.5658 - val_auc: 0.6387
# Epoch 11/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6780 - accuracy: 0.5824 - auc: 0.5952 - val_loss: 0.6262 - val_accuracy: 0.6466 - val_auc: 0.6995
# Epoch 12/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6743 - accuracy: 0.5762 - auc: 0.6023 - val_loss: 1.2018 - val_accuracy: 0.5119 - val_auc: 0.5901
# Epoch 13/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6695 - accuracy: 0.5910 - auc: 0.6116 - val_loss: 0.6319 - val_accuracy: 0.6799 - val_auc: 0.7212
# Epoch 14/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6675 - accuracy: 0.5848 - auc: 0.6126 - val_loss: 0.6618 - val_accuracy: 0.6054 - val_auc: 0.6358
# Epoch 15/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6733 - accuracy: 0.5867 - auc: 0.6043 - val_loss: 0.6050 - val_accuracy: 0.6735 - val_auc: 0.7286
# Epoch 16/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6576 - accuracy: 0.6223 - auc: 0.6376 - val_loss: 0.7206 - val_accuracy: 0.5499 - val_auc: 0.6189
# Epoch 17/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6648 - accuracy: 0.6145 - auc: 0.6282 - val_loss: 0.6830 - val_accuracy: 0.6070 - val_auc: 0.6767
# Epoch 18/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6630 - accuracy: 0.6070 - auc: 0.6234 - val_loss: 0.6618 - val_accuracy: 0.6165 - val_auc: 0.6695
# Epoch 19/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6587 - accuracy: 0.6164 - auc: 0.6374 - val_loss: 0.6169 - val_accuracy: 0.6577 - val_auc: 0.7147
# Epoch 20/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6565 - accuracy: 0.6180 - auc: 0.6430 - val_loss: 0.8492 - val_accuracy: 0.5658 - val_auc: 0.6212
# Epoch 21/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6596 - accuracy: 0.6129 - auc: 0.6377 - val_loss: 0.7884 - val_accuracy: 0.5626 - val_auc: 0.6134
# Epoch 22/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6552 - accuracy: 0.6164 - auc: 0.6359 - val_loss: 0.6676 - val_accuracy: 0.6197 - val_auc: 0.6668
# Epoch 23/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6559 - accuracy: 0.6223 - auc: 0.6362 - val_loss: 0.6076 - val_accuracy: 0.6450 - val_auc: 0.7087
# Epoch 24/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6527 - accuracy: 0.6219 - auc: 0.6497 - val_loss: 0.6115 - val_accuracy: 0.6656 - val_auc: 0.7085
# Epoch 25/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6533 - accuracy: 0.6141 - auc: 0.6366 - val_loss: 0.6132 - val_accuracy: 0.6545 - val_auc: 0.7135
# Epoch 26/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6546 - accuracy: 0.6180 - auc: 0.6443 - val_loss: 0.6280 - val_accuracy: 0.6054 - val_auc: 0.6668
# Epoch 27/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6470 - accuracy: 0.6277 - auc: 0.6568 - val_loss: 0.6639 - val_accuracy: 0.6276 - val_auc: 0.6650
# Epoch 28/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6466 - accuracy: 0.6445 - auc: 0.6585 - val_loss: 0.7201 - val_accuracy: 0.5911 - val_auc: 0.6366
# Epoch 29/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6498 - accuracy: 0.6316 - auc: 0.6660 - val_loss: 0.6218 - val_accuracy: 0.6165 - val_auc: 0.6807
# Epoch 30/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6564 - accuracy: 0.6242 - auc: 0.6422 - val_loss: 0.6050 - val_accuracy: 0.6387 - val_auc: 0.7200
# Epoch 31/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6500 - accuracy: 0.6242 - auc: 0.6576 - val_loss: 0.6162 - val_accuracy: 0.6212 - val_auc: 0.6838
# Epoch 32/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6490 - accuracy: 0.6273 - auc: 0.6437 - val_loss: 0.5975 - val_accuracy: 0.6656 - val_auc: 0.7232
# Epoch 33/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6458 - accuracy: 0.6359 - auc: 0.6506 - val_loss: 0.7191 - val_accuracy: 0.6276 - val_auc: 0.6710
# Epoch 34/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6429 - accuracy: 0.6352 - auc: 0.6632 - val_loss: 0.6256 - val_accuracy: 0.6054 - val_auc: 0.6744
# Epoch 35/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6411 - accuracy: 0.6387 - auc: 0.6769 - val_loss: 0.6413 - val_accuracy: 0.5927 - val_auc: 0.6540
# Epoch 36/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6419 - accuracy: 0.6371 - auc: 0.6585 - val_loss: 0.9273 - val_accuracy: 0.5990 - val_auc: 0.6475
# Epoch 37/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6377 - accuracy: 0.6445 - auc: 0.6636 - val_loss: 0.6617 - val_accuracy: 0.6212 - val_auc: 0.6653
# Epoch 38/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6439 - accuracy: 0.6383 - auc: 0.6634 - val_loss: 0.6917 - val_accuracy: 0.6149 - val_auc: 0.6446
# Epoch 39/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6384 - accuracy: 0.6516 - auc: 0.6628 - val_loss: 0.7971 - val_accuracy: 0.5784 - val_auc: 0.5836
# Epoch 40/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6341 - accuracy: 0.6387 - auc: 0.6719 - val_loss: 0.7150 - val_accuracy: 0.6149 - val_auc: 0.6513
# Epoch 41/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6372 - accuracy: 0.6578 - auc: 0.6597 - val_loss: 0.6715 - val_accuracy: 0.6101 - val_auc: 0.6405
# Epoch 42/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6333 - accuracy: 0.6469 - auc: 0.6779 - val_loss: 0.6931 - val_accuracy: 0.6149 - val_auc: 0.6262
# Epoch 43/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6385 - accuracy: 0.6652 - auc: 0.6762 - val_loss: 0.7432 - val_accuracy: 0.6181 - val_auc: 0.6496
# Epoch 44/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6292 - accuracy: 0.6500 - auc: 0.6664 - val_loss: 0.6260 - val_accuracy: 0.6545 - val_auc: 0.7053
# Epoch 45/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6242 - accuracy: 0.6621 - auc: 0.6860 - val_loss: 0.7839 - val_accuracy: 0.5689 - val_auc: 0.6164
# Epoch 46/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6318 - accuracy: 0.6574 - auc: 0.6707 - val_loss: 0.8027 - val_accuracy: 0.6656 - val_auc: 0.6997
# Epoch 47/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6257 - accuracy: 0.6641 - auc: 0.6826 - val_loss: 0.6456 - val_accuracy: 0.6228 - val_auc: 0.6708
# Epoch 48/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6288 - accuracy: 0.6703 - auc: 0.6811 - val_loss: 0.6597 - val_accuracy: 0.6434 - val_auc: 0.6899
# Epoch 49/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6162 - accuracy: 0.6758 - auc: 0.7009 - val_loss: 0.9036 - val_accuracy: 0.5753 - val_auc: 0.6290
# Epoch 50/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6138 - accuracy: 0.6734 - auc: 0.6964 - val_loss: 0.6920 - val_accuracy: 0.6323 - val_auc: 0.6712
# Epoch 51/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6128 - accuracy: 0.6793 - auc: 0.6986 - val_loss: 0.7553 - val_accuracy: 0.6117 - val_auc: 0.6529
# Epoch 52/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6158 - accuracy: 0.6812 - auc: 0.6912 - val_loss: 0.8760 - val_accuracy: 0.5959 - val_auc: 0.6254
# Epoch 53/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5958 - accuracy: 0.7117 - auc: 0.7209 - val_loss: 1.3302 - val_accuracy: 0.5214 - val_auc: 0.5288
# Epoch 54/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5999 - accuracy: 0.7008 - auc: 0.7100 - val_loss: 0.6869 - val_accuracy: 0.6450 - val_auc: 0.6669
# Epoch 55/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6046 - accuracy: 0.6977 - auc: 0.7100 - val_loss: 0.7242 - val_accuracy: 0.6355 - val_auc: 0.6898
# Epoch 56/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5871 - accuracy: 0.7074 - auc: 0.7205 - val_loss: 0.8231 - val_accuracy: 0.6070 - val_auc: 0.6465
# Epoch 57/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5898 - accuracy: 0.7121 - auc: 0.7232 - val_loss: 0.7535 - val_accuracy: 0.6133 - val_auc: 0.6469
# Epoch 58/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5923 - accuracy: 0.7063 - auc: 0.7169 - val_loss: 0.8267 - val_accuracy: 0.6101 - val_auc: 0.6431
# Epoch 59/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5814 - accuracy: 0.7172 - auc: 0.7350 - val_loss: 0.6791 - val_accuracy: 0.6434 - val_auc: 0.6855
# Epoch 60/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5769 - accuracy: 0.7273 - auc: 0.7389 - val_loss: 0.7957 - val_accuracy: 0.6101 - val_auc: 0.6476
# Epoch 61/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5771 - accuracy: 0.7344 - auc: 0.7393 - val_loss: 1.0284 - val_accuracy: 0.5674 - val_auc: 0.5766
# Epoch 62/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5631 - accuracy: 0.7371 - auc: 0.7491 - val_loss: 0.9585 - val_accuracy: 0.5943 - val_auc: 0.6348
# Epoch 63/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5658 - accuracy: 0.7484 - auc: 0.7469 - val_loss: 0.6659 - val_accuracy: 0.6529 - val_auc: 0.7061
# Epoch 64/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5577 - accuracy: 0.7504 - auc: 0.7472 - val_loss: 0.6779 - val_accuracy: 0.6624 - val_auc: 0.7113
# Epoch 65/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5538 - accuracy: 0.7547 - auc: 0.7521 - val_loss: 0.8955 - val_accuracy: 0.6038 - val_auc: 0.6205
# Epoch 66/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5454 - accuracy: 0.7605 - auc: 0.7429 - val_loss: 0.8405 - val_accuracy: 0.5895 - val_auc: 0.6432
# Epoch 67/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5527 - accuracy: 0.7527 - auc: 0.7545 - val_loss: 0.8767 - val_accuracy: 0.6276 - val_auc: 0.6563
# Epoch 68/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5427 - accuracy: 0.7672 - auc: 0.7592 - val_loss: 0.7933 - val_accuracy: 0.6260 - val_auc: 0.6569
# Epoch 69/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5386 - accuracy: 0.7758 - auc: 0.7642 - val_loss: 0.7820 - val_accuracy: 0.5975 - val_auc: 0.6701
# Epoch 70/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5353 - accuracy: 0.7785 - auc: 0.7662 - val_loss: 0.7583 - val_accuracy: 0.6434 - val_auc: 0.6870
# Epoch 71/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5292 - accuracy: 0.7789 - auc: 0.7610 - val_loss: 0.8423 - val_accuracy: 0.6387 - val_auc: 0.6854
# Epoch 72/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5332 - accuracy: 0.7789 - auc: 0.7720 - val_loss: 0.9095 - val_accuracy: 0.6276 - val_auc: 0.6639
# Epoch 73/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5281 - accuracy: 0.7719 - auc: 0.7697 - val_loss: 0.7803 - val_accuracy: 0.6513 - val_auc: 0.6838
# Epoch 74/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5324 - accuracy: 0.7789 - auc: 0.7608 - val_loss: 0.7877 - val_accuracy: 0.6355 - val_auc: 0.6726
# Epoch 75/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5214 - accuracy: 0.7742 - auc: 0.7793 - val_loss: 0.7610 - val_accuracy: 0.6545 - val_auc: 0.6968
# Epoch 76/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5287 - accuracy: 0.7824 - auc: 0.7674 - val_loss: 0.7664 - val_accuracy: 0.6418 - val_auc: 0.6785
# Epoch 77/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5196 - accuracy: 0.7875 - auc: 0.7646 - val_loss: 0.7706 - val_accuracy: 0.6624 - val_auc: 0.6960
# Epoch 78/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5208 - accuracy: 0.7898 - auc: 0.7765 - val_loss: 0.8194 - val_accuracy: 0.6482 - val_auc: 0.6778
# Epoch 79/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5197 - accuracy: 0.7844 - auc: 0.7767 - val_loss: 0.7675 - val_accuracy: 0.6403 - val_auc: 0.6809
# Epoch 80/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5219 - accuracy: 0.7844 - auc: 0.7736 - val_loss: 0.8141 - val_accuracy: 0.6561 - val_auc: 0.6791
# Epoch 81/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5171 - accuracy: 0.7855 - auc: 0.7733 - val_loss: 0.8498 - val_accuracy: 0.6260 - val_auc: 0.6629
# Epoch 82/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5252 - accuracy: 0.7758 - auc: 0.7674 - val_loss: 0.7745 - val_accuracy: 0.6466 - val_auc: 0.6929
# Epoch 83/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5008 - accuracy: 0.8027 - auc: 0.7964 - val_loss: 0.8014 - val_accuracy: 0.6577 - val_auc: 0.6981
# Epoch 84/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5191 - accuracy: 0.7883 - auc: 0.7613 - val_loss: 0.8089 - val_accuracy: 0.6244 - val_auc: 0.6773
# Epoch 85/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5122 - accuracy: 0.7887 - auc: 0.7779 - val_loss: 0.8166 - val_accuracy: 0.6434 - val_auc: 0.6779
# Epoch 86/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5102 - accuracy: 0.7973 - auc: 0.7706 - val_loss: 0.8255 - val_accuracy: 0.6561 - val_auc: 0.6961
# Epoch 87/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5070 - accuracy: 0.7855 - auc: 0.7845 - val_loss: 0.7909 - val_accuracy: 0.6482 - val_auc: 0.6821
# Epoch 88/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5010 - accuracy: 0.7965 - auc: 0.7871 - val_loss: 0.8201 - val_accuracy: 0.6450 - val_auc: 0.6820
# Epoch 89/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5232 - accuracy: 0.7746 - auc: 0.7720 - val_loss: 0.7998 - val_accuracy: 0.6513 - val_auc: 0.6861
# Epoch 90/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5068 - accuracy: 0.8043 - auc: 0.7787 - val_loss: 0.7973 - val_accuracy: 0.6498 - val_auc: 0.6821
# Epoch 91/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5127 - accuracy: 0.7988 - auc: 0.7816 - val_loss: 0.7854 - val_accuracy: 0.6355 - val_auc: 0.6841
# Epoch 92/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5140 - accuracy: 0.7934 - auc: 0.7846 - val_loss: 0.8503 - val_accuracy: 0.6403 - val_auc: 0.6745
# Epoch 93/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5105 - accuracy: 0.7965 - auc: 0.7717 - val_loss: 0.8127 - val_accuracy: 0.6466 - val_auc: 0.6844
# Epoch 94/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5080 - accuracy: 0.8031 - auc: 0.7768 - val_loss: 0.7929 - val_accuracy: 0.6323 - val_auc: 0.6814
# Epoch 95/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5060 - accuracy: 0.8035 - auc: 0.7838 - val_loss: 0.8023 - val_accuracy: 0.6403 - val_auc: 0.6799
# Epoch 96/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5066 - accuracy: 0.7980 - auc: 0.7860 - val_loss: 0.8002 - val_accuracy: 0.6355 - val_auc: 0.6873
# Epoch 97/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5023 - accuracy: 0.8102 - auc: 0.7681 - val_loss: 0.7960 - val_accuracy: 0.6418 - val_auc: 0.6862
# Epoch 98/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5105 - accuracy: 0.7910 - auc: 0.7806 - val_loss: 0.7915 - val_accuracy: 0.6403 - val_auc: 0.6834
# Epoch 99/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.5086 - accuracy: 0.7969 - auc: 0.7744 - val_loss: 0.8475 - val_accuracy: 0.6577 - val_auc: 0.6842
# Epoch 100/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5102 - accuracy: 0.7852 - auc: 0.7745 - val_loss: 0.8233 - val_accuracy: 0.6577 - val_auc: 0.6883

# %%
import pickle as pk
def save_challenge_model(model_folder, model1, model2, m_name1, m_name2, param_feature) :
    os.makedirs(model_folder, exist_ok=True)
    info_fnm = os.path.join(model_folder, 'desc.pk')
    filename1 = os.path.join(model_folder, m_name1 + '_model1.hdf5')
    filename2 = os.path.join(model_folder, m_name2 + '_model2.hdf5')
    model1.save(filename1)
    model2.save(filename2)
    param_feature['model1'] = m_name1
    param_feature['model2'] = m_name2
    param_feature['model_fnm1'] = filename1
    param_feature['model_fnm2'] = filename2
    with open(info_fnm, 'wb') as f:
        pk.dump(param_feature, f, pk.HIGHEST_PROTOCOL)
    return 1

def load_challenge_model(model_folder, verbose):
    info_fnm = os.path.join(model_folder, 'desc.pk')
    with open(info_fnm, 'rb') as f:
        info_m = pk.load(f)
#    if info_m['model'] == 'toy' :
#        model = get_toy(info_m['mel_shape'])
#    filename = os.path.join(model_folder, info_m['model'] + '_model.hdf5')
#    model.load_weights(filename)
    return info_m

# %%
# Run model.
def run_model(model_folder, data_folder, output_folder, allow_failures, verbose):
    # Load models.
    if verbose >= 1:
        print('Loading Challenge model...')

    model = load_challenge_model(model_folder, verbose) ### Teams: Implement this function!!!

    # Find the patient data files.
    patient_files = find_patient_files(data_folder)
    num_patient_files = len(patient_files)

    if num_patient_files==0:
        raise Exception('No data was provided.')

    # Create a folder for the Challenge outputs if it does not already exist.
    os.makedirs(output_folder, exist_ok=True)

    # Run the team's model on the Challenge data.
    if verbose >= 1:
        print('Running model on Challenge data...')

#    @tf.function
    # Iterate over the patient files.
    for i in range(num_patient_files):
        if verbose >= 2:
            print('    {}/{}...'.format(i+1, num_patient_files))

        patient_data = load_patient_data(patient_files[i])
        recordings = load_recordings(data_folder, patient_data)

        # Allow or disallow the model to fail on parts of the data; helpful for debugging.
        try:
            classes, labels, probabilities = run_challenge_model(model, patient_data, recordings, verbose) ### Teams: Implement this function!!!
        except:
            if allow_failures:
                if verbose >= 2:
                    print('... failed.')
                classes, labels, probabilities = list(), list(), list()
            else:
                raise

        # Save Challenge outputs.
        head, tail = os.path.split(patient_files[i])
        root, extension = os.path.splitext(tail)
        output_file = os.path.join(output_folder, root + '.csv')
        patient_id = get_patient_id(patient_data)
        save_challenge_outputs(output_file, patient_id, classes, labels, probabilities)

    if verbose >= 1:
        print('Done.')

# %%
def run_challenge_model(model, data, recordings, verbose):

    murmur_classes = ['Present', 'Unknown', 'Absent']
    outcome_classes = ['Abnormal', 'Normal']

    if model['model1'] == 'toy1' :
        model1 = get_toy5_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'] )
    if model['model2'] == 'toy2' :
        model2 = get_toy5_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'])
    if model['model1'] == 'lcnn1' :
        model1 = get_LCNN_o_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'lcnn2' :
        model2 = get_LCNN_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'])
    if model['model1'] == 'resmax1' :
        model1 = get_ResMax_o_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'resmax2' :
        model2 = get_ResMax_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'])
    if model['model1'] == 'lcnn1_dr' :
        model1 = get_LCNN_o_1_dr(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'], dp = model['dp'], fc = model['fc'], ext = model[\
'ext'])
    if model['model2'] == 'lcnn2_dr' :
        model2 = get_LCNN_2_dr(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], dp = model['dp'], fc = model['fc'], ext = model['ext'])
    if model['model1'] == 'lcnn_rr_qrs1' :
        model1 = get_LCNN_o_5_dr_qrs1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'lcnn_rr_qrs2' :
        model2 = get_LCNN_o_5_dr_qrs1_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model1'] == 'lcnn_rr_qrs2_1' :
        model1 = get_LCNN_o_5_dr_qrs2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'lcnn_rr_qrs2_2' :
        model2 = get_LCNN_o_5_dr_qrs2_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    
    
    model1.load_weights(model['model_fnm1'])
    model2.load_weights(model['model_fnm2'])

#    classes = model['classes']
    # Load features.
    features = get_feature_one(data, verbose = 0)

    samp_sec = model['samp_sec']
    pre_emphasis = model['pre_emphasis']
    hop_length = model['hop_length']
    win_length = model['win_length']
    n_mels = model['n_mels']
    filter_scale = model['filter_scale']
    n_bins = model['n_bins']
    fmin = model['fmin']
    use_mel = model['use_mel']
    use_cqt = model['use_cqt']
    use_stft = model['use_stft']

    trim = model['trim']
    
    features['rr1'] = [] 
    for i in range(len(recordings)):
        try:
            ____, info = nk.ecg_process(recordings[i], sampling_rate=4000)
            rr = np.mean(np.diff(info['ECG_R_Peaks'])/4000)
            current_rr = rr
        except:
            current_rr=np.zeros(1)
        features['rr1'].append(current_rr)  
    features['rr1'] = np.array(features['rr1'])
    
    
    features['qrs1'] = []
    for i in range(len(recordings)):
        try:
            R_peaks, S_point, Q_point=EKG_QRS_detect1(recording1, 4000, True, False)
            qrs = np.mean(S_point-Q_point)
            current_qrs = qrs
        except:
            current_qrs=np.zeros(1) 
        features['qrs1'].append(current_rr)  
    features['qrs1'] = np.array(features['qrs1'])
    

    features['mel1'] = []
    for i in range(len(recordings)) :
        if use_mel :
            mel1 = feature_extract_melspec(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length,
                                           win_length = win_length, n_mels = n_mels, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1) )
        features['mel1'].append(mel1)
    M, N = features['mel1'][0].shape

    if use_mel :
        for i in range(len(features['mel1'])) :
            features['mel1'][i] = features['mel1'][i].reshape(M,N,1)
    features['mel1'] = np.array(features['mel1'])

    features['cqt1'] = []
    for i in range(len(recordings)) :
        if use_cqt :
            mel1 = feature_extract_cqt(recordings[i], samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale,
                                        n_bins = n_bins, fmin = fmin, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1))
        features['cqt1'].append(mel1)
    M, N = features['cqt1'][0].shape
    if use_cqt :
        for i in range(len(features['cqt1'])) :
            features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)
    features['cqt1'] = np.array(features['cqt1'])

    features['stft1'] = []
    for i in range(len(recordings)) :
        if use_stft :
            mel1 = feature_extract_stft(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length,
                                        win_length = win_length, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1) )
        features['stft1'].append(mel1)
    M, N = features['stft1'][0].shape
    if use_stft :
        for i in range(len(features['stft1'])) :
            features['stft1'][i] = features['stft1'][i].reshape(M,N,1)
    features['stft1'] = np.array(features['stft1'])

    #    print(features)
    # Impute missing data.
    res1 = model1.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], 
                           features['rr1'], features['qrs1'], features['mel1'], features['cqt1'], features['stft1']])
    res2 = model2.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], 
                           features['rr1'], features['qrs1'], features['mel1'], features['cqt1'], features['stft1']])

    # Get classifier probabilities.
    if model['ord1'] :
        idx1 = res1.argmax(axis=0)[0]
        murmur_p = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
        murmur_probabilities = np.zeros((3,))
        murmur_probabilities[0] = murmur_p[0]
        murmur_probabilities[1] = 0
        murmur_probabilities[2] = murmur_p[1]
        outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기
    else :
        if model['mm_mean'] :
            murmur_probabilities = res1.mean(axis = 0)
        else :
            idx1 = res1.argmax(axis=0)[0]
            murmur_probabilities = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
        outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기

        
    ## 이부분도 생각 필요.. rule 을 cost를 maximize 하는 기준으로 threshold 탐색 필요할지도..
    # Choose label with highest probability.
    murmur_labels = np.zeros(len(murmur_classes), dtype=np.int_)
    idx = np.argmax(murmur_probabilities)
    murmur_labels[idx] = 1
    outcome_labels = np.zeros(len(outcome_classes), dtype=np.int_)
    idx = np.argmax(outcome_probabilities)
    outcome_labels[idx] = 1

    # Concatenate classes, labels, and probabilities.
    classes = murmur_classes + outcome_classes
    labels = np.concatenate((murmur_labels, outcome_labels))
    probabilities = np.concatenate((murmur_probabilities, outcome_probabilities))

    return classes, labels, probabilities

# %%
save_challenge_model(model_folder, model1, model2, m_name1 = 'lcnn_rr_qrs2_1', m_name2 = 'lcnn_rr_qrs2_2', param_feature = params_feature)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 1

# %%
model_folder
# Out:
# 'lcnn__rr_qrs2'

# %%
data_folder = test_folder
data_folder
# Out:
# '/Data2/hmd/data_split/murmur/test'

# %%
output_folder
# Out:
# '/Data2/hmd/hmd_sy/notebooks/out_lcnn__rr_qrs2'

# %%
run_model(model_folder, test_folder, output_folder, allow_failures = True, verbose = 1)
# Out:
# Loading Challenge model...
# Running model on Challenge data...
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb14c66b4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb14c6043a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Done.

# %%
murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)
classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
    + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string

if len(sys.argv) == 3:
    print(output_string)
elif len(sys.argv) == 4:
    with open(sys.argv[3], 'w') as f:
        f.write(output_string)
#Murmur scores
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.562,0.843,0.801,17140.771
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.649,0.660,0.532,16117.494
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.782,0.000,0.904
# Accuracy,0.895,0.000,0.914
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.586,0.711
# Accuracy,0.469,0.860

# %%
label_folder = test_folder
murmur_classes = ['Present', 'Unknown', 'Absent']
outcome_classes = ['Abnormal', 'Normal']

# Load and parse label and model output files.
label_files, output_files = find_challenge_files(label_folder, output_folder)
murmur_labels = load_murmurs(label_files, murmur_classes)
murmur_binary_outputs, murmur_scalar_outputs = load_classifier_outputs(output_files, murmur_classes)
outcome_labels = load_outcomes(label_files, outcome_classes)
outcome_binary_outputs, outcome_scalar_outputs = load_classifier_outputs(output_files, outcome_classes)


print(np.mean(murmur_scalar_outputs[:,0]))
print(np.mean(murmur_scalar_outputs[:,2]))
print(np.mean(outcome_scalar_outputs[:,0]))
print(np.mean(outcome_scalar_outputs[:,1]))
# Out:
# 0.3017470398613804
# 0.6982529666305262
# 0.42276952842845344
# 0.5772304692884196

# %%
for th1 in [0.01, 0.05, 0.1, 0.15,0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8] :
    murmur_binary_outputs[:,0] = murmur_scalar_outputs[:,0] > th1
    murmur_binary_outputs[:,2] = murmur_scalar_outputs[:,2] > 1 - th1
    outcome_binary_outputs[:,0] = outcome_scalar_outputs[:,0] > th1
    outcome_binary_outputs[:,1] = outcome_scalar_outputs[:,1] > 1 - th1
    # For each patient, set the 'Present' or 'Abnormal' class to positive if no class is positive or if multiple classes are positive.
    murmur_labels = enforce_positives(murmur_labels, murmur_classes, 'Present')
    murmur_binary_outputs = enforce_positives(murmur_binary_outputs, murmur_classes, 'Present')
    outcome_labels = enforce_positives(outcome_labels, outcome_classes, 'Abnormal')
    outcome_binary_outputs = enforce_positives(outcome_binary_outputs, outcome_classes, 'Abnormal')
    # Evaluate the murmur model by comparing the labels and model outputs.
    murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes = compute_auc(murmur_labels, murmur_scalar_outputs)
    murmur_f_measure, murmur_f_measure_classes = compute_f_measure(murmur_labels, murmur_binary_outputs)
    murmur_accuracy, murmur_accuracy_classes = compute_accuracy(murmur_labels, murmur_binary_outputs)
    murmur_weighted_accuracy = compute_weighted_accuracy(murmur_labels, murmur_binary_outputs, murmur_classes) # This is the murmur scoring metric.
    murmur_cost = compute_cost(outcome_labels, murmur_binary_outputs, outcome_classes, murmur_classes) # Use *outcomes* to score *murmurs* for the Challenge cost metric, but this is not the actual murmur scoring metric.
    murmur_scores = (murmur_classes, murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes, \
                 murmur_f_measure, murmur_f_measure_classes, murmur_accuracy, murmur_accuracy_classes, murmur_weighted_accuracy, murmur_cost)

    # Evaluate the outcome model by comparing the labels and model outputs.
    outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes = compute_auc(outcome_labels, outcome_scalar_outputs)
    outcome_f_measure, outcome_f_measure_classes = compute_f_measure(outcome_labels, outcome_binary_outputs)
    outcome_accuracy, outcome_accuracy_classes = compute_accuracy(outcome_labels, outcome_binary_outputs)
    outcome_weighted_accuracy = compute_weighted_accuracy(outcome_labels, outcome_binary_outputs, outcome_classes)
    outcome_cost = compute_cost(outcome_labels, outcome_binary_outputs, outcome_classes, outcome_classes) # This is the clinical outcomes scoring metric.
    outcome_scores = (outcome_classes, outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes, \
                  outcome_f_measure, outcome_f_measure_classes, outcome_accuracy, outcome_accuracy_classes, outcome_weighted_accuracy, outcome_cost)



    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
    murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
    outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
                + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
    print("threshold: ", th1)
    print(output_string)
    print("-------------")
# Out:
# threshold:  0.01
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.170,0.262,0.544,14311.277
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.355,0.000,0.156
# Accuracy,1.000,0.000,0.086
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.05
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.337,0.492,0.652,12655.241
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.360,0.518,0.835,14704.473
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.443,0.000,0.567
# Accuracy,0.974,0.000,0.410
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.678,0.042
# Accuracy,0.990,0.022
#
# -------------
# threshold:  0.1
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.411,0.618,0.706,12927.102
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.419,0.529,0.804,13473.581
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.514,0.000,0.719
# Accuracy,0.947,0.000,0.590
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.672,0.167
# Accuracy,0.939,0.097
#
# -------------
# threshold:  0.15
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.440,0.665,0.730,13315.266
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.485,0.560,0.801,12333.634
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.554,0.000,0.765
# Accuracy,0.947,0.000,0.655
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.682,0.288
# Accuracy,0.918,0.183
#
# -------------
# threshold:  0.2
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.482,0.733,0.765,14360.911
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.540,0.581,0.767,11646.925
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.621,0.000,0.825
# Accuracy,0.947,0.000,0.748
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.677,0.403
# Accuracy,0.857,0.290
#
# -------------
# threshold:  0.25
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.504,0.770,0.774,14910.999
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.594,0.618,0.765,11064.184
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.654,0.000,0.858
# Accuracy,0.921,0.000,0.806
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.692,0.497
# Accuracy,0.837,0.387
#
# -------------
# threshold:  0.3
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.518,0.791,0.784,15096.470
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.665,0.670,0.741,10962.256
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.680,0.000,0.875
# Accuracy,0.921,0.000,0.835
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.707,0.623
# Accuracy,0.776,0.559
#
# -------------
# threshold:  0.35
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.519,0.791,0.774,15706.171
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.691,0.691,0.707,11642.536
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.687,0.000,0.870
# Accuracy,0.895,0.000,0.842
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.704,0.678
# Accuracy,0.714,0.667
#
# -------------
# threshold:  0.4
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.542,0.822,0.790,16524.322
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.675,0.675,0.633,13388.893
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.731,0.000,0.895
# Accuracy,0.895,0.000,0.885
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.659,0.690
# Accuracy,0.612,0.742
#
# -------------
# threshold:  0.45
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.550,0.832,0.795,16729.065
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.671,0.675,0.592,14514.172
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.747,0.000,0.903
# Accuracy,0.895,0.000,0.899
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.635,0.708
# Accuracy,0.551,0.806
#
# -------------
# threshold:  0.5
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.562,0.843,0.801,17140.771
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.649,0.660,0.532,16117.494
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.782,0.000,0.904
# Accuracy,0.895,0.000,0.914
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.586,0.711
# Accuracy,0.469,0.860
#
# -------------
# threshold:  0.55
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.554,0.838,0.776,17765.302
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.658,0.675,0.516,16723.457
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.762,0.000,0.901
# Accuracy,0.842,0.000,0.921
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.581,0.735
# Accuracy,0.439,0.925
#
# -------------
# threshold:  0.6
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.536,0.822,0.736,17762.655
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.650,0.670,0.501,17138.143
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.716,0.000,0.892
# Accuracy,0.763,0.000,0.921
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.566,0.734
# Accuracy,0.418,0.935
#
# -------------
# threshold:  0.65
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.543,0.832,0.730,18388.678
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.630,0.660,0.463,18179.253
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.727,0.000,0.900
# Accuracy,0.737,0.000,0.942
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.526,0.735
# Accuracy,0.367,0.968
#
# -------------
# threshold:  0.7
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.540,0.827,0.717,19015.930
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.604,0.644,0.424,19224.494
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.730,0.000,0.891
# Accuracy,0.711,0.000,0.942
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.477,0.730
# Accuracy,0.316,0.989
#
# -------------
# threshold:  0.75
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.554,0.843,0.725,19643.525
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.581,0.628,0.398,19852.251
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.761,0.000,0.902
# Accuracy,0.711,0.000,0.964
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.441,0.722
# Accuracy,0.286,0.989
#
# -------------
# threshold:  0.8
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.763,0.608,0.559,0.848,0.728,19852.766
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.740,0.724,0.550,0.607,0.364,20689.118
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.500,0.852
# AUPRC,0.864,0.073,0.887
# F-measure,0.771,0.000,0.906
# Accuracy,0.711,0.000,0.971
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.740,0.740
# AUPRC,0.775,0.673
# F-measure,0.390,0.710
# Accuracy,0.245,0.989
#
# -------------
