# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# /tmp/ipykernel_73299/912229180.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## LCNN

# %%
pwd
# Out:
# '/Data2/hmd/hmd_sy/notebooks'

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats
import librosa
import librosa.display
import math
import sys
#sys.path.insert(0,'/home/ikwak2/hmd/notebooks')
#sys.path.insert(0,'/home/ikwak2/hmd/iy_classifier')
sys.path.insert(0,'/Data2/hmd/hmd_sy/evaluation-2022')
sys.path.insert(0,'utils')
from helper_code import *
from get_feature import *
from models import *
from Generator0 import *
import tensorflow as tf
import datetime
from evaluate_model import *
# Out:
# 2022-07-29 10:57:36.075047: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
root_dir = 'physionet.org/files/circor-heart-sound/1.0.3'
training_data_file = root_dir + '/' + 'training_data.csv'
training_data_dir = root_dir + '/' + 'training_data'
model_dir = root_dir + '/' + 'model'

# %%
import tensorflow as tf

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
print(gpu_info)
# Out:
# Fri Jul 29 10:57:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |   4344MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Quadro RTX 8000     On   | 00000000:3D:00.0 Off |                  Off |
# | 33%   27C    P8     5W / 260W |   3310MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Quadro RTX 8000     On   | 00000000:3E:00.0 Off |                  Off |
# | 33%   28C    P8    13W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Quadro RTX 8000     On   | 00000000:40:00.0 Off |                  Off |
# | 33%   26C    P8     7W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Quadro RTX 8000     On   | 00000000:41:00.0 Off |                  Off |
# | 33%   28C    P8    14W / 260W |    518MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[4], 'GPU')
    except RuntimeError as e:
        print(e)
# Out:
# 2022-07-29 10:57:44.206650: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-07-29 10:57:44.263906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1a:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-29 10:57:44.266143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:3d:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-29 10:57:44.268430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:3e:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-29 10:57:44.270694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:40:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-29 10:57:44.272959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:41:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-29 10:57:44.273013: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-07-29 10:57:44.276699: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-07-29 10:57:44.276775: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-07-29 10:57:44.277799: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-07-29 10:57:44.278057: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-07-29 10:57:44.279015: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-07-29 10:57:44.279823: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-07-29 10:57:44.279987: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-07-29 10:57:44.296589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4

# %%
data_folder =  '/Data2/hmd/physionet.org/files/circor-heart-sound/1.0.3/training_data'
train_folder =  '/Data2/hmd/data_split/murmur/train'
test_folder = '/Data2/hmd/data_split/murmur/test'

# %% [markdown]
# ## QRS_Utils

# %%
## detect QRS complex from ECG time series

import numpy as np 
import math
from numpy import genfromtxt
import matplotlib.pyplot as plt

def read_ecg(file_name):
	return genfromtxt(file_name, delimiter=',')

def lgth_transform(ecg, ws):
	lgth=ecg.shape[0]
	sqr_diff=np.zeros(lgth)
	diff=np.zeros(lgth)
	ecg=np.pad(ecg, ws, 'edge')
	for i in range(lgth):
		temp=ecg[i:i+ws+ws+1]
		left=temp[ws]-temp[0]
		right=temp[ws]-temp[-1]
		diff[i]=min(left, right)
		diff[diff<0]=0
	# sqr_diff=np.multiply(diff, diff)
	# diff=ecg[:-1]-ecg[1:]
	# sqr_diff[:-1]=np.multiply(diff, diff)
	# sqr_diff[-1]=sqr_diff[-2]
	return np.multiply(diff, diff)

def integrate(ecg, ws):
	lgth=ecg.shape[0]
	integrate_ecg=np.zeros(lgth)
	ecg=np.pad(ecg, math.ceil(ws/2), mode='symmetric')
	for i in range(lgth):
		integrate_ecg[i]=np.sum(ecg[i:i+ws])/ws
	return integrate_ecg

def find_peak(data, ws):
	lgth=data.shape[0]
	true_peaks=list()
	for i in range(lgth-ws+1):
		temp=data[i:i+ws]
		if np.var(temp)<5:
			continue
		index=int((ws-1)/2)
		peak=True
		for j in range(index):
			if temp[index-j]<=temp[index-j-1] or temp[index+j]<=temp[index+j+1]:
				peak=False
				break

		if peak is True:
			true_peaks.append(int(i+(ws-1)/2))
	return np.asarray(true_peaks)

def find_R_peaks(ecg, peaks, ws):
	num_peak=peaks.shape[0]
	R_peaks=list()
	for index in range(num_peak):
		i=peaks[index]
		if i-2*ws>0 and i<ecg.shape[0]:
			temp_ecg=ecg[i-2*ws:i]
			R_peaks.append(int(np.argmax(temp_ecg)+i-2*ws))
	return np.asarray(R_peaks)

def find_S_point(ecg, R_peaks):
	num_peak=R_peaks.shape[0]
	S_point=list()
	for index in range(num_peak):
		i=R_peaks[index]
		cnt=i
		if cnt+1>=ecg.shape[0]:
			break
		while ecg[cnt]>ecg[cnt+1]:
			cnt+=1
			if cnt>=ecg.shape[0]:
				break
		S_point.append(cnt)
	return np.asarray(S_point)


def find_Q_point(ecg, R_peaks):
	num_peak=R_peaks.shape[0]
	Q_point=list()
	for index in range(num_peak):
		i=R_peaks[index]
		cnt=i
		if cnt-1<0:
			break
		while ecg[cnt]>ecg[cnt-1]:
			cnt-=1
			if cnt<0:
				break
		Q_point.append(cnt)
	return np.asarray(Q_point)

# QRS 계산하는 함수
def EKG_QRS_detect1(ecg, fs, QS, plot=False):
	sig_lgth=ecg.shape[0]
	ecg=ecg-np.mean(ecg)
	ecg_lgth_transform=lgth_transform(ecg, int(fs/222))
	# ecg_lgth_transform=lgth_transform(ecg_lgth_transform, int(fs/40))

	ws=int(fs/89)
	ecg_integrate=integrate(ecg_lgth_transform, ws)/ws
	ws=int(fs/67)
	ecg_integrate=integrate(ecg_integrate, ws)
	ws=int(fs/400)
	ecg_integrate=integrate(ecg_integrate, ws)
	ws=int(fs/800)
	ecg_integrate=integrate(ecg_integrate, ws)

	peaks=find_peak(ecg_integrate, int(fs/111))
	R_peaks=find_R_peaks(ecg, peaks, int(fs/444))
	if QS:
		S_point=find_S_point(ecg, R_peaks)
		Q_point=find_Q_point(ecg, R_peaks)
	else:
		S_point=None
		Q_point=None
	if plot:
		index=np.arange(sig_lgth)/fs
		fig, ax=plt.subplots()
		ax.plot(index, ecg, 'b', label='EKG')
		ax.plot(R_peaks/fs, ecg[R_peaks], 'ro', label='R peaks')
		if QS:
			ax.plot(S_point/fs, ecg[S_point], 'go', label='S')
			ax.plot(Q_point/fs, ecg[Q_point], 'yo', label='Q')
		ax.set_xlim([0, sig_lgth/fs])
		ax.set_xlabel('Time [sec]')
		ax.legend()
		# ax[1].plot(ecg_integrate)
		# ax[1].set_xlim([0, ecg_integrate.shape[0]])
		# ax[2].plot(ecg_lgth_transform)
		# ax[2].set_xlim([0, ecg_lgth_transform.shape[0]])
		plt.figure(figsize=(20,45))
		plt.show()
	return R_peaks, S_point, Q_point

# %% [markdown]
# ## Modeling

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint

# %%
def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start
    elif e > end:
        return lr_end

    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))

    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

# %% [markdown]
# ### get feature 함수확장: 음성피쳐 옵션들과, 추가 음성들 고려한 피쳐추출

# %%
patient_files_trn = find_patient_files(train_folder)
patient_files_test = find_patient_files(test_folder)

# %%
pwd
# Out:
# '/Data2/hmd/hmd_sy/notebooks'

# %%
model_folder = 'lcnn__rr_qrs1'
output_folder = '/Data2/hmd/hmd_sy/notebooks/out_lcnn__rr_qrs1'

# %%
def get_features_3lb_all_ord_rr_qrs(data_folder, patient_files_trn, po = .3,
                          samp_sec=20, pre_emphasis = 0, hop_length=256, win_length = 512, n_mels = 100,
                             filter_scale = 1, n_bins = 80, fmin = 10, trim = 4000,
                             use_mel = True, use_cqt = False, use_stft = False, use_raw = False,
                             use_rr = False, use_qrs=False
                         ) :
    features = dict()
    features['id'] = []
    features['age'] = []
    features['sex'] = []
    features['hw'] = []
    features['preg'] = []
    features['loc'] = []
    features['mel1'] = []
    features['cqt1'] = []
    features['stft1'] = []
    features['raw1'] = []
    features['rr1'] = []
    features['qrs1'] = []
    
    mm_labels = []
    out_labels = []

    age_classes = ['Neonate', 'Infant', 'Child', 'Adolescent', 'Young Adult']
    recording_locations = ['AV', 'MV', 'PV', 'TV', 'PhC']

    num_patient_files = len(patient_files_trn)

    for i in tqdm.tqdm(range(num_patient_files)) :

        # Load the current patient data and recordings.
        current_patient_data = load_patient_data(patient_files_trn[i])
        num_locations = get_num_locations(current_patient_data)
        recording_information = current_patient_data.split('\n')[1:num_locations+1]
        for j in range(num_locations) :
            entries = recording_information[j].split(' ')
            recording_file = entries[2]
            filename = os.path.join(data_folder, recording_file)

            # Extract id
            id1 = recording_file.split('_')[0]
            features['id'].append(id1)

            # Extract melspec
            if use_mel :
                mel1 = feature_extract_melspec(filename, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                               win_length = win_length, n_mels = n_mels, trim = trim)[0]
            else :
                mel1 = np.zeros( (1,1,1) )
            features['mel1'].append(mel1)

            if use_cqt :
                mel2 = feature_extract_cqt(filename, samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale, 
                                           n_bins = n_bins, fmin = fmin, trim = trim)[0]
            else :
                mel2 = np.zeros( (1,1,1) )
            features['cqt1'].append(mel2)

            if use_stft :
                mel3 = feature_extract_stft(filename, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                            win_length = win_length, trim = trim)[0]
            else :
                mel3 = np.zeros( (1,1,1) )
            features['stft1'].append(mel3)

            if use_raw :
                frequency1, recording1 = sp.io.wavfile.read(filename)
            else :
                recording1 = np.zeros((1))
            features['raw1'].append(recording1)
            
            
            if use_rr :
                try:
                    ____, recording1 = sp.io.wavfile.read(filename)
                    ____, info = nk.ecg_process(recording1, sampling_rate=4000)
                    rr = np.mean(np.diff(info['ECG_R_Peaks'])/4000)
                    current_rr = rr
                except:
                    print(filename)
                    current_rr=np.zeros((1))
            else :
                current_rr = np.zeros((1))
            features['rr1'].append(current_rr)        
            
            
            if use_qrs :
                ____, recording1 = sp.io.wavfile.read(filename)
                R_peaks, S_point, Q_point=EKG_QRS_detect1(recording1, 4000, True, False)
                qrs = np.mean(S_point-Q_point)
            else :
                qrs = np.zeros((1))
            features['qrs1'].append(qrs)   
            
            
            # Extract age_group
            age_group = get_age(current_patient_data)
            current_age_group = np.zeros(6, dtype=int)
            if age_group in age_classes:
                j = age_classes.index(age_group)
                current_age_group[j] = 1
            else :
                current_age_group[5] = 1
            features['age'].append(current_age_group)

            # Extract sex
            sex = get_sex(current_patient_data)
            sex_features = np.zeros(2, dtype=int)
            if compare_strings(sex, 'Female'):
                sex_features[0] = 1
            elif compare_strings(sex, 'Male'):
                sex_features[1] = 1
            features['sex'].append(sex_features)

            # Extract height and weight.
            height = get_height(current_patient_data)
            weight = get_weight(current_patient_data)
            ## simple impute
            if math.isnan(height) :
                height = 110.846
            if math.isnan(weight) :
                weight = 23.767
                
            features['hw'].append(np.array([height, weight]))

            # Extract pregnancy
            is_pregnant = get_pregnancy_status(current_patient_data)
            features['preg'].append(is_pregnant)

            # Extract location
            locations = entries[0]
            num_recording_locations = len(recording_locations)
            loc_features = np.zeros(num_recording_locations)
            if locations in recording_locations:
                j = recording_locations.index(locations)
                loc_features[j] = 1
            features['loc'].append(loc_features)

            # Extract labels 
            mm_label = get_murmur(current_patient_data)
            out_label = get_outcome(current_patient_data)
            if mm_label == 'Absent' :
                current_mm_labels = np.array([0, 1])
            elif mm_label == 'Unknown' :
                current_mm_labels = np.array([po, 1-po])
            else :
                mm_loc = get_murmur_loc(current_patient_data)
                if mm_loc == 'nan' :
                    current_mm_labels = np.array([0.9, 0.1])
                else :
                    mm_loc = mm_loc.split('+')
                    if locations in mm_loc :
                        current_mm_labels = np.array([1, 0])
                    else :
                        current_mm_labels = np.array([0.8, 0.2])

            if out_label == 'Normal' :
                current_out_labels = np.array([0, 1])
            else :
                current_out_labels = np.array([1, 0])
#                if mm_label == 'Absent' :
#                    current_out_labels = np.array([0.8, 0.2])
#                elif mm_label == 'unknown' :
#                    current_out_labels = np.array([0.85, 0.15])
#                else :
#                    current_out_labels = np.array([1, 0])
                
            mm_labels.append(current_mm_labels)
            out_labels.append(current_out_labels)

    if use_mel : 
        M, N = features['mel1'][i].shape
        for i in range(len(features['mel1'])) :
            features['mel1'][i] = features['mel1'][i].reshape(M,N,1)
        print("melspec: ", M,N)
    else :
        M, N, _ = features['mel1'][i].shape
    mel_input_shape = (M,N,1)
        
    if use_cqt :
        M, N = features['cqt1'][i].shape
        for i in range(len(features['cqt1'])) :
            features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)
        print("cqt: ", M,N)
    else :
        M, N, _ = features['cqt1'][i].shape
    cqt_input_shape = (M,N,1)

    
    if use_stft :
        M, N = features['stft1'][i].shape
        for i in range(len(features['stft1'])) :
            features['stft1'][i] = features['stft1'][i].reshape(M,N,1)
        print("stft: ", M,N)
    else :
        M, N, _ = features['stft1'][i].shape
    stft_input_shape = (M,N,1)
        
    for k1 in features.keys() :
        features[k1] = np.array(features[k1])
    
    mm_labels = np.array(mm_labels)
    out_labels = np.array(out_labels)
    return features, mm_labels, out_labels, mel_input_shape, cqt_input_shape, stft_input_shape

# %%
trim = 0
use_mel = True
use_cqt = True #np.random.choice([True,False])
use_stft = True #np.random.choice([True,False])
use_rr = True
use_qrs = False

params_feature = {'samp_sec': 20,
                  #### melspec, stft 피쳐 옵션들
                  'pre_emphasis': 0,
                  'hop_length': 128,
                  'win_length':256,
                  'n_mels': 100,
                  #### cqt 피쳐 옵션들
                  'filter_scale': 1,
                  'n_bins': 80,
                  'fmin': 10,
                  ### 사용할 피쳐 지정
                      'trim' : trim, # 앞뒤 얼마나 자를지? 4000 이면 1초
                      'use_mel' : use_mel,
                      'use_cqt' : use_cqt,
                      'use_stft' : use_stft,
                      'use_rr': use_rr,
                      'use_qrs': use_qrs
    }

# %%
features_trn, mm_lbs_trn, out_lbs_trn, mel_input_shape, cqt_input_shape, stft_input_shape = get_features_3lb_all_ord_rr_qrs(train_folder, patient_files_trn, **params_feature)
features_test, mm_lbs_test, out_lbs_test, _, _, _ = get_features_3lb_all_ord_rr_qrs(test_folder, patient_files_test, **params_feature)
# Out:
#   0%|▏                                        | 3/751 [01:50<7:47:23, 37.49s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   1%|▍                                        | 7/751 [04:24<8:17:20, 40.11s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   2%|▋                                       | 12/751 [06:33<5:51:56, 28.57s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   4%|█▍                                      | 27/751 [14:28<8:23:07, 41.69s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   5%|██▏                                     | 40/751 [25:22<9:45:39, 49.42s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   5%|██▏                                    | 41/751 [26:27<10:40:15, 54.11s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   6%|██▏                                     | 42/751 [27:00<9:25:47, 47.88s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   6%|██▍                                    | 48/751 [32:07<10:57:52, 56.15s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   7%|██▉                                     | 56/751 [39:37<9:07:38, 47.28s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   8%|███▎                                    | 63/751 [44:47<8:09:51, 42.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   9%|███▌                                    | 66/751 [47:18<9:07:34, 47.96s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   9%|███▍                                   | 67/751 [48:23<10:04:34, 53.03s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   9%|███▌                                    | 68/751 [48:48<8:28:07, 44.64s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  11%|████▌                                   | 85/751 [57:08<4:06:49, 22.24s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  12%|████▋                                   | 87/751 [58:07<4:39:46, 25.28s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  12%|████▌                                 | 89/751 [1:00:17<8:15:36, 44.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  12%|████▌                                 | 90/751 [1:01:20<9:16:06, 50.48s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  13%|████▉                                 | 98/751 [1:05:48<6:35:25, 36.33s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  14%|█████                                | 104/751 [1:09:55<6:50:01, 38.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▎                               | 109/751 [1:13:10<7:56:50, 44.56s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▌                               | 114/751 [1:17:12<8:29:14, 47.97s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▋                               | 115/751 [1:17:44<7:35:39, 42.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  15%|█████▋                               | 116/751 [1:18:41<8:19:29, 47.20s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  16%|█████▊                               | 117/751 [1:19:28<8:20:01, 47.32s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  17%|██████▍                              | 131/751 [1:29:33<7:57:42, 46.23s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  18%|██████▌                              | 134/751 [1:32:32<9:43:19, 56.73s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  19%|██████▉                              | 140/751 [1:35:57<5:59:40, 35.32s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  20%|███████▎                             | 148/751 [1:40:09<5:02:22, 30.09s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  20%|███████▍                             | 152/751 [1:41:55<4:27:18, 26.77s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  21%|███████▌                             | 154/751 [1:43:02<5:10:37, 31.22s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  21%|███████▋                             | 155/751 [1:43:50<6:02:51, 36.53s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  22%|████████▏                            | 166/751 [1:48:57<4:20:33, 26.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  22%|████████▏                            | 167/751 [1:49:49<5:33:46, 34.29s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  23%|████████▍                            | 171/751 [1:52:14<5:28:34, 33.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  24%|████████▊                            | 179/751 [1:58:02<6:40:00, 41.96s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  24%|████████▉                            | 181/751 [1:59:07<5:37:20, 35.51s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  24%|█████████                            | 183/751 [2:00:45<6:34:33, 41.68s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  25%|█████████▏                           | 186/751 [2:02:08<5:15:33, 33.51s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  25%|█████████▍                           | 191/751 [2:05:49<6:12:45, 39.94s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▍                           | 192/751 [2:06:13<5:29:35, 35.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▌                           | 193/751 [2:07:00<6:00:24, 38.75s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▌                           | 194/751 [2:07:54<6:41:30, 43.25s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  26%|█████████▋                           | 197/751 [2:10:07<6:31:19, 42.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  27%|█████████▊                           | 200/751 [2:12:19<6:35:19, 43.05s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  27%|██████████                           | 203/751 [2:13:52<5:11:17, 34.08s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  28%|██████████▍                          | 211/751 [2:19:02<4:54:30, 32.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  28%|██████████▍                          | 213/751 [2:20:31<5:51:13, 39.17s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  28%|██████████▌                          | 214/751 [2:21:24<6:27:34, 43.30s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  29%|██████████▊                          | 219/751 [2:25:10<7:22:36, 49.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|███████████                          | 225/751 [2:29:48<6:44:34, 46.15s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|███████████▏                         | 227/751 [2:31:14<6:16:01, 43.06s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|███████████▏                         | 228/751 [2:31:51<5:59:50, 41.28s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  31%|███████████▍                         | 232/751 [2:34:51<6:23:49, 44.37s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  31%|███████████▍                         | 233/751 [2:35:47<6:53:56, 47.95s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  31%|███████████▋                         | 236/751 [2:38:18<7:01:30, 49.11s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  32%|███████████▊                         | 241/751 [2:42:47<7:25:22, 52.40s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  33%|████████████                         | 245/751 [2:45:06<5:03:44, 36.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  34%|████████████▍                        | 253/751 [2:50:20<5:49:06, 42.06s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  34%|████████████▌                        | 256/751 [2:52:39<6:22:51, 46.41s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  35%|████████████▊                        | 260/751 [2:55:08<5:47:44, 42.49s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  35%|████████████▉                        | 263/751 [2:56:58<5:01:07, 37.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  35%|█████████████                        | 264/751 [2:57:51<5:40:50, 41.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  36%|█████████████▍                       | 273/751 [3:04:49<6:17:25, 47.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  36%|█████████████▍                       | 274/751 [3:05:42<6:29:02, 48.94s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  37%|█████████████▌                       | 276/751 [3:07:33<6:54:36, 52.37s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  37%|█████████████▋                       | 279/751 [3:09:35<6:04:17, 46.31s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  38%|█████████████▉                       | 283/751 [3:12:34<5:51:38, 45.08s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  38%|██████████████                       | 286/751 [3:15:01<5:49:58, 45.16s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  39%|██████████████▌                      | 296/751 [3:21:41<4:53:02, 38.64s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|██████████████▊                      | 300/751 [3:24:38<5:14:49, 41.88s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|██████████████▊                      | 301/751 [3:25:29<5:34:44, 44.63s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|██████████████▉                      | 304/751 [3:27:57<5:57:22, 47.97s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  41%|███████████████                      | 306/751 [3:29:36<6:03:10, 48.97s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  41%|███████████████▏                     | 307/751 [3:30:26<6:03:24, 49.11s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▍                     | 313/751 [3:34:21<5:06:44, 42.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▌                     | 315/751 [3:35:34<4:59:38, 41.23s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▌                     | 317/751 [3:36:38<4:11:13, 34.73s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  42%|███████████████▋                     | 318/751 [3:37:29<4:47:24, 39.82s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  43%|███████████████▊                     | 320/751 [3:38:46<4:32:50, 37.98s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  43%|████████████████                     | 326/751 [3:43:07<5:32:48, 46.98s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  44%|████████████████▎                    | 331/751 [3:47:21<5:56:51, 50.98s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  44%|████████████████▎                    | 332/751 [3:48:09<5:51:02, 50.27s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  44%|████████████████▍                    | 333/751 [3:49:14<6:19:45, 54.51s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|████████████████▋                    | 338/751 [3:52:57<5:00:06, 43.60s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|████████████████▊                    | 340/751 [3:53:54<4:06:08, 35.93s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|████████████████▉                    | 345/751 [3:55:56<2:39:38, 23.59s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|█████████████████                    | 346/751 [3:56:14<2:27:28, 21.85s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|█████████████████▏                   | 348/751 [3:57:18<3:04:15, 27.43s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  46%|█████████████████▏                   | 349/751 [3:57:30<2:33:13, 22.87s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  47%|█████████████████▏                   | 350/751 [3:57:48<2:22:45, 21.36s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  47%|█████████████████▍                   | 353/751 [3:59:07<2:35:26, 23.43s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|█████████████████▋                   | 358/751 [4:00:21<1:52:38, 17.20s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|█████████████████▊                   | 361/751 [4:01:06<1:44:07, 16.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|█████████████████▉                   | 364/751 [4:02:13<2:00:00, 18.60s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|█████████████████▉                   | 365/751 [4:02:24<1:44:51, 16.30s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|██████████████████                   | 367/751 [4:03:02<1:51:08, 17.37s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|██████████████████▏                  | 368/751 [4:03:19<1:50:27, 17.31s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▍                  | 374/751 [4:05:07<2:07:38, 20.32s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▌                  | 377/751 [4:06:16<2:19:28, 22.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▌                  | 378/751 [4:06:46<2:32:58, 24.61s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|██████████████████▋                  | 379/751 [4:07:15<2:41:26, 26.04s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  51%|██████████████████▋                  | 380/751 [4:07:31<2:21:28, 22.88s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  51%|██████████████████▊                  | 383/751 [4:08:19<2:04:03, 20.23s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  52%|███████████████████                  | 387/751 [4:10:13<2:53:29, 28.60s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  52%|███████████████████▏                 | 390/751 [4:11:23<2:17:54, 22.92s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  53%|███████████████████▍                 | 395/751 [4:13:29<2:30:37, 25.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  53%|███████████████████▌                 | 397/751 [4:14:22<2:34:26, 26.18s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  53%|███████████████████▋                 | 400/751 [4:16:03<3:13:07, 33.01s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  30%|████████████▏                           | 58/191 [33:45<1:13:58, 33.38s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  32%|████████████▊                           | 61/191 [35:21<1:07:11, 31.01s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  32%|████████████▉                           | 62/191 [36:30<1:31:20, 42.48s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  34%|█████████████▌                          | 65/191 [38:05<1:06:54, 31.86s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  37%|██████████████▊                         | 71/191 [45:26<2:36:10, 78.08s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  38%|███████████████▎                        | 73/191 [46:47<1:56:07, 59.04s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|███████████████▉                        | 76/191 [49:06<1:37:38, 50.94s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  40%|████████████████▏                       | 77/191 [49:57<1:36:41, 50.89s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  45%|██████████████████▉                       | 86/191 [53:25<35:07, 20.07s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  48%|████████████████████▏                     | 92/191 [55:48<38:42, 23.46s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  49%|████████████████████▍                     | 93/191 [56:19<42:01, 25.73s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  50%|████████████████████▉                     | 95/191 [57:14<44:31, 27.83s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  54%|█████████████████████                  | 103/191 [1:00:37<44:05, 30.06s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  54%|█████████████████████▏                 | 104/191 [1:00:50<36:05, 24.89s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  56%|█████████████████████▊                 | 107/191 [1:02:19<37:51, 27.04s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  63%|████████████████████████▌              | 120/191 [1:06:38<30:08, 25.47s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  63%|████████████████████████▋              | 121/191 [1:07:01<28:50, 24.73s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  64%|████████████████████████▉              | 122/191 [1:07:13<24:13, 21.07s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  65%|█████████████████████████▎             | 124/191 [1:07:53<23:21, 20.91s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  66%|█████████████████████████▉             | 127/191 [1:08:58<21:00, 19.70s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  68%|██████████████████████████▎            | 129/191 [1:10:02<26:30, 25.65s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  73%|████████████████████████████▍          | 139/191 [1:14:01<20:36, 23.78s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  75%|█████████████████████████████▍         | 144/191 [1:16:23<23:21, 29.82s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  77%|██████████████████████████████▏        | 148/191 [1:18:09<18:45, 26.17s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  79%|██████████████████████████████▊        | 151/191 [1:19:28<18:00, 27.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  84%|████████████████████████████████▋      | 160/191 [1:22:58<13:17, 25.72s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  87%|█████████████████████████████████▉     | 166/191 [1:25:37<09:59, 23.99s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  91%|███████████████████████████████████▌   | 174/191 [1:28:28<06:15, 22.10s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  93%|████████████████████████████████████▏  | 177/191 [1:29:41<05:45, 24.66s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  95%|████████████████████████████████████▉  | 181/191 [1:31:09<03:40, 22.02s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  96%|█████████████████████████████████████▎ | 183/191 [1:32:11<03:38, 27.31s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  97%|█████████████████████████████████████▉ | 186/191 [1:33:19<01:59, 23.95s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  98%|██████████████████████████████████████▏| 187/191 [1:33:55<01:50, 27.68s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  99%|██████████████████████████████████████▌| 189/191 [1:34:45<00:54, 27.07s/it]/usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|███████████████████████████████████████| 191/191 [1:35:22<00:00, 29.96s/it]
# melspec:  100 626
# cqt:  80 157
# stft:  129 626

# %%
with open('features_trn_rr_qrs.pkl','wb') as f:
    pickle.dump(features_trn,f)
    
with open('mm_lbs_trn_rr_qrs.pkl','wb') as f:
    pickle.dump(mm_lbs_trn,f)
    
with open('out_lbs_trn_rr_qrs.pkl','wb') as f:
    pickle.dump(out_lbs_trn,f)
    
with open('mel_input_shape_rr_qrs.pkl','wb') as f:
    pickle.dump(mel_input_shape,f)

with open('cqt_input_shape_rr_qrs.pkl','wb') as f:
    pickle.dump(cqt_input_shape,f)
    
with open('stft_input_shape_rr_qrs.pkl','wb') as f:
    pickle.dump(stft_input_shape,f)
    
with open('features_test_rr_qrs.pkl','wb') as f:
    pickle.dump(features_test,f)
    
with open('mm_lbs_test_rr_qrs.pkl','wb') as f:
    pickle.dump(mm_lbs_test,f)

with open('out_lbs_test_rr_qrs.pkl','wb') as f:
    pickle.dump(out_lbs_test,f)

# %%
import pickle
with open('/Data2/hmd/hmd_sy/notebooks/features_trn_rr_qrs.pkl','rb') as f:
    features_trn = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/mm_lbs_trn_rr_qrs.pkl','rb') as f:
    mm_lbs_trn = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/out_lbs_trn_rr_qrs.pkl','rb') as f:
    out_lbs_trn = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/mel_input_shape_rr_qrs.pkl','rb') as f:
    mel_input_shape = pickle.load(f)

with open('/Data2/hmd/hmd_sy/notebooks/cqt_input_shape_rr_qrs.pkl','rb') as f:
    cqt_input_shape = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/stft_input_shape_rr_qrs.pkl','rb') as f:
    stft_input_shape = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/features_test_rr_qrs.pkl','rb') as f:
    features_test = pickle.load(f)
    
with open('/Data2/hmd/hmd_sy/notebooks/mm_lbs_test_rr_qrs.pkl','rb') as f:
    mm_lbs_test = pickle.load(f)

with open('/Data2/hmd/hmd_sy/notebooks/out_lbs_test_rr_qrs.pkl','rb') as f:
    out_lbs_test = pickle.load(f)

# %% [markdown]
# ### model

# %%
def get_LCNN_o_5_dr_qrs1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, 
                        use_stft = True, ord1 = True, dp = .5, fc = False, ext = False):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    rr = keras.Input(shape=(1,), name = 'rr')
    qrs = keras.Input(shape=(1,), name = 'qrs') 
    mel1 = keras.Input(shape=mel_input_shape, name = 'mel')
    cqt1 = keras.Input(shape=cqt_input_shape, name = 'cqt')
    stft1 = keras.Input(shape=stft_input_shape, name = 'stft')
    
    
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)
    
    ## rr interval embedding
    
    rr1 = layers.Dense(20, activation = "relu")(rr)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)

    ## qrs interval embedding    
    qrs1 = layers.Dense(20, activation = "relu")(qrs)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)

    ## mel embedding
    if use_mel :
        
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)

        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        mel2 = layers.GlobalAveragePooling2D()(max28)
        mel2 = Dropout(dp)(mel2)

    if use_cqt :
        
        ## cqt embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm27)
        cqt2 = layers.GlobalAveragePooling2D()(max28)
        if dp :
            cqt2 = Dropout(dp)(cqt2)
            
    if use_stft :
        ## stft embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)
        
        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)
        
        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])
        
        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])
        
        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        stft2 = layers.GlobalAveragePooling2D()(max28)
        stft2 = Dropout(dp)(stft2)
    
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2

    if ext :
        concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg])
        d1 = layers.Dense(5, activation = 'relu')(concat1)
        concat2 = layers.Concatenate()([concat2, d1,rr1,qrs1]) # rr1,qrs1 따로 concat
        
    if fc :
        concat2 = layers.Dense(10, activation = "relu")(concat2)
        concat2 = Dropout(dp)(concat2)
        
    if ord1 :
        res1 = layers.Dense(2, activation = "softmax")(concat2)
    else :
        res1 = layers.Dense(3, activation = "softmax")(concat2)

        
#     res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,rr,qrs, mel1,cqt1, stft1] , outputs = res1 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)




def get_LCNN_o_5_dr_qrs1_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, 
                        use_stft = True, ord1 = True, dp = .5, fc = False, ext = False):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    rr = keras.Input(shape=(1,), name = 'rr')
    qrs = keras.Input(shape=(1,), name = 'qrs') 
    mel1 = keras.Input(shape=mel_input_shape, name = 'mel')
    cqt1 = keras.Input(shape=cqt_input_shape, name = 'cqt')
    stft1 = keras.Input(shape=stft_input_shape, name = 'stft')
    
    
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)
    
    ## rr interval embedding
    
    rr1 = layers.Dense(20, activation = "relu")(rr)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)
    rr1 = layers.Dense(20, activation = "relu")(rr1)
    rr1 = BatchNormalization()(rr1)

    ## qrs interval embedding    
    qrs1 = layers.Dense(20, activation = "relu")(qrs)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)
    qrs1 = layers.Dense(20, activation = "relu")(qrs1)
    qrs1 = BatchNormalization()(qrs1)

    ## mel embedding
    if use_mel :
        
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)

        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        mel2 = layers.GlobalAveragePooling2D()(max28)
        mel2 = Dropout(dp)(mel2)

    if use_cqt :
        
        ## cqt embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm27)
        cqt2 = layers.GlobalAveragePooling2D()(max28)
        if dp :
            cqt2 = Dropout(dp)(cqt2)
            
    if use_stft :
        ## stft embedding
        conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
        mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
        max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)
        
        conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
        mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
        batch6 = BatchNormalization(axis=3, scale=False)(mfm5)
        
        conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
        mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])
        
        max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
        batch10 = BatchNormalization(axis=3, scale=False)(max9)
        
        conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
        mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
        batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

        conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
        mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])
        
        max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

        conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
        mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
        batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

        conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
        mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
        batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

        conv23_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        conv23_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch22)
        mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
        batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

        conv26_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        conv26_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch25)
        mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])
        
        max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
        stft2 = layers.GlobalAveragePooling2D()(max28)
        stft2 = Dropout(dp)(stft2)
    
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2

    if ext :
        concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg])
        d1 = layers.Dense(5, activation = 'relu')(concat1)
        concat2 = layers.Concatenate()([concat2, d1,rr1,qrs1]) # rr1,qrs1 따로 concat
        
    if fc :
        concat2 = layers.Dense(10, activation = "relu")(concat2)
        concat2 = Dropout(dp)(concat2)
        
    if ord1 :
        res2 = layers.Dense(2, activation = "softmax")(concat2)
    else :
        res2 = layers.Dense(3, activation = "softmax")(concat2)

        
#     res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,rr,qrs, mel1,cqt1, stft1] , outputs = res2 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)

# %%
use_mel = True
use_cqt = True
use_stft = True

model1 = get_LCNN_o_5_dr_qrs1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = use_mel, use_cqt = use_cqt, use_stft = use_stft)
model2 = get_LCNN_o_5_dr_qrs1_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = use_mel, use_cqt = use_cqt, use_stft = use_stft)
# Out:
# 2022-07-30 01:35:24.483352: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-30 01:35:24.518372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2022-07-30 01:35:24.528236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 4
# 2022-07-30 01:35:24.551756: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-07-30 01:35:26.069928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-07-30 01:35:26.070016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      4
# 2022-07-30 01:35:26.070034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   N
# 2022-07-30 01:35:26.079531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 46717 MB memory) -> physical GPU (device: 4, name: Quadro RTX 8000, pci bus id: 0000:41:00.0, compute capability: 7.5)

# %%
params_feature['ord1'] = True 
params_feature['mm_mean'] = False
params_feature['trim'] = False

# %%
    n_epoch = 100
    lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
    batch_size = 64
    params = {'batch_size': batch_size,
              #          'input_shape': (100, 313, 1),
              'shuffle': True,
              'beta_param': 0.7,
              'mixup': True,
              #          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
              #          'highpass': [.5, [78,79,80,81,82,83,84,85]]
              'ranfilter2' : [3, [18,19,20,21,22,23]]
              #           'dropblock' : [30, 100]
              #'device' : device
    }

    params_no_shuffle = {'batch_size': batch_size,
                         #          'input_shape': (100, 313, 1),
                         'shuffle': False,
                         'beta_param': 0.7,
                         'mixup': False
                         #'device': device
    }

    TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'],
                              features_trn['rr1'],features_trn['qrs1'],
                              features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']],
                             mm_lbs_trn,  ## our Y
                             **params)()

    class_weight = {0: 3, 1: 1.}

    model1.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'],
                              features_test['preg'], features_test['loc'], 
                              features_test['rr1'], features_test['qrs1'],
                              features_test['mel1'],
                              features_test['cqt1'], features_test['stft1']],
                             mm_lbs_test),
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(mm_lbs_trn)/64),
                           class_weight=class_weight,
                             epochs = n_epoch)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 2022-07-30 01:35:31.734029: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-07-30 01:35:31.756876: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2100000000 Hz
# 2022-07-30 01:35:35.141896: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-07-30 01:35:36.050124: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8100
# 2022-07-30 01:35:38.612535: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-07-30 01:35:40.002291: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 40/40 [==============================] - 26s 362ms/step - loss: 1.2190 - accuracy: 0.6363 - auc: 0.6819 - val_loss: 4.4988 - val_accuracy: 0.7892 - val_auc: 0.7915
# Epoch 2/100
# 40/40 [==============================] - 12s 302ms/step - loss: 0.9683 - accuracy: 0.6930 - auc: 0.7639 - val_loss: 1.6613 - val_accuracy: 0.7892 - val_auc: 0.8133
# Epoch 3/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.8574 - accuracy: 0.7707 - auc: 0.8195 - val_loss: 0.4655 - val_accuracy: 0.8003 - val_auc: 0.8740
# Epoch 4/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.8370 - accuracy: 0.8000 - auc: 0.8332 - val_loss: 0.5991 - val_accuracy: 0.7353 - val_auc: 0.8028
# Epoch 5/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.7983 - accuracy: 0.8160 - auc: 0.8484 - val_loss: 0.7458 - val_accuracy: 0.4532 - val_auc: 0.4952
# Epoch 6/100
# 40/40 [==============================] - 12s 310ms/step - loss: 0.7987 - accuracy: 0.8223 - auc: 0.8539 - val_loss: 0.4607 - val_accuracy: 0.8304 - val_auc: 0.8879
# Epoch 7/100
# 40/40 [==============================] - 12s 308ms/step - loss: 0.7399 - accuracy: 0.8473 - auc: 0.8581 - val_loss: 0.4339 - val_accuracy: 0.8162 - val_auc: 0.8901
# Epoch 8/100
# 40/40 [==============================] - 12s 310ms/step - loss: 0.7504 - accuracy: 0.8508 - auc: 0.8583 - val_loss: 0.4502 - val_accuracy: 0.8257 - val_auc: 0.8947
# Epoch 9/100
# 40/40 [==============================] - 13s 331ms/step - loss: 0.6914 - accuracy: 0.8660 - auc: 0.8673 - val_loss: 0.4549 - val_accuracy: 0.7956 - val_auc: 0.8810
# Epoch 10/100
# 40/40 [==============================] - 13s 314ms/step - loss: 0.7102 - accuracy: 0.8656 - auc: 0.8770 - val_loss: 0.7351 - val_accuracy: 0.5689 - val_auc: 0.6198
# Epoch 11/100
# 40/40 [==============================] - 13s 318ms/step - loss: 0.6851 - accuracy: 0.8758 - auc: 0.8794 - val_loss: 0.3278 - val_accuracy: 0.8716 - val_auc: 0.9437
# Epoch 12/100
# 40/40 [==============================] - 13s 315ms/step - loss: 0.6881 - accuracy: 0.8758 - auc: 0.8788 - val_loss: 0.3580 - val_accuracy: 0.8669 - val_auc: 0.9371
# Epoch 13/100
# 40/40 [==============================] - 13s 320ms/step - loss: 0.6630 - accuracy: 0.8820 - auc: 0.8760 - val_loss: 1.3898 - val_accuracy: 0.2108 - val_auc: 0.3388
# Epoch 14/100
# 40/40 [==============================] - 15s 370ms/step - loss: 0.6678 - accuracy: 0.8785 - auc: 0.8868 - val_loss: 0.3031 - val_accuracy: 0.8875 - val_auc: 0.9494
# Epoch 15/100
# 40/40 [==============================] - 12s 308ms/step - loss: 0.6719 - accuracy: 0.8824 - auc: 0.8754 - val_loss: 0.3835 - val_accuracy: 0.8748 - val_auc: 0.9412
# Epoch 16/100
# 40/40 [==============================] - 13s 318ms/step - loss: 0.6309 - accuracy: 0.8957 - auc: 0.8880 - val_loss: 0.2934 - val_accuracy: 0.9049 - val_auc: 0.9481
# Epoch 17/100
# 40/40 [==============================] - 16s 416ms/step - loss: 0.6590 - accuracy: 0.8773 - auc: 0.8895 - val_loss: 0.3824 - val_accuracy: 0.8700 - val_auc: 0.9274
# Epoch 18/100
# 40/40 [==============================] - 61s 2s/step - loss: 0.6380 - accuracy: 0.8945 - auc: 0.8812 - val_loss: 0.3370 - val_accuracy: 0.8780 - val_auc: 0.9410
# Epoch 19/100
# 40/40 [==============================] - 50s 1s/step - loss: 0.6232 - accuracy: 0.8902 - auc: 0.8849 - val_loss: 0.6270 - val_accuracy: 0.6117 - val_auc: 0.6871
# Epoch 20/100
# 40/40 [==============================] - 40s 1s/step - loss: 0.6513 - accuracy: 0.8789 - auc: 0.8797 - val_loss: 0.3624 - val_accuracy: 0.8669 - val_auc: 0.9305
# Epoch 21/100
# 40/40 [==============================] - 22s 561ms/step - loss: 0.6347 - accuracy: 0.9008 - auc: 0.8919 - val_loss: 0.3019 - val_accuracy: 0.9049 - val_auc: 0.9464
# Epoch 22/100
# 40/40 [==============================] - 35s 890ms/step - loss: 0.6348 - accuracy: 0.8918 - auc: 0.8853 - val_loss: 0.3243 - val_accuracy: 0.9017 - val_auc: 0.9406
# Epoch 23/100
# 40/40 [==============================] - 59s 1s/step - loss: 0.6459 - accuracy: 0.8926 - auc: 0.8830 - val_loss: 0.2791 - val_accuracy: 0.9081 - val_auc: 0.9529
# Epoch 24/100
# 40/40 [==============================] - 49s 1s/step - loss: 0.6184 - accuracy: 0.9016 - auc: 0.8919 - val_loss: 0.4080 - val_accuracy: 0.8621 - val_auc: 0.9098
# Epoch 25/100
# 40/40 [==============================] - 26s 664ms/step - loss: 0.6200 - accuracy: 0.8969 - auc: 0.8848 - val_loss: 0.3131 - val_accuracy: 0.9065 - val_auc: 0.9440
# Epoch 26/100
# 40/40 [==============================] - 35s 885ms/step - loss: 0.6394 - accuracy: 0.8902 - auc: 0.8812 - val_loss: 0.2894 - val_accuracy: 0.8938 - val_auc: 0.9519
# Epoch 27/100
# 40/40 [==============================] - 30s 753ms/step - loss: 0.6033 - accuracy: 0.8941 - auc: 0.8937 - val_loss: 0.8918 - val_accuracy: 0.8019 - val_auc: 0.8918
# Epoch 28/100
# 40/40 [==============================] - 53s 1s/step - loss: 0.6319 - accuracy: 0.8840 - auc: 0.8856 - val_loss: 0.4866 - val_accuracy: 0.8669 - val_auc: 0.9258
# Epoch 29/100
# 40/40 [==============================] - 54s 1s/step - loss: 0.6220 - accuracy: 0.8926 - auc: 0.8868 - val_loss: 0.3061 - val_accuracy: 0.8954 - val_auc: 0.9465
# Epoch 30/100
# 40/40 [==============================] - 35s 880ms/step - loss: 0.6244 - accuracy: 0.8953 - auc: 0.8864 - val_loss: 0.3296 - val_accuracy: 0.8859 - val_auc: 0.9408
# Epoch 31/100
# 40/40 [==============================] - 40s 1s/step - loss: 0.6231 - accuracy: 0.8922 - auc: 0.8880 - val_loss: 0.4446 - val_accuracy: 0.7765 - val_auc: 0.8696
# Epoch 32/100
# 40/40 [==============================] - 45s 1s/step - loss: 0.5814 - accuracy: 0.9035 - auc: 0.8857 - val_loss: 0.3083 - val_accuracy: 0.8796 - val_auc: 0.9464
# Epoch 33/100
# 40/40 [==============================] - 49s 1s/step - loss: 0.6054 - accuracy: 0.8992 - auc: 0.8900 - val_loss: 0.4096 - val_accuracy: 0.8780 - val_auc: 0.9384
# Epoch 34/100
# 40/40 [==============================] - 67s 2s/step - loss: 0.6054 - accuracy: 0.8965 - auc: 0.8855 - val_loss: 0.3163 - val_accuracy: 0.8843 - val_auc: 0.9479
# Epoch 35/100
# 40/40 [==============================] - 41s 1s/step - loss: 0.5914 - accuracy: 0.9062 - auc: 0.8915 - val_loss: 0.3648 - val_accuracy: 0.8605 - val_auc: 0.9317
# Epoch 36/100
# 40/40 [==============================] - 23s 585ms/step - loss: 0.5950 - accuracy: 0.8934 - auc: 0.8964 - val_loss: 0.3073 - val_accuracy: 0.8986 - val_auc: 0.9454
# Epoch 37/100
# 40/40 [==============================] - 39s 991ms/step - loss: 0.5948 - accuracy: 0.8910 - auc: 0.8922 - val_loss: 0.4557 - val_accuracy: 0.8685 - val_auc: 0.9315
# Epoch 38/100
# 40/40 [==============================] - 16s 396ms/step - loss: 0.5948 - accuracy: 0.8949 - auc: 0.8975 - val_loss: 0.5153 - val_accuracy: 0.8542 - val_auc: 0.9303
# Epoch 39/100
# 40/40 [==============================] - 49s 1s/step - loss: 0.5799 - accuracy: 0.9102 - auc: 0.8877 - val_loss: 0.3148 - val_accuracy: 0.8906 - val_auc: 0.9410
# Epoch 40/100
# 40/40 [==============================] - 45s 1s/step - loss: 0.5836 - accuracy: 0.9055 - auc: 0.8953 - val_loss: 0.3377 - val_accuracy: 0.8590 - val_auc: 0.9353
# Epoch 41/100
# 40/40 [==============================] - 50s 1s/step - loss: 0.5627 - accuracy: 0.9133 - auc: 0.8973 - val_loss: 0.4858 - val_accuracy: 0.8574 - val_auc: 0.9348
# Epoch 42/100
# 40/40 [==============================] - 49s 1s/step - loss: 0.5823 - accuracy: 0.9039 - auc: 0.8943 - val_loss: 0.4358 - val_accuracy: 0.8114 - val_auc: 0.8905
# Epoch 43/100
# 40/40 [==============================] - 39s 959ms/step - loss: 0.5909 - accuracy: 0.9148 - auc: 0.8898 - val_loss: 0.3681 - val_accuracy: 0.8479 - val_auc: 0.9177
# Epoch 44/100
# 40/40 [==============================] - 39s 991ms/step - loss: 0.5602 - accuracy: 0.9133 - auc: 0.8963 - val_loss: 0.3261 - val_accuracy: 0.8796 - val_auc: 0.9395
# Epoch 45/100
# 40/40 [==============================] - 52s 1s/step - loss: 0.5649 - accuracy: 0.9164 - auc: 0.8965 - val_loss: 0.4067 - val_accuracy: 0.8685 - val_auc: 0.9383
# Epoch 46/100
# 40/40 [==============================] - 54s 1s/step - loss: 0.5298 - accuracy: 0.9195 - auc: 0.8996 - val_loss: 0.3077 - val_accuracy: 0.8891 - val_auc: 0.9499
# Epoch 47/100
# 40/40 [==============================] - 43s 1s/step - loss: 0.5334 - accuracy: 0.9281 - auc: 0.8951 - val_loss: 0.2922 - val_accuracy: 0.9033 - val_auc: 0.9502
# Epoch 48/100
# 40/40 [==============================] - 44s 1s/step - loss: 0.5619 - accuracy: 0.9168 - auc: 0.9028 - val_loss: 0.4157 - val_accuracy: 0.8035 - val_auc: 0.8911
# Epoch 49/100
# 40/40 [==============================] - 43s 1s/step - loss: 0.5503 - accuracy: 0.9207 - auc: 0.8999 - val_loss: 0.3873 - val_accuracy: 0.8843 - val_auc: 0.9394
# Epoch 50/100
# 40/40 [==============================] - 48s 1s/step - loss: 0.5520 - accuracy: 0.9180 - auc: 0.9003 - val_loss: 0.6470 - val_accuracy: 0.8288 - val_auc: 0.9153
# Epoch 51/100
# 40/40 [==============================] - 46s 1s/step - loss: 0.5480 - accuracy: 0.9227 - auc: 0.9013 - val_loss: 0.2824 - val_accuracy: 0.9017 - val_auc: 0.9540
# Epoch 52/100
# 40/40 [==============================] - 26s 660ms/step - loss: 0.5357 - accuracy: 0.9258 - auc: 0.9051 - val_loss: 0.2827 - val_accuracy: 0.8906 - val_auc: 0.9539
# Epoch 53/100
# 40/40 [==============================] - 14s 358ms/step - loss: 0.5264 - accuracy: 0.9293 - auc: 0.9015 - val_loss: 0.3086 - val_accuracy: 0.8986 - val_auc: 0.9515
# Epoch 54/100
# 40/40 [==============================] - 12s 306ms/step - loss: 0.5198 - accuracy: 0.9285 - auc: 0.8974 - val_loss: 0.5419 - val_accuracy: 0.7718 - val_auc: 0.8464
# Epoch 55/100
# 40/40 [==============================] - 14s 363ms/step - loss: 0.5096 - accuracy: 0.9340 - auc: 0.8933 - val_loss: 0.4143 - val_accuracy: 0.8764 - val_auc: 0.9385
# Epoch 56/100
# 40/40 [==============================] - 15s 381ms/step - loss: 0.5014 - accuracy: 0.9422 - auc: 0.9048 - val_loss: 0.3379 - val_accuracy: 0.8875 - val_auc: 0.9497
# Epoch 57/100
# 40/40 [==============================] - 12s 307ms/step - loss: 0.5221 - accuracy: 0.9254 - auc: 0.9069 - val_loss: 0.2945 - val_accuracy: 0.8986 - val_auc: 0.9513
# Epoch 58/100
# 40/40 [==============================] - 16s 400ms/step - loss: 0.5277 - accuracy: 0.9297 - auc: 0.8992 - val_loss: 0.6976 - val_accuracy: 0.8368 - val_auc: 0.9089
# Epoch 59/100
# 40/40 [==============================] - 21s 543ms/step - loss: 0.5181 - accuracy: 0.9297 - auc: 0.9022 - val_loss: 0.3090 - val_accuracy: 0.8685 - val_auc: 0.9452
# Epoch 60/100
# 40/40 [==============================] - 23s 593ms/step - loss: 0.5164 - accuracy: 0.9352 - auc: 0.9077 - val_loss: 0.3325 - val_accuracy: 0.9002 - val_auc: 0.9461
# Epoch 61/100
# 40/40 [==============================] - 44s 1s/step - loss: 0.5045 - accuracy: 0.9383 - auc: 0.9025 - val_loss: 0.3233 - val_accuracy: 0.8843 - val_auc: 0.9487
# Epoch 62/100
# 40/40 [==============================] - 22s 562ms/step - loss: 0.4936 - accuracy: 0.9422 - auc: 0.9070 - val_loss: 0.4524 - val_accuracy: 0.7924 - val_auc: 0.8869
# Epoch 63/100
# 40/40 [==============================] - 15s 387ms/step - loss: 0.4829 - accuracy: 0.9465 - auc: 0.9016 - val_loss: 0.3382 - val_accuracy: 0.8906 - val_auc: 0.9501
# Epoch 64/100
# 40/40 [==============================] - 21s 519ms/step - loss: 0.4953 - accuracy: 0.9477 - auc: 0.9090 - val_loss: 0.3935 - val_accuracy: 0.8938 - val_auc: 0.9397
# Epoch 65/100
# 40/40 [==============================] - 15s 385ms/step - loss: 0.5032 - accuracy: 0.9414 - auc: 0.9056 - val_loss: 0.3230 - val_accuracy: 0.8558 - val_auc: 0.9389
# Epoch 66/100
# 40/40 [==============================] - 14s 349ms/step - loss: 0.4997 - accuracy: 0.9410 - auc: 0.9079 - val_loss: 0.3850 - val_accuracy: 0.8811 - val_auc: 0.9382
# Epoch 67/100
# 40/40 [==============================] - 14s 361ms/step - loss: 0.4901 - accuracy: 0.9438 - auc: 0.9038 - val_loss: 0.3131 - val_accuracy: 0.9049 - val_auc: 0.9489
# Epoch 68/100
# 40/40 [==============================] - 14s 345ms/step - loss: 0.4960 - accuracy: 0.9445 - auc: 0.9100 - val_loss: 0.4125 - val_accuracy: 0.8906 - val_auc: 0.9378
# Epoch 69/100
# 40/40 [==============================] - 18s 456ms/step - loss: 0.4868 - accuracy: 0.9418 - auc: 0.9063 - val_loss: 0.3050 - val_accuracy: 0.8954 - val_auc: 0.9511
# Epoch 70/100
# 40/40 [==============================] - 14s 343ms/step - loss: 0.4964 - accuracy: 0.9387 - auc: 0.9117 - val_loss: 0.3063 - val_accuracy: 0.8875 - val_auc: 0.9484
# Epoch 71/100
# 40/40 [==============================] - 19s 479ms/step - loss: 0.4735 - accuracy: 0.9500 - auc: 0.9088 - val_loss: 0.3295 - val_accuracy: 0.8938 - val_auc: 0.9456
# Epoch 72/100
# 40/40 [==============================] - 17s 421ms/step - loss: 0.5136 - accuracy: 0.9438 - auc: 0.9095 - val_loss: 0.3245 - val_accuracy: 0.8938 - val_auc: 0.9470
# Epoch 73/100
# 40/40 [==============================] - 15s 372ms/step - loss: 0.4996 - accuracy: 0.9336 - auc: 0.9059 - val_loss: 0.3052 - val_accuracy: 0.8906 - val_auc: 0.9486
# Epoch 74/100
# 40/40 [==============================] - 17s 429ms/step - loss: 0.4731 - accuracy: 0.9504 - auc: 0.9167 - val_loss: 0.3550 - val_accuracy: 0.8970 - val_auc: 0.9471
# Epoch 75/100
# 40/40 [==============================] - 32s 819ms/step - loss: 0.4617 - accuracy: 0.9484 - auc: 0.9064 - val_loss: 0.3291 - val_accuracy: 0.8986 - val_auc: 0.9470
# Epoch 76/100
# 40/40 [==============================] - 36s 925ms/step - loss: 0.4627 - accuracy: 0.9480 - auc: 0.9088 - val_loss: 0.3221 - val_accuracy: 0.8938 - val_auc: 0.9495
# Epoch 77/100
# 40/40 [==============================] - 61s 2s/step - loss: 0.4769 - accuracy: 0.9523 - auc: 0.9059 - val_loss: 0.3065 - val_accuracy: 0.8954 - val_auc: 0.9512
# Epoch 78/100
# 40/40 [==============================] - 56s 1s/step - loss: 0.4709 - accuracy: 0.9516 - auc: 0.9049 - val_loss: 0.3096 - val_accuracy: 0.8970 - val_auc: 0.9506
# Epoch 79/100
# 40/40 [==============================] - 39s 982ms/step - loss: 0.4886 - accuracy: 0.9387 - auc: 0.9066 - val_loss: 0.3320 - val_accuracy: 0.9033 - val_auc: 0.9484
# Epoch 80/100
# 40/40 [==============================] - 50s 1s/step - loss: 0.4918 - accuracy: 0.9453 - auc: 0.9129 - val_loss: 0.3127 - val_accuracy: 0.8891 - val_auc: 0.9505
# Epoch 81/100
# 40/40 [==============================] - 108s 3s/step - loss: 0.4764 - accuracy: 0.9492 - auc: 0.9108 - val_loss: 0.3131 - val_accuracy: 0.8875 - val_auc: 0.9469
# Epoch 82/100
# 40/40 [==============================] - 44s 1s/step - loss: 0.4657 - accuracy: 0.9586 - auc: 0.9009 - val_loss: 0.3188 - val_accuracy: 0.8796 - val_auc: 0.9447
# Epoch 83/100
# 40/40 [==============================] - 61s 2s/step - loss: 0.4886 - accuracy: 0.9457 - auc: 0.9030 - val_loss: 0.3142 - val_accuracy: 0.8906 - val_auc: 0.9468
# Epoch 84/100
# 40/40 [==============================] - 62s 2s/step - loss: 0.4850 - accuracy: 0.9465 - auc: 0.9094 - val_loss: 0.3198 - val_accuracy: 0.8891 - val_auc: 0.9503
# Epoch 85/100
# 40/40 [==============================] - 68s 2s/step - loss: 0.4613 - accuracy: 0.9441 - auc: 0.9083 - val_loss: 0.3215 - val_accuracy: 0.8986 - val_auc: 0.9498
# Epoch 86/100
# 40/40 [==============================] - 58s 1s/step - loss: 0.4906 - accuracy: 0.9426 - auc: 0.9099 - val_loss: 0.3136 - val_accuracy: 0.8938 - val_auc: 0.9509
# Epoch 87/100
# 40/40 [==============================] - 45s 1s/step - loss: 0.4750 - accuracy: 0.9473 - auc: 0.9113 - val_loss: 0.3160 - val_accuracy: 0.8986 - val_auc: 0.9506
# Epoch 88/100
# 40/40 [==============================] - 49s 1s/step - loss: 0.4694 - accuracy: 0.9406 - auc: 0.9053 - val_loss: 0.3233 - val_accuracy: 0.9033 - val_auc: 0.9498
# Epoch 89/100
# 40/40 [==============================] - 85s 2s/step - loss: 0.4898 - accuracy: 0.9434 - auc: 0.9119 - val_loss: 0.3271 - val_accuracy: 0.8970 - val_auc: 0.9500
# Epoch 90/100
# 40/40 [==============================] - 48s 1s/step - loss: 0.4811 - accuracy: 0.9520 - auc: 0.9079 - val_loss: 0.3131 - val_accuracy: 0.8922 - val_auc: 0.9510
# Epoch 91/100
# 40/40 [==============================] - 53s 1s/step - loss: 0.4789 - accuracy: 0.9484 - auc: 0.9090 - val_loss: 0.3208 - val_accuracy: 0.8986 - val_auc: 0.9498
# Epoch 92/100
# 40/40 [==============================] - 50s 1s/step - loss: 0.4907 - accuracy: 0.9473 - auc: 0.9080 - val_loss: 0.3122 - val_accuracy: 0.8922 - val_auc: 0.9499
# Epoch 93/100
# 40/40 [==============================] - 48s 1s/step - loss: 0.4709 - accuracy: 0.9484 - auc: 0.9077 - val_loss: 0.3158 - val_accuracy: 0.8938 - val_auc: 0.9498
# Epoch 94/100
# 40/40 [==============================] - 40s 980ms/step - loss: 0.4732 - accuracy: 0.9473 - auc: 0.9108 - val_loss: 0.3138 - val_accuracy: 0.8906 - val_auc: 0.9504
# Epoch 95/100
# 40/40 [==============================] - 21s 542ms/step - loss: 0.4840 - accuracy: 0.9426 - auc: 0.9136 - val_loss: 0.3244 - val_accuracy: 0.8970 - val_auc: 0.9499
# Epoch 96/100
# 40/40 [==============================] - 25s 628ms/step - loss: 0.4650 - accuracy: 0.9496 - auc: 0.9078 - val_loss: 0.3406 - val_accuracy: 0.8970 - val_auc: 0.9482
# Epoch 97/100
# 40/40 [==============================] - 34s 861ms/step - loss: 0.4716 - accuracy: 0.9516 - auc: 0.9158 - val_loss: 0.3173 - val_accuracy: 0.8970 - val_auc: 0.9507
# Epoch 98/100
# 40/40 [==============================] - 25s 630ms/step - loss: 0.4919 - accuracy: 0.9461 - auc: 0.9117 - val_loss: 0.3251 - val_accuracy: 0.8970 - val_auc: 0.9499
# Epoch 99/100
# 40/40 [==============================] - 42s 1s/step - loss: 0.4765 - accuracy: 0.9492 - auc: 0.9092 - val_loss: 0.3155 - val_accuracy: 0.8970 - val_auc: 0.9505
# Epoch 100/100
# 40/40 [==============================] - 47s 1s/step - loss: 0.4670 - accuracy: 0.9520 - auc: 0.9091 - val_loss: 0.3171 - val_accuracy: 0.9002 - val_auc: 0.9497

# %%
    n_epoch = 100
    lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
    batch_size = 64
    params = {'batch_size': batch_size,
              #          'input_shape': (100, 313, 1),
              'shuffle': True,
              'beta_param': 0.7,
              'mixup': True,
              #          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
            'highpass': [.5, [78,79,80,81,82,83,84,85]],
              'ranfilter2' : [3, [18,19,20,21,22,23]]
            #           'dropblock' : [30, 100]
              #'device' : device
    }
    params_no_shuffle = {'batch_size': batch_size,
                         #          'input_shape': (100, 313, 1),
                         'shuffle': False,
                         'beta_param': 0.7,
                         'mixup': False
                         #'device': device
    }

    TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'],
                              features_trn['rr1'],features_trn['qrs1'],
                              features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']],
                             out_lbs_trn,  ## our Y
                             **params)()

    class_weight = {0: 3, 1: 1.}

    model2.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'],
                              features_test['preg'], features_test['loc'], 
                              features_test['rr1'], features_test['qrs1'],
                              features_test['mel1'],
                              features_test['cqt1'], features_test['stft1']],
                             out_lbs_test),
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(out_lbs_trn)/64),
                             epochs = n_epoch)


    params_feature['mel_shape'] = mel_input_shape
    params_feature['cqt_shape'] = cqt_input_shape
    params_feature['stft_shape'] = stft_input_shape

    params_feature['use_mel'] = use_mel
    params_feature['use_cqt'] = use_cqt
    params_feature['use_stft'] = use_stft
# Out:
# Epoch 1/100
# 40/40 [==============================] - 73s 2s/step - loss: 0.9809 - accuracy: 0.5227 - auc: 0.5146 - val_loss: 3.3906 - val_accuracy: 0.5008 - val_auc: 0.5008
# Epoch 2/100
# 40/40 [==============================] - 253s 6s/step - loss: 0.7688 - accuracy: 0.5164 - auc: 0.5319 - val_loss: 0.7362 - val_accuracy: 0.5119 - val_auc: 0.5812
# Epoch 3/100
# 40/40 [==============================] - 382s 10s/step - loss: 0.7209 - accuracy: 0.5461 - auc: 0.5682 - val_loss: 0.6764 - val_accuracy: 0.5642 - val_auc: 0.6010
# Epoch 4/100
# 40/40 [==============================] - 234s 6s/step - loss: 0.7053 - accuracy: 0.5309 - auc: 0.5660 - val_loss: 0.6777 - val_accuracy: 0.4913 - val_auc: 0.5356
# Epoch 5/100
# 40/40 [==============================] - 270s 7s/step - loss: 0.7020 - accuracy: 0.5551 - auc: 0.5588 - val_loss: 0.8618 - val_accuracy: 0.5309 - val_auc: 0.6079
# Epoch 6/100
# 40/40 [==============================] - 208s 5s/step - loss: 0.6955 - accuracy: 0.5492 - auc: 0.5783 - val_loss: 0.6520 - val_accuracy: 0.5975 - val_auc: 0.6592
# Epoch 7/100
# 40/40 [==============================] - 164s 4s/step - loss: 0.6944 - accuracy: 0.5375 - auc: 0.5534 - val_loss: 0.6818 - val_accuracy: 0.5721 - val_auc: 0.6390
# Epoch 8/100
# 40/40 [==============================] - 118s 3s/step - loss: 0.6876 - accuracy: 0.5602 - auc: 0.5926 - val_loss: 0.7206 - val_accuracy: 0.5626 - val_auc: 0.6067
# Epoch 9/100
# 40/40 [==============================] - 316s 8s/step - loss: 0.6835 - accuracy: 0.5762 - auc: 0.5815 - val_loss: 0.8398 - val_accuracy: 0.5214 - val_auc: 0.5990
# Epoch 10/100
# 40/40 [==============================] - 342s 9s/step - loss: 0.6869 - accuracy: 0.5551 - auc: 0.5777 - val_loss: 0.6368 - val_accuracy: 0.6371 - val_auc: 0.6895
# Epoch 11/100
# 40/40 [==============================] - 345s 9s/step - loss: 0.6767 - accuracy: 0.5656 - auc: 0.5991 - val_loss: 0.6592 - val_accuracy: 0.5895 - val_auc: 0.6445
# Epoch 12/100
# 40/40 [==============================] - 409s 10s/step - loss: 0.6785 - accuracy: 0.5809 - auc: 0.5878 - val_loss: 0.6383 - val_accuracy: 0.6228 - val_auc: 0.6837
# Epoch 13/100
# 40/40 [==============================] - 468s 12s/step - loss: 0.6750 - accuracy: 0.5918 - auc: 0.5973 - val_loss: 0.6302 - val_accuracy: 0.6307 - val_auc: 0.6945
# Epoch 14/100
# 40/40 [==============================] - 378s 10s/step - loss: 0.6704 - accuracy: 0.5953 - auc: 0.6161 - val_loss: 0.6534 - val_accuracy: 0.5943 - val_auc: 0.6562
# Epoch 15/100
# 40/40 [==============================] - 331s 8s/step - loss: 0.6652 - accuracy: 0.6062 - auc: 0.6309 - val_loss: 0.6166 - val_accuracy: 0.6434 - val_auc: 0.7099
# Epoch 16/100
# 40/40 [==============================] - 164s 4s/step - loss: 0.6659 - accuracy: 0.6027 - auc: 0.6262 - val_loss: 0.6861 - val_accuracy: 0.5895 - val_auc: 0.6483
# Epoch 17/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6667 - accuracy: 0.6000 - auc: 0.6140 - val_loss: 0.6671 - val_accuracy: 0.5927 - val_auc: 0.6610
# Epoch 18/100
# 40/40 [==============================] - 12s 294ms/step - loss: 0.6608 - accuracy: 0.6059 - auc: 0.6283 - val_loss: 0.6154 - val_accuracy: 0.6735 - val_auc: 0.7238
# Epoch 19/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6632 - accuracy: 0.6156 - auc: 0.6291 - val_loss: 0.6168 - val_accuracy: 0.6593 - val_auc: 0.7205
# Epoch 20/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6616 - accuracy: 0.5945 - auc: 0.6424 - val_loss: 0.7892 - val_accuracy: 0.5689 - val_auc: 0.6322
# Epoch 21/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6644 - accuracy: 0.5969 - auc: 0.6199 - val_loss: 0.6177 - val_accuracy: 0.6593 - val_auc: 0.7085
# Epoch 22/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6625 - accuracy: 0.6137 - auc: 0.6345 - val_loss: 0.7180 - val_accuracy: 0.6371 - val_auc: 0.6973
# Epoch 23/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6581 - accuracy: 0.6164 - auc: 0.6389 - val_loss: 0.6082 - val_accuracy: 0.6450 - val_auc: 0.7136
# Epoch 24/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6518 - accuracy: 0.6266 - auc: 0.6395 - val_loss: 0.6230 - val_accuracy: 0.6545 - val_auc: 0.7046
# Epoch 25/100
# 40/40 [==============================] - 12s 295ms/step - loss: 0.6544 - accuracy: 0.6219 - auc: 0.6486 - val_loss: 0.6742 - val_accuracy: 0.6339 - val_auc: 0.6749
# Epoch 26/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.6572 - accuracy: 0.6133 - auc: 0.6400 - val_loss: 0.6720 - val_accuracy: 0.6006 - val_auc: 0.6498
# Epoch 27/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6487 - accuracy: 0.6289 - auc: 0.6556 - val_loss: 0.6013 - val_accuracy: 0.6624 - val_auc: 0.7232
# Epoch 28/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6556 - accuracy: 0.6254 - auc: 0.6455 - val_loss: 0.6072 - val_accuracy: 0.6640 - val_auc: 0.7243
# Epoch 29/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6529 - accuracy: 0.6250 - auc: 0.6487 - val_loss: 0.8742 - val_accuracy: 0.5689 - val_auc: 0.6184
# Epoch 30/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6530 - accuracy: 0.6250 - auc: 0.6449 - val_loss: 0.6311 - val_accuracy: 0.6529 - val_auc: 0.7135
# Epoch 31/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6439 - accuracy: 0.6406 - auc: 0.6675 - val_loss: 0.7512 - val_accuracy: 0.5610 - val_auc: 0.5912
# Epoch 32/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6430 - accuracy: 0.6523 - auc: 0.6764 - val_loss: 1.0039 - val_accuracy: 0.5880 - val_auc: 0.6294
# Epoch 33/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6474 - accuracy: 0.6418 - auc: 0.6521 - val_loss: 0.6413 - val_accuracy: 0.6133 - val_auc: 0.6720
# Epoch 34/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6441 - accuracy: 0.6352 - auc: 0.6553 - val_loss: 0.6375 - val_accuracy: 0.6498 - val_auc: 0.6884
# Epoch 35/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6463 - accuracy: 0.6363 - auc: 0.6565 - val_loss: 0.6464 - val_accuracy: 0.6403 - val_auc: 0.6862
# Epoch 36/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6444 - accuracy: 0.6426 - auc: 0.6503 - val_loss: 0.6593 - val_accuracy: 0.6228 - val_auc: 0.6710
# Epoch 37/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6363 - accuracy: 0.6430 - auc: 0.6652 - val_loss: 0.8077 - val_accuracy: 0.5832 - val_auc: 0.6240
# Epoch 38/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6336 - accuracy: 0.6500 - auc: 0.6708 - val_loss: 0.9852 - val_accuracy: 0.5261 - val_auc: 0.5995
# Epoch 39/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6418 - accuracy: 0.6484 - auc: 0.6663 - val_loss: 0.8022 - val_accuracy: 0.5911 - val_auc: 0.6192
# Epoch 40/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6360 - accuracy: 0.6316 - auc: 0.6690 - val_loss: 0.7189 - val_accuracy: 0.6149 - val_auc: 0.6526
# Epoch 41/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6364 - accuracy: 0.6520 - auc: 0.6742 - val_loss: 0.6203 - val_accuracy: 0.6450 - val_auc: 0.6959
# Epoch 42/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6342 - accuracy: 0.6484 - auc: 0.6605 - val_loss: 0.6608 - val_accuracy: 0.6450 - val_auc: 0.6647
# Epoch 43/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6384 - accuracy: 0.6492 - auc: 0.6662 - val_loss: 0.6538 - val_accuracy: 0.6355 - val_auc: 0.6887
# Epoch 44/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.6345 - accuracy: 0.6598 - auc: 0.6735 - val_loss: 0.7327 - val_accuracy: 0.6117 - val_auc: 0.6285
# Epoch 45/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6270 - accuracy: 0.6578 - auc: 0.6741 - val_loss: 0.6650 - val_accuracy: 0.6339 - val_auc: 0.6732
# Epoch 46/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6163 - accuracy: 0.6703 - auc: 0.7022 - val_loss: 0.6539 - val_accuracy: 0.6371 - val_auc: 0.6823
# Epoch 47/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6219 - accuracy: 0.6664 - auc: 0.6812 - val_loss: 0.6183 - val_accuracy: 0.6498 - val_auc: 0.7064
# Epoch 48/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6252 - accuracy: 0.6738 - auc: 0.6866 - val_loss: 0.7543 - val_accuracy: 0.5880 - val_auc: 0.5855
# Epoch 49/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.6142 - accuracy: 0.6871 - auc: 0.6893 - val_loss: 0.6480 - val_accuracy: 0.6149 - val_auc: 0.6628
# Epoch 50/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.6111 - accuracy: 0.6754 - auc: 0.6924 - val_loss: 0.6551 - val_accuracy: 0.6719 - val_auc: 0.7108
# Epoch 51/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6071 - accuracy: 0.6984 - auc: 0.7055 - val_loss: 0.7227 - val_accuracy: 0.6307 - val_auc: 0.6587
# Epoch 52/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6040 - accuracy: 0.6941 - auc: 0.6994 - val_loss: 0.7285 - val_accuracy: 0.6387 - val_auc: 0.6648
# Epoch 53/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6014 - accuracy: 0.6879 - auc: 0.7056 - val_loss: 0.6531 - val_accuracy: 0.6006 - val_auc: 0.6573
# Epoch 54/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6011 - accuracy: 0.6871 - auc: 0.7086 - val_loss: 0.9243 - val_accuracy: 0.6101 - val_auc: 0.6382
# Epoch 55/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.6019 - accuracy: 0.6926 - auc: 0.7065 - val_loss: 0.8738 - val_accuracy: 0.5246 - val_auc: 0.5981
# Epoch 56/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5904 - accuracy: 0.7063 - auc: 0.7169 - val_loss: 0.6989 - val_accuracy: 0.6181 - val_auc: 0.6631
# Epoch 57/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.5848 - accuracy: 0.7125 - auc: 0.7293 - val_loss: 0.6712 - val_accuracy: 0.6038 - val_auc: 0.6601
# Epoch 58/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5704 - accuracy: 0.7367 - auc: 0.7484 - val_loss: 0.7319 - val_accuracy: 0.6355 - val_auc: 0.6738
# Epoch 59/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5805 - accuracy: 0.7203 - auc: 0.7276 - val_loss: 0.7520 - val_accuracy: 0.6276 - val_auc: 0.6510
# Epoch 60/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5665 - accuracy: 0.7352 - auc: 0.7376 - val_loss: 0.7823 - val_accuracy: 0.5674 - val_auc: 0.6214
# Epoch 61/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5579 - accuracy: 0.7445 - auc: 0.7443 - val_loss: 0.9037 - val_accuracy: 0.6022 - val_auc: 0.6313
# Epoch 62/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5593 - accuracy: 0.7445 - auc: 0.7450 - val_loss: 0.7586 - val_accuracy: 0.6070 - val_auc: 0.6593
# Epoch 63/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5520 - accuracy: 0.7477 - auc: 0.7550 - val_loss: 0.7005 - val_accuracy: 0.6101 - val_auc: 0.6728
# Epoch 64/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5481 - accuracy: 0.7527 - auc: 0.7482 - val_loss: 0.8067 - val_accuracy: 0.5959 - val_auc: 0.6414
# Epoch 65/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5309 - accuracy: 0.7711 - auc: 0.7688 - val_loss: 0.7748 - val_accuracy: 0.6149 - val_auc: 0.6706
# Epoch 66/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5311 - accuracy: 0.7695 - auc: 0.7721 - val_loss: 0.8079 - val_accuracy: 0.6086 - val_auc: 0.6517
# Epoch 67/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5380 - accuracy: 0.7711 - auc: 0.7577 - val_loss: 0.8520 - val_accuracy: 0.6244 - val_auc: 0.6566
# Epoch 68/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5281 - accuracy: 0.7809 - auc: 0.7656 - val_loss: 0.8090 - val_accuracy: 0.6149 - val_auc: 0.6615
# Epoch 69/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5214 - accuracy: 0.7820 - auc: 0.7683 - val_loss: 0.7707 - val_accuracy: 0.5864 - val_auc: 0.6370
# Epoch 70/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5169 - accuracy: 0.7887 - auc: 0.7785 - val_loss: 0.8126 - val_accuracy: 0.6086 - val_auc: 0.6600
# Epoch 71/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5211 - accuracy: 0.7859 - auc: 0.7690 - val_loss: 1.0612 - val_accuracy: 0.5943 - val_auc: 0.6178
# Epoch 72/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.5208 - accuracy: 0.7863 - auc: 0.7676 - val_loss: 0.8577 - val_accuracy: 0.5642 - val_auc: 0.6292
# Epoch 73/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5128 - accuracy: 0.7934 - auc: 0.7811 - val_loss: 0.8873 - val_accuracy: 0.5832 - val_auc: 0.6362
# Epoch 74/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4993 - accuracy: 0.8074 - auc: 0.7885 - val_loss: 0.8153 - val_accuracy: 0.6117 - val_auc: 0.6660
# Epoch 75/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5049 - accuracy: 0.7910 - auc: 0.7812 - val_loss: 0.8096 - val_accuracy: 0.6149 - val_auc: 0.6507
# Epoch 76/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.5032 - accuracy: 0.8000 - auc: 0.7783 - val_loss: 0.7828 - val_accuracy: 0.6197 - val_auc: 0.6676
# Epoch 77/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.5073 - accuracy: 0.8012 - auc: 0.7756 - val_loss: 0.8075 - val_accuracy: 0.6149 - val_auc: 0.6672
# Epoch 78/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.5034 - accuracy: 0.8082 - auc: 0.7783 - val_loss: 0.9281 - val_accuracy: 0.6149 - val_auc: 0.6549
# Epoch 79/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4956 - accuracy: 0.8121 - auc: 0.7889 - val_loss: 0.8193 - val_accuracy: 0.6292 - val_auc: 0.6652
# Epoch 80/100
# 40/40 [==============================] - 12s 300ms/step - loss: 0.4932 - accuracy: 0.8223 - auc: 0.8035 - val_loss: 0.8485 - val_accuracy: 0.5911 - val_auc: 0.6493
# Epoch 81/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4969 - accuracy: 0.8145 - auc: 0.7871 - val_loss: 1.0843 - val_accuracy: 0.6101 - val_auc: 0.6326
# Epoch 82/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4905 - accuracy: 0.8145 - auc: 0.7906 - val_loss: 0.8331 - val_accuracy: 0.6403 - val_auc: 0.6694
# Epoch 83/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4922 - accuracy: 0.8039 - auc: 0.7938 - val_loss: 0.8264 - val_accuracy: 0.6260 - val_auc: 0.6636
# Epoch 84/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4969 - accuracy: 0.8117 - auc: 0.7837 - val_loss: 0.8233 - val_accuracy: 0.6276 - val_auc: 0.6667
# Epoch 85/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4886 - accuracy: 0.8234 - auc: 0.7962 - val_loss: 0.8554 - val_accuracy: 0.6244 - val_auc: 0.6714
# Epoch 86/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4873 - accuracy: 0.8230 - auc: 0.7932 - val_loss: 0.8390 - val_accuracy: 0.6292 - val_auc: 0.6674
# Epoch 87/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4983 - accuracy: 0.8082 - auc: 0.7915 - val_loss: 0.8166 - val_accuracy: 0.6133 - val_auc: 0.6686
# Epoch 88/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4801 - accuracy: 0.8242 - auc: 0.7981 - val_loss: 0.8499 - val_accuracy: 0.6244 - val_auc: 0.6689
# Epoch 89/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4899 - accuracy: 0.8090 - auc: 0.7950 - val_loss: 0.8368 - val_accuracy: 0.6181 - val_auc: 0.6654
# Epoch 90/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4960 - accuracy: 0.7992 - auc: 0.7847 - val_loss: 0.8496 - val_accuracy: 0.6260 - val_auc: 0.6670
# Epoch 91/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4879 - accuracy: 0.8137 - auc: 0.7976 - val_loss: 0.8347 - val_accuracy: 0.6307 - val_auc: 0.6732
# Epoch 92/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4935 - accuracy: 0.8066 - auc: 0.7859 - val_loss: 0.8733 - val_accuracy: 0.6228 - val_auc: 0.6580
# Epoch 93/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4973 - accuracy: 0.8105 - auc: 0.7858 - val_loss: 0.8656 - val_accuracy: 0.6228 - val_auc: 0.6622
# Epoch 94/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4883 - accuracy: 0.8133 - auc: 0.7979 - val_loss: 0.8471 - val_accuracy: 0.6165 - val_auc: 0.6650
# Epoch 95/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4918 - accuracy: 0.8223 - auc: 0.7876 - val_loss: 0.9128 - val_accuracy: 0.6181 - val_auc: 0.6676
# Epoch 96/100
# 40/40 [==============================] - 12s 298ms/step - loss: 0.4858 - accuracy: 0.8211 - auc: 0.7942 - val_loss: 0.9042 - val_accuracy: 0.6181 - val_auc: 0.6653
# Epoch 97/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4813 - accuracy: 0.8340 - auc: 0.8009 - val_loss: 0.8423 - val_accuracy: 0.6260 - val_auc: 0.6664
# Epoch 98/100
# 40/40 [==============================] - 12s 299ms/step - loss: 0.4782 - accuracy: 0.8219 - auc: 0.7990 - val_loss: 0.8963 - val_accuracy: 0.6228 - val_auc: 0.6618
# Epoch 99/100
# 40/40 [==============================] - 12s 296ms/step - loss: 0.4912 - accuracy: 0.8031 - auc: 0.7837 - val_loss: 0.8734 - val_accuracy: 0.6244 - val_auc: 0.6687
# Epoch 100/100
# 40/40 [==============================] - 12s 297ms/step - loss: 0.4820 - accuracy: 0.8273 - auc: 0.7984 - val_loss: 0.8646 - val_accuracy: 0.6339 - val_auc: 0.6759

# %%
import pickle as pk
def save_challenge_model(model_folder, model1, model2, m_name1, m_name2, param_feature) :
    os.makedirs(model_folder, exist_ok=True)
    info_fnm = os.path.join(model_folder, 'desc.pk')
    filename1 = os.path.join(model_folder, m_name1 + '_model1.hdf5')
    filename2 = os.path.join(model_folder, m_name2 + '_model2.hdf5')
    model1.save(filename1)
    model2.save(filename2)
    param_feature['model1'] = m_name1
    param_feature['model2'] = m_name2
    param_feature['model_fnm1'] = filename1
    param_feature['model_fnm2'] = filename2
    with open(info_fnm, 'wb') as f:
        pk.dump(param_feature, f, pk.HIGHEST_PROTOCOL)
    return 1

def load_challenge_model(model_folder, verbose):
    info_fnm = os.path.join(model_folder, 'desc.pk')
    with open(info_fnm, 'rb') as f:
        info_m = pk.load(f)
#    if info_m['model'] == 'toy' :
#        model = get_toy(info_m['mel_shape'])
#    filename = os.path.join(model_folder, info_m['model'] + '_model.hdf5')
#    model.load_weights(filename)
    return info_m

# %%
# Run model.
def run_model(model_folder, data_folder, output_folder, allow_failures, verbose):
    # Load models.
    if verbose >= 1:
        print('Loading Challenge model...')

    model = load_challenge_model(model_folder, verbose) ### Teams: Implement this function!!!

    # Find the patient data files.
    patient_files = find_patient_files(data_folder)
    num_patient_files = len(patient_files)

    if num_patient_files==0:
        raise Exception('No data was provided.')

    # Create a folder for the Challenge outputs if it does not already exist.
    os.makedirs(output_folder, exist_ok=True)

    # Run the team's model on the Challenge data.
    if verbose >= 1:
        print('Running model on Challenge data...')

#    @tf.function
    # Iterate over the patient files.
    for i in range(num_patient_files):
        if verbose >= 2:
            print('    {}/{}...'.format(i+1, num_patient_files))

        patient_data = load_patient_data(patient_files[i])
        recordings = load_recordings(data_folder, patient_data)

        # Allow or disallow the model to fail on parts of the data; helpful for debugging.
        try:
            classes, labels, probabilities = run_challenge_model(model, patient_data, recordings, verbose) ### Teams: Implement this function!!!
        except:
            if allow_failures:
                if verbose >= 2:
                    print('... failed.')
                classes, labels, probabilities = list(), list(), list()
            else:
                raise

        # Save Challenge outputs.
        head, tail = os.path.split(patient_files[i])
        root, extension = os.path.splitext(tail)
        output_file = os.path.join(output_folder, root + '.csv')
        patient_id = get_patient_id(patient_data)
        save_challenge_outputs(output_file, patient_id, classes, labels, probabilities)

    if verbose >= 1:
        print('Done.')

# %%
def run_challenge_model(model, data, recordings, verbose):

    murmur_classes = ['Present', 'Unknown', 'Absent']
    outcome_classes = ['Abnormal', 'Normal']

    if model['model1'] == 'toy1' :
        model1 = get_toy5_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'] )
    if model['model2'] == 'toy2' :
        model2 = get_toy5_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'])
    if model['model1'] == 'lcnn1' :
        model1 = get_LCNN_o_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'lcnn2' :
        model2 = get_LCNN_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'])
    if model['model1'] == 'resmax1' :
        model1 = get_ResMax_o_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'resmax2' :
        model2 = get_ResMax_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'])
    if model['model1'] == 'lcnn1_dr' :
        model1 = get_LCNN_o_1_dr(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'], dp = model['dp'], fc = model['fc'], ext = model[\
'ext'])
    if model['model2'] == 'lcnn2_dr' :
        model2 = get_LCNN_2_dr(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], dp = model['dp'], fc = model['fc'], ext = model['ext'])
    if model['model1'] == 'lcnn_rr_qrs1' :
        model1 = get_LCNN_o_5_dr_qrs1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    if model['model2'] == 'lcnn_rr_qrs2' :
        model2 = get_LCNN_o_5_dr_qrs1_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = model['use_mel'], use_cqt = model['use_cqt'], use_stft = model['use_stft'], ord1 = model['ord1'])
    
    
    model1.load_weights(model['model_fnm1'])
    model2.load_weights(model['model_fnm2'])

#    classes = model['classes']
    # Load features.
    features = get_feature_one(data, verbose = 0)

    samp_sec = model['samp_sec']
    pre_emphasis = model['pre_emphasis']
    hop_length = model['hop_length']
    win_length = model['win_length']
    n_mels = model['n_mels']
    filter_scale = model['filter_scale']
    n_bins = model['n_bins']
    fmin = model['fmin']
    use_mel = model['use_mel']
    use_cqt = model['use_cqt']
    use_stft = model['use_stft']

    trim = model['trim']
    
    features['rr1'] = [] 
    for i in range(len(recordings)):
        try:
            ____, info = nk.ecg_process(recordings[i], sampling_rate=4000)
            rr = np.mean(np.diff(info['ECG_R_Peaks'])/4000)
            current_rr = rr
        except:
            current_rr=np.zeros(1)
        features['rr1'].append(current_rr)  
    features['rr1'] = np.array(features['rr1'])
    
    
    features['qrs1'] = []
    for i in range(len(recordings)):
        try:
            R_peaks, S_point, Q_point=EKG_QRS_detect1(recording1, 4000, True, False)
            qrs = np.mean(S_point-Q_point)
            current_qrs = qrs
        except:
            current_qrs=np.zeros(1) 
        features['qrs1'].append(current_rr)  
    features['qrs1'] = np.array(features['qrs1'])
    

    features['mel1'] = []
    for i in range(len(recordings)) :
        if use_mel :
            mel1 = feature_extract_melspec(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length,
                                           win_length = win_length, n_mels = n_mels, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1) )
        features['mel1'].append(mel1)
    M, N = features['mel1'][0].shape

    if use_mel :
        for i in range(len(features['mel1'])) :
            features['mel1'][i] = features['mel1'][i].reshape(M,N,1)
    features['mel1'] = np.array(features['mel1'])

    features['cqt1'] = []
    for i in range(len(recordings)) :
        if use_cqt :
            mel1 = feature_extract_cqt(recordings[i], samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale,
                                        n_bins = n_bins, fmin = fmin, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1))
        features['cqt1'].append(mel1)
    M, N = features['cqt1'][0].shape
    if use_cqt :
        for i in range(len(features['cqt1'])) :
            features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)
    features['cqt1'] = np.array(features['cqt1'])

    features['stft1'] = []
    for i in range(len(recordings)) :
        if use_stft :
            mel1 = feature_extract_stft(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length,
                                        win_length = win_length, trim = trim)[0]
        else :
            mel1 = np.zeros( (1,1) )
        features['stft1'].append(mel1)
    M, N = features['stft1'][0].shape
    if use_stft :
        for i in range(len(features['stft1'])) :
            features['stft1'][i] = features['stft1'][i].reshape(M,N,1)
    features['stft1'] = np.array(features['stft1'])

    #    print(features)
    # Impute missing data.
    res1 = model1.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], 
                           features['rr1'], features['qrs1'], features['mel1'], features['cqt1'], features['stft1']])
    res2 = model2.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], 
                           features['rr1'], features['qrs1'], features['mel1'], features['cqt1'], features['stft1']])

    # Get classifier probabilities.
    if model['ord1'] :
        idx1 = res1.argmax(axis=0)[0]
        murmur_p = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
        murmur_probabilities = np.zeros((3,))
        murmur_probabilities[0] = murmur_p[0]
        murmur_probabilities[1] = 0
        murmur_probabilities[2] = murmur_p[1]
        outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기
    else :
        if model['mm_mean'] :
            murmur_probabilities = res1.mean(axis = 0)
        else :
            idx1 = res1.argmax(axis=0)[0]
            murmur_probabilities = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
        outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기

        
    ## 이부분도 생각 필요.. rule 을 cost를 maximize 하는 기준으로 threshold 탐색 필요할지도..
    # Choose label with highest probability.
    murmur_labels = np.zeros(len(murmur_classes), dtype=np.int_)
    idx = np.argmax(murmur_probabilities)
    murmur_labels[idx] = 1
    outcome_labels = np.zeros(len(outcome_classes), dtype=np.int_)
    idx = np.argmax(outcome_probabilities)
    outcome_labels[idx] = 1

    # Concatenate classes, labels, and probabilities.
    classes = murmur_classes + outcome_classes
    labels = np.concatenate((murmur_labels, outcome_labels))
    probabilities = np.concatenate((murmur_probabilities, outcome_probabilities))

    return classes, labels, probabilities

# %%
save_challenge_model(model_folder, model1, model2, m_name1 = 'lcnn_rr_qrs1', m_name2 = 'lcnn_rr_qrs2', param_feature = params_feature)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 1

# %%
model_folder
# Out:
# 'lcnn__rr_qrs1'

# %%
data_folder = test_folder
data_folder
# Out:
# '/Data2/hmd/data_split/murmur/test'

# %%
output_folder
# Out:
# '/Data2/hmd/hmd_sy/notebooks/out_lcnn__rr_qrs1'

# %%
run_model(model_folder, test_folder, output_folder, allow_failures = True, verbose = 1)
# Out:
# Loading Challenge model...
# Running model on Challenge data...
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6364730430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f63646cda60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Done.

# %%
murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)
classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
    + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string

if len(sys.argv) == 3:
    print(output_string)
elif len(sys.argv) == 4:
    with open(sys.argv[3], 'w') as f:
        f.write(output_string)
#Murmur scores
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.560,0.843,0.790,17556.991
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.642,0.644,0.581,14570.335
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.776,0.000,0.905
# Accuracy,0.868,0.000,0.921
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.614,0.670
# Accuracy,0.551,0.742

# %%
label_folder = test_folder
murmur_classes = ['Present', 'Unknown', 'Absent']
outcome_classes = ['Abnormal', 'Normal']

# Load and parse label and model output files.
label_files, output_files = find_challenge_files(label_folder, output_folder)
murmur_labels = load_murmurs(label_files, murmur_classes)
murmur_binary_outputs, murmur_scalar_outputs = load_classifier_outputs(output_files, murmur_classes)
outcome_labels = load_outcomes(label_files, outcome_classes)
outcome_binary_outputs, outcome_scalar_outputs = load_classifier_outputs(output_files, outcome_classes)


print(np.mean(murmur_scalar_outputs[:,0]))
print(np.mean(murmur_scalar_outputs[:,2]))
print(np.mean(outcome_scalar_outputs[:,0]))
print(np.mean(outcome_scalar_outputs[:,1]))
# Out:
# 0.29585031257810973
# 0.7041496907407174
# 0.44369894220293815
# 0.5563010561402005

# %%
for th1 in [0.01, 0.05, 0.1, 0.15,0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8] :
    murmur_binary_outputs[:,0] = murmur_scalar_outputs[:,0] > th1
    murmur_binary_outputs[:,2] = murmur_scalar_outputs[:,2] > 1 - th1
    outcome_binary_outputs[:,0] = outcome_scalar_outputs[:,0] > th1
    outcome_binary_outputs[:,1] = outcome_scalar_outputs[:,1] > 1 - th1
    # For each patient, set the 'Present' or 'Abnormal' class to positive if no class is positive or if multiple classes are positive.
    murmur_labels = enforce_positives(murmur_labels, murmur_classes, 'Present')
    murmur_binary_outputs = enforce_positives(murmur_binary_outputs, murmur_classes, 'Present')
    outcome_labels = enforce_positives(outcome_labels, outcome_classes, 'Abnormal')
    outcome_binary_outputs = enforce_positives(outcome_binary_outputs, outcome_classes, 'Abnormal')
    # Evaluate the murmur model by comparing the labels and model outputs.
    murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes = compute_auc(murmur_labels, murmur_scalar_outputs)
    murmur_f_measure, murmur_f_measure_classes = compute_f_measure(murmur_labels, murmur_binary_outputs)
    murmur_accuracy, murmur_accuracy_classes = compute_accuracy(murmur_labels, murmur_binary_outputs)
    murmur_weighted_accuracy = compute_weighted_accuracy(murmur_labels, murmur_binary_outputs, murmur_classes) # This is the murmur scoring metric.
    murmur_cost = compute_cost(outcome_labels, murmur_binary_outputs, outcome_classes, murmur_classes) # Use *outcomes* to score *murmurs* for the Challenge cost metric, but this is not the actual murmur scoring metric.
    murmur_scores = (murmur_classes, murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes, \
                 murmur_f_measure, murmur_f_measure_classes, murmur_accuracy, murmur_accuracy_classes, murmur_weighted_accuracy, murmur_cost)

    # Evaluate the outcome model by comparing the labels and model outputs.
    outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes = compute_auc(outcome_labels, outcome_scalar_outputs)
    outcome_f_measure, outcome_f_measure_classes = compute_f_measure(outcome_labels, outcome_binary_outputs)
    outcome_accuracy, outcome_accuracy_classes = compute_accuracy(outcome_labels, outcome_binary_outputs)
    outcome_weighted_accuracy = compute_weighted_accuracy(outcome_labels, outcome_binary_outputs, outcome_classes)
    outcome_cost = compute_cost(outcome_labels, outcome_binary_outputs, outcome_classes, outcome_classes) # This is the clinical outcomes scoring metric.
    outcome_scores = (outcome_classes, outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes, \
                  outcome_f_measure, outcome_f_measure_classes, outcome_accuracy, outcome_accuracy_classes, outcome_weighted_accuracy, outcome_cost)



    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
    murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
    outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
                + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
    print("threshold: ", th1)
    print(output_string)
    print("-------------")
# Out:
# threshold:  0.01
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.184,0.277,0.553,14022.531
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.349,0.513,0.834,14916.196
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.360,0.000,0.191
# Accuracy,1.000,0.000,0.108
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.676,0.021
# Accuracy,0.990,0.011
#
# -------------
# threshold:  0.05
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.357,0.524,0.679,13198.352
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.369,0.518,0.828,14500.929
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.469,0.000,0.602
# Accuracy,1.000,0.000,0.446
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.676,0.061
# Accuracy,0.980,0.032
#
# -------------
# threshold:  0.1
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.407,0.607,0.712,13017.043
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.406,0.518,0.794,13683.005
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.517,0.000,0.702
# Accuracy,0.974,0.000,0.568
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.664,0.148
# Accuracy,0.929,0.086
#
# -------------
# threshold:  0.15
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.448,0.675,0.747,13695.924
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.486,0.555,0.786,12339.302
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.578,0.000,0.767
# Accuracy,0.974,0.000,0.662
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.674,0.298
# Accuracy,0.898,0.194
#
# -------------
# threshold:  0.2
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.464,0.707,0.741,14174.246
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.580,0.613,0.784,11044.617
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.593,0.000,0.800
# Accuracy,0.921,0.000,0.719
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.697,0.464
# Accuracy,0.867,0.344
#
# -------------
# threshold:  0.25
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.482,0.733,0.755,14740.422
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.616,0.639,0.786,10645.335
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.625,0.000,0.820
# Accuracy,0.921,0.000,0.755
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.709,0.524
# Accuracy,0.857,0.409
#
# -------------
# threshold:  0.3
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.503,0.764,0.771,15532.732
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.639,0.649,0.748,10950.558
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.660,0.000,0.847
# Accuracy,0.921,0.000,0.799
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.700,0.579
# Accuracy,0.796,0.495
#
# -------------
# threshold:  0.35
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.512,0.780,0.768,15924.261
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.657,0.660,0.710,11549.897
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.673,0.000,0.861
# Accuracy,0.895,0.000,0.827
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.689,0.624
# Accuracy,0.735,0.581
#
# -------------
# threshold:  0.4
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.530,0.806,0.782,16114.128
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.664,0.665,0.684,12089.406
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.708,0.000,0.882
# Accuracy,0.895,0.000,0.863
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.680,0.648
# Accuracy,0.694,0.634
#
# -------------
# threshold:  0.45
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.542,0.822,0.779,16727.018
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.660,0.660,0.635,13259.086
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.733,0.000,0.892
# Accuracy,0.868,0.000,0.892
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.652,0.667
# Accuracy,0.622,0.699
#
# -------------
# threshold:  0.5
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.560,0.843,0.790,17556.991
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.642,0.644,0.581,14570.335
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.776,0.000,0.905
# Accuracy,0.868,0.000,0.921
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.614,0.670
# Accuracy,0.551,0.742
#
# -------------
# threshold:  0.55
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.565,0.848,0.782,18181.503
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.636,0.644,0.533,15929.052
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.790,0.000,0.906
# Accuracy,0.842,0.000,0.935
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.580,0.691
# Accuracy,0.480,0.817
#
# -------------
# threshold:  0.6
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.558,0.843,0.757,18598.553
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.623,0.644,0.479,17558.235
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.769,0.000,0.903
# Accuracy,0.789,0.000,0.942
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.534,0.712
# Accuracy,0.398,0.903
#
# -------------
# threshold:  0.65
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.579,0.864,0.768,19434.524
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.619,0.649,0.453,18388.678
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.822,0.000,0.915
# Accuracy,0.789,0.000,0.971
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.511,0.727
# Accuracy,0.357,0.957
#
# -------------
# threshold:  0.7
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.587,0.869,0.771,19643.525
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.592,0.634,0.413,19433.918
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.845,0.000,0.916
# Accuracy,0.789,0.000,0.978
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.462,0.722
# Accuracy,0.306,0.978
#
# -------------
# threshold:  0.75
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.580,0.864,0.757,19643.342
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.554,0.607,0.370,20480.149
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.829,0.000,0.913
# Accuracy,0.763,0.000,0.978
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.400,0.708
# Accuracy,0.255,0.978
#
# -------------
# threshold:  0.8
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.765,0.615,0.579,0.864,0.747,19852.423
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.700,0.534,0.597,0.346,21107.390
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.951,0.500,0.845
# AUPRC,0.883,0.073,0.889
# F-measure,0.824,0.000,0.913
# Accuracy,0.737,0.000,0.986
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.750,0.649
# F-measure,0.364,0.705
# Accuracy,0.224,0.989
#
# -------------
