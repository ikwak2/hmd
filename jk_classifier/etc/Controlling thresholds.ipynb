# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats
import librosa
import librosa.display
import math
import sys

# %%
sys.path.insert(0,'utils')
from helper_code import *
from get_feature import *
from models import *
from Generator0 import *

# %%
root_dir = 'physionet.org/files/circor-heart-sound/1.0.3'
training_data_file = root_dir + '/' + 'training_data.csv'
training_data_dir = root_dir + '/' + 'training_data'
model_dir = root_dir + '/' + 'model'

# %%
data_folder =  'physionet.org/files/circor-heart-sound/1.0.3/training_data'
train_folder =  '/home/ubuntu/data/hmd/murmur/train'
test_folder = '/home/ubuntu/data/hmd/murmur/test'

# %% [markdown]
# 피쳐 다 쓴 모형 결과 확인부분 (Upgrading models2.ipynb)

# %%
model_folder = 'tmp_model4'
output_folder = '/home/ubuntu/hmd/notebooks/out2'

# %%
from evaluate_model import *

# %%
murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
    + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string

print(output_string)
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.519,0.801,0.714,18391.704
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.619,0.649,0.453,18388.678
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.683,0.000,0.874
# Accuracy,0.737,0.000,0.899
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.511,0.727
# Accuracy,0.357,0.957

# %% [markdown]
# melspec 피쳐만 쓴거 결과 확인 (Upgrading models1.ipynb)

# %%
model_folder = 'tmp_model'
output_folder = '/home/ubuntu/hmd/notebooks/out__1'

# %%
murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
    + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string

print(output_string)
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.515,0.791,0.730,17561.153
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.616,0.618,0.648,12807.619
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.682,0.000,0.864
# Accuracy,0.789,0.000,0.871
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.640,0.592
# Accuracy,0.663,0.570

# %% [markdown]
# ### accuracy, cost 는 threshold 에 따라 결정됨으로 이를 조절해보며 weighted Accuracy, Cost 의 최적값을 탐색해볼 필요가 있음

# %% [markdown]
# ### melspec 피쳐만 쓴거 결과 확인 (Upgrading models1.ipynb)

# %%
model_folder = 'tmp_model'
output_folder = '/home/ubuntu/hmd/notebooks/out__1'

# %%
label_folder = test_folder
murmur_classes = ['Present', 'Unknown', 'Absent']
outcome_classes = ['Abnormal', 'Normal']

# Load and parse label and model output files.
label_files, output_files = find_challenge_files(label_folder, output_folder)
murmur_labels = load_murmurs(label_files, murmur_classes)
murmur_binary_outputs, murmur_scalar_outputs = load_classifier_outputs(output_files, murmur_classes)
outcome_labels = load_outcomes(label_files, outcome_classes)
outcome_binary_outputs, outcome_scalar_outputs = load_classifier_outputs(output_files, outcome_classes)


print(np.mean(murmur_scalar_outputs[:,0]))
print(np.mean(murmur_scalar_outputs[:,2]))
print(np.mean(outcome_scalar_outputs[:,0]))
print(np.mean(outcome_scalar_outputs[:,1]))
# Out:
# 0.3392682311232984
# 0.6508482133010471
# 0.5543625781675393
# 0.44563742186387434

# %%
## threshold 바꿔가면서 결과 출력

for th1 in [0.05, 0.1, 0.15,0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75] :
    murmur_binary_outputs[:,0] = murmur_scalar_outputs[:,0] > th1
    murmur_binary_outputs[:,2] = murmur_scalar_outputs[:,2] > 1 - th1
    outcome_binary_outputs[:,0] = outcome_scalar_outputs[:,0] > th1
    outcome_binary_outputs[:,1] = outcome_scalar_outputs[:,1] > 1 - th1
    # For each patient, set the 'Present' or 'Abnormal' class to positive if no class is positive or if multiple classes are positive.
    murmur_labels = enforce_positives(murmur_labels, murmur_classes, 'Present')
    murmur_binary_outputs = enforce_positives(murmur_binary_outputs, murmur_classes, 'Present')
    outcome_labels = enforce_positives(outcome_labels, outcome_classes, 'Abnormal')
    outcome_binary_outputs = enforce_positives(outcome_binary_outputs, outcome_classes, 'Abnormal')
    # Evaluate the murmur model by comparing the labels and model outputs.
    murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes = compute_auc(murmur_labels, murmur_scalar_outputs)
    murmur_f_measure, murmur_f_measure_classes = compute_f_measure(murmur_labels, murmur_binary_outputs)
    murmur_accuracy, murmur_accuracy_classes = compute_accuracy(murmur_labels, murmur_binary_outputs)
    murmur_weighted_accuracy = compute_weighted_accuracy(murmur_labels, murmur_binary_outputs, murmur_classes) # This is the murmur scoring metric.
    murmur_cost = compute_cost(outcome_labels, murmur_binary_outputs, outcome_classes, murmur_classes) # Use *outcomes* to score *murmurs* for the Challenge cost metric, but this is not the actual murmur scoring metric.
    murmur_scores = (murmur_classes, murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes, \
                 murmur_f_measure, murmur_f_measure_classes, murmur_accuracy, murmur_accuracy_classes, murmur_weighted_accuracy, murmur_cost)

    # Evaluate the outcome model by comparing the labels and model outputs.
    outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes = compute_auc(outcome_labels, outcome_scalar_outputs)
    outcome_f_measure, outcome_f_measure_classes = compute_f_measure(outcome_labels, outcome_binary_outputs)
    outcome_accuracy, outcome_accuracy_classes = compute_accuracy(outcome_labels, outcome_binary_outputs)
    outcome_weighted_accuracy = compute_weighted_accuracy(outcome_labels, outcome_binary_outputs, outcome_classes)
    outcome_cost = compute_cost(outcome_labels, outcome_binary_outputs, outcome_classes, outcome_classes) # This is the clinical outcomes scoring metric.
    outcome_scores = (outcome_classes, outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes, \
                  outcome_f_measure, outcome_f_measure_classes, outcome_accuracy, outcome_accuracy_classes, outcome_weighted_accuracy, outcome_cost)



    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
    murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
    outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
                + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
    print("threshold: ", th1)
    print(output_string)
    print("-------------")
# Out:
# threshold:  0.05
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.170,0.262,0.544,14064.560
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.353,0.000,0.157
# Accuracy,1.000,0.000,0.086
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.1
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.272,0.393,0.601,12173.756
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.396,0.000,0.420
# Accuracy,0.974,0.000,0.273
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.15
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.336,0.492,0.642,11578.831
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.442,0.000,0.566
# Accuracy,0.947,0.000,0.417
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.2
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.385,0.576,0.674,12872.688
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.483,0.000,0.673
# Accuracy,0.921,0.000,0.540
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.25
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.420,0.644,0.677,14288.929
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.508,0.000,0.752
# Accuracy,0.842,0.000,0.655
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.3
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.452,0.696,0.704,15397.448
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.334,0.503,0.823,15125.621
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.557,0.000,0.798
# Accuracy,0.842,0.000,0.727
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.669,0.000
# Accuracy,0.980,0.000
#
# -------------
# threshold:  0.35
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.463,0.717,0.704,15965.050
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.371,0.508,0.804,14344.120
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.574,0.000,0.815
# Accuracy,0.816,0.000,0.763
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.664,0.078
# Accuracy,0.949,0.043
#
# -------------
# threshold:  0.4
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.487,0.754,0.722,16552.533
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.448,0.529,0.770,12961.906
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.614,0.000,0.846
# Accuracy,0.816,0.000,0.813
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.659,0.237
# Accuracy,0.888,0.151
#
# -------------
# threshold:  0.45
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.494,0.764,0.717,16948.706
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.572,0.597,0.744,11483.032
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.632,0.000,0.850
# Accuracy,0.789,0.000,0.835
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.675,0.469
# Accuracy,0.816,0.366
#
# -------------
# threshold:  0.5
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.515,0.791,0.730,17561.153
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.616,0.618,0.648,12807.619
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.682,0.000,0.864
# Accuracy,0.789,0.000,0.871
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.640,0.592
# Accuracy,0.663,0.570
#
# -------------
# threshold:  0.55
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.505,0.785,0.695,18183.159
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.684,0.686,0.630,13545.974
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.651,0.000,0.863
# Accuracy,0.711,0.000,0.885
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.663,0.706
# Accuracy,0.602,0.774
#
# -------------
# threshold:  0.6
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.514,0.801,0.693,19017.401
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.656,0.665,0.547,15710.355
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.667,0.000,0.876
# Accuracy,0.684,0.000,0.914
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.600,0.712
# Accuracy,0.490,0.849
#
# -------------
# threshold:  0.65
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.525,0.812,0.698,19644.495
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.634,0.654,0.489,17348.811
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.693,0.000,0.881
# Accuracy,0.684,0.000,0.928
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.548,0.720
# Accuracy,0.408,0.914
#
# -------------
# threshold:  0.7
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.522,0.812,0.687,19853.373
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.560,0.602,0.389,19853.149
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.685,0.000,0.881
# Accuracy,0.658,0.000,0.935
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.424,0.696
# Accuracy,0.286,0.935
#
# -------------
# threshold:  0.75
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.699,0.582,0.538,0.832,0.687,20689.948
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.696,0.680,0.526,0.592,0.338,21316.468
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.890,0.401,0.806
# AUPRC,0.797,0.063,0.884
# F-measure,0.716,0.000,0.897
# Accuracy,0.632,0.000,0.971
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.696,0.696
# AUPRC,0.754,0.606
# F-measure,0.350,0.702
# Accuracy,0.214,0.989
#
# -------------

# %% [markdown]
# ### 피쳐 다 쓴 모형 결과 확인부분 (Upgrading models2.ipynb)

# %%
model_folder = 'tmp_model4'
output_folder = '/home/ubuntu/hmd/notebooks/out2'

# %%
label_folder = test_folder
murmur_classes = ['Present', 'Unknown', 'Absent']
outcome_classes = ['Abnormal', 'Normal']

# Load and parse label and model output files.
label_files, output_files = find_challenge_files(label_folder, output_folder)
murmur_labels = load_murmurs(label_files, murmur_classes)
murmur_binary_outputs, murmur_scalar_outputs = load_classifier_outputs(output_files, murmur_classes)
outcome_labels = load_outcomes(label_files, outcome_classes)
outcome_binary_outputs, outcome_scalar_outputs = load_classifier_outputs(output_files, outcome_classes)


print(np.mean(murmur_scalar_outputs[:,0]))
print(np.mean(murmur_scalar_outputs[:,2]))
print(np.mean(outcome_scalar_outputs[:,0]))
print(np.mean(outcome_scalar_outputs[:,1]))
# Out:
# 0.35794719224607335
# 0.6245149852460734
# 0.3430279438225131
# 0.6569720580994763

# %%
## threshold 바꿔가면서 결과 출력

for th1 in [0.05, 0.1, 0.15,0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75] :
    murmur_binary_outputs[:,0] = murmur_scalar_outputs[:,0] > th1
    murmur_binary_outputs[:,2] = murmur_scalar_outputs[:,2] > 1 - th1
    outcome_binary_outputs[:,0] = outcome_scalar_outputs[:,0] > th1
    outcome_binary_outputs[:,1] = outcome_scalar_outputs[:,1] > 1 - th1
    # For each patient, set the 'Present' or 'Abnormal' class to positive if no class is positive or if multiple classes are positive.
    murmur_labels = enforce_positives(murmur_labels, murmur_classes, 'Present')
    murmur_binary_outputs = enforce_positives(murmur_binary_outputs, murmur_classes, 'Present')
    outcome_labels = enforce_positives(outcome_labels, outcome_classes, 'Abnormal')
    outcome_binary_outputs = enforce_positives(outcome_binary_outputs, outcome_classes, 'Abnormal')
    # Evaluate the murmur model by comparing the labels and model outputs.
    murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes = compute_auc(murmur_labels, murmur_scalar_outputs)
    murmur_f_measure, murmur_f_measure_classes = compute_f_measure(murmur_labels, murmur_binary_outputs)
    murmur_accuracy, murmur_accuracy_classes = compute_accuracy(murmur_labels, murmur_binary_outputs)
    murmur_weighted_accuracy = compute_weighted_accuracy(murmur_labels, murmur_binary_outputs, murmur_classes) # This is the murmur scoring metric.
    murmur_cost = compute_cost(outcome_labels, murmur_binary_outputs, outcome_classes, murmur_classes) # Use *outcomes* to score *murmurs* for the Challenge cost metric, but this is not the actual murmur scoring metric.
    murmur_scores = (murmur_classes, murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes, \
                 murmur_f_measure, murmur_f_measure_classes, murmur_accuracy, murmur_accuracy_classes, murmur_weighted_accuracy, murmur_cost)

    # Evaluate the outcome model by comparing the labels and model outputs.
    outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes = compute_auc(outcome_labels, outcome_scalar_outputs)
    outcome_f_measure, outcome_f_measure_classes = compute_f_measure(outcome_labels, outcome_binary_outputs)
    outcome_accuracy, outcome_accuracy_classes = compute_accuracy(outcome_labels, outcome_binary_outputs)
    outcome_weighted_accuracy = compute_weighted_accuracy(outcome_labels, outcome_binary_outputs, outcome_classes)
    outcome_cost = compute_cost(outcome_labels, outcome_binary_outputs, outcome_classes, outcome_classes) # This is the clinical outcomes scoring metric.
    outcome_scores = (outcome_classes, outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes, \
                  outcome_f_measure, outcome_f_measure_classes, outcome_accuracy, outcome_accuracy_classes, outcome_weighted_accuracy, outcome_cost)



    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
    murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
    outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
                + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
    print("threshold: ", th1)
    print(output_string)
    print("-------------")
# Out:
# threshold:  0.05
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.121,0.209,0.518,14916.196
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.334,0.503,0.823,15125.621
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.335,0.000,0.028
# Accuracy,1.000,0.000,0.014
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.669,0.000
# Accuracy,0.980,0.000
#
# -------------
# threshold:  0.1
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.137,0.225,0.526,14718.457
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.422,0.534,0.813,13436.288
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.341,0.000,0.069
# Accuracy,1.000,0.000,0.036
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.676,0.168
# Accuracy,0.949,0.097
#
# -------------
# threshold:  0.15
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.234,0.340,0.574,13124.084
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.503,0.555,0.758,12187.710
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.372,0.000,0.331
# Accuracy,0.974,0.000,0.201
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.664,0.341
# Accuracy,0.857,0.237
#
# -------------
# threshold:  0.2
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.312,0.455,0.612,11872.451
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.639,0.649,0.748,10950.558
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.409,0.000,0.528
# Accuracy,0.921,0.000,0.374
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.700,0.579
# Accuracy,0.796,0.495
#
# -------------
# threshold:  0.25
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.370,0.550,0.660,12297.663
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.675,0.675,0.695,11879.982
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.461,0.000,0.648
# Accuracy,0.921,0.000,0.504
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.690,0.659
# Accuracy,0.704,0.645
#
# -------------
# threshold:  0.3
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.414,0.634,0.671,14096.782
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.648,0.649,0.604,14003.185
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.504,0.000,0.739
# Accuracy,0.842,0.000,0.640
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.630,0.667
# Accuracy,0.582,0.720
#
# -------------
# threshold:  0.35
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.459,0.707,0.709,15360.057
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.660,0.665,0.575,14917.930
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.577,0.000,0.802
# Accuracy,0.842,0.000,0.741
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.619,0.701
# Accuracy,0.531,0.806
#
# -------------
# threshold:  0.4
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.467,0.728,0.687,16548.052
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.650,0.665,0.520,16521.880
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.580,0.000,0.821
# Accuracy,0.763,0.000,0.791
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.579,0.722
# Accuracy,0.449,0.892
#
# -------------
# threshold:  0.45
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.512,0.791,0.720,17559.619
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.632,0.654,0.482,17555.878
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.667,0.000,0.868
# Accuracy,0.763,0.000,0.878
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.542,0.723
# Accuracy,0.398,0.925
#
# -------------
# threshold:  0.5
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.519,0.801,0.714,18391.704
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.619,0.649,0.453,18388.678
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.683,0.000,0.874
# Accuracy,0.737,0.000,0.899
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.511,0.727
# Accuracy,0.357,0.957
#
# -------------
# threshold:  0.55
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.536,0.822,0.714,19016.222
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.602,0.639,0.429,19015.676
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.720,0.000,0.887
# Accuracy,0.711,0.000,0.935
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.481,0.723
# Accuracy,0.327,0.968
#
# -------------
# threshold:  0.6
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.550,0.838,0.722,19643.725
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.573,0.618,0.395,19852.593
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.750,0.000,0.899
# Accuracy,0.711,0.000,0.957
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.434,0.711
# Accuracy,0.286,0.968
#
# -------------
# threshold:  0.65
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.543,0.832,0.709,19643.525
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.542,0.597,0.360,20689.573
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.732,0.000,0.896
# Accuracy,0.684,0.000,0.957
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.384,0.700
# Accuracy,0.245,0.968
#
# -------------
# threshold:  0.7
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.536,0.827,0.695,19852.766
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.522,0.586,0.336,21316.814
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.714,0.000,0.893
# Accuracy,0.658,0.000,0.957
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.347,0.697
# Accuracy,0.214,0.978
#
# -------------
# threshold:  0.75
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.774,0.601,0.535,0.832,0.677,20689.573
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.720,0.705,0.501,0.576,0.312,21943.414
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.876,0.638,0.809
# AUPRC,0.794,0.116,0.892
# F-measure,0.708,0.000,0.898
# Accuracy,0.605,0.000,0.978
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.720,0.720
# AUPRC,0.774,0.637
# F-measure,0.308,0.694
# Accuracy,0.184,0.989
#
# -------------

# %% [markdown]
# Weighted accuracy 와 Cost가 동시에 최적화 되지 않음으로 선택과 집중을 해야 할듯..
