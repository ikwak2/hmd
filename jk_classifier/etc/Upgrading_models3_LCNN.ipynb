# %% [markdown]
# ## LCNN

# %%
import os
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats
import librosa
import librosa.display
import math
import sys
#sys.path.insert(0,'/home/ikwak2/hmd/notebooks')
#sys.path.insert(0,'/home/ikwak2/hmd/iy_classifier')
sys.path.insert(0,'utils')
from helper_code import *
from get_feature import *
from models import *
from Generator0 import *

# %%
root_dir = 'physionet.org/files/circor-heart-sound/1.0.3'
training_data_file = root_dir + '/' + 'training_data.csv'
training_data_dir = root_dir + '/' + 'training_data'
model_dir = root_dir + '/' + 'model'

# %%
import tensorflow as tf

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
print(gpu_info)
# Out:
# Mon Jul 11 13:05:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:05.0 Off |                  Off |
# | N/A   37C    P0    39W / 300W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:00:06.0 Off |                  Off |
# | N/A   34C    P0    37W / 300W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
    except RuntimeError as e:
        print(e)

# %%
data_folder =  'physionet.org/files/circor-heart-sound/1.0.3/training_data'
train_folder =  '/home/ubuntu/data/hmd/murmur/train'
test_folder = '/home/ubuntu/data/hmd/murmur/test'

# %%
model_folder = 'lcnn1'

# %% [markdown]
# ## Modeling

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint

# %%
def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start
    elif e > end:
        return lr_end

    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))

    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

# %% [markdown]
# ### get feature 함수확장: 음성피쳐 옵션들과, 추가 음성들 고려한 피쳐추출

# %%
patient_files_trn = find_patient_files(train_folder)
patient_files_test = find_patient_files(test_folder)

# %%
params_feature = {'samp_sec': 20,
                  #### melspec, stft 피쳐 옵션들  
                  'pre_emphasis': 0,
                  'hop_length': 256,
                  'win_length':512,
                  'n_mels': 100,
                  #### cqt 피쳐 옵션들  
                  'filter_scale': 1,
                  'n_bins': 80,
                  'fmin': 10
}

# %%
features_trn, mm_lbs_trn, out_lbs_trn, mel_input_shape, cqt_input_shape, stft_input_shape = get_features_3lb_all(train_folder, patient_files_trn, **params_feature)
features_test, mm_lbs_test, out_lbs_test, _, _, _ = get_features_3lb_all(test_folder, patient_files_test, **params_feature)
# Out:
# melspec:  100 313
# cqt:  80 157
# stft:  257 313
# utils/get_feature.py:599: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   features[k1] = np.array(features[k1])
# melspec:  100 313
# cqt:  80 157
# stft:  257 313

# %% [markdown]
# ### LCNN

# %% [markdown]
# LCNN 초기모형 작성

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Convolution2D, GlobalAveragePooling2D, MaxPool2D

def get_LCNN_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, use_stft = True):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    mel1 = keras.Input(shape=(mel_input_shape), name = 'mel')
    cqt1 = keras.Input(shape=(cqt_input_shape), name = 'cqt')
    stft1 = keras.Input(shape=(stft_input_shape), name = 'stft')
        
        
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)

    ## mel embedding
    conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
    conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
    mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
    max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

    conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
    batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

    conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

    max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
    batch10 = BatchNormalization(axis=3, scale=False)(max9)

    conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
    batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

    conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

    max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

    conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
    batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

    conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
    batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

    conv23_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    conv23_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
    batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

    conv26_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    conv26_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

    max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
    mel2 = layers.GlobalAveragePooling2D()(max28)

    ## cqt embedding
    conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
    conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
    mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
    max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

    conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
    batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

    conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

    max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
    batch10 = BatchNormalization(axis=3, scale=False)(max9)

    conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
    batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

    conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

    max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

    conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
    batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

    conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
    batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

    conv23_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    conv23_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
    batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

    conv26_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    conv26_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

    max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
    cqt2 = layers.GlobalAveragePooling2D()(max28)

    ## stft embedding
    conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
    conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
    mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
    max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

    conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
    batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

    conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

    max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
    batch10 = BatchNormalization(axis=3, scale=False)(max9)

    conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
    batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

    conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

    max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

    conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
    batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

    conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
    batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

    conv23_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    conv23_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
    batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

    conv26_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    conv26_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

    max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
    stft2 = layers.GlobalAveragePooling2D()(max28)
    
#    concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg])
#    d1 = layers.Dense(2, activation = 'relu')(concat1)
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2
#    concat2 = layers.Dense(10, activation = 'relu')(concat2)
    res1 = layers.Dense(3, activation = "softmax")(concat2)
    res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,mel1,cqt1,stft1] , outputs = res1 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)

def get_LCNN_2(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = True, use_stft = True):
        # Create a towy model.
    age = keras.Input(shape=(6,), name = 'age_cat')
    sex = keras.Input(shape=(2,), name = 'sex_cat')
    hw = keras.Input(shape=(2,), name = 'height_weight')
    preg = keras.Input(shape=(1,), name = 'is_preg')
    loc = keras.Input(shape=(5,), name = 'loc')
    mel1 = keras.Input(shape=(mel_input_shape), name = 'mel')
    cqt1 = keras.Input(shape=(cqt_input_shape), name = 'cqt')
    stft1 = keras.Input(shape=(stft_input_shape), name = 'stft')
        
        
    ## age embeddig
    age1 = layers.Dense(2, activation = None)(age)

    ## sex embedding
    sex1 = layers.Dense(1, activation = None)(sex)

    ## hw embedding
    hw1 = layers.Dense(1, activation = None)(hw)

    ## loc embedding
    loc1 = layers.Dense(3, activation = None)(loc)

    ## mel embedding
    conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
    conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(mel1)
    mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
    max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

    conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
    batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

    conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

    max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
    batch10 = BatchNormalization(axis=3, scale=False)(max9)

    conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
    batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

    conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

    max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

    conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
    batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

    conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
    batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

    conv23_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    conv23_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
    batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

    conv26_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    conv26_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

    max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
    mel2 = layers.GlobalAveragePooling2D()(max28)

    ## cqt embedding
    conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
    conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(cqt1)
    mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
    max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

    conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
    batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

    conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

    max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
    batch10 = BatchNormalization(axis=3, scale=False)(max9)

    conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
    batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

    conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

    max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

    conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
    batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

    conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
    batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

    conv23_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    conv23_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
    batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

    conv26_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    conv26_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

    max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
    cqt2 = layers.GlobalAveragePooling2D()(max28)

    ## stft embedding
    conv1_1 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
    conv1_2 = Conv2D(filters = 32, kernel_size =5, strides=(1, 1), padding='same', activation=None)(stft1)
    mfm2 = tensorflow.keras.layers.maximum([conv1_1, conv1_2])
    max3 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm2)

    conv4_1 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    conv4_2 = Conv2D(filters = 32, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max3)
    mfm5 = tensorflow.keras.layers.maximum([conv4_1, conv4_2])
    batch6 = BatchNormalization(axis=3, scale=False)(mfm5)

    conv7_1 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    conv7_2 = Conv2D(filters = 48, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch6)
    mfm8 = tensorflow.keras.layers.maximum([conv7_1, conv7_2])

    max9 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm8)
    batch10 = BatchNormalization(axis=3, scale=False)(max9)

    conv11_1 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    conv11_2 = Conv2D(filters = 48, kernel_size =1, strides=(1, 1), padding='same', activation=None)(batch10)
    mfm12 = tensorflow.keras.layers.maximum([conv11_1, conv11_2])
    batch13 = BatchNormalization(axis=3, scale=False)(mfm12)

    conv14_1 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    conv14_2 = Conv2D(filters = 64, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch13)
    mfm15 = tensorflow.keras.layers.maximum([conv14_1, conv14_2])

    max16 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(mfm15)

    conv17_1 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    conv17_2 = Conv2D(filters = 64, kernel_size =1, strides=(1, 1), padding='same', activation=None)(max16)
    mfm18 = tensorflow.keras.layers.maximum([conv17_1, conv17_2])
    batch19 = BatchNormalization(axis=3, scale=False)(mfm18)

    conv20_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    conv20_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch19)
    mfm21 = tensorflow.keras.layers.maximum([conv20_1, conv20_2])
    batch22 = BatchNormalization(axis=3, scale=False)(mfm21)

    conv23_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    conv23_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch22)
    mfm24 = tensorflow.keras.layers.maximum([conv23_1, conv23_2])
    batch25 = BatchNormalization(axis=3, scale=False)(mfm24)

    conv26_1 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    conv26_2 = Conv2D(filters = 32, kernel_size =3, strides=(1, 1), padding='same', activation=None)(batch25)
    mfm27 = tensorflow.keras.layers.maximum([conv26_1, conv26_2])

    max28 = MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(mfm27)
    stft2 = layers.GlobalAveragePooling2D()(max28)
    
#    concat1 = layers.Concatenate()([age1, sex1, hw1, loc1, preg])
#    d1 = layers.Dense(2, activation = 'relu')(concat1)
    
    if use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2, stft2])
    if not use_mel and use_cqt and use_stft :
        concat2 = layers.Concatenate()([cqt2, stft2])
    if use_mel and not use_cqt and use_stft :
        concat2 = layers.Concatenate()([mel2, stft2])
    if use_mel and use_cqt and not use_stft :
        concat2 = layers.Concatenate()([mel2, cqt2])
    if not use_mel and not use_cqt and use_stft :  ## stft 만
        concat2 = stft2
    if use_mel and not use_cqt and not use_stft :  ### mel만
        concat2 = mel2
    if not use_mel and use_cqt and not use_stft :  ### cqt만
        concat2 = cqt2
#    concat2 = layers.Dense(10, activation = 'relu')(concat2)
    res1 = layers.Dense(3, activation = "softmax")(concat2)
    res2 = layers.Dense(2, activation = "softmax")(concat2)

    model = keras.Model(inputs = [age,sex,hw,preg,loc,mel1,cqt1,stft1] , outputs = res2 )
    
    model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy','AUC'])
    return(model)

# %%
#model1 = get_toy5_1(mel_input_shape, cqt_input_shape, stft_input_shape)
#model2 = get_toy5_2(mel_input_shape, cqt_input_shape, stft_input_shape)

# %%
model1 = get_LCNN_1(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = False, use_stft = False)
model2 = get_LCNN_2(mel_input_shape, cqt_input_shape, stft_input_shape, use_mel = True, use_cqt = False, use_stft = False)

# %%
model1.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# mel (InputLayer)                [(None, 100, 313, 1) 0
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 100, 313, 32) 832         mel[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 100, 313, 32) 832         mel[0][0]
# __________________________________________________________________________________________________
# maximum_109 (Maximum)           (None, 100, 313, 32) 0           conv2d_254[0][0]
#                                                                  conv2d_255[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_84 (MaxPooling2D) (None, 50, 157, 32)  0           maximum_109[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 50, 157, 32)  1056        max_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 50, 157, 32)  1056        max_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# maximum_110 (Maximum)           (None, 50, 157, 32)  0           conv2d_256[0][0]
#                                                                  conv2d_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 50, 157, 32)  96          maximum_110[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 50, 157, 48)  13872       batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 50, 157, 48)  13872       batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# maximum_111 (Maximum)           (None, 50, 157, 48)  0           conv2d_258[0][0]
#                                                                  conv2d_259[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_85 (MaxPooling2D) (None, 25, 79, 48)   0           maximum_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 25, 79, 48)   144         max_pooling2d_85[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 25, 79, 48)   2352        batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 25, 79, 48)   2352        batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# maximum_112 (Maximum)           (None, 25, 79, 48)   0           conv2d_260[0][0]
#                                                                  conv2d_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 25, 79, 48)   144         maximum_112[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 25, 79, 64)   27712       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 25, 79, 64)   27712       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# maximum_113 (Maximum)           (None, 25, 79, 64)   0           conv2d_262[0][0]
#                                                                  conv2d_263[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_86 (MaxPooling2D) (None, 13, 40, 64)   0           maximum_113[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 13, 40, 64)   4160        max_pooling2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 13, 40, 64)   4160        max_pooling2d_86[0][0]
# __________________________________________________________________________________________________
# maximum_114 (Maximum)           (None, 13, 40, 64)   0           conv2d_264[0][0]
#                                                                  conv2d_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 13, 40, 64)   192         maximum_114[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 13, 40, 32)   18464       batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 13, 40, 32)   18464       batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# maximum_115 (Maximum)           (None, 13, 40, 32)   0           conv2d_266[0][0]
#                                                                  conv2d_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 13, 40, 32)   96          maximum_115[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 13, 40, 32)   9248        batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 13, 40, 32)   9248        batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# maximum_116 (Maximum)           (None, 13, 40, 32)   0           conv2d_268[0][0]
#                                                                  conv2d_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 13, 40, 32)   96          maximum_116[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 13, 40, 32)   9248        batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 13, 40, 32)   9248        batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# maximum_117 (Maximum)           (None, 13, 40, 32)   0           conv2d_270[0][0]
#                                                                  conv2d_271[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_87 (MaxPooling2D) (None, 6, 20, 32)    0           maximum_117[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_21 (Gl (None, 32)           0           max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# age_cat (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# sex_cat (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# height_weight (InputLayer)      [(None, 2)]          0
# __________________________________________________________________________________________________
# is_preg (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# loc (InputLayer)                [(None, 5)]          0
# __________________________________________________________________________________________________
# cqt (InputLayer)                [(None, 80, 157, 1)] 0
# __________________________________________________________________________________________________
# stft (InputLayer)               [(None, 257, 313, 1) 0
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 3)            99          global_average_pooling2d_21[0][0]
# ==================================================================================================
# Total params: 174,755
# Trainable params: 174,243
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
n_epoch = 100
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
batch_size = 64
params = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': True,
          'beta_param': 0.7,
          'mixup': True,
#          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
#          'highpass': [.5, [78,79,80,81,82,83,84,85]]
          'ranfilter2' : [3, [18,19,20,21,22,23]]
#           'dropblock' : [30, 100]
          #'device' : device
}

params_no_shuffle = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': False,
          'beta_param': 0.7,
          'mixup': False
          #'device': device
}

TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
           features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                        mm_lbs_trn,  ## our Y
                        **params)()

#ValDGen_1 = Generator0([features_test[0]['age'],features_test[0]['sex'], features_test[0]['hw'], features_test[0]['preg'], features_test[0]['loc'], 
#           features_test[0]['mel1'],features_test[0]['cqt1'],features_test[0]['stft1']], 
#                        mm_lbs_test,  ## our Y
#                        **params_no_shuffle)()

    
model1.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                              features_test['preg'], features_test['loc'], features_test['mel1'], 
                              features_test['cqt1'], features_test['stft1']], 
                             mm_lbs_test), 
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(mm_lbs_trn)/64),
                             epochs = n_epoch)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 9s 190ms/step - loss: 0.6499 - accuracy: 0.7140 - auc: 0.8508 - val_loss: 1.7670 - val_accuracy: 0.7448 - val_auc: 0.8158
# Epoch 2/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5820 - accuracy: 0.7711 - auc: 0.8755 - val_loss: 2.4488 - val_accuracy: 0.2552 - val_auc: 0.3179
# Epoch 3/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.5776 - accuracy: 0.7714 - auc: 0.8720 - val_loss: 0.5485 - val_accuracy: 0.7623 - val_auc: 0.8866
# Epoch 4/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5713 - accuracy: 0.7789 - auc: 0.8800 - val_loss: 0.8037 - val_accuracy: 0.4073 - val_auc: 0.6645
# Epoch 5/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.5616 - accuracy: 0.7729 - auc: 0.8838 - val_loss: 0.5073 - val_accuracy: 0.7971 - val_auc: 0.8976
# Epoch 6/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5607 - accuracy: 0.7710 - auc: 0.8849 - val_loss: 0.5648 - val_accuracy: 0.8035 - val_auc: 0.8931
# Epoch 7/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5574 - accuracy: 0.7906 - auc: 0.8869 - val_loss: 0.6234 - val_accuracy: 0.7686 - val_auc: 0.8589
# Epoch 8/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5778 - accuracy: 0.7677 - auc: 0.8815 - val_loss: 0.5336 - val_accuracy: 0.7544 - val_auc: 0.8972
# Epoch 9/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.5768 - accuracy: 0.7706 - auc: 0.8801 - val_loss: 0.4941 - val_accuracy: 0.8225 - val_auc: 0.9052
# Epoch 10/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5404 - accuracy: 0.7865 - auc: 0.8911 - val_loss: 0.4966 - val_accuracy: 0.7987 - val_auc: 0.9089
# Epoch 11/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.5463 - accuracy: 0.7816 - auc: 0.8901 - val_loss: 0.4990 - val_accuracy: 0.8225 - val_auc: 0.9097
# Epoch 12/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5504 - accuracy: 0.7607 - auc: 0.8933 - val_loss: 0.5682 - val_accuracy: 0.8241 - val_auc: 0.9116
# Epoch 13/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5442 - accuracy: 0.7857 - auc: 0.8901 - val_loss: 0.5349 - val_accuracy: 0.8193 - val_auc: 0.8842
# Epoch 14/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.5364 - accuracy: 0.7902 - auc: 0.8889 - val_loss: 0.5151 - val_accuracy: 0.8003 - val_auc: 0.8902
# Epoch 15/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5570 - accuracy: 0.7698 - auc: 0.8894 - val_loss: 0.5338 - val_accuracy: 0.8241 - val_auc: 0.9128
# Epoch 16/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5337 - accuracy: 0.7816 - auc: 0.8993 - val_loss: 0.5277 - val_accuracy: 0.7797 - val_auc: 0.9053
# Epoch 17/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5219 - accuracy: 0.7978 - auc: 0.8868 - val_loss: 0.5121 - val_accuracy: 0.8051 - val_auc: 0.8996
# Epoch 18/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.5391 - accuracy: 0.7705 - auc: 0.8954 - val_loss: 0.5026 - val_accuracy: 0.7892 - val_auc: 0.9050
# Epoch 19/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5506 - accuracy: 0.7742 - auc: 0.8839 - val_loss: 0.5249 - val_accuracy: 0.7971 - val_auc: 0.8998
# Epoch 20/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5429 - accuracy: 0.7805 - auc: 0.8920 - val_loss: 0.5439 - val_accuracy: 0.8209 - val_auc: 0.9021
# Epoch 21/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.5587 - accuracy: 0.7728 - auc: 0.8863 - val_loss: 0.4260 - val_accuracy: 0.8431 - val_auc: 0.9151
# Epoch 22/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5653 - accuracy: 0.7689 - auc: 0.8862 - val_loss: 0.4601 - val_accuracy: 0.8415 - val_auc: 0.9147
# Epoch 23/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5415 - accuracy: 0.7766 - auc: 0.8920 - val_loss: 0.5553 - val_accuracy: 0.8304 - val_auc: 0.9024
# Epoch 24/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.5548 - accuracy: 0.7808 - auc: 0.8891 - val_loss: 0.4849 - val_accuracy: 0.8146 - val_auc: 0.9054
# Epoch 25/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5248 - accuracy: 0.7952 - auc: 0.9007 - val_loss: 0.5376 - val_accuracy: 0.8019 - val_auc: 0.9066
# Epoch 26/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5268 - accuracy: 0.7826 - auc: 0.9004 - val_loss: 0.4952 - val_accuracy: 0.7765 - val_auc: 0.9016
# Epoch 27/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.5288 - accuracy: 0.7815 - auc: 0.8969 - val_loss: 0.4386 - val_accuracy: 0.8447 - val_auc: 0.9191
# Epoch 28/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5522 - accuracy: 0.7583 - auc: 0.8961 - val_loss: 0.5301 - val_accuracy: 0.8051 - val_auc: 0.8980
# Epoch 29/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5251 - accuracy: 0.7847 - auc: 0.8989 - val_loss: 0.4948 - val_accuracy: 0.8384 - val_auc: 0.9185
# Epoch 30/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5343 - accuracy: 0.7799 - auc: 0.8963 - val_loss: 0.4654 - val_accuracy: 0.8225 - val_auc: 0.9143
# Epoch 31/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5120 - accuracy: 0.8045 - auc: 0.9006 - val_loss: 0.5033 - val_accuracy: 0.7924 - val_auc: 0.8997
# Epoch 32/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5632 - accuracy: 0.7651 - auc: 0.8989 - val_loss: 0.4315 - val_accuracy: 0.8542 - val_auc: 0.9231
# Epoch 33/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.5326 - accuracy: 0.7949 - auc: 0.8936 - val_loss: 0.4882 - val_accuracy: 0.7670 - val_auc: 0.9057
# Epoch 34/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5264 - accuracy: 0.7920 - auc: 0.9012 - val_loss: 0.4785 - val_accuracy: 0.8431 - val_auc: 0.9099
# Epoch 35/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5324 - accuracy: 0.7869 - auc: 0.8965 - val_loss: 0.4527 - val_accuracy: 0.8479 - val_auc: 0.9092
# Epoch 36/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.5376 - accuracy: 0.7917 - auc: 0.8947 - val_loss: 0.4965 - val_accuracy: 0.8526 - val_auc: 0.9187
# Epoch 37/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5212 - accuracy: 0.7972 - auc: 0.8975 - val_loss: 0.5358 - val_accuracy: 0.8209 - val_auc: 0.9097
# Epoch 38/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5230 - accuracy: 0.7686 - auc: 0.9005 - val_loss: 0.5633 - val_accuracy: 0.8336 - val_auc: 0.9097
# Epoch 39/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5291 - accuracy: 0.7724 - auc: 0.8975 - val_loss: 0.4325 - val_accuracy: 0.8510 - val_auc: 0.9169
# Epoch 40/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.5302 - accuracy: 0.7816 - auc: 0.9019 - val_loss: 0.4890 - val_accuracy: 0.8019 - val_auc: 0.9092
# Epoch 41/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.5027 - accuracy: 0.7977 - auc: 0.8993 - val_loss: 0.4841 - val_accuracy: 0.8146 - val_auc: 0.9170
# Epoch 42/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5244 - accuracy: 0.7946 - auc: 0.9035 - val_loss: 0.4612 - val_accuracy: 0.8082 - val_auc: 0.9154
# Epoch 43/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5230 - accuracy: 0.7869 - auc: 0.8997 - val_loss: 0.4178 - val_accuracy: 0.8463 - val_auc: 0.9189
# Epoch 44/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5339 - accuracy: 0.7668 - auc: 0.8976 - val_loss: 0.4956 - val_accuracy: 0.8035 - val_auc: 0.8991
# Epoch 45/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.5252 - accuracy: 0.7714 - auc: 0.9010 - val_loss: 0.4641 - val_accuracy: 0.8304 - val_auc: 0.9068
# Epoch 46/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5205 - accuracy: 0.7937 - auc: 0.9027 - val_loss: 0.4845 - val_accuracy: 0.7892 - val_auc: 0.9076
# Epoch 47/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.5342 - accuracy: 0.7768 - auc: 0.9026 - val_loss: 0.4328 - val_accuracy: 0.8510 - val_auc: 0.9214
# Epoch 48/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5107 - accuracy: 0.7887 - auc: 0.9039 - val_loss: 0.4745 - val_accuracy: 0.8685 - val_auc: 0.9252
# Epoch 49/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5264 - accuracy: 0.7918 - auc: 0.9006 - val_loss: 0.4504 - val_accuracy: 0.8336 - val_auc: 0.9155
# Epoch 50/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.5304 - accuracy: 0.7787 - auc: 0.9008 - val_loss: 0.4659 - val_accuracy: 0.8304 - val_auc: 0.9144
# Epoch 51/100
# 40/40 [==============================] - 6s 152ms/step - loss: 0.5108 - accuracy: 0.7902 - auc: 0.9036 - val_loss: 0.4802 - val_accuracy: 0.8447 - val_auc: 0.9185
# Epoch 52/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.5203 - accuracy: 0.7828 - auc: 0.9059 - val_loss: 0.4315 - val_accuracy: 0.8415 - val_auc: 0.9179
# Epoch 53/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5204 - accuracy: 0.7882 - auc: 0.9000 - val_loss: 0.4405 - val_accuracy: 0.8447 - val_auc: 0.9182
# Epoch 54/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.5121 - accuracy: 0.7937 - auc: 0.9021 - val_loss: 0.4257 - val_accuracy: 0.8415 - val_auc: 0.9217
# Epoch 55/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5067 - accuracy: 0.7869 - auc: 0.9113 - val_loss: 0.4639 - val_accuracy: 0.8114 - val_auc: 0.9157
# Epoch 56/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.5188 - accuracy: 0.7960 - auc: 0.9026 - val_loss: 0.4895 - val_accuracy: 0.8621 - val_auc: 0.9079
# Epoch 57/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5248 - accuracy: 0.7864 - auc: 0.9038 - val_loss: 0.4435 - val_accuracy: 0.8209 - val_auc: 0.9216
# Epoch 58/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5010 - accuracy: 0.7986 - auc: 0.9071 - val_loss: 0.4340 - val_accuracy: 0.8479 - val_auc: 0.9212
# Epoch 59/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5085 - accuracy: 0.7795 - auc: 0.9110 - val_loss: 0.4269 - val_accuracy: 0.8431 - val_auc: 0.9185
# Epoch 60/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5112 - accuracy: 0.7865 - auc: 0.9084 - val_loss: 0.4148 - val_accuracy: 0.8590 - val_auc: 0.9214
# Epoch 61/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.5103 - accuracy: 0.8001 - auc: 0.9098 - val_loss: 0.4098 - val_accuracy: 0.8574 - val_auc: 0.9244
# Epoch 62/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.4931 - accuracy: 0.8077 - auc: 0.9034 - val_loss: 0.4251 - val_accuracy: 0.8653 - val_auc: 0.9272
# Epoch 63/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.5034 - accuracy: 0.7983 - auc: 0.9027 - val_loss: 0.4151 - val_accuracy: 0.8621 - val_auc: 0.9265
# Epoch 64/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5015 - accuracy: 0.7965 - auc: 0.9054 - val_loss: 0.4359 - val_accuracy: 0.8510 - val_auc: 0.9229
# Epoch 65/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5263 - accuracy: 0.7731 - auc: 0.9126 - val_loss: 0.4261 - val_accuracy: 0.8479 - val_auc: 0.9212
# Epoch 66/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.4981 - accuracy: 0.8120 - auc: 0.9053 - val_loss: 0.4397 - val_accuracy: 0.8399 - val_auc: 0.9203
# Epoch 67/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.4917 - accuracy: 0.7991 - auc: 0.9129 - val_loss: 0.4456 - val_accuracy: 0.8288 - val_auc: 0.9200
# Epoch 68/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.4909 - accuracy: 0.8064 - auc: 0.9057 - val_loss: 0.4329 - val_accuracy: 0.8320 - val_auc: 0.9195
# Epoch 69/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5069 - accuracy: 0.7813 - auc: 0.9056 - val_loss: 0.4312 - val_accuracy: 0.8463 - val_auc: 0.9202
# Epoch 70/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5080 - accuracy: 0.7894 - auc: 0.9041 - val_loss: 0.4269 - val_accuracy: 0.8431 - val_auc: 0.9234
# Epoch 71/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.4868 - accuracy: 0.8112 - auc: 0.9077 - val_loss: 0.4343 - val_accuracy: 0.8399 - val_auc: 0.9203
# Epoch 72/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5069 - accuracy: 0.7831 - auc: 0.9120 - val_loss: 0.4421 - val_accuracy: 0.8526 - val_auc: 0.9166
# Epoch 73/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5139 - accuracy: 0.7801 - auc: 0.9015 - val_loss: 0.4468 - val_accuracy: 0.8463 - val_auc: 0.9157
# Epoch 74/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5253 - accuracy: 0.7936 - auc: 0.9070 - val_loss: 0.4405 - val_accuracy: 0.8494 - val_auc: 0.9174
# Epoch 75/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.5108 - accuracy: 0.7816 - auc: 0.9090 - val_loss: 0.4385 - val_accuracy: 0.8590 - val_auc: 0.9190
# Epoch 76/100
# 40/40 [==============================] - 6s 155ms/step - loss: 0.4983 - accuracy: 0.7986 - auc: 0.9108 - val_loss: 0.4465 - val_accuracy: 0.8479 - val_auc: 0.9176
# Epoch 77/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5025 - accuracy: 0.7995 - auc: 0.9121 - val_loss: 0.4436 - val_accuracy: 0.8384 - val_auc: 0.9186
# Epoch 78/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5048 - accuracy: 0.7829 - auc: 0.9099 - val_loss: 0.4565 - val_accuracy: 0.8257 - val_auc: 0.9155
# Epoch 79/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5021 - accuracy: 0.8035 - auc: 0.9083 - val_loss: 0.4463 - val_accuracy: 0.8431 - val_auc: 0.9174
# Epoch 80/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5008 - accuracy: 0.7907 - auc: 0.9123 - val_loss: 0.4351 - val_accuracy: 0.8526 - val_auc: 0.9187
# Epoch 81/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.5121 - accuracy: 0.8007 - auc: 0.9064 - val_loss: 0.4309 - val_accuracy: 0.8542 - val_auc: 0.9191
# Epoch 82/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.4958 - accuracy: 0.7963 - auc: 0.9114 - val_loss: 0.4307 - val_accuracy: 0.8510 - val_auc: 0.9191
# Epoch 83/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.5110 - accuracy: 0.8036 - auc: 0.9062 - val_loss: 0.4327 - val_accuracy: 0.8510 - val_auc: 0.9191
# Epoch 84/100
# 40/40 [==============================] - 6s 154ms/step - loss: 0.4890 - accuracy: 0.8010 - auc: 0.9090 - val_loss: 0.4378 - val_accuracy: 0.8447 - val_auc: 0.9182
# Epoch 85/100
# 40/40 [==============================] - 6s 157ms/step - loss: 0.4881 - accuracy: 0.8118 - auc: 0.9151 - val_loss: 0.4395 - val_accuracy: 0.8447 - val_auc: 0.9181
# Epoch 86/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.4953 - accuracy: 0.8029 - auc: 0.9080 - val_loss: 0.4376 - val_accuracy: 0.8479 - val_auc: 0.9175
# Epoch 87/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.5011 - accuracy: 0.7875 - auc: 0.9142 - val_loss: 0.4387 - val_accuracy: 0.8510 - val_auc: 0.9178
# Epoch 88/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.5219 - accuracy: 0.7862 - auc: 0.9038 - val_loss: 0.4364 - val_accuracy: 0.8479 - val_auc: 0.9179
# Epoch 89/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5159 - accuracy: 0.7853 - auc: 0.9097 - val_loss: 0.4345 - val_accuracy: 0.8494 - val_auc: 0.9188
# Epoch 90/100
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5003 - accuracy: 0.8015 - auc: 0.9075 - val_loss: 0.4370 - val_accuracy: 0.8494 - val_auc: 0.9184
# Epoch 91/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.5098 - accuracy: 0.7971 - auc: 0.9065 - val_loss: 0.4338 - val_accuracy: 0.8526 - val_auc: 0.9190
# Epoch 92/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.4889 - accuracy: 0.8050 - auc: 0.9160 - val_loss: 0.4324 - val_accuracy: 0.8526 - val_auc: 0.9190
# Epoch 93/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.5278 - accuracy: 0.7832 - auc: 0.9114 - val_loss: 0.4347 - val_accuracy: 0.8574 - val_auc: 0.9192
# Epoch 94/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5004 - accuracy: 0.7863 - auc: 0.9082 - val_loss: 0.4357 - val_accuracy: 0.8494 - val_auc: 0.9186
# Epoch 95/100
# 40/40 [==============================] - 6s 162ms/step - loss: 0.4985 - accuracy: 0.7801 - auc: 0.9091 - val_loss: 0.4369 - val_accuracy: 0.8542 - val_auc: 0.9189
# Epoch 96/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.5144 - accuracy: 0.7799 - auc: 0.9047 - val_loss: 0.4328 - val_accuracy: 0.8526 - val_auc: 0.9189
# Epoch 97/100
# 40/40 [==============================] - 6s 153ms/step - loss: 0.5114 - accuracy: 0.7980 - auc: 0.9090 - val_loss: 0.4324 - val_accuracy: 0.8526 - val_auc: 0.9193
# Epoch 98/100
# 40/40 [==============================] - 6s 156ms/step - loss: 0.5144 - accuracy: 0.7892 - auc: 0.9048 - val_loss: 0.4330 - val_accuracy: 0.8494 - val_auc: 0.9191
# Epoch 99/100
# 40/40 [==============================] - 6s 159ms/step - loss: 0.5026 - accuracy: 0.7872 - auc: 0.9162 - val_loss: 0.4332 - val_accuracy: 0.8479 - val_auc: 0.9192
# Epoch 100/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.5076 - accuracy: 0.7994 - auc: 0.9075 - val_loss: 0.4337 - val_accuracy: 0.8447 - val_auc: 0.9191

# %% [markdown]
# 트레이닝 accuracy 와 auc 가 validation accuracy, auc 와 거의 유사함

# %%
n_epoch = 100
lr = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=n_epoch))
batch_size = 64
params = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': True,
          'beta_param': 0.7,
          'mixup': True,
#          'lowpass': [.5, [11,12,13,14,15,16,17,18]]
          'highpass': [.5, [78,79,80,81,82,83,84,85]],
          'ranfilter2' : [3, [18,19,20,21,22,23]]
#           'dropblock' : [30, 100]
          #'device' : device
}

params_no_shuffle = {'batch_size': batch_size,
#          'input_shape': (100, 313, 1),
          'shuffle': False,
          'beta_param': 0.7,
          'mixup': False
          #'device': device
}

TrainDGen_1 = Generator0([features_trn['age'],features_trn['sex'], features_trn['hw'], features_trn['preg'], features_trn['loc'], 
           features_trn['mel1'],features_trn['cqt1'],features_trn['stft1']], 
                        out_lbs_trn,  ## our Y
                        **params)()

#ValDGen_1 = Generator0([features_test[0]['age'],features_test[0]['sex'], features_test[0]['hw'], features_test[0]['preg'], features_test[0]['loc'], 
#           features_test[0]['mel1'],features_test[0]['cqt1'],features_test[0]['stft1']], 
#                        features_test[2],  ## our Y
#                        **params_no_shuffle)()

    
model2.fit(TrainDGen_1,
          validation_data = ([features_test['age'],features_test['sex'], features_test['hw'], 
                              features_test['preg'], features_test['loc'], features_test['mel1'], 
                              features_test['cqt1'], features_test['stft1']], 
                             out_lbs_test), 
                             callbacks=[lr],
                              steps_per_epoch=np.ceil(len(out_lbs_trn)/64),
                             epochs = n_epoch)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 9s 200ms/step - loss: 0.7910 - accuracy: 0.5078 - auc: 0.5205 - val_loss: 3.2856 - val_accuracy: 0.5008 - val_auc: 0.5160
# Epoch 2/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6963 - accuracy: 0.5362 - auc: 0.5476 - val_loss: 0.9902 - val_accuracy: 0.4913 - val_auc: 0.4067
# Epoch 3/100
# 40/40 [==============================] - 7s 178ms/step - loss: 0.6933 - accuracy: 0.5365 - auc: 0.5710 - val_loss: 0.9764 - val_accuracy: 0.5008 - val_auc: 0.5820
# Epoch 4/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6985 - accuracy: 0.5218 - auc: 0.5604 - val_loss: 0.7153 - val_accuracy: 0.5357 - val_auc: 0.6106
# Epoch 5/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6918 - accuracy: 0.5348 - auc: 0.5666 - val_loss: 0.7647 - val_accuracy: 0.5135 - val_auc: 0.5265
# Epoch 6/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6853 - accuracy: 0.5581 - auc: 0.6102 - val_loss: 0.7951 - val_accuracy: 0.5151 - val_auc: 0.6053
# Epoch 7/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6985 - accuracy: 0.5366 - auc: 0.5684 - val_loss: 0.6659 - val_accuracy: 0.5848 - val_auc: 0.6316
# Epoch 8/100
# 40/40 [==============================] - 7s 178ms/step - loss: 0.6913 - accuracy: 0.5370 - auc: 0.5791 - val_loss: 0.6789 - val_accuracy: 0.5610 - val_auc: 0.5834
# Epoch 9/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6864 - accuracy: 0.5601 - auc: 0.6240 - val_loss: 0.6814 - val_accuracy: 0.5452 - val_auc: 0.5729
# Epoch 10/100
# 40/40 [==============================] - 7s 183ms/step - loss: 0.6872 - accuracy: 0.5372 - auc: 0.6023 - val_loss: 0.6774 - val_accuracy: 0.5325 - val_auc: 0.5899
# Epoch 11/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6765 - accuracy: 0.5858 - auc: 0.6424 - val_loss: 0.6564 - val_accuracy: 0.6466 - val_auc: 0.6876
# Epoch 12/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6830 - accuracy: 0.5617 - auc: 0.6131 - val_loss: 0.6499 - val_accuracy: 0.6529 - val_auc: 0.6804
# Epoch 13/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6857 - accuracy: 0.5733 - auc: 0.6098 - val_loss: 0.7166 - val_accuracy: 0.5024 - val_auc: 0.5081
# Epoch 14/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6950 - accuracy: 0.5461 - auc: 0.5757 - val_loss: 0.6508 - val_accuracy: 0.6403 - val_auc: 0.6691
# Epoch 15/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6825 - accuracy: 0.5777 - auc: 0.6309 - val_loss: 0.6335 - val_accuracy: 0.6672 - val_auc: 0.7218
# Epoch 16/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6838 - accuracy: 0.5676 - auc: 0.6044 - val_loss: 0.6570 - val_accuracy: 0.6387 - val_auc: 0.6818
# Epoch 17/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6897 - accuracy: 0.5379 - auc: 0.5791 - val_loss: 0.7457 - val_accuracy: 0.4976 - val_auc: 0.5061
# Epoch 18/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6851 - accuracy: 0.5553 - auc: 0.5911 - val_loss: 0.7236 - val_accuracy: 0.5008 - val_auc: 0.6004
# Epoch 19/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6784 - accuracy: 0.5614 - auc: 0.6299 - val_loss: 0.6582 - val_accuracy: 0.6149 - val_auc: 0.6508
# Epoch 20/100
# 40/40 [==============================] - 7s 177ms/step - loss: 0.6768 - accuracy: 0.5788 - auc: 0.6316 - val_loss: 0.6654 - val_accuracy: 0.6307 - val_auc: 0.6711
# Epoch 21/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6856 - accuracy: 0.5472 - auc: 0.6085 - val_loss: 0.6627 - val_accuracy: 0.5943 - val_auc: 0.6429
# Epoch 22/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.6758 - accuracy: 0.5976 - auc: 0.6295 - val_loss: 0.6613 - val_accuracy: 0.6086 - val_auc: 0.6436
# Epoch 23/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6780 - accuracy: 0.5696 - auc: 0.6184 - val_loss: 0.6348 - val_accuracy: 0.6624 - val_auc: 0.7250
# Epoch 24/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6838 - accuracy: 0.5528 - auc: 0.6183 - val_loss: 0.6217 - val_accuracy: 0.6593 - val_auc: 0.7322
# Epoch 25/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6809 - accuracy: 0.5686 - auc: 0.6188 - val_loss: 0.6502 - val_accuracy: 0.6133 - val_auc: 0.6683
# Epoch 26/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.6853 - accuracy: 0.5615 - auc: 0.6147 - val_loss: 0.6397 - val_accuracy: 0.6656 - val_auc: 0.7184
# Epoch 27/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6736 - accuracy: 0.6020 - auc: 0.6410 - val_loss: 0.6587 - val_accuracy: 0.6307 - val_auc: 0.6950
# Epoch 28/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6795 - accuracy: 0.5793 - auc: 0.6161 - val_loss: 0.7093 - val_accuracy: 0.5784 - val_auc: 0.6266
# Epoch 29/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6841 - accuracy: 0.5653 - auc: 0.6153 - val_loss: 0.6182 - val_accuracy: 0.6688 - val_auc: 0.7152
# Epoch 30/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.6842 - accuracy: 0.5650 - auc: 0.6218 - val_loss: 0.6468 - val_accuracy: 0.6323 - val_auc: 0.6752
# Epoch 31/100
# 40/40 [==============================] - 7s 178ms/step - loss: 0.6796 - accuracy: 0.5775 - auc: 0.6321 - val_loss: 0.6319 - val_accuracy: 0.6466 - val_auc: 0.7026
# Epoch 32/100
# 40/40 [==============================] - 7s 178ms/step - loss: 0.6745 - accuracy: 0.5814 - auc: 0.6292 - val_loss: 0.6234 - val_accuracy: 0.6593 - val_auc: 0.7180
# Epoch 33/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.6715 - accuracy: 0.6002 - auc: 0.6550 - val_loss: 0.6676 - val_accuracy: 0.5943 - val_auc: 0.6338
# Epoch 34/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6820 - accuracy: 0.5588 - auc: 0.6254 - val_loss: 0.7329 - val_accuracy: 0.5642 - val_auc: 0.6154
# Epoch 35/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6794 - accuracy: 0.5624 - auc: 0.6295 - val_loss: 0.6298 - val_accuracy: 0.6783 - val_auc: 0.7259
# Epoch 36/100
# 40/40 [==============================] - 7s 180ms/step - loss: 0.6721 - accuracy: 0.5904 - auc: 0.6529 - val_loss: 0.6600 - val_accuracy: 0.6133 - val_auc: 0.6430
# Epoch 37/100
# 40/40 [==============================] - 7s 178ms/step - loss: 0.6798 - accuracy: 0.5726 - auc: 0.6303 - val_loss: 0.6189 - val_accuracy: 0.6609 - val_auc: 0.7197
# Epoch 38/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.6771 - accuracy: 0.5703 - auc: 0.6473 - val_loss: 0.6297 - val_accuracy: 0.6513 - val_auc: 0.7081
# Epoch 39/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.6745 - accuracy: 0.5604 - auc: 0.6516 - val_loss: 0.6442 - val_accuracy: 0.6339 - val_auc: 0.6953
# Epoch 40/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6781 - accuracy: 0.5689 - auc: 0.6312 - val_loss: 0.6548 - val_accuracy: 0.5769 - val_auc: 0.6499
# Epoch 41/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.6684 - accuracy: 0.5897 - auc: 0.6535 - val_loss: 0.6441 - val_accuracy: 0.6767 - val_auc: 0.6979
# Epoch 42/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6760 - accuracy: 0.5749 - auc: 0.6427 - val_loss: 0.6672 - val_accuracy: 0.6244 - val_auc: 0.6323
# Epoch 43/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6781 - accuracy: 0.5631 - auc: 0.6328 - val_loss: 0.6396 - val_accuracy: 0.6529 - val_auc: 0.7197
# Epoch 44/100
# 40/40 [==============================] - 7s 178ms/step - loss: 0.6715 - accuracy: 0.5894 - auc: 0.6616 - val_loss: 0.6348 - val_accuracy: 0.5626 - val_auc: 0.6574
# Epoch 45/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6664 - accuracy: 0.5869 - auc: 0.6748 - val_loss: 0.6513 - val_accuracy: 0.6276 - val_auc: 0.6716
# Epoch 46/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.6725 - accuracy: 0.5790 - auc: 0.6536 - val_loss: 0.6328 - val_accuracy: 0.6593 - val_auc: 0.7001
# Epoch 47/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6676 - accuracy: 0.6164 - auc: 0.6607 - val_loss: 0.6334 - val_accuracy: 0.6434 - val_auc: 0.7019
# Epoch 48/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6683 - accuracy: 0.6041 - auc: 0.6584 - val_loss: 0.6260 - val_accuracy: 0.6656 - val_auc: 0.7299
# Epoch 49/100
# 40/40 [==============================] - 7s 166ms/step - loss: 0.6711 - accuracy: 0.5850 - auc: 0.6588 - val_loss: 0.6441 - val_accuracy: 0.6355 - val_auc: 0.6969
# Epoch 50/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6695 - accuracy: 0.5999 - auc: 0.6564 - val_loss: 0.6248 - val_accuracy: 0.6513 - val_auc: 0.7136
# Epoch 51/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.6643 - accuracy: 0.6089 - auc: 0.6674 - val_loss: 0.6291 - val_accuracy: 0.6735 - val_auc: 0.7150
# Epoch 52/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6685 - accuracy: 0.6004 - auc: 0.6705 - val_loss: 0.6484 - val_accuracy: 0.6513 - val_auc: 0.6889
# Epoch 53/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.6758 - accuracy: 0.5842 - auc: 0.6519 - val_loss: 0.6344 - val_accuracy: 0.6418 - val_auc: 0.6963
# Epoch 54/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6684 - accuracy: 0.6118 - auc: 0.6792 - val_loss: 0.6413 - val_accuracy: 0.6529 - val_auc: 0.6843
# Epoch 55/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.6648 - accuracy: 0.5950 - auc: 0.6709 - val_loss: 0.6409 - val_accuracy: 0.6482 - val_auc: 0.7022
# Epoch 56/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6709 - accuracy: 0.5903 - auc: 0.6744 - val_loss: 0.6531 - val_accuracy: 0.6418 - val_auc: 0.6623
# Epoch 57/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6706 - accuracy: 0.5960 - auc: 0.6571 - val_loss: 0.6405 - val_accuracy: 0.6593 - val_auc: 0.7009
# Epoch 58/100
# 40/40 [==============================] - 6s 161ms/step - loss: 0.6567 - accuracy: 0.6155 - auc: 0.6926 - val_loss: 0.6854 - val_accuracy: 0.6276 - val_auc: 0.6432
# Epoch 59/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6600 - accuracy: 0.5940 - auc: 0.6944 - val_loss: 0.6336 - val_accuracy: 0.6387 - val_auc: 0.7014
# Epoch 60/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6643 - accuracy: 0.5956 - auc: 0.6708 - val_loss: 0.6450 - val_accuracy: 0.6418 - val_auc: 0.6820
# Epoch 61/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6697 - accuracy: 0.5733 - auc: 0.6760 - val_loss: 0.6252 - val_accuracy: 0.6751 - val_auc: 0.7239
# Epoch 62/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6674 - accuracy: 0.6072 - auc: 0.6664 - val_loss: 0.6533 - val_accuracy: 0.6450 - val_auc: 0.6705
# Epoch 63/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.6685 - accuracy: 0.5968 - auc: 0.6713 - val_loss: 0.6337 - val_accuracy: 0.6418 - val_auc: 0.7021
# Epoch 64/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6593 - accuracy: 0.6090 - auc: 0.6948 - val_loss: 0.6446 - val_accuracy: 0.6371 - val_auc: 0.6766
# Epoch 65/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6697 - accuracy: 0.6035 - auc: 0.6762 - val_loss: 0.6309 - val_accuracy: 0.6529 - val_auc: 0.7037
# Epoch 66/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6630 - accuracy: 0.5957 - auc: 0.6908 - val_loss: 0.6328 - val_accuracy: 0.6640 - val_auc: 0.7075
# Epoch 67/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6648 - accuracy: 0.5982 - auc: 0.7031 - val_loss: 0.6296 - val_accuracy: 0.6466 - val_auc: 0.7059
# Epoch 68/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6631 - accuracy: 0.5991 - auc: 0.6968 - val_loss: 0.6345 - val_accuracy: 0.6561 - val_auc: 0.6985
# Epoch 69/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6556 - accuracy: 0.6209 - auc: 0.7144 - val_loss: 0.6374 - val_accuracy: 0.6577 - val_auc: 0.7065
# Epoch 70/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6578 - accuracy: 0.6146 - auc: 0.7066 - val_loss: 0.6399 - val_accuracy: 0.6529 - val_auc: 0.7001
# Epoch 71/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6609 - accuracy: 0.6135 - auc: 0.6849 - val_loss: 0.6440 - val_accuracy: 0.6355 - val_auc: 0.6815
# Epoch 72/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6558 - accuracy: 0.6165 - auc: 0.6923 - val_loss: 0.6337 - val_accuracy: 0.6545 - val_auc: 0.6974
# Epoch 73/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6654 - accuracy: 0.6050 - auc: 0.6801 - val_loss: 0.6505 - val_accuracy: 0.6371 - val_auc: 0.6790
# Epoch 74/100
# 40/40 [==============================] - 7s 179ms/step - loss: 0.6633 - accuracy: 0.6065 - auc: 0.7016 - val_loss: 0.6388 - val_accuracy: 0.6434 - val_auc: 0.6993
# Epoch 75/100
# 40/40 [==============================] - 7s 170ms/step - loss: 0.6626 - accuracy: 0.5915 - auc: 0.7041 - val_loss: 0.6368 - val_accuracy: 0.6498 - val_auc: 0.6997
# Epoch 76/100
# 40/40 [==============================] - 7s 177ms/step - loss: 0.6624 - accuracy: 0.6118 - auc: 0.7123 - val_loss: 0.6409 - val_accuracy: 0.6434 - val_auc: 0.6940
# Epoch 77/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6581 - accuracy: 0.6152 - auc: 0.7065 - val_loss: 0.6382 - val_accuracy: 0.6498 - val_auc: 0.6910
# Epoch 78/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6685 - accuracy: 0.5825 - auc: 0.6875 - val_loss: 0.6400 - val_accuracy: 0.6498 - val_auc: 0.6985
# Epoch 79/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6647 - accuracy: 0.6077 - auc: 0.6820 - val_loss: 0.6436 - val_accuracy: 0.6418 - val_auc: 0.6863
# Epoch 80/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6569 - accuracy: 0.6011 - auc: 0.7114 - val_loss: 0.6339 - val_accuracy: 0.6450 - val_auc: 0.7029
# Epoch 81/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6584 - accuracy: 0.5974 - auc: 0.7067 - val_loss: 0.6426 - val_accuracy: 0.6434 - val_auc: 0.6887
# Epoch 82/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6544 - accuracy: 0.6131 - auc: 0.7040 - val_loss: 0.6470 - val_accuracy: 0.6371 - val_auc: 0.6793
# Epoch 83/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6545 - accuracy: 0.6274 - auc: 0.7208 - val_loss: 0.6408 - val_accuracy: 0.6387 - val_auc: 0.6876
# Epoch 84/100
# 40/40 [==============================] - 7s 173ms/step - loss: 0.6589 - accuracy: 0.5897 - auc: 0.7131 - val_loss: 0.6440 - val_accuracy: 0.6387 - val_auc: 0.6810
# Epoch 85/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6596 - accuracy: 0.6176 - auc: 0.6982 - val_loss: 0.6424 - val_accuracy: 0.6403 - val_auc: 0.6844
# Epoch 86/100
# 40/40 [==============================] - 6s 164ms/step - loss: 0.6596 - accuracy: 0.6116 - auc: 0.7007 - val_loss: 0.6365 - val_accuracy: 0.6498 - val_auc: 0.6987
# Epoch 87/100
# 40/40 [==============================] - 6s 165ms/step - loss: 0.6625 - accuracy: 0.6049 - auc: 0.6959 - val_loss: 0.6333 - val_accuracy: 0.6513 - val_auc: 0.7029
# Epoch 88/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6549 - accuracy: 0.6215 - auc: 0.6966 - val_loss: 0.6320 - val_accuracy: 0.6577 - val_auc: 0.7062
# Epoch 89/100
# 40/40 [==============================] - 7s 176ms/step - loss: 0.6570 - accuracy: 0.6215 - auc: 0.6801 - val_loss: 0.6336 - val_accuracy: 0.6593 - val_auc: 0.7051
# Epoch 90/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6622 - accuracy: 0.6006 - auc: 0.6780 - val_loss: 0.6348 - val_accuracy: 0.6561 - val_auc: 0.7028
# Epoch 91/100
# 40/40 [==============================] - 7s 169ms/step - loss: 0.6657 - accuracy: 0.5935 - auc: 0.6874 - val_loss: 0.6372 - val_accuracy: 0.6561 - val_auc: 0.7015
# Epoch 92/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.6543 - accuracy: 0.6064 - auc: 0.7148 - val_loss: 0.6360 - val_accuracy: 0.6482 - val_auc: 0.7011
# Epoch 93/100
# 40/40 [==============================] - 6s 163ms/step - loss: 0.6541 - accuracy: 0.6187 - auc: 0.7140 - val_loss: 0.6387 - val_accuracy: 0.6482 - val_auc: 0.6944
# Epoch 94/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6615 - accuracy: 0.6026 - auc: 0.7003 - val_loss: 0.6380 - val_accuracy: 0.6529 - val_auc: 0.6974
# Epoch 95/100
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6590 - accuracy: 0.5993 - auc: 0.7028 - val_loss: 0.6396 - val_accuracy: 0.6418 - val_auc: 0.6933
# Epoch 96/100
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6633 - accuracy: 0.6127 - auc: 0.6951 - val_loss: 0.6403 - val_accuracy: 0.6466 - val_auc: 0.6953
# Epoch 97/100
# 40/40 [==============================] - 7s 168ms/step - loss: 0.6625 - accuracy: 0.5977 - auc: 0.6982 - val_loss: 0.6382 - val_accuracy: 0.6450 - val_auc: 0.6954
# Epoch 98/100
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6604 - accuracy: 0.6134 - auc: 0.7049 - val_loss: 0.6427 - val_accuracy: 0.6418 - val_auc: 0.6873
# Epoch 99/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6529 - accuracy: 0.6200 - auc: 0.6989 - val_loss: 0.6405 - val_accuracy: 0.6418 - val_auc: 0.6904
# Epoch 100/100
# 40/40 [==============================] - 7s 167ms/step - loss: 0.6581 - accuracy: 0.5998 - auc: 0.7201 - val_loss: 0.6373 - val_accuracy: 0.6450 - val_auc: 0.6991

# %% [markdown]
# ### 팀코드 수정해야 할 함수들..

# %%
params_feature
# Out:
# {'samp_sec': 20,
#  'pre_emphasis': 0,
#  'hop_length': 256,
#  'win_length': 512,
#  'n_mels': 100,
#  'filter_scale': 1,
#  'n_bins': 80,
#  'fmin': 10}

# %%
params_feature['mel_shape'] = mel_input_shape
params_feature['cqt_shape'] = cqt_input_shape
params_feature['stft_shape'] = stft_input_shape

# %%
import pickle as pk
def save_challenge_model(model_folder, model1, model2, m_name1, m_name2, param_feature) :
    os.makedirs(model_folder, exist_ok=True)
    info_fnm = os.path.join(model_folder, 'desc.pk')
    filename1 = os.path.join(model_folder, m_name1 + '_model1.hdf5')
    filename2 = os.path.join(model_folder, m_name2 + '_model2.hdf5')
    model1.save(filename1)
    model2.save(filename2)
    param_feature['model1'] = m_name1
    param_feature['model2'] = m_name2
    param_feature['model_fnm1'] = filename1
    param_feature['model_fnm2'] = filename2

    with open(info_fnm, 'wb') as f:
        pk.dump(param_feature, f, pk.HIGHEST_PROTOCOL)
    return 1

# %%
model_folder
# Out:
# 'lcnn1'

# %%
save_challenge_model(model_folder, model1, model2, m_name1 = 'lcnn1', m_name2 = 'lcnn2', param_feature = params_feature)
# Out:
# 1

# %%
def load_challenge_model(model_folder, verbose):
    info_fnm = os.path.join(model_folder, 'desc.pk')
    with open(info_fnm, 'rb') as f:
        info_m = pk.load(f)
#    if info_m['model'] == 'toy' :
#        model = get_toy(info_m['mel_shape'])
#    filename = os.path.join(model_folder, info_m['model'] + '_model.hdf5')
#    model.load_weights(filename)
    return info_m

# %%
params_feature
# Out:
# {'samp_sec': 20,
#  'pre_emphasis': 0,
#  'hop_length': 256,
#  'win_length': 512,
#  'n_mels': 100,
#  'filter_scale': 1,
#  'n_bins': 80,
#  'fmin': 10,
#  'mel_shape': (100, 313, 1),
#  'cqt_shape': (80, 157, 1),
#  'stft_shape': (257, 313, 1),
#  'model1': 'lcnn1',
#  'model2': 'lcnn2',
#  'model_fnm1': 'lcnn1/lcnn1_model1.hdf5',
#  'model_fnm2': 'lcnn1/lcnn2_model2.hdf5'}

# %%
def run_challenge_model(model, data, recordings, verbose):
    
    murmur_classes = ['Present', 'Unknown', 'Absent']
    outcome_classes = ['Abnormal', 'Normal']
    
    if model['model1'] == 'toy1' :
        model1 = get_toy5_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'] )
    if model['model2'] == 'toy2' :
        model2 = get_toy5_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'])
    if model['model1'] == 'lcnn1' :
        model1 = get_LCNN_1(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    if model['model2'] == 'lcnn2' :
        model2 = get_LCNN_2(model['mel_shape'],model['cqt_shape'],model['stft_shape'], use_mel = True, use_cqt = False, use_stft = False)
    model1.load_weights(model['model_fnm1'])
    model2.load_weights(model['model_fnm2'])
    
#    classes = model['classes']
    # Load features.
    features = get_feature_one(data, verbose = 0)

    samp_sec = model['samp_sec'] 
    pre_emphasis = model['pre_emphasis']
    hop_length = model['hop_length']
    win_length = model['win_length']
    n_mels = model['n_mels']
    filter_scale = model['filter_scale']
    n_bins = model['n_bins']
    fmin = model['fmin']
    
    features['mel1'] = []
    for i in range(len(recordings)) :
        mel1 = feature_extract_melspec(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                           win_length = win_length, n_mels = n_mels)[0]
        features['mel1'].append(mel1)
    M, N = features['mel1'][0].shape
    for i in range(len(features['mel1'])) :
        features['mel1'][i] = features['mel1'][i].reshape(M,N,1)   
    features['mel1'] = np.array(features['mel1'])

    features['cqt1'] = []
    for i in range(len(recordings)) :
        mel1 = feature_extract_cqt(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, filter_scale = filter_scale, 
                                        n_bins = n_bins, fmin = fmin)[0]
        features['cqt1'].append(mel1)
    M, N = features['cqt1'][0].shape
    for i in range(len(features['cqt1'])) :
        features['cqt1'][i] = features['cqt1'][i].reshape(M,N,1)   
    features['cqt1'] = np.array(features['cqt1'])

    features['stft1'] = []
    for i in range(len(recordings)) :
        mel1 = feature_extract_stft(recordings[i]/ 32768, samp_sec=samp_sec, pre_emphasis = pre_emphasis, hop_length=hop_length, 
                                       win_length = win_length)[0]
        features['stft1'].append(mel1)
    M, N = features['stft1'][0].shape
    for i in range(len(features['stft1'])) :
        features['stft1'][i] = features['stft1'][i].reshape(M,N,1)           
    features['stft1'] = np.array(features['stft1'])

    #    print(features)
    # Impute missing data.
    res1 = model1.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], features['mel1'], features['cqt1'], features['stft1']])
    res2 = model2.predict([features['age'], features['sex'], features['hw'], features['preg'], features['loc'], features['mel1'], features['cqt1'], features['stft1']])

    # Get classifier probabilities.
    idx1 = res1.argmax(axis=0)[0]
    murmur_probabilities = res1[idx1,]  ## mumur 확률 최대화 되는 애 뽑기
    outcome_probabilities = res2.mean(axis = 0) ##  outcome 은 그냥 평균으로 뽑기
#    idx = np.argmax(prob1)

    ## 이부분도 생각 필요.. rule 을 cost를 maximize 하는 기준으로 threshold 탐색 필요할지도..
    # Choose label with highest probability.
    murmur_labels = np.zeros(len(murmur_classes), dtype=np.int_)
    idx = np.argmax(murmur_probabilities)
    murmur_labels[idx] = 1
    outcome_labels = np.zeros(len(outcome_classes), dtype=np.int_)
    idx = np.argmax(outcome_probabilities)
    outcome_labels[idx] = 1
    
    # Concatenate classes, labels, and probabilities.
    classes = murmur_classes + outcome_classes
    labels = np.concatenate((murmur_labels, outcome_labels))
    probabilities = np.concatenate((murmur_probabilities, outcome_probabilities))
    
    return classes, labels, probabilities

# %% [markdown]
# ### 대회 평가용 run_model 함수 (수정 불필요)

# %%
# Run model.
def run_model(model_folder, data_folder, output_folder, allow_failures, verbose):
    # Load models.
    if verbose >= 1:
        print('Loading Challenge model...')

    model = load_challenge_model(model_folder, verbose) ### Teams: Implement this function!!!

    # Find the patient data files.
    patient_files = find_patient_files(data_folder)
    num_patient_files = len(patient_files)

    if num_patient_files==0:
        raise Exception('No data was provided.')

    # Create a folder for the Challenge outputs if it does not already exist.
    os.makedirs(output_folder, exist_ok=True)

    # Run the team's model on the Challenge data.
    if verbose >= 1:
        print('Running model on Challenge data...')

    # Iterate over the patient files.
    for i in range(num_patient_files):
        if verbose >= 2:
            print('    {}/{}...'.format(i+1, num_patient_files))

        patient_data = load_patient_data(patient_files[i])
        recordings = load_recordings(data_folder, patient_data)

        # Allow or disallow the model to fail on parts of the data; helpful for debugging.
        try:
            classes, labels, probabilities = run_challenge_model(model, patient_data, recordings, verbose) ### Teams: Implement this function!!!
        except:
            if allow_failures:
                if verbose >= 2:
                    print('... failed.')
                classes, labels, probabilities = list(), list(), list()
            else:
                raise

        # Save Challenge outputs.
        head, tail = os.path.split(patient_files[i])
        root, extension = os.path.splitext(tail)
        output_file = os.path.join(output_folder, root + '.csv')
        patient_id = get_patient_id(patient_data)
        save_challenge_outputs(output_file, patient_id, classes, labels, probabilities)

    if verbose >= 1:
        print('Done.')

# %%
## 우리 모형 저장된 폴더이름
model_folder
# Out:
# 'lcnn1'

# %%
## 테스트 데이터 폴더
test_folder
# Out:
# '/home/ubuntu/data/hmd/murmur/test'

# %%
## 테스트 데이터에 모형 돌려서 스코어 저장할 폴더
output_folder = '/home/ubuntu/hmd/notebooks/out_lcnn1'

# %%
run_model(model_folder, test_folder, output_folder, allow_failures = True, verbose = 1)
# Out:
# Loading Challenge model...
# Running model on Challenge data...
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc6a9290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc6ad8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1ee440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc23ef80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb15c1099e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0547cc320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0143b75f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc5df710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c2b1560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1eeef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c079290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb01435fe60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c44b3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb15c109b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c56e440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c72e0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc5757a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc629320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc136440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0143b77a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb15c1098c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb15c109a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1f33b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb155fd1830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb155ca4ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb054227f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1eeb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c2f9c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c57d0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c7b49e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc677320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc677d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc575a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c2f9d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0144f0d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb15c109dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c75b290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc68cb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc575440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb155ca4c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb1541e65f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c72ee60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c73f8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0542454d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1eed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc054dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc6297a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb054245950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc68cd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c44b9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc659b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1ee7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb15c109dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc1ee4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc629b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc60e320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafa87f0680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc60e200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc09a170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc5f3680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c079cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc629050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc60ea70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c2f97a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c536c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0540cd290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c2f9200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c75b830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c6105f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c47e3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc20c320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc3583b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c536d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafa87aab00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0144f7950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c72e200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c72e560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c536a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0144f7950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c75b320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb0545708c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c3525f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb03c2f97a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafe40a6440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fafdc20c9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Done.

# %%
# !cat /home/ubuntu/hmd/notebooks/out_lcnn1/49628.csv
# Out:
# #49628
# Present,Unknown,Absent,Abnormal,Normal
# 1,0,0,1,0
# 0.6172488,0.0019498507,0.38080138,0.6646719,0.3353281

# %%
from evaluate_model import *

# %%
murmur_scores, outcome_scores = evaluate_model(test_folder, output_folder)
classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
    + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string

if len(sys.argv) == 3:
    print(output_string)
elif len(sys.argv) == 4:
    with open(sys.argv[3], 'w') as f:
        f.write(output_string)
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.536,0.832,0.698,19852.949
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.657,0.670,0.528,16314.897
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.704,0.000,0.902
# Accuracy,0.658,0.000,0.964
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.588,0.725
# Accuracy,0.459,0.892

# %% [markdown]
# ### Threshold 변경해가며 결과 탐색

# %%
label_folder = test_folder
murmur_classes = ['Present', 'Unknown', 'Absent']
outcome_classes = ['Abnormal', 'Normal']

# Load and parse label and model output files.
label_files, output_files = find_challenge_files(label_folder, output_folder)
murmur_labels = load_murmurs(label_files, murmur_classes)
murmur_binary_outputs, murmur_scalar_outputs = load_classifier_outputs(output_files, murmur_classes)
outcome_labels = load_outcomes(label_files, outcome_classes)
outcome_binary_outputs, outcome_scalar_outputs = load_classifier_outputs(output_files, outcome_classes)


print(np.mean(murmur_scalar_outputs[:,0]))
print(np.mean(murmur_scalar_outputs[:,2]))
print(np.mean(outcome_scalar_outputs[:,0]))
print(np.mean(outcome_scalar_outputs[:,1]))
# Out:
# 0.2878257771989529
# 0.7005484710994765
# 0.45549928062827216
# 0.5445007222513089

# %%
## threshold 바꿔가면서 결과 출력

for th1 in [0.01, 0.05, 0.1, 0.15,0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8] :
    murmur_binary_outputs[:,0] = murmur_scalar_outputs[:,0] > th1
    murmur_binary_outputs[:,2] = murmur_scalar_outputs[:,2] > 1 - th1
    outcome_binary_outputs[:,0] = outcome_scalar_outputs[:,0] > th1
    outcome_binary_outputs[:,1] = outcome_scalar_outputs[:,1] > 1 - th1
    # For each patient, set the 'Present' or 'Abnormal' class to positive if no class is positive or if multiple classes are positive.
    murmur_labels = enforce_positives(murmur_labels, murmur_classes, 'Present')
    murmur_binary_outputs = enforce_positives(murmur_binary_outputs, murmur_classes, 'Present')
    outcome_labels = enforce_positives(outcome_labels, outcome_classes, 'Abnormal')
    outcome_binary_outputs = enforce_positives(outcome_binary_outputs, outcome_classes, 'Abnormal')
    # Evaluate the murmur model by comparing the labels and model outputs.
    murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes = compute_auc(murmur_labels, murmur_scalar_outputs)
    murmur_f_measure, murmur_f_measure_classes = compute_f_measure(murmur_labels, murmur_binary_outputs)
    murmur_accuracy, murmur_accuracy_classes = compute_accuracy(murmur_labels, murmur_binary_outputs)
    murmur_weighted_accuracy = compute_weighted_accuracy(murmur_labels, murmur_binary_outputs, murmur_classes) # This is the murmur scoring metric.
    murmur_cost = compute_cost(outcome_labels, murmur_binary_outputs, outcome_classes, murmur_classes) # Use *outcomes* to score *murmurs* for the Challenge cost metric, but this is not the actual murmur scoring metric.
    murmur_scores = (murmur_classes, murmur_auroc, murmur_auprc, murmur_auroc_classes, murmur_auprc_classes, \
                 murmur_f_measure, murmur_f_measure_classes, murmur_accuracy, murmur_accuracy_classes, murmur_weighted_accuracy, murmur_cost)

    # Evaluate the outcome model by comparing the labels and model outputs.
    outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes = compute_auc(outcome_labels, outcome_scalar_outputs)
    outcome_f_measure, outcome_f_measure_classes = compute_f_measure(outcome_labels, outcome_binary_outputs)
    outcome_accuracy, outcome_accuracy_classes = compute_accuracy(outcome_labels, outcome_binary_outputs)
    outcome_weighted_accuracy = compute_weighted_accuracy(outcome_labels, outcome_binary_outputs, outcome_classes)
    outcome_cost = compute_cost(outcome_labels, outcome_binary_outputs, outcome_classes, outcome_classes) # This is the clinical outcomes scoring metric.
    outcome_scores = (outcome_classes, outcome_auroc, outcome_auprc, outcome_auroc_classes, outcome_auprc_classes, \
                  outcome_f_measure, outcome_f_measure_classes, outcome_accuracy, outcome_accuracy_classes, outcome_weighted_accuracy, outcome_cost)



    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = murmur_scores
    murmur_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    murmur_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    classes, auroc, auprc, auroc_classes, auprc_classes, f_measure, f_measure_classes, accuracy, accuracy_classes, weighted_accuracy, cost = outcome_scores
    outcome_output_string = 'AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost\n{:.3f},{:.3f},{:.3f},{:.3f},{:.3f},{:.3f}\n'.format(auroc, auprc, f_measure, accuracy, weighted_accuracy, cost)
    outcome_class_output_string = 'Classes,{}\nAUROC,{}\nAUPRC,{}\nF-measure,{}\nAccuracy,{}\n'.format(
    ','.join(classes),
    ','.join('{:.3f}'.format(x) for x in auroc_classes),
    ','.join('{:.3f}'.format(x) for x in auprc_classes),
    ','.join('{:.3f}'.format(x) for x in f_measure_classes),
    ','.join('{:.3f}'.format(x) for x in accuracy_classes))

    output_string = '#Murmur scores\n' + murmur_output_string + '\n#Outcome scores\n' + outcome_output_string \
                + '\n#Murmur scores (per class)\n' + murmur_class_output_string + '\n#Outcome scores (per class)\n' + outcome_class_output_string
    print("threshold: ", th1)
    print(output_string)
    print("-------------")
# Out:
# threshold:  0.01
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.111,0.199,0.512,15140.890
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.332,0.000,0.000
# Accuracy,1.000,0.000,0.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.05
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.116,0.204,0.515,15131.464
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.333,0.000,0.014
# Accuracy,1.000,0.000,0.007
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.1
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.126,0.215,0.520,15123.321
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.336,0.000,0.042
# Accuracy,1.000,0.000,0.022
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.15
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.234,0.340,0.585,12758.150
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.339,0.513,0.840,15140.890
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.378,0.000,0.323
# Accuracy,1.000,0.000,0.194
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.678,0.000
# Accuracy,1.000,0.000
#
# -------------
# threshold:  0.2
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.350,0.513,0.663,13044.799
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.337,0.508,0.832,15131.464
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.454,0.000,0.595
# Accuracy,0.974,0.000,0.439
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.674,0.000
# Accuracy,0.990,0.000
#
# -------------
# threshold:  0.25
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.460,0.696,0.757,14917.201
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.349,0.513,0.834,14916.196
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.587,0.000,0.793
# Accuracy,0.974,0.000,0.691
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.676,0.021
# Accuracy,0.990,0.011
#
# -------------
# threshold:  0.3
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.506,0.770,0.774,15526.569
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.390,0.529,0.832,14101.680
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.667,0.000,0.852
# Accuracy,0.921,0.000,0.806
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.681,0.100
# Accuracy,0.980,0.054
#
# -------------
# threshold:  0.35
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.523,0.801,0.757,16524.322
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.514,0.581,0.815,11846.100
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.688,0.000,0.880
# Accuracy,0.842,0.000,0.871
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.695,0.333
# Accuracy,0.929,0.215
#
# -------------
# threshold:  0.4
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.559,0.848,0.771,18181.503
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.643,0.649,0.727,11265.182
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.765,0.000,0.913
# Accuracy,0.816,0.000,0.942
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.691,0.594
# Accuracy,0.765,0.527
#
# -------------
# threshold:  0.45
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.556,0.848,0.749,18807.526
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.617,0.618,0.573,14631.457
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.753,0.000,0.914
# Accuracy,0.763,0.000,0.957
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.597,0.637
# Accuracy,0.551,0.688
#
# -------------
# threshold:  0.5
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.536,0.832,0.698,19852.949
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.657,0.670,0.528,16314.897
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.704,0.000,0.902
# Accuracy,0.658,0.000,0.964
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.588,0.725
# Accuracy,0.459,0.892
#
# -------------
# threshold:  0.55
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.540,0.838,0.690,20480.524
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.628,0.654,0.468,17971.397
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.716,0.000,0.904
# Accuracy,0.632,0.000,0.978
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.529,0.727
# Accuracy,0.378,0.946
#
# -------------
# threshold:  0.6
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.504,0.817,0.615,21943.908
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.546,0.602,0.362,20689.358
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.621,0.000,0.890
# Accuracy,0.474,0.000,0.993
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.387,0.705
# Accuracy,0.245,0.978
#
# -------------
# threshold:  0.65
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.440,0.785,0.523,23403.075
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.478,0.565,0.288,22569.101
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.449,0.000,0.871
# Accuracy,0.289,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.265,0.691
# Accuracy,0.153,1.000
#
# -------------
# threshold:  0.7
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.316,0.738,0.402,25274.571
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.339,0.492,0.168,25482.058
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.100,0.000,0.848
# Accuracy,0.053,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.020,0.657
# Accuracy,0.010,1.000
#
# -------------
# threshold:  0.75
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.339,0.492,0.168,25482.058
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.020,0.657
# Accuracy,0.010,1.000
#
# -------------
# threshold:  0.8
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.748,0.639,0.281,0.728,0.375,25689.450
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.721,0.721,0.327,0.487,0.160,25689.450
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.937,0.436,0.873
# AUPRC,0.842,0.140,0.935
# F-measure,0.000,0.000,0.842
# Accuracy,0.000,0.000,1.000
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.721,0.721
# AUPRC,0.773,0.668
# F-measure,0.000,0.655
# Accuracy,0.000,1.000
#
# -------------
